# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import re
from textblob import TextBlob
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from gensim.parsing.preprocessing import remove_stopwords
import csv

# %%
data = '/content/drive/MyDrive/final_asan1_1.csv'
input_1=[]
output=[]

# %%
benefits = []
with open(data,'r') as file:
    reader = csv.reader(file)
    print(reader)
    for row in reader:
        benefits.append(row[3])
print(benefits)
# Out:
# <_csv.reader object at 0x7f021ad844d0>
# ['Benefits', 'This group of asanas is concerned with loosening up the joints\nof the body. It is excellent for those debilitated by rheumatism,\narthritis, high blood pressure, heart problems or other ail-\nments where vigorous physical exercise is not advised. It is\nparticularly useful for eliminating energy blockages in the\njoints of the physical body, and for improving coordination,\nself-awareness and self-confidence.', 'This group of asanas is concerned with loosening up the joints\nof the body. It is excellent for those debilitated by rheumatism,\n\narthritis, high blood pressure, heart problems or other ail-\nments where vigorous physical exercise is not advised. It is\n\nparticularly useful for eliminating energy blockages in the\njoints of the physical body, and for improving coordination,\nself-awareness and self-confidence.', 'This group of asanas is concerned with loosening up the joints\nof the body. It is excellent for those debilitated by rheumatism,\n\narthritis, high blood pressure, heart problems or other ail-\nments where vigorous physical exercise is not advised. It is\n\nparticularly useful for eliminating energy blockages in the\njoints of the physical body, and for improving coordination,\nself-awareness and self-confidence.', 'All the foot and calf asanas help in returning the\nstagnant lymph and venous blood. They thus relieve\ntiredness and cramp, and help prevent venous thrombosis,\nespecially in bedridden, post-operative patients.', 'This group of asanas is concerned with loosening up the joints\nof the body. It is excellent for those debilitated by rheumatism,\n\narthritis, high blood pressure, heart problems or other ail-\nments where vigorous physical exercise is not advised. It is\n\nparticularly useful for eliminating energy blockages in the\njoints of the physical body, and for improving coordination,\nself-awareness and self-confidence.', 'This group of asanas is concerned with loosening up the joints\nof the body. It is excellent for those debilitated by rheumatism,\n\narthritis, high blood pressure, heart problems or other ail-\nments where vigorous physical exercise is not advised. It is\n\nparticularly useful for eliminating energy blockages in the\njoints of the physical body, and for improving coordination,\nself-awareness and self-confidence.', 'Since the knee joint bears the whole weight of the\nbody and has no strong muscles for support, it is most\nvulnerable to injuries, sprains and osteoarthritis. All the\nknee asanas strengthen the quadriceps muscle and the\nligaments around the knee joint. These asanas rejuvenate\nthe joint by activating the healing energies.', 'This is an excellent preparatory practice for loos-\nening up the knee and hip joints for meditative poses.\n\nThose people who cannot sit con1fortably in cross-legged\npositions should practise ardha titali asana daily, both\nmorning and evening.', 'This group of asanas is concerned with loosening up the joints\nof the body. It is excellent for those debilitated by rheumatism,\n\narthritis, high blood pressure, heart problems or other ail-\nments where vigorous physical exercise is not advised. It is\n\nparticularly useful for eliminating energy blockages in the\njoints of the physical body, and for improving coordination,\nself-awareness and self-confidence.', 'Both stages prepare the legs for mastery of\npadmasana and other meditative asanas. The inner thigh\nmuscles hold a lot of tension which is relieved by these\nasanas. They also remove tiredness due to long hours of\nstanding and walking.', 'This group of asanas is concerned with loosening up the joints\nof the body. It is excellent for those debilitated by rheumatism,\n\narthritis, high blood pressure, heart problems or other ail-\nments where vigorous physical exercise is not advised. It is\n\nparticularly useful for eliminating energy blockages in the\njoints of the physical body, and for improving coordination,\nself-awareness and self-confidence.', 'This g ...

# %%
import re
new_data = []
for i in range (len(benefits)):
    line = benefits[i]
    line = line.lower()
    line = re.sub(r'[^A-Za-z\n]+', ' ', line)
    line = remove_stopwords(line)
    input_1.append(line)

# %%
input_1
# Out:
# ['benefits',
#  'group asanas concerned loosening joints body excellent debilitated rheumatism arthritis high blood pressure heart problems ail ments vigorous physical exercise advised particularly useful eliminating energy blockages joints physical body improving coordination self awareness self confidence',
#  'group asanas concerned loosening joints body excellent debilitated rheumatism arthritis high blood pressure heart problems ail ments vigorous physical exercise advised particularly useful eliminating energy blockages joints physical body improving coordination self awareness self confidence',
#  'group asanas concerned loosening joints body excellent debilitated rheumatism arthritis high blood pressure heart problems ail ments vigorous physical exercise advised particularly useful eliminating energy blockages joints physical body improving coordination self awareness self confidence',
#  'foot calf asanas help returning stagnant lymph venous blood relieve tiredness cramp help prevent venous thrombosis especially bedridden post operative patients',
#  'group asanas concerned loosening joints body excellent debilitated rheumatism arthritis high blood pressure heart problems ail ments vigorous physical exercise advised particularly useful eliminating energy blockages joints physical body improving coordination self awareness self confidence',
#  'group asanas concerned loosening joints body excellent debilitated rheumatism arthritis high blood pressure heart problems ail ments vigorous physical exercise advised particularly useful eliminating energy blockages joints physical body improving coordination self awareness self confidence',
#  'knee joint bears weight body strong muscles support vulnerable injuries sprains osteoarthritis knee asanas strengthen quadriceps muscle ligaments knee joint asanas rejuvenate joint activating healing energies',
#  'excellent preparatory practice loos ening knee hip joints meditative poses people sit fortably cross legged positions practise ardha titali asana daily morning evening',
#  'group asanas concerned loosening joints body excellent debilitated rheumatism arthritis high blood pressure heart problems ail ments vigorous physical exercise advised particularly useful eliminating energy blockages joints physical body improving coordination self awareness self confidence',
#  'stages prepare legs mastery padmasana meditative asanas inner thigh muscles hold lot tension relieved asanas remove tiredness long hours standing walking',
#  'group asanas concerned loosening joints body excellent debilitated rheumatism arthritis high blood pressure heart problems ail ments vigorous physical exercise advised particularly useful eliminating energy blockages joints physical body improving coordination self awareness self confidence',
#  'group asanas concerned loosening joints body excellent debilitated rheumatism arthritis high blood pressure heart problems ail ments vigorous physical exercise advised particularly useful eliminating energy blockages joints physical body improving coordination self awareness self confidence',
#  'hand wrist asanas beneficial related joints relieve tension caused prolonged writing typing',
#  'group asanas concerned loosening joints body excellent debilitated rheumatism arthritis high blood pressure heart problems ail ments vigorous physical exercise advised particularly useful eliminating energy blockages joints physical body improving coordination self awareness self confidence',
#  'group asanas concerned loosening joints body excellent debilitated rheumatism arthritis high blood pressure heart problems ail ments vigorous physical exercise advised particularly useful eliminating energy blockages joints physical body improving coordination self awareness self confidence',
#  'shoulder asanas relieve strain driving office work help relieve pressure cervical spondylitis frozen shoulder maintain shape shoulders chest',
#  'nerves connecting different organs limbs body pass neck muscles neck shoulders accumulate tension especially prolonged work desk asanas release tension heaviness stiffness head neck shoulder region',
#  'asana strengthens abdominal muscles massages organs strengthens digestive lower pelvic perineal muscles helps correct prolapse',
#  'good hip joints obesity toning abdominal spinal muscles',
#  'good hip knee joints strengthens abdominal lower muscles',
#  'supta pawanmuktasana strengthens lower muscles loosens spinal vertebrae massages abdomen digestive organs effective removing wind constipation massaging pelvic muscles reproductive organs useful impotence sterility menstrual problems',
#  'asana massages buttocks hips useful thing morning waking',
#  'asana gives excellent stretch abdominal muscles organs helps improve diges tion eliminate constipation twisting stretch spinal muscles relieves strain stiffness caused prolonged sitting distance feet buttocks determines placement spinal twist feet em buttocks adjustment lower area spine feet approach buttocks adjustment rises spine feet buttocks adjustment area cardiac plexus ther efore moving feet em time works vertebra bringing suppleness spinal column',
#  'tightness tiredness relieved especially lower pelvic abdominal organs toned massaging action',
#  'asana stimulates muscular digestive circu latory nervous hormonal systems tones organs removes lethargy especially useful fo r eliminating nervous tension bringing deep relaxation performed shavasana order attain deeper state relaxation practised waking immediately restores freshness useful fo r women preparing childbearing practised second trimester pregnancy',
#  'asana loosens shoulder joints stretches upper muscles firms breast develops muscles chest',
#  'asana removes stiffness increases flexibility spine',
#  'asana excellent toning nerves organs pelvis abdomen useful regulating menstrual cycle performed months pregnancy excellent exercise postnatal recovery',
#  'asana positive effect pelvis abdomen releases energy blockages areas especially useful gynaecological disorders post natal recovery removes constipation',
#  'asana loosens pelvic girdle tones pelvic muscles special effect usually inaccessible muscles shoulder blades shoulder joints upper muscles helps io release frustration lighten mood',
#  'asana profound effect nerves muscles thighs knees shoulders arms neck increases flexibility hips',
#  'like namaskarasana pose beneficial effect nerves muscles thighs knees shoulders arms neck pelvic organs muscles mas saged gives equal stretch spine arm leg muscles vertebrae joints pulled away pressure balanced simultaneously spinal nerves stretched toned useful relieving flatulence',
#  'asana prepares legs meditation asanas improves blood circulation legs helps remove constipation',
#  'pose useful abdominal ailments alternately compresses stretches organs muscles region relieves constipation',
#  'palming relaxes revitalizes eye muscles stimulates circulation aqueous humour liquid runs cornea lens eye aiding correction defective vision',
#  'people defective eyesight blink irregularly unnaturally related state habitual tension eyes exercise encourages blinking reflex becmne spontaneous inducing relaxation eye muscles',
#  'sideways viewing relaxes tension muscles strained constant reading close work prevents corrects squint',
#  'sideways viewing improves coordination medial lateral muscles eyeball',
#  'viewing balances upper lower eyeball muscles',
#  'rotational viewing improves coordinated acti vities eye muscles',
#  'exercise improves accommodating focusing power eye muscles',
#  'exercise improves accommodating focusing power eye muscles range movements eye muscles increased',
#  'asana relaxes psycho physiological ideally practised sleep asana practice particularly dynamic exercises surya namaskara practi tioner feels physically mentally tired develops body awareness body completely relaxed awareness mind increases developing pratyahara',
#  'recommended slipped disc stiff neck stooping figure',
#  'asana helpful spinal complaints es pecially cervical spondylitis stiff neck upper',
#  'asana effective people suffering slipped disc sciatica certain types lower pain remain asana extended periods time encourages vertebral column resume normal shape releases compression spinal nerves asthmatics people lung ailments practise simple asana regularly breath awareness allows air enter lungs',
#  'asana stimulates digestive peristalsis relieves sciatic pain relaxing nerves legs people practice fotward bending asanas recom tnended practise matsya kridasana counterpose backward bending asanas relaxes tension perineum later months pregnancy lying cause pressure major veins block circulation circumstances posture ideal relaxing sleeping practising yoga nidra bent knee head supported pillow comfort',
#  'sukhasana easiest comfortable meditation postures utilized ill effect persons unable sit difficult medita tion postures facilitates mental physical balance causing strain pain',
#  'benefits given padmasana reduced level',
#  'padmasana allows body held completely steady long periods time holds trunk head like pillar legs firm foundation body steadied mind calm steadi ness calmness step real meditation padmasana directs flow prana mooladhara chakra perineum sahasrara chakra head heightening experience meditation posture applies pressure lower spine relaxing effect nervous breath slow muscular tension decreased blood pressure reduced normally large blood flow legs redirected abdominal region activity stimulates digestive process',
#  'siddhasana directs energy lower psychic centres upward spine stimulating brain calming entire nervous position lower foot perineum presses mooladhara chakra stimulating moola bandha pressure applied pubic bone presses trigger point swadhisthana automatically activating vajroli sahajoli mudra psycho muscular locks redirect sexual nervous impulses spinal cord brain establishing control reproductive hormones necessary order maintain brahmacharya spiritual purposes prolonged periods siddhasana result noticeable tingling sensations mooladhara region minutes caused reduction blood supply area rebalancing pranic flow lower chakras posture redirects blood circulation lower spine abdomen toning lumbar region spine pelvis abdominal organs balancing reproductive blood pressure',
#  'siddha yoni asana directs energy lower psychic centres upward spine stimulating brain calming entire nervous position lower foot perineum presses mooladhara chakra stimulating moola bandha pressure applied pubic bone presses trigger point swadhisthana automatically activating vajroli sahajoli mudra psycho muscular locks redirect sexual nervous impulses spinal cord brain establishing control reproductive hormones necessary order maintain brahmacharya spiritual purposes prolonged periods siddhasana result noticeable tingling sensations mooladhara region minutes caused reduction blood supply area rebalancing pranic flow lower chakras posture redirects blood circulation lower spine abdomen toning lumbar region spine pelvis abdominal organs balancing reproductive blood pressure',
#  'swastikasana healthy position sit especially suffering varicose veins tired aching muscles fluid retention legs',
#  'asana easy comfortable sustain long periods time comparatively large area body contact floor useful alternative meditation asanas legs hips rotated outwards meditation postures knees brought centre affects pelvic structure stretches outer inner muscles thigh position massages tones pelvic reproductive organs',
#  'vajrasana alters flow blood nervous impulses pelvic region strengthens pelvic muscles preventative measure hernia helps relieve piles reduces blood flow genitals massages nerve fibres feed making useful dilated veins testicles hydrocele men alleviates menstrual disorders increases efficiency entire digestive relieving stomach ailments hyperacidity peptic ulcer',
#  'asana primarily awaken ajna chakra calms mind relaxes nervous gives benefits vajrasana',
#  'pressure armpits helps open nostrils facilitate practice pranayama breath flow right left nostrils influences activities sympathetic parasympathetic nervous systems respectively opening nostrils induces state autonomic balance',
#  'predominantly pose spiritual aspirants stimulating influence mooladhara chakra excellent meditation pose benefits basically vajrasana',
#  'posture definite extension spinal cord body absolutely fixed total physical stability',
#  'excellent asana throat nose ears eyes mouth especially performed facing healing rays early morning sun relieves frustration releases emotional tension tension removed chest diaphragm simhagarjanasana useful people stutter nervous introverted develops strong beautiful voice benefits shambhavi mudra',
#  'asana balances mind increases power concentration allows awareness unconscious realms induces physical mental relaxation quickly thinking process beco nes clear precise useful think nuch disturbed uncontrollable thoughts good kidneys liver reproductive abdominal organs',
#  'asana improves flexibility neck shoulders spine gently tones female reproductive giving relief menstrual cramps leucorrhea safely practised pregnancy forceful contraction abdomen avoided',
#  'asana exercises loosens bending alternately directions tones spinal nerves relaxes sciatic nerves relieving sciatica loosens legs hip joints tones female reproductive organs especially beneficial women childbirth given birth children stretches abdominal muscles promotes digestion stimulates blood circulation weight reduced hips thighs',
#  'asana stretches strengthens muscles separates individual vertebrae releasing pressure discs nerve connections emanating spinal cord squeezed discs giving rise forms backache posture helps relieve problem cases encourages discs resume correct position regulates functioning adrenal glands tones pelvic muscles sciatic nerves beneficial male female reproductive organs regular practice relieves constipation',
#  'shashank bhujangasana gives similar benefits bhujangasana shashankasana benefits postures come maintaining final position shashank bhujangasana acts mainly alternately flexing spine backward forward asana gently tones male female reproductive organs alleviates menstrual disorders excellent post natal asana strengthening tightening abdominal pelvic region tones improves functioning liver kidneys visceral organs stregthens muscles',
#  'preparatory practice sirshasana headstand pose allows brain gradually adapt extra pressure head body inverted gives benefits sirshasana lesser degree',
#  'asana tones abdominal organs gives good stretch lower strengthens hips legs ankles feet induces balance nervous',
#  'given ushtrasana reduced level',
#  'asana beneficial digestive reproductive systems stretches stomach intestines alleviating constipation backward bend loosens vertebrae stimulates spinal nerves relieving backache rounded drooping shoulders posture improved neck fully stretched toning organs region regulating thyroid gland helpful people suffering asthma',
#  'asana massages abdominal organs alleviating digestive ailments constipation tones spinal nerves n akes flexible realigns rounded shoulders nerves neck thyroid gland particularly influenced chest stretched expanded capacity filling lungs bringing oxygen beneficial suffering fi om asthma bronchitis lung ailments loosens legs preparation sitting meditation asanas redirects sexual energy brain spiritual purposes',
#  'asana rectifies round shoulders removes stiffness shoulders upper deep synchronized breaths improves breathing capacity asana influences heart improves blood circulation body especially brain receives extra supply oxygen',
#  'asana exercises shoulders uses short deep muscles neck shoulder blades muscles exercised hold significant postural subconscious tension responsible stiffness pain alternate tensing relaxing smoothes energy flow relaxes muscles asana helpful people bad posture cervical spondylitis writer s cramp shoulder ann stiffness',
#  'asana develops physical mental balance entire spine stretched loosened helping clear congestion spinal nerves points emerge spinal column helps increase height stretching muscles ligaments enabling growing bones grow longer tadasana stretches rectus abdomini muscles intestines useful months pregnancy abdominal muscles nerves toned',
#  'tadasana especially massages loosens exercises sides waist balances right left groups postural muscles',
#  'asana tones neck shoulders waist hips useful correcting stiffness postural problems relaxation twisting movement induces feeling lightness relieve physical mental tension time day',
#  'kati chakrasana asana strengthens muscles improves balance coordination',
#  'asana stretches spine tones muscles redistributes excess weight waistline',
#  'asana strengthens muscles middle pelvis uterus thighs knees ankles',
#  'muscles legs strengthened',
#  'asana works specifically shoulders directly chest rectifies tension poor posture',
#  'asana strengthens muscles upper spine shoulder blades develops chest neck especially good young growing bodies',
#  'series affects muscles sides trunk waist legs stimulates nervous alleviates nervous depression improves digestion strengthens pelvic area tones reproductive organs regular practice help reduce waistline fat',
#  'asana helps remove tiredness stimulating circulation toning spinal nerves stretches han strings muscles loosens hips massages visceral organs excellent prepranayama practice opens alveoli helps drainage stagnant mucus added benefits inverted asanas especially brain',
#  'asana strengthens hamstrings muscles makes supple tones spinal nerves improves blood circulation head face',
#  'pose establishes state concentration calmness preparation practice performed',
#  '',
#  '',
#  '',
#  'pose strengthens nerves muscles limbs helps increase height stretching muscles ligaments enabling growing bones grow longer circulation stimulated especially upper spine shoulder blades',
#  'pose strengthens leg arm muscles develops chest exercises region spine shoulder blades',
#  '',
#  'excellent asana massaging abdominal organs removing constipation indigestion stretches freeing spinal nerves emerge spaces vertebrae contributing good general health yogamudrasana awaken manipura chakra',
#  'asana stretches intestines abdominal organs useful abdominal ailments remove constipation drink glasses water perform asana relieves inflamed bleeding piles practice good asthma bronchitis encourages deep respiration recirculates stagnant blood alleviating backache regulates function thyroid gland stimulates thymus gland boosting immune pelvic region given good stretch pressure feet thighs greatly reduces blood circulation legs diverting pelvic organs youthfulness vitality increased',
#  'asana helps correct postural defects spine useful achieving productive meditation posture relaxation pose induces peace stability emotional balance',
#  'alleviates pain shoulders arms encourages normal growth children poorly developed chests spiritually process awakening kundalini',
#  'asana regulating effect adrenal glands calms excited mind helps emotional stability generally giving sense security experience uncontrollable anger practise pose regularly massages tones abdominal organs stimulates digestive increases appetite develops sense balance',
#  'asana tones abdominal organs lower abdominal muscles removes excess weight strength ens especially thigh muscles induces state relaxation equanimity',
#  'asana strengthens arms shoulders especially good stiff backs',
#  'bhujangasana increased influence arms intestines',
#  'basically benefits bhujangasana addition sarpasana helps correct posture particularly rounded shoulders profound strengthening effect muscles',
#  'ardha shalabhasana excellent asana pelvic organs release tension pelvic area',
#  'shalabhasana strengthens lower pelvic organs provides relief backache mild sciatica slipped disc long condition tones balances functioning liver stomach bowels abdominal organs stimulates appetite tightens muscles buttocks causes body vajroli mudra spontaneously',
#  'benefits dhanurasana creased levels posture useful lower pain slipped disc cervical spondylitis performed discomfort tones heart lungs beneficial respiratory disorders helps improve posture',
#  'entire alimentary canal reconditioned asana liver abdominal organs muscles massag ed pancreas adrenal glands toned balancing secretions kidneys massaged excess weight reduced abdominal area leads improved functioning digestive excretory reproductive organs helps remove gastrointestinal disorders dyspepsia chronic constipation sluggishness liver useful management diabetes menstrual disorders improves blood circulation generally spinal column realigned ligaments muscles netves activated removing stiffness helps correct hunching upper strengthens leg muscles especially thighs dhanurasana useful freeing netvous energy cetvical thoracic area generally improving respiration',
#  'asana utilized realign spine eliminating rounded shoulders relieving backache massages stretches colon abdominal organs improving digestion tones female reproductive organs useful women tendency miscarry management menstrual disorders prolapse asthma bronchial thyroid conditions',
#  'asana exercises strengthens chest diaphragm tones entire gives benefits inverted asanas risk effects excellent relieving tightness shoulder blades held time helps relieve constipation piles',
#  'asana similar benefits chakrasana generally strengthening shoulders thighs wrists tones lumbar region spine achilles tendons',
#  'gomukhasana excellent asana inducing relaxation practised minutes alleviate tiredness tension anxiety relieves ache sciatica rheumatism general stiffness shoulders neck improves posture increasing energy awareness generally opening chest area alleviates cramp legs makes leg muscles supple',
#  'asana stretches pelvic region insides thighs opens hip joints balances nervous massages abdominal organs gently compressing alternately thighs',
#  'asana stretches hamstring muscles increases flexibility hip joints tones massages entire abdominal pelvic region including liver pancreas spleen uro genital kidneys adrenal glands helps remove excess weight area stimulates circulation nerves muscles spine',
#  'benefits paschimottanasana reduced level dynamic practice speeds circulation metabolic processes addition renders body flexible stimulating physical pranic energy',
#  'providing essentially benefits paschimottanasana asana gives extended stretch inside legs muscles shoulder blades chest opened paschimottanasana effect asana distributed upper lower parts body',
#  'practice gives basically benefits paschimottanasana loosening legs preparation meditation asanas',
#  'benefits asana identical janu sirshasana paschimottanasana distinct characteristic foot bent leg applies intense massage abdominal organs leg bent turn helps stimulate intestinal peristalsis alleviate constipation asana prepares legs hips prolonged sitting meditation asanas',
#  'practice makes hip joints flexible helps proper development shaping pelvis young girls reduces excess weight hips thighs develops sense balance coordination making posture gait steady graceful',
#  'asana relaxes hamstring inner thigh abdominal muscles stretches muscles sides body rendering stronger flexible reduces weight hips thighs develops sense balance coordination making posture gait steady graceful',
#  'asana stretches hamstring thigh mus cles area shoulder blades provides lateral stretch body stimulates nervous appetite helps remove abdominal complaints reduces excess weight waist',
#  'asana stimulates pancreas relaxes hip joints stretches hamstring muscles massages spinal nerves revitalizes brain',
#  'asana renders hamstring muscles hip joints flexible tones adrenals reproductive',
#  'meru wakrasana stretches spine loosening vertebrae toning nerves alleviates backache neck pain lumbago mild forms sciatica good asana beginners preparing difficult spinal twists',
#  'asana stretches spine lower making muscles supple stimulating nerves',
#  'asana simultaneously stretches muscles abdomen contracting muscles tones nerves spine makes muscles supple relieves lumbago musrular spasms duces tendency adjoining vertebrae develop inflammatory problems calcium deposits massages abdominal organs alleviating digestive ailments regulates secretions adrenal gland liver pancreas beneficial kidneys',
#  'asana gives lateral stretch body stretches hamstrings shoulders gives beneficial compression abdominal muscles organs body simultaneously stretches prepares body long hours sitting meditation asanas',
#  '',
#  '',
#  'asana helps cases low blood pressure balances nervous strengthens neck muscles brings rich supply blood brain preliminary pose sirshasana accustoms brain increased influx blood crown supporting weight body',
#  'asana helps cases low blood pressure balances nervous strengthens neck muscles brings rich supply blood brain preliminary pose sirshasana accustoms brain increased influx blood crown supporting weight body neck thyroid gland breath spiritual vishuddhi chakra',
#  'sarvangasana free drainage blood legs impeded effective treatment piles varicose veins asana gives additional stretch massage pelvic region internal organs strengthens coordinates leg muscles improves sense balance',
#  'stretches pelvis regulates kidneys activates intestines removes excess weight good preparatory pose attempting halasana',
#  'movement diaphragm takes place practice halasana massages internal organs activates digestion relieving constipation dyspepsia revitalizes spleen suprarenal glands promotes production insulin pancreas improves liver kidney function strengthens abdominal muscles relieves spasms muscles',
#  'practice benefits halasana paschimottanasana strengthens abdomin al muscles activates intestinal peristalsis improving diges tion removing constipation facilitates break fats exercising liver gall bladder stretches pelvic region',
#  'strengthens abdomin al muscles activates intestinal peristalsis improving diges tion removing constipation facilitates break fats exercising liver gall bladder stretches pelvic region',
#  'strengthens abdomin al muscles activates intestinal peristalsis improving diges tion removing constipation facilitates break fats exercising liver gall bladder stretches pelvic region',
#  'asana powerful awakening sahasrara chakra considered greatest asanas sirshasana revitalizes entire body mind relieves anxiety psychological disturbances form root cause disorders asthma hay fever diabetes menopausal imbalance helps rectify forms nervous glandular disorder especially related reproductive asana reverses effect gravity body strain alleviated reversed flow blood legs visceral regions aids tissue regen eration weight abdominal organs diaphragm encourages deep exhalation larger amounts carbon dioxide removed lungs',
#  'asana powerful awakening sahasrara chakra considered greatest asanas sirshasana revitalizes entire body mind relieves anxiety psychological disturbances form root cause disorders asthma hay fever diabetes menopausal imbalance helps rectify forms nervous glandular disorder especially related reproductive asana reverses effect gravity body strain alleviated reversed flow blood legs visceral regions aids tissue regen eration weight abdominal organs diaphragm encourages deep exhalation larger amounts carbon dioxide removed lungs',
#  'asana powerful awakening sahasrara chakra considered greatest asanas sirshasana revitalizes entire body mind relieves anxiety psychological disturbances form root cause disorders asthma hay fever diabetes menopausal imbalance helps rectify forms nervous glandular disorder especially related reproductive asana reverses effect gravity body strain alleviated reversed flow blood legs visceral regions aids tissue regen eration weight abdominal organs diaphragm encourages deep exhalation larger amounts carbon dioxide removed lungs',
#  'sirshasana free drainage blood legs impeded asana induces expansion chest stretches massages pelvic region benefiting internal organs strengthens coordinates leg muscles improves sense balance',
#  'asana powerful awakening sahasrara chakra considered greatest asanas sirshasana revitalizes entire body mind relieves anxiety psychological disturbances form root cause disorders asthma hay fever diabetes menopausal imbalance helps rectify forms nervous glandular disorder especially related reproductive asana reverses effect gravity body strain alleviated reversed flow blood legs visceral regions aids tissue regen eration weight abdominal organs diaphragm encourages deep exhalation larger amounts carbon dioxide removed lungs',
#  'asana develops nervous balance streng thens leg ankle foot muscles',
#  'natavarasana helps develop nervous balance concentration',
#  'garudasana improves concentration strengthens muscles loosens joints shoulders arms legs good upper',
#  'asana balances nervous develops control body mental concentration makes legs supple',
#  'asana strengthens shoulders arms hips legs helps develop sense balance coordination improves concentration',
#  'asana strengthens shoulders arms hips legs helps develop sense balance coordination improves concentration',
#  'asana strengthens arms wrists hips leg muscles helps develop muscular coordina tion nervous balance concentration',
#  'strengthens hip leg muscles improves blood circulation gives beneficial compression abdominal organs aids concentration balance nervous coordination',
#  'improves concentration coordinates muscular nervous balance hips leg muscles strengthened toned hamstrings stretch ed helping knee ankle joints',
#  'asana tones abdominal organs especially liver strengthens abdominal muscles helps stimulate intestinal peristalsis alleviating constipation tones sympathetic parasympathetic nervous systems strengthens muscles helps realign spine helps remove tiredness legs giving feeling lightness balance good knees',
#  'practice similar benefits paschimottan asana addition helps improve sense ofbalance',
#  'asana helps improves sense balance activates intestinal peristalsis alleviating constipation',
#  'asana stimulates digestion removes constipation improves blood circulation strengthens legs',
#  'asana strengthens leg muscles knee joints develops ability retain seminal fluid maintenance brahmacharya',
#  'asana helps maintain brahmacharya regulates reproductive strengthens toes ankles concentration improved',
#  'asana balances nervous streng thens arms wrists develops sense physical balance',
#  '',
#  'asana develops arm muscles increases flexibility shoulder joints lower massages tones abdomen visceral organs stimulating pancreas',
#  'asana strengthens arm muscles increases flexibility shoulders hips lower strengthens abdominal organs tones perin eum muscles contract helps preservation sexual energy spiritual purposes',
#  'hamsasana massages stimulates abdominal organs muscles beneficial healthy digestive',
#  'asana improves nervous balance develops sense inner equilibrium harmony strengthens muscles thighs arms shoulders spine',
#  'asana improves nervous balance makes leg muscles supple strengthens arms tones lower',
#  'asana keeps spine supple healthy tones ovaries uterus beneficial abdominal organs especially liver kidneys pranic level asana strong effect organs related swadhisthana manipura anahata vishuddhi chakras',
#  'koormasana tones organs abdomen helpful managing diabetes flatulence consti pation increases circulation spine soothing nerves relieving head neck ache induces introversion mental relaxation composure sense inner security surrender passion fear anger subside body mind refreshed practice',
#  'poorna shalabhasana strengthens pelvic organs tones balances functioning liver stomach bowels abdominal organs sti mulates appetite tightens muscles buttocks causes body vajroli mudra spontaneously benefits inverted asanas apply',
#  '',
#  'excellent asana loosening hip joints making legs supple strengthens arms tones abdominal organs helps relieve tension neck helpful people hydrocele',
#  'asana beneficially stretches abdominal muscles organs increases circulation stimulating toning nerves spine streng thens legs develops balance',
#  'posture gives good lateral stretch pelvic region trunk massages abdominal muscles organs helping prevent accumulation fat sagging skin abdomen',
#  'chakrasana strengthens legs beneficial nervous digestive respiratory cardiovascular glandular systems influences horn onal secretions helps relieve gynaecological disorders',
#  'pose improves flexibility blood circulation legs hips massages abdominal organs tones reproductive n akes pelvic area supple',
#  'asana strengthens abdominal organs muscles thighs arms muscles perineum contract strongly asana performed automatically inducing vajroli mudra ashwini mudra moola bandha consequently important asana conservation sexual energy spiritual purposes',
#  'grivasana strengthens neck thighs improves sense balance',
#  'asana makes muscles strong supple stimulates spinal nerves blood circulation strengthens thigh neck abdominal muscles excellent pose inducing relaxation',
#  'asana simultaneously stretches muscles abdomen contracting muscles tones nerves spine makes muscles supple relieves lumbago muscular spasms duces tendency adjoining vertebrae develop inflammatory problems calcium deposits massages abdominal organs alleviating digestive ailments regulates secretions adrenal gland liver pancreas beneficial kidneys',
#  'asana stimulates metabolic processes increase secretions different glands stimulates elimination toxins blood assisting removal skin conditions boils digestive organs massaged intestinal peristalsis stimulated useful managing flatulence constipation diabetes sluggishness liver kidneys harmonizes glands endocrine develops mental physical balance strengthens muscles body develops muscular control particular toxins accumulated body burnt bringing doshas humours vata wind kapha phlegm pitta bile balance harmony',
#  '',
#  'asana automatically induces moola bandha primarily awakening mooladhara chakra important asana conservation sexual energy tones reproductive eliminatory organs makes legs feet exceptionally supple',
#  'asana reverses flow apana directing upward higher centres use meditative states makes legs feet extremely supple',
#  'asana develops netvous control body mind reverses flow apana directing energy manipura chakra helping maintain brahmacharya celibacy strengthens wrists arm leg muscles muscles abdomen',
#  'vrischikasana reorganizes prana body arrest ing physical ageing process improves blood flow brain pituitary gland revitalizing body s systems improves circulation lower limbs abdomen tones reproductive organs arched position stretches loosens toning nerves spine strengthens arms develops sense balance',
#  'asana compresses abdomen thoroughly massaging internal organs stimulating peristalsis removing constipation tones repro ductive organs improves blood circulation legs relieving varicose veins increases level energy chakras vitalizing body mind',
#  'eka pada sirasana addition asana strengthens thigh muscles improves concentration',
#  '',
#  'asana helps control nervous solar plexus adrenal glands powerfully mas saged increasing vitality tones abdominal pelvic organs improving efficiency digestive reproductive eliminatory systems',
#  'addition benefits padmasana asana develops sense balance',
#  'asana strengthens shoulders arms legs opens chest anahata manipura chakras activated samana vayu sense balance concentration developed',
#  'asana stretches tones muscles arms legs sciatic nerves strengthens internal organs improves concentration sense balance',
#  'technique increases awareness sensitivity breath nostrils minor blockages removed flow breath nostrils balanced breathing left nostril tends activate right brain hemisphere breathing right nostril activates left hemisphere long slow balanced breathing stage profound effects calming balancing energies',
#  'practice cools body affects important brain centres associated biological drives temperature regulation cools reduces mental emotional excitation encourages free flow prana body induces muscular relaxation mental tranquillity tranquillizer sleep gives control hunger thirst generates feeling satisfaction',
#  '',
#  'bhramari relieves stress cerebral tension helps alleviating anger anxiety insomnia increasing healing capacity body strengthens improves voice bhramari induces meditative state harmonizing mind directing awareness inward vibration humming sound creates soothing effect mind nen ous',
#  'ujjayi classified tranquillizing pranayama heating effect body practice soothes nervous calms mind profoundly relaxing effect psychic level helps relieve insomnia practised shavasana sleep slows heart rate useful people suffering high blood pressure',
#  'practice burns toxins helps balance doshas humours kapha phlegm pitta bile vata wind useful practice women labour months proper preparation rapid exchange air lungs increase exchange oxygen carbon dioxide bloodstream stimulates metabolic rate producing heat flushing wastes toxins rapid rhythmic movement diaphragm massages stimulates visceral organs toning digestive bhastrika reduces level carbon dioxide blood helps alleviate inflammation throat accumulation phlegm balances strengthens nervous inducing peace tranquillity onepointedness mind preparation meditation',
#  'kapalbhati cleansing effect lungs good practice respiratory disorders balances strengthens nervous tones digestive organs purifies nadis removes sensory distractions energizes mind mental work removes sleepiness',
#  'moorchha pranayama excellent preparation meditation draws mind inwards enables psychic state experienced cuts distractions outside world inhibits identification physical body brings mental tranquillity helps alleviate tension anxiety anger neuroses raises level prana',
#  'practice creates heat body counteracts imbalances vata wind kapha phlegm doshas humours stimulates awakens pranic energy activating pingala nadi increasing extroversion dynamism enables physical activities performed efficiently helps alleviate depression especially recommended dull lethargic difficult communicate external world makes mind alert perceptive excellent pre meditation pranayama',
#  'jnana mudra chin mudra simple important psycho neural finger locks meditation asanas powerful palms fingers hands nerve root endings constantly emit energy index finger touches thumb circuit produced allows energy normally dissipate environment travel body brain fingers hands placed knees knees sensitized creating pranic circuit maintains redirects prana body addition placing hands knees stimulates nadi runs knees inside thighs perineum nadi known gupta hidden nadi sensitizing channel helps stimulate energies mooladhara chakra palms face upward chin mudra chest area opened practitioner experience sense lightness receptivity absent practice jnana mudra',
#  'jnana mudra chin mudra simple important psycho neural finger locks meditation asanas powerful palms fingers hands nerve root endings constantly emit energy index finger touches thumb circuit produced allows energy normally dissipate environment travel body brain fingers hands placed knees knees sensitized creating pranic circuit maintains redirects prana body addition placing hands knees stimulates nadi runs knees inside thighs perineum nadi known gupta hidden nadi sensitizing channel helps stimulate energies mooladhara chakra palms face upward chin mudra chest area opened practitioner experience sense lightness receptivity absent practice jnana mudra',
#  'interlocking fingers practice creates complete cross connection energies right hand left vice versa balancing energies body helps balance activities right left hemispheres brain placing tips index fingers thumbs intensifies flow prana mudra makes body mind stable meditation develops greater concentration awareness internal physical relaxation redirects prana body othetwise dispersed hands fingers elbows naturally tend point performing mudra helps open chest area',
#  'hands represent ida pingala dis union individual supreme consciousness bhairava mudra prano mudra pranayama meditation practice',
#  'mudra diverts flow prana hands heart area improving vitality heart middle ring fmgers relate directly nadis connected heart thumb closes pranic circuit acts energizer diverting flow prana hands nadis hridaya mudra beneficial heart simple safely easily acute situations heart centre emotion hridaya mudra helps release pentup emotion unburden heart practised emotional conflict crisis',
#  'physically shambhavi mudra strengthens eye muscles releases accumulated tension area mentally calms mind removing emotional stress anger develops concentration mental stability state thoughtlessness',
#  'nasikagra drishti excellent technique calming anger disturbed states mind eyes open aim practice create introspection open eyes aware outside world focusing nosetip concentrates mind mudra develops powers concentration induces meditative states takes practitioner psychic spiritual planes consciousness',
#  'khechari mudra stimulates number pressure points located mouth nasal cavity points influence body number glands massaged stimulating secretion certain hormones saliva practice reduces sensations hunger thirst induces state inner calm stillness preserves vitality body especially beneficial inner healing ultimately mudra potential stimulate prana awaken kundalini shakti',
#  'kaki mudra cools body mind soothes mental tensions addition benefits nasikagra drishti act pursing lips practice contact indrawn air membranes mouth stimulates digestive secretions aiding digestive process generally',
#  'bhujangini mudra tones stomach removes stagnant wind helps alleviate abdominal disorders retaining air stomach enables practitioner float water length time',
#  'bhoochari mudra develops power concentration memory tranquillizes introverts mind particularly beneficial calming anger stress develops mental stability state thoughtlessness helps awaken ajna chakra induce meditative states takes practitioner psychic spiritual planes consciousness',
#  'practice combines benefits kumbhaka ujjayi shambhavi khechari induces calmness tranquillity develops control senses perfected arrests thought processes induces higher states consciousness',
#  'physically energy heat hands fingers stimulate relax nerves muscles face mentally introverts awareness spiritually induces state pratyahara sense withdrawal',
#  'unmani mudra calms stress agitation induces meditative state',
#  'practice gives benefits vipareeta karani asana balances activities thyroid posture reverses downward outward movement energy revitalizing expanding awareness flow prana ida pingala nadis balanced resulting equal flow breath nostrils balancing effect helps prevent disease physical mental planes',
#  'pashinee mudra brings balance tranquillity nervous induces pratyahara sensory drawal stretches spine muscles stimulates spinal nerves massages abdominal organs',
#  'tadagi mudra relieves tension stored dia phragm pelvic floor tones abdominal organs stimulates blood circulation areas nerve plexuses visceral area stimulated toned bending fo ward extending stomach stretches diaphragm pelvic floor creates pressure trunk body stimulates manipura chakra centre energy distribution raises level prana generally',
#  'prana mudra awakens dormant prana shakti vital energy distributes body increasing strength health confidence develops awareness nadis chakras subtle flow prana body instils inner attitude peace equanimity adopting external attitude offering receiving energy cosmic source',
#  'practice massages abdominal organs stretches contributing good general health addition excellent preparatory practice meditation engendering sense relaxation relieves anger tension inducing tranquillity develops awareness control psychic energy awaken manipura chakra',
#  'manduki asana counterpose cross legged meditative asanas manduki mudra activates mooladhara chakra calms disturbances fluctuations mind balances ida pingala nadis leading directly meditation',
#  'maha mudra combines benefits shatnbhavi mudra khechari mudra moola bandha kumbhaka stimulates energy circuit linking mooladhara ajna chakra charged prana intensifies awareness induces spontaneous meditation energy blockages removed',
#  'maha bheda mudra profound influence pranic level influences mooladhara manipura vishuddhi chakras harnessing energies induce concentration mind meditation maha bheda supplements follows maha mudra supercharge body mind complex',
#  'powerful practice introverting mind awakens psychic faculties kundalini resides mooladhara chakra',
#  'practice strengthens anal muscles pre vents escape pranic energy redirects upward spiritual purposes',
#  'vajroli sahajoli mudra regulates tones entire uro genital helps overcome psycho sexual conflicts unwanted sexual thoughts conserves redirects energy enhancing meditative states',
#  'form jalandhara bandha compresses carotid sinuses located carotid arteries main arteries neck simple variation exerts subtler pressure sinuses help regulate circulatory respiratory systems normally decrease oxygen increase carbon dioxide body leads increased heart rate heavier breathing process initiated carotid sinuses exerting pressure sinuses tendency prevented allowing decreased heart rate increased breath retention practice produces mental relaxation relieving stress anxiety anger develops meditative introversion pointedness stimulus throat helps balance thyroid function regulate metabolism',
#  'moola bandha bestows physical mental spiritual benefits stimulates pelvic nerves tones uro genital excretory systems helpful psychosomatic degenerative illnesses relieves depression promotes good health helps realign physical mental psychic bodies preparation spiritual awakening moola bandha means attain sexual control sublimate sexual energy spiritual develop ment brahmacharya enhancement marital relations',
#  'uddiyana bandha panacea abdomen stimulates function pancreas liver strengthens internal organs digestive stimulated abdominal organs massaged toned adrenal glands balanced removing lethargy soothing anxiety tension improves blood circulation torso uddiyana bandha stimulates solar plexus subtle influences distribution energy body creates suction pressure reverses energy flow apana prana uniting samana stimulating manipura chakra',
#  'maha bandha gives enhanced benefits bandhas affects hormonal secretions pineal gland regulates entire endocrine degenerative ageing processes checked cell body rejuvenated introverts mind prior meditation perfected fully awaken prana main chakras leads merger prana apana samana manipura chakra culmination pranayamas',
#  'j ala neti removes mucus pollution nasal passages sinuses allowing air flow obstruction helps prevent manage respiratory tract diseases helps maintain good health ears eyes throat jala neti relieves muscular tension face helps practitioner maintain fresh youthful appear ance calming soothing influence brain alleviates anxiety anger depression removes drowsiness makes head feel light fresh jala neti stimulates nerve endings nose improving sense smell overall health individual balance brought right left nostrils corresponding left right brain hemispheres inducing state harmony balance body mind importantly neti helps awaken ajna chakra',
#  'benefits jala neti addition sutra neti rectify problem deviated nasal septum nostrils flowing freely deformed bone fleshy outgrowths regular friction sutra neti causes obstructions disappear months']

# %%
import pandas as pd
asanas = pd.read_csv('/content/drive/MyDrive/final_asan1_1.csv')
asanas = asanas.drop(['You tube Vdo link'],axis = 1)

# %%
asanas = asanas.drop(['References','Variations','Photo'],axis=1)

# %%
asanas = asanas.drop(['AID'],axis=1)

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()

# %%
asanas
# Out:
#                   AName                                        Description  \
# 0       Padanguli Naman  Sit in the base position with the legs outstre...
# 1           Goolf Naman  Remain in the base position.\nSlowly move both...
# 2          Goolf Chakra  Remain in the base position.\nKeep the legs sh...
# 3         Goolf Ghooman  Remain in the base position.\nBend the right k...
# 4    Janufalak Akarshan  Stay in the base position.\nGently contract th...
# ..                  ...                                                ...
# 221        MOOLA BANDHA  Close the eyes and relax the whole body for a ...
# 222     UDDIYANA BANDHA  Sit in siddha/siddha yoni asana or padmasana w...
# 223         MAHA BANDHA  Sit in siddha/siddha yoni asana or padmasana w...
# 224           JALA NETI  A special neti lota, 'neti pof should be used....
# 225          SUTRA NETI  Take any comfortable standing, sitting or squa...
#
#                                               Benefits  \
# 0    This group of asanas is concerned with looseni...
# 1    This group of asanas is concerned with looseni...
# 2    This group of asanas is concerned with looseni...
# 3    All the foot and calf asanas help in returning...
# 4    This group of asanas is concerned with looseni...
# ..                                                 ...
# 221  Moola bandha bestows many physical, mental and...
# 222  Uddiyana bandha is a panacea for the abdomen. ...
# 223  Maha bandha gives enhanced benefits of all thr...
# 224  J ala neti removes mucus and pollution from th...
# 225  The benefits are the same as for jala neti. In...
#
#                                      Contraindications  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 221  This practice should only be performed\nunder ...
# 222  Persons suffering from colitis, stomach\nor in...
# 223  People suffering from high or low blood\npress...
# 224  People who suffer from chronic bleeding in\nth...
# 225  Those people who suffer from chronic\nbleeding...
#
#                                              Breathing  \
# 0    Inhale as the toes move backward.\nExhale as t...
# 1    Inhale as the feet move backward.\nExhale as t...
# 2    Inhale on the upward movement.\nExhale on the ...
# 3    Inhale on the upward movement.\nExhale on the ...
# 4    Inhale while contracting.\nExhale while relaxi...
# ..                                                 ...
# 221  The above practice may also be performed with\...
# 222  Uddiyana bandha is performed with external\nbr...
# 223                                                NaN
# 224                                                NaN
# 225                                                NaN
#
#                                              awareness      Level
# 0    On the stretching produced by the movement and...  Beginners
# 1    On the stretch in the foot, ankle, calf and le...  Beginners
# 2         On the rotation of the ankle and the breath.  Beginners
# 3                      On the rotation and the breath.  Beginners
# 4                   On the contraction and the breath.  Beginners
# ..                                                 ...        ...
# 221  Physical - at the point of perineal contractio...   Begineer
# 222  Physical - on the abdomen and breath.\nSpiritu...   Begineer
# 223  Physical - on the perineal, abdominal and thro...   Begineer
# 224  Physical - on relaxing and positioning the bod...        NaN
# 225  Physical - on relaxing the body and moving the...        NaN
#
# [226 rows x 7 columns]

# %%
import spacy
from collections import Counter
from string import punctuation
nlp = spacy.load("en_core_web_sm")
length_input_1 = len(input_1)
word_soup_first = []
def get_hotwords(text):
    result = []
    pos_tag = ['PROPN', 'ADJ', 'NOUN'] 
    doc = nlp(text.lower()) 
    for token in doc:
        if(token.text in nlp.Defaults.stop_words or token.text in punctuation):
            continue
        if(token.pos_ in pos_tag):
            result.append(token.text)
    return result
for i in range(length_input_1):
  new_text = input_1[i]
  output = set(get_hotwords(new_text))
  most_common_list = Counter(output).most_common(25)
  word_soup_first.append(most_common_list)

# %%
most_common_list
# Out:
# [('bone', 1),
#  ('fleshy', 1),
#  ('months', 1),
#  ('neti', 1),
#  ('outgrowths', 1),
#  ('obstructions', 1),
#  ('friction', 1),
#  ('benefits', 1),
#  ('sutra', 1),
#  ('regular', 1),
#  ('jala', 1),
#  ('addition', 1),
#  ('nostrils', 1),
#  ('nasal', 1),
#  ('septum', 1),
#  ('problem', 1)]

# %%
word_soup_first
# Out:
# [[('benefits', 1)],
#  [('physical', 1),
#   ('vigorous', 1),
#   ('exercise', 1),
#   ('useful', 1),
#   ('pressure', 1),
#   ('problems', 1),
#   ('self', 1),
#   ('excellent', 1),
#   ('heart', 1),
#   ('coordination', 1),
#   ('ments', 1),
#   ('energy', 1),
#   ('awareness', 1),
#   ('blockages', 1),
#   ('arthritis', 1),
#   ('confidence', 1),
#   ('group', 1),
#   ('asanas', 1),
#   ('rheumatism', 1),
#   ('high', 1),
#   ('body', 1),
#   ('joints', 1),
#   ('blood', 1)],
#  [('physical', 1),
#   ('vigorous', 1),
#   ('exercise', 1),
#   ('useful', 1),
#   ('pressure', 1),
#   ('problems', 1),
#   ('self', 1),
#   ('excellent', 1),
#   ('heart', 1),
#   ('coordination', 1),
#   ('ments', 1),
#   ('energy', 1),
#   ('awareness', 1),
#   ('blockages', 1),
#   ('arthritis', 1),
#   ('confidence', 1),
#   ('group', 1),
#   ('asanas', 1),
#   ('rheumatism', 1),
#   ('high', 1),
#   ('body', 1),
#   ('joints', 1),
#   ('blood', 1)],
#  [('physical', 1),
#   ('vigorous', 1),
#   ('exercise', 1),
#   ('useful', 1),
#   ('pressure', 1),
#   ('problems', 1),
#   ('self', 1),
#   ('excellent', 1),
#   ('heart', 1),
#   ('coordination', 1),
#   ('ments', 1),
#   ('energy', 1),
#   ('awareness', 1),
#   ('blockages', 1),
#   ('arthritis', 1),
#   ('confidence', 1),
#   ('group', 1),
#   ('asanas', 1),
#   ('rheumatism', 1),
#   ('high', 1),
#   ('body', 1),
#   ('joints', 1),
#   ('blood', 1)],
#  [('help', 1),
#   ('blood', 1),
#   ('calf', 1),
#   ('relieve', 1),
#   ('thrombosis', 1),
#   ('foot', 1),
#   ('lymph', 1),
#   ('post', 1),
#   ('patients', 1),
#   ('asanas', 1),
#   ('tiredness', 1),
#   ('bedridden', 1),
#   ('operative', 1),
#   ('stagnant', 1),
#   ('cramp', 1),
#   ('venous', 1)],
#  [('physical', 1),
#   ('vigorous', 1),
#   ('exercise', 1),
#   ('useful', 1),
#   ('pressure', 1),
#   ('problems', 1),
#   ('self', 1),
#   ('excellent', 1),
#   ('heart', 1),
#   ('coordination', 1),
#   ('ments', 1),
#   ('energy', 1),
#   ('awareness', 1),
#   ('blockages', 1),
#   ('arthritis', 1),
#   ('confidence', 1),
#   ('group', 1),
#   ('asanas', 1),
#   ('rheumatism', 1),
#   ('high', 1),
#   ('body', 1),
#   ('joints', 1),
#   ('blood', 1)],
#  [('physical', 1),
#   ('vigorous', 1),
#   ('exercise', 1),
#   ('useful', 1),
#   ('pressure', 1),
#   ('problems', 1),
#   ('self', 1),
#   ('excellent', 1),
#   ('heart', 1),
#   ('coordination', 1),
#   ('ments', 1),
#   ('energy', 1),
#   ('awareness', 1),
#   ('blockages', 1),
#   ('arthritis', 1),
#   ('confidence', 1),
#   ('group', 1),
#   ('asanas', 1),
#   ('rheumatism', 1),
#   ('high', 1),
#   ('body', 1),
#   ('joints', 1),
#   ('blood', 1)],
#  [('muscle', 1),
#   ('sprains', 1),
#   ('weight', 1),
#   ('knee', 1),
#   ('injuries', 1),
#   ('vulnerable', 1),
#   ('asanas', 1),
#   ('ligaments', 1),
#   ('healing', 1),
#   ('joint', 1),
#   ('quadriceps', 1),
#   ('muscles', 1),
#   ('energies', 1),
#   ('strong', 1),
#   ('body', 1)],
#  [('people', 1),
#   ('daily', 1),
#   ('practice', 1),
#   ('joints', 1),
#   ('knee', 1),
#   ('meditative', 1),
#   ('excellent', 1),
#   ('evening', 1),
#   ('morning', 1),
#   ('legged', 1),
#   ('preparatory', 1),
#   ('asana', 1),
#   ('ardha', 1),
#   ('loos', 1),
#   ('hip', 1),
#   ('positions', 1),
#   ('titali', 1)],
#  [('physical', 1),
#   ('vigorous', 1),
#   ('exercise', 1),
#   ('useful', 1),
#   ('pressure', 1),
#   ('problems', 1),
#   ('self', 1),
#   ('excellent', 1),
#   ('heart', 1),
#   ('coordination', 1),
#   ('ments', 1),
#   ('energy', 1),
#   ('awareness', 1),
#   ('blockages', 1),
#   ('arthritis', 1),
#   ('confidence', 1),
#   ('group', 1),
#   ('asanas', 1),
#   ('rheumatism', 1),
#   ('high', 1),
#   ('body', 1),
#   ('joints', 1),
#   ('blood', 1)],
#  [('stages', 1),
#   ('tension', 1),
#   ('meditative', 1),
#   ('inner', 1),
#   ('long', 1),
#   ('asanas', 1),
#   ('tiredness', 1),
#   ('legs', 1),
#   ('mastery', 1),
#   ('thigh', 1),
#   ('lot', 1),
#   ('hours', 1),
#   ('muscles', 1),
#   ('padmasana', 1)],
#  [('physical', 1),
#   ('vigorous', 1),
#   ('exercise', 1),
#   ('useful', 1),
#   ('pressure', 1),
#   ('problems', 1),
#   ('self', 1),
#   ('excellent', 1),
#   ('heart', 1),
#   ('coordination', 1),
#   ('ments', 1),
#   ('energy', 1),
#   ('awareness', 1),
#   ('blockages', 1),
#   ('arthritis', 1),
#   ('confidence', 1),
#   ('group', 1),
#   ('asanas', 1),
#   ('rheumatism', 1),
#   ('high', 1),
#   ('body', 1),
#   ('joints', 1),
#   ('blood', 1)],
#  [('physical', 1),
#   ('vigorous', 1),
#   ('exercise', 1),
#   ('useful', 1),
#   ('pressure', 1),
#   ('problems', 1),
#   ('self', 1),
#   ('excellent', 1),
#   ('heart', 1),
#   ('coordination', 1),
#   ('ments', 1),
#   ('energy', 1),
#   ('awareness', 1),
#   ('blockages', 1),
#   ('arthritis', 1),
#   ('confidence', 1),
#   ('group', 1),
#   ('asanas', 1),
#   ('rheumatism', 1),
#   ('high', 1),
#   ('body', 1),
#   ('joints', 1),
#   ('blood', 1)],
#  [('tension', 1),
#   ('joints', 1),
#   ('hand', 1),
#   ('wrist', 1),
#   ('prolonged', 1),
#   ('asanas', 1),
#   ('writing', 1),
#   ('beneficial', 1),
#   ('typing', 1)],
#  [('physical', 1),
#   ('vigorous', 1),
#   ('exercise', 1),
#   ('useful', 1),
#   ('pressure', 1),
#   ('problems', 1),
#   ('self', 1),
#   ('excellent', 1),
#   ('heart', 1),
#   ('coordination', 1),
#   ('ments', 1),
#   ('energy', 1),
#   ('awareness', 1),
#   ('blockages', 1),
#   ('arthritis', 1),
#   ('confidence', 1),
#   ('group', 1),
#   ('asanas', 1),
#   ('rheumatism', 1),
#   ('high', 1),
#   ('body', 1),
#   ('joints', 1),
#   ('blood', 1)],
#  [('physical', 1),
#   ('vigorous', 1),
#   ('exercise', 1),
#   ('useful', 1),
#   ('pressure', 1),
#   ('problems', 1),
#   ('self', 1),
#   ('excellent', 1),
#   ('heart', 1),
#   ('coordination', 1),
#   ('ments', 1),
#   ('energy', 1),
#   ('awareness', 1),
#   ('blockages', 1),
#   ('arthritis', 1),
#   ('confidence', 1),
#   ('group', 1),
#   ('asanas', 1),
#   ('rheumatism', 1),
#   ('high', 1),
#   ('body', 1),
#   ('joints', 1),
#   ('blood', 1)],
#  [('office', 1),
#   ('help', 1),
#   ('pressure', 1),
#   ('frozen', 1),
#   ('work', 1),
#   ('shoulders', 1),
#   ('shape', 1),
#   ('cervical', 1),
#   ('asanas', 1),
#   ('shoulder', 1),
#   ('spondylitis', 1),
#   ('strain', 1)],
#  [('tension', 1),
#   ('desk', 1),
#   ('work', 1),
#   ('shoulders', 1),
#   ('nerves', 1),
#   ('different', 1),
#   ('limbs', 1),
#   ('neck', 1),
#   ('asanas', 1),
#   ('region', 1),
#   ('shoulder', 1),
#   ('release', 1),
#   ('head', 1),
#   ('heaviness', 1),
#   ('muscles', 1),
#   ('organs', 1),
#   ('stiffness', 1),
#   ('body', 1)],
#  [('strengthens', 1),
#   ('perineal', 1),
#   ('massages', 1),
#   ('digestive', 1),
#   ('prolapse', 1),
#   ('asana', 1),
#   ('abdominal', 1),
#   ('pelvic', 1),
#   ('muscles', 1),
#   ('lower', 1)],
#  [('joints', 1),
#   ('obesity', 1),
#   ('abdominal', 1),
#   ('spinal', 1),
#   ('muscles', 1),
#   ('hip', 1),
#   ('good', 1)],
#  [('joints', 1),
#   ('knee', 1),
#   ('muscles', 1),
#   ('abdominal', 1),
#   ('lower', 1),
#   ('hip', 1),
#   ('good', 1)],
#  [('effective', 1),
#   ('massages', 1),
#   ('digestive', 1),
#   ('lower', 1),
#   ('useful', 1),
#   ('problems', 1),
#   ('constipation', 1),
#   ('vertebrae', 1),
#   ('wind', 1),
#   ('pelvic', 1),
#   ('spinal', 1),
#   ('pawanmuktasana', 1),
#   ('sterility', 1),
#   ('muscles', 1),
#   ('menstrual', 1),
#   ('supta', 1),
#   ('reproductive', 1),
#   ('impotence', 1),
#   ('organs', 1)],
#  [('morning', 1),
#   ('massages', 1),
#   ('hips', 1),
#   ('asana', 1),
#   ('thing', 1),
#   ('useful', 1)],
#  [('column', 1),
#   ('distance', 1),
#   ('area', 1),
#   ('sitting', 1),
#   ('lower', 1),
#   ('constipation', 1),
#   ('relieves', 1),
#   ('excellent', 1),
#   ('prolonged', 1),
#   ('placement', 1),
#   ('stretch', 1),
#   ('cardiac', 1),
#   ('feet', 1),
#   ('twist', 1),
#   ('stiffness', 1),
#   ('twisting', 1),
#   ('buttocks', 1),
#   ('efore', 1),
#   ('diges', 1),
#   ('asana', 1),
#   ('tion', 1),
#   ('spinal', 1),
#   ('muscles', 1),
#   ('vertebra', 1),
#   ('time', 1)],
#  [('action', 1),
#   ('tiredness', 1),
#   ('abdominal', 1),
#   ('tightness', 1),
#   ('pelvic', 1),
#   ('organs', 1),
#   ('lower', 1)],
#  [('deep', 1),
#   ('latory', 1),
#   ('digestive', 1),
#   ('useful', 1),
#   ('tones', 1),
#   ('muscular', 1),
#   ('systems', 1),
#   ('trimester', 1),
#   ('freshness', 1),
#   ('relaxation', 1),
#   ('tension', 1),
#   ('nervous', 1),
#   ('pregnancy', 1),
#   ('asana', 1),
#   ('lethargy', 1),
#   ('second', 1),
#   ('childbearing', 1),
#   ('state', 1),
#   ('hormonal', 1),
#   ('deeper', 1),
#   ('circu', 1),
#   ('women', 1),
#   ('order', 1),
#   ('organs', 1),
#   ('shavasana', 1)],
#  [('breast', 1),
#   ('joints', 1),
#   ('upper', 1),
#   ('asana', 1),
#   ('shoulder', 1),
#   ('firms', 1),
#   ('muscles', 1),
#   ('loosens', 1),
#   ('chest', 1)],
#  [('flexibility', 1),
#   ('increases', 1),
#   ('asana', 1),
#   ('spine', 1),
#   ('stiffness', 1)],
#  [('abdomen', 1),
#   ('cycle', 1),
#   ('organs', 1),
#   ('excellent', 1),
#   ('nerves', 1),
#   ('postnatal', 1),
#   ('pelvis', 1),
#   ('asana', 1),
#   ('recovery', 1),
#   ('exercise', 1),
#   ('toning', 1),
#   ('menstrual', 1),
#   ('useful', 1),
#   ('months', 1)],
#  [('abdomen', 1),
#   ('disorders', 1),
#   ('constipation', 1),
#   ('natal', 1),
#   ('gynaecological', 1),
#   ('pelvis', 1),
#   ('asana', 1),
#   ('effect', 1),
#   ('areas', 1),
#   ('recovery', 1),
#   ('positive', 1),
#   ('post', 1),
#   ('energy', 1),
#   ('useful', 1),
#   ('blockages', 1)],
#  [('special', 1),
#   ('joints', 1),
#   ('upper', 1),
#   ('lighten', 1),
#   ('inaccessible', 1),
#   ('blades', 1),
#   ('asana', 1),
#   ('effect', 1),
#   ('shoulder', 1),
#   ('pelvic', 1),
#   ('mood', 1),
#   ('frustration', 1),
#   ('muscles', 1),
#   ('girdle', 1),
#   ('tones', 1)],
#  [('arms', 1),
#   ('flexibility', 1),
#   ('thighs', 1),
#   ('hips', 1),
#   ('neck', 1),
#   ('asana', 1),
#   ('effect', 1),
#   ('profound', 1),
#   ('muscles', 1)],
#  [('namaskarasana', 1),
#   ('arm', 1),
#   ('effect', 1),
#   ('beneficial', 1),
#   ('useful', 1),
#   ('pressure', 1),
#   ('vertebrae', 1),
#   ('flatulence', 1),
#   ('stretch', 1),
#   ('mas', 1),
#   ('pelvic', 1),
#   ('leg', 1),
#   ('arms', 1),
#   ('thighs', 1),
#   ('neck', 1),
#   ('toned', 1),
#   ('equal', 1),
#   ('spinal', 1),
#   ('muscles', 1),
#   ('joints', 1),
#   ('nerves', 1),
#   ('spine', 1),
#   ('organs', 1)],
#  [('constipation', 1),
#   ('blood', 1),
#   ('asanas', 1),
#   ('asana', 1),
#   ('legs', 1),
#   ('meditation', 1),
#   ('circulation', 1)],
#  [('constipation', 1),
#   ('region', 1),
#   ('abdominal', 1),
#   ('muscles', 1),
#   ('organs', 1),
#   ('ailments', 1),
#   ('useful', 1)],
#  [('defective', 1),
#   ('vision', 1),
#   ('relaxes', 1),
#   ('humour', 1),
#   ('aqueous', 1),
#   ('stimulates', 1),
#   ('liquid', 1),
#   ('correction', 1),
#   ('palming', 1),
#   ('cornea', 1),
#   ('circulation', 1),
#   ('muscles', 1),
#   ('eye', 1)],
#  [('people', 1),
#   ('eyesight', 1),
#   ('tension', 1),
#   ('eyes', 1),
#   ('becmne', 1),
#   ('habitual', 1),
#   ('muscles', 1),
#   ('relaxation', 1),
#   ('encourages', 1),
#   ('blink', 1),
#   ('reflex', 1),
#   ('defective', 1),
#   ('eye', 1),
#   ('spontaneous', 1),
#   ('state', 1)],
#  [('tension', 1),
#   ('corrects', 1),
#   ('work', 1),
#   ('sideways', 1),
#   ('muscles', 1),
#   ('close', 1),
#   ('reading', 1),
#   ('constant', 1),
#   ('viewing', 1)],
#  [('eyeball', 1),
#   ('sideways', 1),
#   ('coordination', 1),
#   ('lateral', 1),
#   ('muscles', 1),
#   ('medial', 1),
#   ('viewing', 1)],
#  [('balances', 1), ('muscles', 1), ('eyeball', 1), ('lower', 1)],
#  [('rotational', 1),
#   ('vities', 1),
#   ('coordinated', 1),
#   ('muscles', 1),
#   ('acti', 1),
#   ('viewing', 1),
#   ('eye', 1)],
#  [('power', 1), ('muscles', 1), ('exercise', 1), ('eye', 1)],
#  [('movements', 1), ('power', 1), ('exercise', 1), ('muscles', 1), ('eye', 1)],
#  [('sleep', 1),
#   ('practice', 1),
#   ('practi', 1),
#   ('exercises', 1),
#   ('pratyahara', 1),
#   ('dynamic', 1),
#   ('awareness', 1),
#   ('relaxed', 1),
#   ('asana', 1),
#   ('tioner', 1),
#   ('tired', 1),
#   ('psycho', 1),
#   ('physiological', 1),
#   ('namaskara', 1),
#   ('mind', 1),
#   ('body', 1)],
#  [('figure', 1), ('neck', 1), ('stiff', 1), ('disc', 1)],
#  [('upper', 1),
#   ('complaints', 1),
#   ('cervical', 1),
#   ('stiff', 1),
#   ('asana', 1),
#   ('neck', 1),
#   ('spinal', 1),
#   ('helpful', 1),
#   ('spondylitis', 1)],
#  [('column', 1),
#   ('pain', 1),
#   ('effective', 1),
#   ('shape', 1),
#   ('air', 1),
#   ('lung', 1),
#   ('lower', 1),
#   ('disc', 1),
#   ('people', 1),
#   ('types', 1),
#   ('normal', 1),
#   ('awareness', 1),
#   ('simple', 1),
#   ('compression', 1),
#   ('certain', 1),
#   ('vertebral', 1),
#   ('asana', 1),
#   ('periods', 1),
#   ('releases', 1),
#   ('spinal', 1),
#   ('lungs', 1),
#   ('sciatica', 1),
#   ('time', 1),
#   ('nerves', 1),
#   ('ailments', 1)],
#  [('sciatic', 1),
#   ('pain', 1),
#   ('ideal', 1),
#   ('nidra', 1),
#   ('digestive', 1),
#   ('matsya', 1),
#   ('cause', 1),
#   ('pressure', 1),
#   ('people', 1),
#   ('practise', 1),
#   ('fotward', 1),
#   ('knee', 1),
#   ('comfort', 1),
#   ('kridasana', 1),
#   ('tnended', 1),
#   ('block', 1),
#   ('bent', 1),
#   ('perineum', 1),
#   ('head', 1),
#   ('tension', 1),
#   ('asanas', 1),
#   ('asana', 1),
#   ('circumstances', 1),
#   ('circulation', 1),
#   ('peristalsis', 1)],
#  [('mental', 1),
#   ('comfortable', 1),
#   ('pain', 1),
#   ('physical', 1),
#   ('sukhasana', 1),
#   ('easiest', 1),
#   ('unable', 1),
#   ('persons', 1),
#   ('ill', 1),
#   ('effect', 1),
#   ('tion', 1),
#   ('balance', 1),
#   ('meditation', 1),
#   ('postures', 1),
#   ('difficult', 1),
#   ('strain', 1),
#   ('medita', 1)],
#  [('level', 1), ('benefits', 1), ('padmasana', 1)],
#  [('trunk', 1),
#   ('experience', 1),
#   ('digestive', 1),
#   ('firm', 1),
#   ('prana', 1),
#   ('chakra', 1),
#   ('effect', 1),
#   ('slow', 1),
#   ('meditation', 1),
#   ('padmasana', 1),
#   ('lower', 1),
#   ('flow', 1),
#   ('pressure', 1),
#   ('pillar', 1),
#   ('muscular', 1),
#   ('perineum', 1),
#   ('head', 1),
#   ('process', 1),
#   ('tension', 1),
#   ('sahasrara', 1),
#   ('large', 1),
#   ('step', 1),
#   ('nervous', 1),
#   ('calm', 1),
#   ('region', 1)],
#  [('abdomen', 1),
#   ('noticeable', 1),
#   ('locks', 1),
#   ('reduction', 1),
#   ('area', 1),
#   ('psychic', 1),
#   ('centres', 1),
#   ('bandha', 1),
#   ('chakra', 1),
#   ('vajroli', 1),
#   ('psycho', 1),
#   ('cord', 1),
#   ('necessary', 1),
#   ('lower', 1),
#   ('hormones', 1),
#   ('pressure', 1),
#   ('flow', 1),
#   ('mudra', 1),
#   ('muscular', 1),
#   ('posture', 1),
#   ('moola', 1),
#   ('brahmacharya', 1),
#   ('perineum', 1),
#   ('swadhisthana', 1),
#   ('spiritual', 1)],
#  [('abdomen', 1),
#   ('noticeable', 1),
#   ('locks', 1),
#   ('reduction', 1),
#   ('area', 1),
#   ('psychic', 1),
#   ('centres', 1),
#   ('point', 1),
#   ('bandha', 1),
#   ('chakra', 1),
#   ('vajroli', 1),
#   ('psycho', 1),
#   ('cord', 1),
#   ('necessary', 1),
#   ('lower', 1),
#   ('hormones', 1),
#   ('pressure', 1),
#   ('flow', 1),
#   ('mudra', 1),
#   ('muscular', 1),
#   ('posture', 1),
#   ('moola', 1),
#   ('brahmacharya', 1),
#   ('perineum', 1),
#   ('swadhisthana', 1)],
#  [('position', 1),
#   ('varicose', 1),
#   ('tired', 1),
#   ('healthy', 1),
#   ('swastikasana', 1),
#   ('retention', 1),
#   ('legs', 1),
#   ('fluid', 1),
#   ('veins', 1),
#   ('muscles', 1)],
#  [('area', 1),
#   ('massages', 1),
#   ('hips', 1),
#   ('thigh', 1),
#   ('meditation', 1),
#   ('outer', 1),
#   ('useful', 1),
#   ('knees', 1),
#   ('structure', 1),
#   ('pelvic', 1),
#   ('alternative', 1),
#   ('large', 1),
#   ('contact', 1),
#   ('inner', 1),
#   ('asanas', 1),
#   ('asana', 1),
#   ('periods', 1),
#   ('sustain', 1),
#   ('muscles', 1),
#   ('floor', 1),
#   ('body', 1),
#   ('comfortable', 1),
#   ('position', 1),
#   ('time', 1),
#   ('outwards', 1)],
#  [('nerve', 1),
#   ('measure', 1),
#   ('massages', 1),
#   ('digestive', 1),
#   ('efficiency', 1),
#   ('hyperacidity', 1),
#   ('feed', 1),
#   ('useful', 1),
#   ('flow', 1),
#   ('piles', 1),
#   ('alters', 1),
#   ('disorders', 1),
#   ('preventative', 1),
#   ('peptic', 1),
#   ('pelvic', 1),
#   ('ulcer', 1),
#   ('stomach', 1),
#   ('testicles', 1),
#   ('nervous', 1),
#   ('hernia', 1),
#   ('entire', 1),
#   ('region', 1),
#   ('dilated', 1),
#   ('muscles', 1),
#   ('menstrual', 1)],
#  [('ajna', 1),
#   ('nervous', 1),
#   ('calms', 1),
#   ('benefits', 1),
#   ('asana', 1),
#   ('chakra', 1),
#   ('mind', 1),
#   ('vajrasana', 1)],
#  [('pressure', 1),
#   ('facilitate', 1),
#   ('practice', 1),
#   ('pranayama', 1),
#   ('systems', 1),
#   ('activities', 1),
#   ('nervous', 1),
#   ('balance', 1),
#   ('autonomic', 1),
#   ('nostrils', 1),
#   ('armpits', 1),
#   ('breath', 1),
#   ('right', 1),
#   ('influences', 1),
#   ('parasympathetic', 1),
#   ('state', 1),
#   ('flow', 1)],
#  [('aspirants', 1),
#   ('excellent', 1),
#   ('influence', 1),
#   ('mooladhara', 1),
#   ('benefits', 1),
#   ('chakra', 1),
#   ('spiritual', 1),
#   ('meditation', 1),
#   ('vajrasana', 1)],
#  [('physical', 1),
#   ('stability', 1),
#   ('total', 1),
#   ('cord', 1),
#   ('spinal', 1),
#   ('definite', 1),
#   ('posture', 1),
#   ('body', 1),
#   ('extension', 1)],
#  [('introverted', 1),
#   ('stutter', 1),
#   ('frustration', 1),
#   ('nose', 1),
#   ('chest', 1),
#   ('useful', 1),
#   ('people', 1),
#   ('mudra', 1),
#   ('excellent', 1),
#   ('ears', 1),
#   ('early', 1),
#   ('voice', 1),
#   ('beautiful', 1),
#   ('healing', 1),
#   ('tension', 1),
#   ('diaphragm', 1),
#   ('simhagarjanasana', 1),
#   ('nervous', 1),
#   ('benefits', 1),
#   ('asana', 1),
#   ('emotional', 1),
#   ('strong', 1),
#   ('eyes', 1),
#   ('throat', 1),
#   ('mouth', 1)],
#  [('physical', 1),
#   ('uncontrollable', 1),
#   ('useful', 1),
#   ('mental', 1),
#   ('realms', 1),
#   ('concentration', 1),
#   ('unconscious', 1),
#   ('precise', 1),
#   ('relaxation', 1),
#   ('beco', 1),
#   ('clear', 1),
#   ('nuch', 1),
#   ('awareness', 1),
#   ('process', 1),
#   ('thoughts', 1),
#   ('asana', 1),
#   ('nes', 1),
#   ('balances', 1),
#   ('kidneys', 1),
#   ('power', 1),
#   ('reproductive', 1),
#   ('abdominal', 1),
#   ('organs', 1),
#   ('mind', 1),
#   ('good', 1)],
#  [('flexibility', 1),
#   ('abdomen', 1),
#   ('shoulders', 1),
#   ('cramps', 1),
#   ('pregnancy', 1),
#   ('neck', 1),
#   ('asana', 1),
#   ('relief', 1),
#   ('reproductive', 1),
#   ('forceful', 1),
#   ('contraction', 1),
#   ('female', 1),
#   ('menstrual', 1),
#   ('leucorrhea', 1)],
#  [('sciatic', 1),
#   ('hips', 1),
#   ('female', 1),
#   ('beneficial', 1),
#   ('tones', 1),
#   ('birth', 1),
#   ('directions', 1),
#   ('loosens', 1),
#   ('thighs', 1),
#   ('exercises', 1),
#   ('digestion', 1),
#   ('asana', 1),
#   ('spinal', 1),
#   ('circulation', 1),
#   ('muscles', 1),
#   ('children', 1),
#   ('hip', 1),
#   ('sciatica', 1),
#   ('joints', 1),
#   ('blood', 1),
#   ('weight', 1),
#   ('nerves', 1),
#   ('legs', 1),
#   ('reproductive', 1),
#   ('abdominal', 1)],
#  [('nerve', 1),
#   ('sciatic', 1),
#   ('cord', 1),
#   ('discs', 1),
#   ('female', 1),
#   ('connections', 1),
#   ('beneficial', 1),
#   ('male', 1),
#   ('tones', 1),
#   ('pressure', 1),
#   ('correct', 1),
#   ('constipation', 1),
#   ('vertebrae', 1),
#   ('backache', 1),
#   ('pelvic', 1),
#   ('adrenal', 1),
#   ('problem', 1),
#   ('strengthens', 1),
#   ('glands', 1),
#   ('practice', 1),
#   ('asana', 1),
#   ('spinal', 1),
#   ('cases', 1),
#   ('muscles', 1),
#   ('position', 1)],
#  [('final', 1),
#   ('female', 1),
#   ('male', 1),
#   ('tones', 1),
#   ('disorders', 1),
#   ('excellent', 1),
#   ('pelvic', 1),
#   ('liver', 1),
#   ('bhujangasana', 1),
#   ('natal', 1),
#   ('visceral', 1),
#   ('benefits', 1),
#   ('asana', 1),
#   ('region', 1),
#   ('muscles', 1),
#   ('menstrual', 1),
#   ('position', 1),
#   ('similar', 1),
#   ('kidneys', 1),
#   ('reproductive', 1),
#   ('shashank', 1),
#   ('abdominal', 1),
#   ('spine', 1),
#   ('postures', 1),
#   ('organs', 1)],
#  [('extra', 1),
#   ('pressure', 1),
#   ('practice', 1),
#   ('lesser', 1),
#   ('benefits', 1),
#   ('preparatory', 1),
#   ('brain', 1),
#   ('head', 1),
#   ('sirshasana', 1),
#   ('degree', 1),
#   ('body', 1),
#   ('headstand', 1)],
#  [('strengthens', 1),
#   ('ankles', 1),
#   ('good', 1),
#   ('nervous', 1),
#   ('hips', 1),
#   ('stretch', 1),
#   ('asana', 1),
#   ('legs', 1),
#   ('abdominal', 1),
#   ('balance', 1),
#   ('feet', 1),
#   ('organs', 1),
#   ('lower', 1),
#   ('tones', 1)],
#  [('level', 1), ('ushtrasana', 1)],
#  [('shoulders', 1),
#   ('intestines', 1),
#   ('digestive', 1),
#   ('beneficial', 1),
#   ('people', 1),
#   ('constipation', 1),
#   ('vertebrae', 1),
#   ('systems', 1),
#   ('backache', 1),
#   ('loosens', 1),
#   ('rounded', 1),
#   ('stomach', 1),
#   ('neck', 1),
#   ('asana', 1),
#   ('region', 1),
#   ('spinal', 1),
#   ('helpful', 1),
#   ('asthma', 1),
#   ('thyroid', 1),
#   ('nerves', 1),
#   ('reproductive', 1),
#   ('posture', 1),
#   ('organs', 1)],
#  [('shoulders', 1),
#   ('gland', 1),
#   ('massages', 1),
#   ('digestive', 1),
#   ('om', 1),
#   ('meditation', 1),
#   ('lung', 1),
#   ('beneficial', 1),
#   ('organs', 1),
#   ('chest', 1),
#   ('tones', 1),
#   ('constipation', 1),
#   ('flexible', 1),
#   ('spiritual', 1),
#   ('loosens', 1),
#   ('sexual', 1),
#   ('energy', 1),
#   ('purposes', 1),
#   ('rounded', 1),
#   ('capacity', 1),
#   ('neck', 1),
#   ('asana', 1),
#   ('asanas', 1),
#   ('realigns', 1),
#   ('oxygen', 1)],
#  [('deep', 1),
#   ('shoulders', 1),
#   ('round', 1),
#   ('rectifies', 1),
#   ('breaths', 1),
#   ('breathing', 1),
#   ('upper', 1),
#   ('heart', 1),
#   ('influences', 1),
#   ('stiffness', 1),
#   ('capacity', 1),
#   ('extra', 1),
#   ('asana', 1),
#   ('brain', 1),
#   ('oxygen', 1),
#   ('circulation', 1),
#   ('body', 1),
#   ('blood', 1),
#   ('supply', 1)],
#  [('pain', 1),
#   ('deep', 1),
#   ('smoothes', 1),
#   ('shoulders', 1),
#   ('blades', 1),
#   ('spondylitis', 1),
#   ('cramp', 1),
#   ('flow', 1),
#   ('people', 1),
#   ('alternate', 1),
#   ('bad', 1),
#   ('stiffness', 1),
#   ('energy', 1),
#   ('short', 1),
#   ('tension', 1),
#   ('writer', 1),
#   ('exercises', 1),
#   ('tensing', 1),
#   ('neck', 1),
#   ('asana', 1),
#   ('postural', 1),
#   ('helpful', 1),
#   ('ann', 1),
#   ('muscles', 1),
#   ('cervical', 1)],
#  [('column', 1),
#   ('physical', 1),
#   ('points', 1),
#   ('useful', 1),
#   ('mental', 1),
#   ('rectus', 1),
#   ('congestion', 1),
#   ('longer', 1),
#   ('balance', 1),
#   ('clear', 1),
#   ('pregnancy', 1),
#   ('entire', 1),
#   ('asana', 1),
#   ('abdomini', 1),
#   ('ligaments', 1),
#   ('spinal', 1),
#   ('tadasana', 1),
#   ('muscles', 1),
#   ('months', 1),
#   ('height', 1),
#   ('nerves', 1),
#   ('abdominal', 1),
#   ('spine', 1),
#   ('bones', 1)],
#  [('groups', 1),
#   ('sides', 1),
#   ('waist', 1),
#   ('massages', 1),
#   ('postural', 1),
#   ('tadasana', 1),
#   ('muscles', 1)],
#  [('physical', 1),
#   ('shoulders', 1),
#   ('useful', 1),
#   ('tones', 1),
#   ('problems', 1),
#   ('mental', 1),
#   ('waist', 1),
#   ('relaxation', 1),
#   ('stiffness', 1),
#   ('twisting', 1),
#   ('tension', 1),
#   ('movement', 1),
#   ('neck', 1),
#   ('asana', 1),
#   ('postural', 1),
#   ('lightness', 1),
#   ('time', 1),
#   ('day', 1),
#   ('feeling', 1)],
#  [('coordination', 1),
#   ('asana', 1),
#   ('balance', 1),
#   ('kati', 1),
#   ('chakrasana', 1),
#   ('muscles', 1)],
#  [('weight', 1),
#   ('excess', 1),
#   ('asana', 1),
#   ('waistline', 1),
#   ('spine', 1),
#   ('muscles', 1),
#   ('tones', 1)],
#  [('middle', 1),
#   ('thighs', 1),
#   ('uterus', 1),
#   ('pelvis', 1),
#   ('asana', 1),
#   ('muscles', 1),
#   ('ankles', 1)],
#  [('legs', 1), ('muscles', 1)],
#  [('shoulders', 1),
#   ('posture', 1),
#   ('asana', 1),
#   ('rectifies', 1),
#   ('poor', 1),
#   ('chest', 1)],
#  [('bodies', 1),
#   ('upper', 1),
#   ('blades', 1),
#   ('neck', 1),
#   ('asana', 1),
#   ('shoulder', 1),
#   ('spine', 1),
#   ('young', 1),
#   ('muscles', 1),
#   ('chest', 1),
#   ('good', 1)],
#  [('trunk', 1),
#   ('fat', 1),
#   ('area', 1),
#   ('waistline', 1),
#   ('tones', 1),
#   ('depression', 1),
#   ('alleviates', 1),
#   ('waist', 1),
#   ('pelvic', 1),
#   ('practice', 1),
#   ('digestion', 1),
#   ('sides', 1),
#   ('series', 1),
#   ('nervous', 1),
#   ('muscles', 1),
#   ('help', 1),
#   ('regular', 1),
#   ('legs', 1),
#   ('reproductive', 1),
#   ('organs', 1)],
#  [('massages', 1),
#   ('tiredness', 1),
#   ('han', 1),
#   ('excellent', 1),
#   ('prepranayama', 1),
#   ('practice', 1),
#   ('visceral', 1),
#   ('benefits', 1),
#   ('asanas', 1),
#   ('asana', 1),
#   ('spinal', 1),
#   ('circulation', 1),
#   ('muscles', 1),
#   ('alveoli', 1),
#   ('strings', 1),
#   ('nerves', 1),
#   ('mucus', 1),
#   ('stagnant', 1),
#   ('organs', 1)],
#  [('blood', 1),
#   ('face', 1),
#   ('nerves', 1),
#   ('hamstrings', 1),
#   ('asana', 1),
#   ('spinal', 1),
#   ('head', 1),
#   ('circulation', 1),
#   ('muscles', 1),
#   ('supple', 1),
#   ('tones', 1)],
#  [('practice', 1),
#   ('concentration', 1),
#   ('calmness', 1),
#   ('preparation', 1),
#   ('state', 1)],
#  [],
#  [],
#  [],
#  [('strengthens', 1),
#   ('height', 1),
#   ('upper', 1),
#   ('longer', 1),
#   ('limbs', 1),
#   ('blades', 1),
#   ('ligaments', 1),
#   ('shoulder', 1),
#   ('spine', 1),
#   ('bones', 1),
#   ('circulation', 1),
#   ('muscles', 1)],
#  [('strengthens', 1),
#   ('exercises', 1),
#   ('arm', 1),
#   ('blades', 1),
#   ('region', 1),
#   ('shoulder', 1),
#   ('leg', 1),
#   ('spine', 1),
#   ('muscles', 1),
#   ('chest', 1)],
#  [],
#  [('constipation', 1),
#   ('vertebrae', 1),
#   ('good', 1),
#   ('excellent', 1),
#   ('health', 1),
#   ('yogamudrasana', 1),
#   ('nerves', 1),
#   ('indigestion', 1),
#   ('asana', 1),
#   ('abdominal', 1),
#   ('chakra', 1),
#   ('spinal', 1),
#   ('general', 1),
#   ('manipura', 1),
#   ('organs', 1),
#   ('spaces', 1)],
#  [('thymus', 1),
#   ('deep', 1),
#   ('gland', 1),
#   ('glasses', 1),
#   ('useful', 1),
#   ('piles', 1),
#   ('pressure', 1),
#   ('constipation', 1),
#   ('relieves', 1),
#   ('stretch', 1),
#   ('backache', 1),
#   ('pelvic', 1),
#   ('feet', 1),
#   ('thighs', 1),
#   ('stimulates', 1),
#   ('asana', 1),
#   ('region', 1),
#   ('water', 1),
#   ('circulation', 1),
#   ('asthma', 1),
#   ('blood', 1),
#   ('function', 1),
#   ('thyroid', 1),
#   ('respiration', 1),
#   ('legs', 1)],
#  [('defects', 1),
#   ('productive', 1),
#   ('stability', 1),
#   ('asana', 1),
#   ('balance', 1),
#   ('postural', 1),
#   ('relaxation', 1),
#   ('meditation', 1),
#   ('posture', 1),
#   ('emotional', 1),
#   ('peace', 1),
#   ('useful', 1)],
#  [('arms', 1),
#   ('kundalini', 1),
#   ('pain', 1),
#   ('chests', 1),
#   ('shoulders', 1),
#   ('normal', 1),
#   ('awakening', 1),
#   ('children', 1),
#   ('growth', 1)],
#  [('excited', 1),
#   ('uncontrollable', 1),
#   ('massages', 1),
#   ('experience', 1),
#   ('digestive', 1),
#   ('effect', 1),
#   ('appetite', 1),
#   ('practise', 1),
#   ('security', 1),
#   ('balance', 1),
#   ('adrenal', 1),
#   ('glands', 1),
#   ('stability', 1),
#   ('stimulates', 1),
#   ('increases', 1),
#   ('asana', 1),
#   ('emotional', 1),
#   ('calms', 1),
#   ('sense', 1),
#   ('abdominal', 1),
#   ('anger', 1),
#   ('organs', 1),
#   ('mind', 1)],
#  [('strength', 1),
#   ('equanimity', 1),
#   ('weight', 1),
#   ('excess', 1),
#   ('asana', 1),
#   ('abdominal', 1),
#   ('relaxation', 1),
#   ('thigh', 1),
#   ('muscles', 1),
#   ('organs', 1),
#   ('lower', 1),
#   ('state', 1),
#   ('tones', 1)],
#  [('arms', 1),
#   ('backs', 1),
#   ('shoulders', 1),
#   ('stiff', 1),
#   ('asana', 1),
#   ('good', 1)],
#  [('arms', 1), ('bhujangasana', 1), ('influence', 1)],
#  [('bhujangasana', 1),
#   ('shoulders', 1),
#   ('effect', 1),
#   ('profound', 1),
#   ('addition', 1),
#   ('sarpasana', 1),
#   ('posture', 1),
#   ('muscles', 1)],
#  [('tension', 1),
#   ('excellent', 1),
#   ('area', 1),
#   ('asana', 1),
#   ('ardha', 1),
#   ('pelvic', 1),
#   ('organs', 1),
#   ('shalabhasana', 1)],
#  [('bowels', 1),
#   ('mild', 1),
#   ('appetite', 1),
#   ('lower', 1),
#   ('disc', 1),
#   ('tones', 1),
#   ('mudra', 1),
#   ('relief', 1),
#   ('backache', 1),
#   ('pelvic', 1),
#   ('liver', 1),
#   ('stomach', 1),
#   ('buttocks', 1),
#   ('stimulates', 1),
#   ('balances', 1),
#   ('muscles', 1),
#   ('body', 1),
#   ('sciatica', 1),
#   ('shalabhasana', 1),
#   ('long', 1),
#   ('abdominal', 1),
#   ('condition', 1),
#   ('organs', 1)],
#  [('pain', 1),
#   ('respiratory', 1),
#   ('disorders', 1),
#   ('levels', 1),
#   ('disc', 1),
#   ('benefits', 1),
#   ('cervical', 1),
#   ('heart', 1),
#   ('creased', 1),
#   ('discomfort', 1),
#   ('dhanurasana', 1),
#   ('posture', 1),
#   ('spondylitis', 1),
#   ('beneficial', 1),
#   ('lungs', 1),
#   ('lower', 1),
#   ('useful', 1),
#   ('tones', 1)],
#  [('column', 1),
#   ('alimentary', 1),
#   ('area', 1),
#   ('excess', 1),
#   ('digestive', 1),
#   ('sluggishness', 1),
#   ('canal', 1),
#   ('thoracic', 1),
#   ('netves', 1),
#   ('organs', 1),
#   ('useful', 1),
#   ('disorders', 1),
#   ('constipation', 1),
#   ('correct', 1),
#   ('upper', 1),
#   ('dhanurasana', 1),
#   ('secretions', 1),
#   ('leg', 1),
#   ('adrenal', 1),
#   ('chronic', 1),
#   ('cetvical', 1),
#   ('stiffness', 1),
#   ('liver', 1),
#   ('energy', 1),
#   ('glands', 1)],
#  [('realign', 1),
#   ('shoulders', 1),
#   ('massages', 1),
#   ('miscarry', 1),
#   ('female', 1),
#   ('useful', 1),
#   ('tones', 1),
#   ('disorders', 1),
#   ('backache', 1),
#   ('rounded', 1),
#   ('digestion', 1),
#   ('bronchial', 1),
#   ('asana', 1),
#   ('asthma', 1),
#   ('colon', 1),
#   ('menstrual', 1),
#   ('thyroid', 1),
#   ('prolapse', 1),
#   ('abdominal', 1),
#   ('reproductive', 1),
#   ('conditions', 1),
#   ('spine', 1),
#   ('management', 1),
#   ('women', 1),
#   ('organs', 1)],
#  [('constipation', 1),
#   ('exercises', 1),
#   ('excellent', 1),
#   ('time', 1),
#   ('diaphragm', 1),
#   ('benefits', 1),
#   ('blades', 1),
#   ('entire', 1),
#   ('asana', 1),
#   ('asanas', 1),
#   ('shoulder', 1),
#   ('risk', 1),
#   ('tightness', 1),
#   ('effects', 1),
#   ('piles', 1),
#   ('chest', 1),
#   ('tones', 1)],
#  [('thighs', 1),
#   ('achilles', 1),
#   ('shoulders', 1),
#   ('similar', 1),
#   ('benefits', 1),
#   ('wrists', 1),
#   ('asana', 1),
#   ('region', 1),
#   ('tendons', 1),
#   ('spine', 1),
#   ('lumbar', 1),
#   ('chakrasana', 1)],
#  [('shoulders', 1),
#   ('area', 1),
#   ('tiredness', 1),
#   ('cramp', 1),
#   ('chest', 1),
#   ('supple', 1),
#   ('alleviates', 1),
#   ('ache', 1),
#   ('relieves', 1),
#   ('excellent', 1),
#   ('relaxation', 1),
#   ('leg', 1),
#   ('stiffness', 1),
#   ('energy', 1),
#   ('minutes', 1),
#   ('awareness', 1),
#   ('tension', 1),
#   ('rheumatism', 1),
#   ('asana', 1),
#   ('neck', 1),
#   ('general', 1),
#   ('muscles', 1),
#   ('gomukhasana', 1),
#   ('sciatica', 1),
#   ('legs', 1)],
#  [('thighs', 1),
#   ('joints', 1),
#   ('nervous', 1),
#   ('massages', 1),
#   ('insides', 1),
#   ('asana', 1),
#   ('region', 1),
#   ('abdominal', 1),
#   ('pelvic', 1),
#   ('organs', 1),
#   ('alternately', 1),
#   ('hip', 1)],
#  [('area', 1),
#   ('massages', 1),
#   ('excess', 1),
#   ('uro', 1),
#   ('pelvic', 1),
#   ('adrenal', 1),
#   ('liver', 1),
#   ('glands', 1),
#   ('hamstring', 1),
#   ('entire', 1),
#   ('asana', 1),
#   ('region', 1),
#   ('circulation', 1),
#   ('muscles', 1),
#   ('hip', 1),
#   ('flexibility', 1),
#   ('joints', 1),
#   ('weight', 1),
#   ('pancreas', 1),
#   ('spleen', 1),
#   ('kidneys', 1),
#   ('genital', 1),
#   ('abdominal', 1),
#   ('spine', 1)],
#  [('level', 1),
#   ('practice', 1),
#   ('physical', 1),
#   ('dynamic', 1),
#   ('processes', 1),
#   ('flexible', 1),
#   ('benefits', 1),
#   ('paschimottanasana', 1),
#   ('metabolic', 1),
#   ('addition', 1),
#   ('speeds', 1),
#   ('circulation', 1),
#   ('pranic', 1),
#   ('energy', 1),
#   ('body', 1)],
#  [('upper', 1),
#   ('benefits', 1),
#   ('paschimottanasana', 1),
#   ('blades', 1),
#   ('stretch', 1),
#   ('asana', 1),
#   ('effect', 1),
#   ('legs', 1),
#   ('shoulder', 1),
#   ('lower', 1),
#   ('parts', 1),
#   ('muscles', 1),
#   ('chest', 1),
#   ('body', 1)],
#  [('practice', 1),
#   ('paschimottanasana', 1),
#   ('asanas', 1),
#   ('loosening', 1),
#   ('legs', 1),
#   ('meditation', 1),
#   ('preparation', 1)],
#  [('intense', 1),
#   ('hips', 1),
#   ('meditation', 1),
#   ('sirshasana', 1),
#   ('identical', 1),
#   ('constipation', 1),
#   ('turn', 1),
#   ('bent', 1),
#   ('leg', 1),
#   ('janu', 1),
#   ('massage', 1),
#   ('benefits', 1),
#   ('asanas', 1),
#   ('asana', 1),
#   ('peristalsis', 1),
#   ('characteristic', 1),
#   ('foot', 1),
#   ('paschimottanasana', 1),
#   ('alleviate', 1),
#   ('legs', 1),
#   ('distinct', 1),
#   ('abdominal', 1),
#   ('organs', 1),
#   ('intestinal', 1)],
#  [('proper', 1),
#   ('excess', 1),
#   ('hips', 1),
#   ('development', 1),
#   ('flexible', 1),
#   ('coordination', 1),
#   ('balance', 1),
#   ('young', 1),
#   ('practice', 1),
#   ('thighs', 1),
#   ('girls', 1),
#   ('hip', 1),
#   ('steady', 1),
#   ('joints', 1),
#   ('weight', 1),
#   ('graceful', 1),
#   ('pelvis', 1),
#   ('sense', 1),
#   ('posture', 1)],
#  [('hips', 1),
#   ('thigh', 1),
#   ('reduces', 1),
#   ('stronger', 1),
#   ('flexible', 1),
#   ('coordination', 1),
#   ('balance', 1),
#   ('thighs', 1),
#   ('inner', 1),
#   ('sides', 1),
#   ('asana', 1),
#   ('muscles', 1),
#   ('body', 1),
#   ('steady', 1),
#   ('weight', 1),
#   ('graceful', 1),
#   ('sense', 1),
#   ('abdominal', 1),
#   ('posture', 1)],
#  [('hamstring', 1),
#   ('weight', 1),
#   ('area', 1),
#   ('waist', 1),
#   ('nervous', 1),
#   ('complaints', 1),
#   ('blades', 1),
#   ('cles', 1),
#   ('asana', 1),
#   ('stretch', 1),
#   ('lateral', 1),
#   ('shoulder', 1),
#   ('appetite', 1),
#   ('abdominal', 1),
#   ('thigh', 1),
#   ('excess', 1),
#   ('mus', 1),
#   ('body', 1)],
#  [('hamstring', 1),
#   ('joints', 1),
#   ('pancreas', 1),
#   ('stimulates', 1),
#   ('nerves', 1),
#   ('massages', 1),
#   ('asana', 1),
#   ('brain', 1),
#   ('spinal', 1),
#   ('muscles', 1),
#   ('hip', 1)],
#  [('hamstring', 1),
#   ('joints', 1),
#   ('flexible', 1),
#   ('adrenals', 1),
#   ('asana', 1),
#   ('muscles', 1),
#   ('hip', 1),
#   ('tones', 1)],
#  [('beginners', 1),
#   ('pain', 1),
#   ('twists', 1),
#   ('vertebrae', 1),
#   ('wakrasana', 1),
#   ('meru', 1),
#   ('lumbago', 1),
#   ('nerves', 1),
#   ('neck', 1),
#   ('asana', 1),
#   ('mild', 1),
#   ('loosening', 1),
#   ('forms', 1),
#   ('spine', 1),
#   ('spinal', 1),
#   ('difficult', 1),
#   ('good', 1)],
#  [('nerves', 1), ('asana', 1), ('spine', 1), ('muscles', 1), ('supple', 1)],
#  [('abdomen', 1),
#   ('tendency', 1),
#   ('adjoining', 1),
#   ('gland', 1),
#   ('musrular', 1),
#   ('massages', 1),
#   ('digestive', 1),
#   ('beneficial', 1),
#   ('tones', 1),
#   ('problems', 1),
#   ('vertebrae', 1),
#   ('relieves', 1),
#   ('calcium', 1),
#   ('deposits', 1),
#   ('secretions', 1),
#   ('adrenal', 1),
#   ('liver', 1),
#   ('spasms', 1),
#   ('ailments', 1),
#   ('asana', 1),
#   ('muscles', 1),
#   ('inflammatory', 1),
#   ('pancreas', 1),
#   ('nerves', 1),
#   ('kidneys', 1)],
#  [('shoulders', 1),
#   ('compression', 1),
#   ('long', 1),
#   ('hamstrings', 1),
#   ('stretch', 1),
#   ('asana', 1),
#   ('asanas', 1),
#   ('lateral', 1),
#   ('abdominal', 1),
#   ('muscles', 1),
#   ('hours', 1),
#   ('meditation', 1),
#   ('beneficial', 1),
#   ('organs', 1),
#   ('body', 1)],
#  [],
#  [],
#  [('low', 1),
#   ('sirshasana', 1),
#   ('crown', 1),
#   ('pressure', 1),
#   ('influx', 1),
#   ('accustoms', 1),
#   ('strengthens', 1),
#   ('preliminary', 1),
#   ('nervous', 1),
#   ('neck', 1),
#   ('asana', 1),
#   ('brain', 1),
#   ('cases', 1),
#   ('muscles', 1),
#   ('body', 1),
#   ('blood', 1),
#   ('rich', 1),
#   ('supply', 1),
#   ('weight', 1)],
#  [('gland', 1),
#   ('low', 1),
#   ('chakra', 1),
#   ('sirshasana', 1),
#   ('crown', 1),
#   ('pressure', 1),
#   ('influx', 1),
#   ('vishuddhi', 1),
#   ('spiritual', 1),
#   ('accustoms', 1),
#   ('strengthens', 1),
#   ('preliminary', 1),
#   ('nervous', 1),
#   ('neck', 1),
#   ('asana', 1),
#   ('brain', 1),
#   ('cases', 1),
#   ('breath', 1),
#   ('muscles', 1),
#   ('body', 1),
#   ('blood', 1),
#   ('rich', 1),
#   ('supply', 1),
#   ('weight', 1),
#   ('thyroid', 1)],
#  [('effective', 1),
#   ('additional', 1),
#   ('sarvangasana', 1),
#   ('piles', 1),
#   ('internal', 1),
#   ('treatment', 1),
#   ('stretch', 1),
#   ('balance', 1),
#   ('free', 1),
#   ('pelvic', 1),
#   ('drainage', 1),
#   ('coordinates', 1),
#   ('leg', 1),
#   ('massage', 1),
#   ('asana', 1),
#   ('region', 1),
#   ('muscles', 1),
#   ('blood', 1),
#   ('sense', 1),
#   ('legs', 1),
#   ('veins', 1),
#   ('organs', 1)],
#  [('halasana', 1),
#   ('weight', 1),
#   ('intestines', 1),
#   ('kidneys', 1),
#   ('excess', 1),
#   ('pelvis', 1),
#   ('preparatory', 1),
#   ('good', 1)],
#  [('place', 1),
#   ('massages', 1),
#   ('production', 1),
#   ('constipation', 1),
#   ('internal', 1),
#   ('kidney', 1),
#   ('suprarenal', 1),
#   ('liver', 1),
#   ('halasana', 1),
#   ('glands', 1),
#   ('practice', 1),
#   ('digestion', 1),
#   ('diaphragm', 1),
#   ('insulin', 1),
#   ('movement', 1),
#   ('spasms', 1),
#   ('muscles', 1),
#   ('function', 1),
#   ('pancreas', 1),
#   ('abdominal', 1),
#   ('dyspepsia', 1),
#   ('organs', 1)],
#  [('gall', 1),
#   ('constipation', 1),
#   ('pelvic', 1),
#   ('facilitates', 1),
#   ('abdomin', 1),
#   ('liver', 1),
#   ('halasana', 1),
#   ('fats', 1),
#   ('al', 1),
#   ('practice', 1),
#   ('benefits', 1),
#   ('diges', 1),
#   ('bladder', 1),
#   ('region', 1),
#   ('tion', 1),
#   ('peristalsis', 1),
#   ('muscles', 1),
#   ('paschimottanasana', 1),
#   ('intestinal', 1)],
#  [('fats', 1),
#   ('al', 1),
#   ('constipation', 1),
#   ('diges', 1),
#   ('facilitates', 1),
#   ('bladder', 1),
#   ('region', 1),
#   ('tion', 1),
#   ('gall', 1),
#   ('pelvic', 1),
#   ('peristalsis', 1),
#   ('muscles', 1),
#   ('abdomin', 1),
#   ('intestinal', 1),
#   ('liver', 1)],
#  [('fats', 1),
#   ('al', 1),
#   ('constipation', 1),
#   ('diges', 1),
#   ('facilitates', 1),
#   ('bladder', 1),
#   ('region', 1),
#   ('tion', 1),
#   ('gall', 1),
#   ('pelvic', 1),
#   ('peristalsis', 1),
#   ('muscles', 1),
#   ('abdomin', 1),
#   ('intestinal', 1),
#   ('liver', 1)],
#  [('form', 1),
#   ('deep', 1),
#   ('gravity', 1),
#   ('effect', 1),
#   ('chakra', 1),
#   ('cause', 1),
#   ('eration', 1),
#   ('sirshasana', 1),
#   ('awakening', 1),
#   ('flow', 1),
#   ('disorders', 1),
#   ('disorder', 1),
#   ('regions', 1),
#   ('reversed', 1),
#   ('exhalation', 1),
#   ('root', 1),
#   ('sahasrara', 1),
#   ('greatest', 1),
#   ('dioxide', 1),
#   ('visceral', 1),
#   ('nervous', 1),
#   ('diaphragm', 1),
#   ('asanas', 1),
#   ('asana', 1),
#   ('entire', 1)],
#  [('form', 1),
#   ('deep', 1),
#   ('gravity', 1),
#   ('effect', 1),
#   ('chakra', 1),
#   ('cause', 1),
#   ('eration', 1),
#   ('sirshasana', 1),
#   ('awakening', 1),
#   ('flow', 1),
#   ('disorders', 1),
#   ('disorder', 1),
#   ('regions', 1),
#   ('reversed', 1),
#   ('exhalation', 1),
#   ('root', 1),
#   ('sahasrara', 1),
#   ('greatest', 1),
#   ('dioxide', 1),
#   ('visceral', 1),
#   ('nervous', 1),
#   ('diaphragm', 1),
#   ('asanas', 1),
#   ('asana', 1),
#   ('entire', 1)],
#  [('form', 1),
#   ('deep', 1),
#   ('gravity', 1),
#   ('effect', 1),
#   ('chakra', 1),
#   ('cause', 1),
#   ('eration', 1),
#   ('sirshasana', 1),
#   ('awakening', 1),
#   ('flow', 1),
#   ('disorders', 1),
#   ('disorder', 1),
#   ('regions', 1),
#   ('reversed', 1),
#   ('exhalation', 1),
#   ('root', 1),
#   ('sahasrara', 1),
#   ('greatest', 1),
#   ('dioxide', 1),
#   ('visceral', 1),
#   ('nervous', 1),
#   ('diaphragm', 1),
#   ('asanas', 1),
#   ('asana', 1),
#   ('entire', 1)],
#  [('blood', 1),
#   ('internal', 1),
#   ('expansion', 1),
#   ('massages', 1),
#   ('asana', 1),
#   ('region', 1),
#   ('legs', 1),
#   ('sense', 1),
#   ('balance', 1),
#   ('free', 1),
#   ('pelvic', 1),
#   ('drainage', 1),
#   ('coordinates', 1),
#   ('sirshasana', 1),
#   ('leg', 1),
#   ('muscles', 1),
#   ('organs', 1),
#   ('chest', 1)],
#  [('form', 1),
#   ('deep', 1),
#   ('gravity', 1),
#   ('effect', 1),
#   ('chakra', 1),
#   ('cause', 1),
#   ('eration', 1),
#   ('sirshasana', 1),
#   ('awakening', 1),
#   ('flow', 1),
#   ('disorders', 1),
#   ('disorder', 1),
#   ('regions', 1),
#   ('reversed', 1),
#   ('exhalation', 1),
#   ('root', 1),
#   ('sahasrara', 1),
#   ('greatest', 1),
#   ('dioxide', 1),
#   ('visceral', 1),
#   ('nervous', 1),
#   ('diaphragm', 1),
#   ('asanas', 1),
#   ('asana', 1),
#   ('entire', 1)],
#  [('foot', 1),
#   ('nervous', 1),
#   ('asana', 1),
#   ('balance', 1),
#   ('ankle', 1),
#   ('leg', 1),
#   ('muscles', 1),
#   ('streng', 1),
#   ('thens', 1)],
#  [('balance', 1), ('nervous', 1), ('concentration', 1), ('natavarasana', 1)],
#  [('arms', 1),
#   ('garudasana', 1),
#   ('joints', 1),
#   ('concentration', 1),
#   ('upper', 1),
#   ('legs', 1),
#   ('muscles', 1),
#   ('good', 1)],
#  [('control', 1),
#   ('mental', 1),
#   ('concentration', 1),
#   ('develops', 1),
#   ('nervous', 1),
#   ('asana', 1),
#   ('legs', 1),
#   ('balances', 1),
#   ('body', 1)],
#  [('arms', 1),
#   ('concentration', 1),
#   ('shoulders', 1),
#   ('hips', 1),
#   ('coordination', 1),
#   ('asana', 1),
#   ('sense', 1),
#   ('legs', 1),
#   ('balance', 1)],
#  [('arms', 1),
#   ('concentration', 1),
#   ('shoulders', 1),
#   ('hips', 1),
#   ('coordination', 1),
#   ('asana', 1),
#   ('sense', 1),
#   ('legs', 1),
#   ('balance', 1)],
#  [('arms', 1),
#   ('concentration', 1),
#   ('muscular', 1),
#   ('nervous', 1),
#   ('wrists', 1),
#   ('hips', 1),
#   ('asana', 1),
#   ('coordina', 1),
#   ('balance', 1),
#   ('tion', 1),
#   ('leg', 1),
#   ('muscles', 1)],
#  [('blood', 1),
#   ('concentration', 1),
#   ('compression', 1),
#   ('nervous', 1),
#   ('coordination', 1),
#   ('balance', 1),
#   ('abdominal', 1),
#   ('leg', 1),
#   ('circulation', 1),
#   ('muscles', 1),
#   ('organs', 1),
#   ('hip', 1),
#   ('beneficial', 1)],
#  [('ed', 1),
#   ('joints', 1),
#   ('concentration', 1),
#   ('muscular', 1),
#   ('knee', 1),
#   ('nervous', 1),
#   ('hamstrings', 1),
#   ('hips', 1),
#   ('balance', 1),
#   ('ankle', 1),
#   ('coordinates', 1),
#   ('leg', 1),
#   ('muscles', 1)],
#  [('sympathetic', 1),
#   ('tiredness', 1),
#   ('intestinal', 1),
#   ('knees', 1),
#   ('tones', 1),
#   ('constipation', 1),
#   ('systems', 1),
#   ('balance', 1),
#   ('nervous', 1),
#   ('asana', 1),
#   ('lightness', 1),
#   ('peristalsis', 1),
#   ('muscles', 1),
#   ('legs', 1),
#   ('abdominal', 1),
#   ('spine', 1),
#   ('organs', 1),
#   ('parasympathetic', 1),
#   ('good', 1)],
#  [('ofbalance', 1),
#   ('similar', 1),
#   ('paschimottan', 1),
#   ('benefits', 1),
#   ('asana', 1),
#   ('sense', 1),
#   ('addition', 1)],
#  [('constipation', 1),
#   ('sense', 1),
#   ('asana', 1),
#   ('balance', 1),
#   ('peristalsis', 1),
#   ('intestinal', 1)],
#  [('constipation', 1),
#   ('blood', 1),
#   ('digestion', 1),
#   ('stimulates', 1),
#   ('asana', 1),
#   ('legs', 1),
#   ('circulation', 1)],
#  [('joints', 1),
#   ('knee', 1),
#   ('ability', 1),
#   ('asana', 1),
#   ('seminal', 1),
#   ('brahmacharya', 1),
#   ('leg', 1),
#   ('fluid', 1),
#   ('muscles', 1),
#   ('maintenance', 1)],
#  [('strengthens', 1),
#   ('concentration', 1),
#   ('toes', 1),
#   ('asana', 1),
#   ('reproductive', 1),
#   ('brahmacharya', 1),
#   ('ankles', 1)],
#  [('arms', 1),
#   ('physical', 1),
#   ('nervous', 1),
#   ('wrists', 1),
#   ('asana', 1),
#   ('sense', 1),
#   ('balance', 1),
#   ('balances', 1),
#   ('streng', 1)],
#  [],
#  [('flexibility', 1),
#   ('abdomen', 1),
#   ('joints', 1),
#   ('arm', 1),
#   ('pancreas', 1),
#   ('visceral', 1),
#   ('massages', 1),
#   ('asana', 1),
#   ('shoulder', 1),
#   ('muscles', 1),
#   ('organs', 1),
#   ('lower', 1)],
#  [('flexibility', 1),
#   ('strengthens', 1),
#   ('preservation', 1),
#   ('shoulders', 1),
#   ('contract', 1),
#   ('asana', 1),
#   ('energy', 1),
#   ('abdominal', 1),
#   ('perin', 1),
#   ('eum', 1),
#   ('purposes', 1),
#   ('spiritual', 1),
#   ('muscles', 1),
#   ('organs', 1),
#   ('sexual', 1),
#   ('lower', 1),
#   ('tones', 1)],
#  [('massages', 1),
#   ('digestive', 1),
#   ('hamsasana', 1),
#   ('abdominal', 1),
#   ('healthy', 1),
#   ('muscles', 1),
#   ('organs', 1),
#   ('beneficial', 1)],
#  [('arms', 1),
#   ('inner', 1),
#   ('equilibrium', 1),
#   ('harmony', 1),
#   ('shoulders', 1),
#   ('nervous', 1),
#   ('sense', 1),
#   ('asana', 1),
#   ('balance', 1),
#   ('muscles', 1)],
#  [('arms', 1),
#   ('nervous', 1),
#   ('asana', 1),
#   ('balance', 1),
#   ('leg', 1),
#   ('muscles', 1),
#   ('supple', 1),
#   ('lower', 1),
#   ('tones', 1)],
#  [('effect', 1),
#   ('manipura', 1),
#   ('beneficial', 1),
#   ('ovaries', 1),
#   ('tones', 1),
#   ('level', 1),
#   ('anahata', 1),
#   ('vishuddhi', 1),
#   ('healthy', 1),
#   ('swadhisthana', 1),
#   ('uterus', 1),
#   ('asana', 1),
#   ('strong', 1),
#   ('kidneys', 1),
#   ('abdominal', 1),
#   ('spine', 1),
#   ('pranic', 1),
#   ('organs', 1),
#   ('supple', 1)],
#  [('abdomen', 1),
#   ('surrender', 1),
#   ('passion', 1),
#   ('tones', 1),
#   ('mental', 1),
#   ('ache', 1),
#   ('flatulence', 1),
#   ('security', 1),
#   ('relaxation', 1),
#   ('head', 1),
#   ('consti', 1),
#   ('subside', 1),
#   ('practice', 1),
#   ('composure', 1),
#   ('inner', 1),
#   ('neck', 1),
#   ('pation', 1),
#   ('helpful', 1),
#   ('introversion', 1),
#   ('circulation', 1),
#   ('diabetes', 1),
#   ('body', 1),
#   ('nerves', 1),
#   ('anger', 1),
#   ('koormasana', 1)],
#  [('stomach', 1),
#   ('mudra', 1),
#   ('poorna', 1),
#   ('buttocks', 1),
#   ('body', 1),
#   ('benefits', 1),
#   ('bowels', 1),
#   ('asanas', 1),
#   ('muscles', 1),
#   ('abdominal', 1),
#   ('appetite', 1),
#   ('pelvic', 1),
#   ('balances', 1),
#   ('shalabhasana', 1),
#   ('organs', 1),
#   ('liver', 1),
#   ('tones', 1)],
#  [],
#  [('arms', 1),
#   ('tension', 1),
#   ('people', 1),
#   ('joints', 1),
#   ('excellent', 1),
#   ('neck', 1),
#   ('asana', 1),
#   ('loosening', 1),
#   ('legs', 1),
#   ('abdominal', 1),
#   ('helpful', 1),
#   ('organs', 1),
#   ('supple', 1),
#   ('hip', 1),
#   ('tones', 1)],
#  [('nerves', 1),
#   ('toning', 1),
#   ('asana', 1),
#   ('legs', 1),
#   ('abdominal', 1),
#   ('balance', 1),
#   ('spine', 1),
#   ('circulation', 1),
#   ('muscles', 1),
#   ('organs', 1),
#   ('streng', 1)],
#  [('abdomen', 1),
#   ('trunk', 1),
#   ('fat', 1),
#   ('massages', 1),
#   ('accumulation', 1),
#   ('stretch', 1),
#   ('region', 1),
#   ('lateral', 1),
#   ('abdominal', 1),
#   ('pelvic', 1),
#   ('posture', 1),
#   ('skin', 1),
#   ('muscles', 1),
#   ('organs', 1),
#   ('good', 1)],
#  [('cardiovascular', 1),
#   ('disorders', 1),
#   ('respiratory', 1),
#   ('glandular', 1),
#   ('systems', 1),
#   ('nervous', 1),
#   ('gynaecological', 1),
#   ('digestive', 1),
#   ('legs', 1),
#   ('onal', 1),
#   ('secretions', 1),
#   ('chakrasana', 1),
#   ('beneficial', 1),
#   ('influences', 1)],
#  [('flexibility', 1),
#   ('n', 1),
#   ('blood', 1),
#   ('area', 1),
#   ('massages', 1),
#   ('legs', 1),
#   ('abdominal', 1),
#   ('reproductive', 1),
#   ('pelvic', 1),
#   ('circulation', 1),
#   ('organs', 1),
#   ('supple', 1),
#   ('tones', 1)],
#  [('arms', 1),
#   ('important', 1),
#   ('mudra', 1),
#   ('contract', 1),
#   ('ashwini', 1),
#   ('moola', 1),
#   ('asana', 1),
#   ('vajroli', 1),
#   ('abdominal', 1),
#   ('bandha', 1),
#   ('purposes', 1),
#   ('perineum', 1),
#   ('spiritual', 1),
#   ('muscles', 1),
#   ('organs', 1),
#   ('sexual', 1),
#   ('energy', 1),
#   ('conservation', 1)],
#  [('thighs', 1), ('neck', 1), ('sense', 1), ('balance', 1), ('grivasana', 1)],
#  [('blood', 1),
#   ('excellent', 1),
#   ('stimulates', 1),
#   ('nerves', 1),
#   ('neck', 1),
#   ('asana', 1),
#   ('abdominal', 1),
#   ('relaxation', 1),
#   ('spinal', 1),
#   ('thigh', 1),
#   ('circulation', 1),
#   ('muscles', 1),
#   ('supple', 1),
#   ('strong', 1)],
#  [('abdomen', 1),
#   ('tendency', 1),
#   ('adjoining', 1),
#   ('gland', 1),
#   ('massages', 1),
#   ('digestive', 1),
#   ('beneficial', 1),
#   ('tones', 1),
#   ('problems', 1),
#   ('vertebrae', 1),
#   ('relieves', 1),
#   ('muscular', 1),
#   ('calcium', 1),
#   ('deposits', 1),
#   ('secretions', 1),
#   ('adrenal', 1),
#   ('liver', 1),
#   ('spasms', 1),
#   ('ailments', 1),
#   ('asana', 1),
#   ('muscles', 1),
#   ('inflammatory', 1),
#   ('pancreas', 1),
#   ('nerves', 1),
#   ('kidneys', 1)],
#  [('physical', 1),
#   ('pitta', 1),
#   ('digestive', 1),
#   ('sluggishness', 1),
#   ('metabolic', 1),
#   ('elimination', 1),
#   ('useful', 1),
#   ('mental', 1),
#   ('constipation', 1),
#   ('muscular', 1),
#   ('processes', 1),
#   ('toxins', 1),
#   ('flatulence', 1),
#   ('different', 1),
#   ('removal', 1),
#   ('balance', 1),
#   ('wind', 1),
#   ('vata', 1),
#   ('liver', 1),
#   ('glands', 1),
#   ('control', 1),
#   ('harmonizes', 1),
#   ('harmony', 1),
#   ('stimulates', 1),
#   ('asana', 1)],
#  [],
#  [('important', 1),
#   ('tones', 1),
#   ('moola', 1),
#   ('asana', 1),
#   ('bandha', 1),
#   ('chakra', 1),
#   ('reproductive', 1),
#   ('eliminatory', 1),
#   ('legs', 1),
#   ('supple', 1),
#   ('feet', 1),
#   ('organs', 1),
#   ('sexual', 1),
#   ('energy', 1),
#   ('conservation', 1)],
#  [('reverses', 1),
#   ('meditative', 1),
#   ('states', 1),
#   ('centres', 1),
#   ('apana', 1),
#   ('asana', 1),
#   ('legs', 1),
#   ('supple', 1),
#   ('feet', 1),
#   ('higher', 1)],
#  [('control', 1),
#   ('abdomen', 1),
#   ('reverses', 1),
#   ('celibacy', 1),
#   ('arm', 1),
#   ('wrists', 1),
#   ('apana', 1),
#   ('asana', 1),
#   ('energy', 1),
#   ('muscles', 1),
#   ('chakra', 1),
#   ('brahmacharya', 1),
#   ('manipura', 1),
#   ('leg', 1),
#   ('netvous', 1),
#   ('mind', 1),
#   ('body', 1)],
#  [('abdomen', 1),
#   ('physical', 1),
#   ('gland', 1),
#   ('prana', 1),
#   ('vrischikasana', 1),
#   ('lower', 1),
#   ('tones', 1),
#   ('flow', 1),
#   ('systems', 1),
#   ('balance', 1),
#   ('loosens', 1),
#   ('pituitary', 1),
#   ('process', 1),
#   ('strengthens', 1),
#   ('arms', 1),
#   ('brain', 1),
#   ('circulation', 1),
#   ('ing', 1),
#   ('body', 1),
#   ('blood', 1),
#   ('position', 1),
#   ('nerves', 1),
#   ('limbs', 1),
#   ('sense', 1),
#   ('reproductive', 1)],
#  [('abdomen', 1),
#   ('tones', 1),
#   ('level', 1),
#   ('constipation', 1),
#   ('internal', 1),
#   ('vitalizing', 1),
#   ('energy', 1),
#   ('asana', 1),
#   ('varicose', 1),
#   ('circulation', 1),
#   ('peristalsis', 1),
#   ('body', 1),
#   ('blood', 1),
#   ('chakras', 1),
#   ('legs', 1),
#   ('veins', 1),
#   ('ductive', 1),
#   ('organs', 1),
#   ('mind', 1)],
#  [('concentration', 1),
#   ('pada', 1),
#   ('asana', 1),
#   ('addition', 1),
#   ('thigh', 1),
#   ('muscles', 1),
#   ('eka', 1),
#   ('sirasana', 1)],
#  [],
#  [('glands', 1),
#   ('organs', 1),
#   ('systems', 1),
#   ('nervous', 1),
#   ('digestive', 1),
#   ('asana', 1),
#   ('vitality', 1),
#   ('mas', 1),
#   ('abdominal', 1),
#   ('pelvic', 1),
#   ('plexus', 1),
#   ('efficiency', 1),
#   ('adrenal', 1),
#   ('reproductive', 1),
#   ('solar', 1),
#   ('eliminatory', 1),
#   ('tones', 1)],
#  [('benefits', 1),
#   ('sense', 1),
#   ('asana', 1),
#   ('balance', 1),
#   ('addition', 1),
#   ('padmasana', 1)],
#  [('arms', 1),
#   ('vayu', 1),
#   ('concentration', 1),
#   ('samana', 1),
#   ('shoulders', 1),
#   ('anahata', 1),
#   ('chakras', 1),
#   ('asana', 1),
#   ('sense', 1),
#   ('legs', 1),
#   ('balance', 1),
#   ('manipura', 1),
#   ('chest', 1)],
#  [('arms', 1),
#   ('sciatic', 1),
#   ('internal', 1),
#   ('concentration', 1),
#   ('nerves', 1),
#   ('asana', 1),
#   ('sense', 1),
#   ('legs', 1),
#   ('balance', 1),
#   ('muscles', 1),
#   ('organs', 1),
#   ('tones', 1)],
#  [('hemisphere', 1),
#   ('slow', 1),
#   ('profound', 1),
#   ('breathing', 1),
#   ('flow', 1),
#   ('minor', 1),
#   ('activates', 1),
#   ('awareness', 1),
#   ('blockages', 1),
#   ('technique', 1),
#   ('brain', 1),
#   ('breath', 1),
#   ('right', 1),
#   ('energies', 1),
#   ('stage', 1),
#   ('balanced', 1),
#   ('nostril', 1),
#   ('sensitivity', 1),
#   ('effects', 1),
#   ('nostrils', 1)],
#  [('centres', 1),
#   ('prana', 1),
#   ('thirst', 1),
#   ('flow', 1),
#   ('important', 1),
#   ('mental', 1),
#   ('sleep', 1),
#   ('muscular', 1),
#   ('free', 1),
#   ('relaxation', 1),
#   ('biological', 1),
#   ('hunger', 1),
#   ('control', 1),
#   ('practice', 1),
#   ('temperature', 1),
#   ('tranquillizer', 1),
#   ('brain', 1),
#   ('excitation', 1),
#   ('emotional', 1),
#   ('cools', 1),
#   ('satisfaction', 1),
#   ('body', 1),
#   ('tranquillity', 1),
#   ('regulation', 1)],
#  [],
#  [('insomnia', 1),
#   ('effect', 1),
#   ('voice', 1),
#   ('healing', 1),
#   ('awareness', 1),
#   ('capacity', 1),
#   ('strengthens', 1),
#   ('tension', 1),
#   ('meditative', 1),
#   ('bhramari', 1),
#   ('nen', 1),
#   ('state', 1),
#   ('body', 1),
#   ('sound', 1),
#   ('cerebral', 1),
#   ('ous', 1),
#   ('anger', 1),
#   ('vibration', 1),
#   ('anxiety', 1),
#   ('mind', 1)],
#  [('insomnia', 1),
#   ('psychic', 1),
#   ('effect', 1),
#   ('useful', 1),
#   ('pressure', 1),
#   ('people', 1),
#   ('level', 1),
#   ('sleep', 1),
#   ('heart', 1),
#   ('soothes', 1),
#   ('practice', 1),
#   ('nervous', 1),
#   ('tranquillizing', 1),
#   ('high', 1),
#   ('calms', 1),
#   ('body', 1),
#   ('heating', 1),
#   ('blood', 1),
#   ('pranayama', 1),
#   ('rate', 1),
#   ('shavasana', 1)],
#  [('proper', 1),
#   ('air', 1),
#   ('pitta', 1),
#   ('massages', 1),
#   ('digestive', 1),
#   ('metabolic', 1),
#   ('meditation', 1),
#   ('organs', 1),
#   ('useful', 1),
#   ('level', 1),
#   ('bhastrika', 1),
#   ('toxins', 1),
#   ('exchange', 1),
#   ('wind', 1),
#   ('rapid', 1),
#   ('vata', 1),
#   ('mind', 1),
#   ('onepointedness', 1),
#   ('practice', 1),
#   ('dioxide', 1),
#   ('visceral', 1),
#   ('stimulates', 1),
#   ('diaphragm', 1),
#   ('rhythmic', 1),
#   ('movement', 1)],
#  [('respiratory', 1),
#   ('digestive', 1),
#   ('kapalbhati', 1),
#   ('effect', 1),
#   ('purifies', 1),
#   ('tones', 1),
#   ('mental', 1),
#   ('disorders', 1),
#   ('energizes', 1),
#   ('sensory', 1),
#   ('distractions', 1),
#   ('practice', 1),
#   ('nadis', 1),
#   ('work', 1),
#   ('sleepiness', 1),
#   ('nervous', 1),
#   ('cleansing', 1),
#   ('organs', 1),
#   ('good', 1)],
#  [('physical', 1),
#   ('psychic', 1),
#   ('prana', 1),
#   ('moorchha', 1),
#   ('meditation', 1),
#   ('mental', 1),
#   ('level', 1),
#   ('excellent', 1),
#   ('distractions', 1),
#   ('world', 1),
#   ('tension', 1),
#   ('cuts', 1),
#   ('inhibits', 1),
#   ('body', 1),
#   ('state', 1),
#   ('inwards', 1),
#   ('neuroses', 1),
#   ('pranayama', 1),
#   ('tranquillity', 1),
#   ('anger', 1),
#   ('identification', 1),
#   ('preparation', 1),
#   ('anxiety', 1),
#   ('mind', 1)],
#  [('physical', 1),
#   ('imbalances', 1),
#   ('activities', 1),
#   ('communicate', 1),
#   ('alert', 1),
#   ('meditation', 1),
#   ('nadi', 1),
#   ('depression', 1),
#   ('excellent', 1),
#   ('dynamism', 1),
#   ('wind', 1),
#   ('vata', 1),
#   ('energy', 1),
#   ('world', 1),
#   ('mind', 1),
#   ('practice', 1),
#   ('stimulates', 1),
#   ('external', 1),
#   ('pingala', 1),
#   ('lethargic', 1),
#   ('difficult', 1),
#   ('extroversion', 1),
#   ('perceptive', 1),
#   ('body', 1),
#   ('dull', 1)],
#  [('neural', 1),
#   ('nerve', 1),
#   ('circuit', 1),
#   ('area', 1),
#   ('index', 1),
#   ('experience', 1),
#   ('prana', 1),
#   ('psycho', 1),
#   ('chakra', 1),
#   ('practitioner', 1),
#   ('meditation', 1),
#   ('nadi', 1),
#   ('maintains', 1),
#   ('chest', 1),
#   ('finger', 1),
#   ('knees', 1),
#   ('receptivity', 1),
#   ('important', 1),
#   ('mudra', 1),
#   ('endings', 1),
#   ('addition', 1),
#   ('perineum', 1),
#   ('energy', 1),
#   ('root', 1),
#   ('simple', 1)],
#  [('neural', 1),
#   ('nerve', 1),
#   ('circuit', 1),
#   ('area', 1),
#   ('index', 1),
#   ('experience', 1),
#   ('prana', 1),
#   ('psycho', 1),
#   ('chakra', 1),
#   ('practitioner', 1),
#   ('meditation', 1),
#   ('nadi', 1),
#   ('maintains', 1),
#   ('chest', 1),
#   ('finger', 1),
#   ('knees', 1),
#   ('receptivity', 1),
#   ('important', 1),
#   ('mudra', 1),
#   ('endings', 1),
#   ('addition', 1),
#   ('perineum', 1),
#   ('energy', 1),
#   ('root', 1),
#   ('simple', 1)],
#  [('physical', 1),
#   ('hand', 1),
#   ('area', 1),
#   ('index', 1),
#   ('activities', 1),
#   ('point', 1),
#   ('prana', 1),
#   ('complete', 1),
#   ('meditation', 1),
#   ('intensifies', 1),
#   ('stable', 1),
#   ('chest', 1),
#   ('mudra', 1),
#   ('concentration', 1),
#   ('internal', 1),
#   ('balance', 1),
#   ('relaxation', 1),
#   ('awareness', 1),
#   ('practice', 1),
#   ('cross', 1),
#   ('brain', 1),
#   ('right', 1),
#   ('energies', 1),
#   ('body', 1),
#   ('vice', 1)],
#  [('consciousness', 1),
#   ('mudra', 1),
#   ('practice', 1),
#   ('pranayama', 1),
#   ('prano', 1),
#   ('bhairava', 1),
#   ('hands', 1),
#   ('dis', 1),
#   ('ida', 1),
#   ('pingala', 1),
#   ('meditation', 1),
#   ('union', 1),
#   ('supreme', 1),
#   ('individual', 1)],
#  [('circuit', 1),
#   ('area', 1),
#   ('prana', 1),
#   ('fmgers', 1),
#   ('hridaya', 1),
#   ('beneficial', 1),
#   ('flow', 1),
#   ('mudra', 1),
#   ('heart', 1),
#   ('ring', 1),
#   ('simple', 1),
#   ('nadis', 1),
#   ('thumb', 1),
#   ('diverts', 1),
#   ('emotional', 1),
#   ('acts', 1),
#   ('unburden', 1),
#   ('middle', 1),
#   ('acute', 1),
#   ('conflict', 1),
#   ('situations', 1),
#   ('crisis', 1),
#   ('emotion', 1),
#   ('hands', 1),
#   ('vitality', 1)],
#  [('thoughtlessness', 1),
#   ('tension', 1),
#   ('mudra', 1),
#   ('mind', 1),
#   ('mental', 1),
#   ('concentration', 1),
#   ('stability', 1),
#   ('area', 1),
#   ('anger', 1),
#   ('emotional', 1),
#   ('stress', 1),
#   ('muscles', 1),
#   ('eye', 1),
#   ('calms', 1),
#   ('state', 1)],
#  [('aware', 1),
#   ('nosetip', 1),
#   ('drishti', 1),
#   ('psychic', 1),
#   ('concentrates', 1),
#   ('practitioner', 1),
#   ('mudra', 1),
#   ('concentration', 1),
#   ('excellent', 1),
#   ('powers', 1),
#   ('nasikagra', 1),
#   ('spiritual', 1),
#   ('world', 1),
#   ('aim', 1),
#   ('consciousness', 1),
#   ('practice', 1),
#   ('meditative', 1),
#   ('calming', 1),
#   ('technique', 1),
#   ('eyes', 1),
#   ('open', 1),
#   ('states', 1),
#   ('anger', 1),
#   ('introspection', 1),
#   ('planes', 1)],
#  [('kundalini', 1),
#   ('number', 1),
#   ('points', 1),
#   ('awaken', 1),
#   ('prana', 1),
#   ('shakti', 1),
#   ('beneficial', 1),
#   ('thirst', 1),
#   ('nasal', 1),
#   ('hormones', 1),
#   ('pressure', 1),
#   ('khechari', 1),
#   ('mudra', 1),
#   ('cavity', 1),
#   ('healing', 1),
#   ('stillness', 1),
#   ('hunger', 1),
#   ('glands', 1),
#   ('practice', 1),
#   ('inner', 1),
#   ('certain', 1),
#   ('calm', 1),
#   ('saliva', 1),
#   ('body', 1),
#   ('state', 1)],
#  [('tensions', 1),
#   ('air', 1),
#   ('drishti', 1),
#   ('digestive', 1),
#   ('lips', 1),
#   ('mental', 1),
#   ('mudra', 1),
#   ('nasikagra', 1),
#   ('addition', 1),
#   ('soothes', 1),
#   ('secretions', 1),
#   ('process', 1),
#   ('practice', 1),
#   ('contact', 1),
#   ('membranes', 1),
#   ('stimulates', 1),
#   ('benefits', 1),
#   ('act', 1),
#   ('cools', 1),
#   ('kaki', 1),
#   ('body', 1),
#   ('mouth', 1),
#   ('mind', 1)],
#  [('stomach', 1),
#   ('mudra', 1),
#   ('disorders', 1),
#   ('time', 1),
#   ('float', 1),
#   ('air', 1),
#   ('length', 1),
#   ('abdominal', 1),
#   ('practitioner', 1),
#   ('wind', 1),
#   ('water', 1),
#   ('bhujangini', 1),
#   ('stagnant', 1),
#   ('tones', 1)],
#  [('psychic', 1),
#   ('chakra', 1),
#   ('practitioner', 1),
#   ('beneficial', 1),
#   ('mental', 1),
#   ('mudra', 1),
#   ('concentration', 1),
#   ('spiritual', 1),
#   ('thoughtlessness', 1),
#   ('consciousness', 1),
#   ('ajna', 1),
#   ('meditative', 1),
#   ('stability', 1),
#   ('calming', 1),
#   ('memory', 1),
#   ('state', 1),
#   ('bhoochari', 1),
#   ('tranquillizes', 1),
#   ('states', 1),
#   ('power', 1),
#   ('anger', 1),
#   ('stress', 1),
#   ('planes', 1)],
#  [('control', 1),
#   ('khechari', 1),
#   ('consciousness', 1),
#   ('practice', 1),
#   ('kumbhaka', 1),
#   ('processes', 1),
#   ('states', 1),
#   ('benefits', 1),
#   ('higher', 1),
#   ('tranquillity', 1),
#   ('induces', 1),
#   ('calmness', 1),
#   ('arrests', 1)],
#  [('pratyahara', 1),
#   ('state', 1),
#   ('nerves', 1),
#   ('withdrawal', 1),
#   ('fingers', 1),
#   ('hands', 1),
#   ('sense', 1),
#   ('heat', 1),
#   ('muscles', 1),
#   ('energy', 1),
#   ('awareness', 1)],
#  [('mudra', 1),
#   ('meditative', 1),
#   ('state', 1),
#   ('agitation', 1),
#   ('calms', 1),
#   ('unmani', 1)],
#  [('physical', 1),
#   ('activities', 1),
#   ('prana', 1),
#   ('effect', 1),
#   ('disease', 1),
#   ('karani', 1),
#   ('flow', 1),
#   ('mental', 1),
#   ('energy', 1),
#   ('awareness', 1),
#   ('downward', 1),
#   ('practice', 1),
#   ('nadis', 1),
#   ('benefits', 1),
#   ('movement', 1),
#   ('asana', 1),
#   ('equal', 1),
#   ('pingala', 1),
#   ('balances', 1),
#   ('breath', 1),
#   ('vipareeta', 1),
#   ('ida', 1),
#   ('outward', 1),
#   ('posture', 1),
#   ('nostrils', 1)],
#  [('drawal', 1),
#   ('mudra', 1),
#   ('pratyahara', 1),
#   ('stimulates', 1),
#   ('nervous', 1),
#   ('sensory', 1),
#   ('pashinee', 1),
#   ('nerves', 1),
#   ('tranquillity', 1),
#   ('massages', 1),
#   ('balance', 1),
#   ('induces', 1),
#   ('abdominal', 1),
#   ('spinal', 1),
#   ('spine', 1),
#   ('muscles', 1),
#   ('organs', 1)],
#  [('nerve', 1),
#   ('dia', 1),
#   ('bending', 1),
#   ('trunk', 1),
#   ('ward', 1),
#   ('area', 1),
#   ('areas', 1),
#   ('prana', 1),
#   ('chakra', 1),
#   ('manipura', 1),
#   ('tones', 1),
#   ('pressure', 1),
#   ('mudra', 1),
#   ('level', 1),
#   ('pelvic', 1),
#   ('energy', 1),
#   ('tension', 1),
#   ('stomach', 1),
#   ('plexuses', 1),
#   ('visceral', 1),
#   ('stimulates', 1),
#   ('diaphragm', 1),
#   ('phragm', 1),
#   ('toned', 1),
#   ('circulation', 1)],
#  [('strength', 1),
#   ('prana', 1),
#   ('health', 1),
#   ('flow', 1),
#   ('mudra', 1),
#   ('energy', 1),
#   ('awareness', 1),
#   ('subtle', 1),
#   ('confidence', 1),
#   ('nadis', 1),
#   ('attitude', 1),
#   ('inner', 1),
#   ('equanimity', 1),
#   ('external', 1),
#   ('source', 1),
#   ('peace', 1),
#   ('body', 1),
#   ('vital', 1),
#   ('dormant', 1),
#   ('chakras', 1),
#   ('cosmic', 1)],
#  [('awaken', 1),
#   ('psychic', 1),
#   ('massages', 1),
#   ('chakra', 1),
#   ('meditation', 1),
#   ('manipura', 1),
#   ('health', 1),
#   ('relieves', 1),
#   ('excellent', 1),
#   ('preparatory', 1),
#   ('addition', 1),
#   ('relaxation', 1),
#   ('energy', 1),
#   ('awareness', 1),
#   ('control', 1),
#   ('tension', 1),
#   ('practice', 1),
#   ('general', 1),
#   ('engendering', 1),
#   ('sense', 1),
#   ('tranquillity', 1),
#   ('abdominal', 1),
#   ('anger', 1),
#   ('stretches', 1),
#   ('organs', 1)],
#  [('counterpose', 1),
#   ('mind', 1),
#   ('mudra', 1),
#   ('fluctuations', 1),
#   ('meditative', 1),
#   ('nadis', 1),
#   ('cross', 1),
#   ('mooladhara', 1),
#   ('legged', 1),
#   ('asanas', 1),
#   ('asana', 1),
#   ('manduki', 1),
#   ('chakra', 1),
#   ('ida', 1),
#   ('pingala', 1),
#   ('meditation', 1),
#   ('calms', 1)],
#  [('khechari', 1),
#   ('mudra', 1),
#   ('ajna', 1),
#   ('kumbhaka', 1),
#   ('circuit', 1),
#   ('spontaneous', 1),
#   ('mooladhara', 1),
#   ('benefits', 1),
#   ('moola', 1),
#   ('maha', 1),
#   ('prana', 1),
#   ('bandha', 1),
#   ('chakra', 1),
#   ('meditation', 1),
#   ('intensifies', 1),
#   ('energy', 1),
#   ('awareness', 1),
#   ('blockages', 1)],
#  [('profound', 1),
#   ('manipura', 1),
#   ('meditation', 1),
#   ('bheda', 1),
#   ('mudra', 1),
#   ('level', 1),
#   ('concentration', 1),
#   ('vishuddhi', 1),
#   ('influences', 1),
#   ('energies', 1),
#   ('body', 1),
#   ('complex', 1),
#   ('influence', 1),
#   ('mooladhara', 1),
#   ('chakras', 1),
#   ('maha', 1),
#   ('supercharge', 1),
#   ('pranic', 1),
#   ('supplements', 1),
#   ('mind', 1)],
#  [('kundalini', 1),
#   ('practice', 1),
#   ('faculties', 1),
#   ('introverting', 1),
#   ('psychic', 1),
#   ('mooladhara', 1),
#   ('chakra', 1),
#   ('mind', 1),
#   ('powerful', 1)],
#  [('practice', 1),
#   ('upward', 1),
#   ('escape', 1),
#   ('purposes', 1),
#   ('anal', 1),
#   ('spiritual', 1),
#   ('redirects', 1),
#   ('pranic', 1),
#   ('muscles', 1),
#   ('energy', 1),
#   ('vents', 1)],
#  [('unwanted', 1),
#   ('mudra', 1),
#   ('meditative', 1),
#   ('states', 1),
#   ('entire', 1),
#   ('genital', 1),
#   ('uro', 1),
#   ('vajroli', 1),
#   ('psycho', 1),
#   ('thoughts', 1),
#   ('conserves', 1),
#   ('sexual', 1),
#   ('energy', 1),
#   ('conflicts', 1),
#   ('tones', 1)],
#  [('variation', 1),
#   ('tendency', 1),
#   ('respiratory', 1),
#   ('compresses', 1),
#   ('arteries', 1),
#   ('bandha', 1),
#   ('pointedness', 1),
#   ('breathing', 1),
#   ('pressure', 1),
#   ('mental', 1),
#   ('exerts', 1),
#   ('systems', 1),
#   ('heart', 1),
#   ('relaxation', 1),
#   ('metabolism', 1),
#   ('subtler', 1),
#   ('process', 1),
#   ('increase', 1),
#   ('simple', 1),
#   ('dioxide', 1),
#   ('practice', 1),
#   ('meditative', 1),
#   ('jalandhara', 1),
#   ('main', 1),
#   ('neck', 1)],
#  [('physical', 1),
#   ('ment', 1),
#   ('psychic', 1),
#   ('uro', 1),
#   ('bandha', 1),
#   ('enhancement', 1),
#   ('relations', 1),
#   ('illnesses', 1),
#   ('health', 1),
#   ('awakening', 1),
#   ('tones', 1),
#   ('mental', 1),
#   ('depression', 1),
#   ('systems', 1),
#   ('moola', 1),
#   ('pelvic', 1),
#   ('brahmacharya', 1),
#   ('spiritual', 1),
#   ('sexual', 1),
#   ('energy', 1),
#   ('control', 1),
#   ('psychosomatic', 1),
#   ('excretory', 1),
#   ('benefits', 1),
#   ('helpful', 1)],
#  [('abdomen', 1),
#   ('digestive', 1),
#   ('prana', 1),
#   ('bandha', 1),
#   ('chakra', 1),
#   ('panacea', 1),
#   ('manipura', 1),
#   ('flow', 1),
#   ('pressure', 1),
#   ('internal', 1),
#   ('adrenal', 1),
#   ('influences', 1),
#   ('energy', 1),
#   ('liver', 1),
#   ('subtle', 1),
#   ('glands', 1),
#   ('tension', 1),
#   ('samana', 1),
#   ('stimulates', 1),
#   ('suction', 1),
#   ('apana', 1),
#   ('uddiyana', 1),
#   ('lethargy', 1),
#   ('torso', 1),
#   ('circulation', 1)],
#  [('culmination', 1),
#   ('pranayamas', 1),
#   ('gland', 1),
#   ('prana', 1),
#   ('bandha', 1),
#   ('merger', 1),
#   ('chakra', 1),
#   ('prior', 1),
#   ('meditation', 1),
#   ('manipura', 1),
#   ('processes', 1),
#   ('secretions', 1),
#   ('endocrine', 1),
#   ('samana', 1),
#   ('benefits', 1),
#   ('introverts', 1),
#   ('main', 1),
#   ('entire', 1),
#   ('ageing', 1),
#   ('apana', 1),
#   ('pineal', 1),
#   ('body', 1),
#   ('cell', 1),
#   ('hormonal', 1),
#   ('chakras', 1)],
#  [('appear', 1),
#   ('nerve', 1),
#   ('passages', 1),
#   ('respiratory', 1),
#   ('awaken', 1),
#   ('air', 1),
#   ('jala', 1),
#   ('chakra', 1),
#   ('practitioner', 1),
#   ('ance', 1),
#   ('nose', 1),
#   ('health', 1),
#   ('nasal', 1),
#   ('flow', 1),
#   ('depression', 1),
#   ('diseases', 1),
#   ('muscular', 1),
#   ('overall', 1),
#   ('ala', 1),
#   ('ears', 1),
#   ('fresh', 1),
#   ('endings', 1),
#   ('balance', 1),
#   ('head', 1),
#   ('tract', 1)],
#  [('bone', 1),
#   ('fleshy', 1),
#   ('months', 1),
#   ('neti', 1),
#   ('outgrowths', 1),
#   ('obstructions', 1),
#   ('friction', 1),
#   ('benefits', 1),
#   ('sutra', 1),
#   ('regular', 1),
#   ('jala', 1),
#   ('addition', 1),
#   ('nostrils', 1),
#   ('nasal', 1),
#   ('septum', 1),
#   ('problem', 1)]]

# %%
len(word_soup_first)
# Out:
# 227

# %%
asanas['word_soup'] = word_soup_first[1:]

# %%
len(asanas)
# Out:
# 226

# %%
not_to_do = []
with open(data,'r') as file:
    reader1 = csv.reader(file)
    print(reader1)
    for row in reader1:
        not_to_do.append(row[4])
print(not_to_do)
# Out:
# <_csv.reader object at 0x7f01418616d0>
# ['Contraindications', '', '', '', '', '', 'Stage 2 is a strenuous practice and should\nnot be attempted by people with weak abdominal muscles,\nback conditions, high blood pressure or heart conditions.', '', '', '', 'People with sciatica and sacral conditions\nshould avoid this asana.', '', '', '', '', '', '', 'These four neck movements should not\nbe performed by elderly people and those suffering from\n\nlow blood pressure, high blood pressure, vertigo or ex-\ntreme cervical spondylosis. Expert advice should be sought\n\nfor any of these problems. Cervical spondylosis patients\nshould strictly avoid fotward bending of the neck.', 'Not to be performed by persons suffer\xading from high blood pressure or serious back conditions such as sciatica and slipped disc.', 'Not to be performed by persons suffering from high blood pressure or serious back conditions such as sciatica and slipped disc.', 'Not to be performed by persons suffering from high blood pressure or serious back conditions such as sciatica and slipped disc.', 'Not to be performed by persons suffering from high blood pressure or serious back conditions such as sciatica and slipped disc.', 'Not to be performed by persons with serious back conditions.', '', 'This asana can realign the hip joint. It should be stopped if the practice is painful.', '', '', 'People with back conditions should avoid this asana.', '', '', 'Not for people with knee problems or sciatica.', 'Not for people with knee problems or sciatica.', 'Not for people with knee problems or sciatica. People with very high blood pressure or arterio\xadsclerosis should not practise this asana - cautions for inverted postures apply.', 'People suffering from disorders of the knees, ankles or toes should not practise this asana.', 'Not fo r people with knee problems or sciatica.', 'Those who suffer from major eye diseases or disorders such as glauco1na, trachoma, cataract, retinal detachment, retinal artery or vein thrombosis, iritis, keratitis or conjunctivitis should only perform yoga practices after consulting an eye specialist. Inverted asanas and kunjal kriya should be avoided altogether while the condition lasts. Adopting a yogic lifestyle and a simple vegetarian diet, however, may be of great benefit.', 'Those who suffer from major eye diseases or disorders such as glauco1na, trachoma, cataract, retinal detachment, retinal artery or vein thrombosis, iritis, keratitis or conjunctivitis should only perform yoga practices after consulting an eye specialist. Inverted asanas and kunjal kriya should be avoided altogether while the condition lasts. Adopting a yogic lifestyle and a simple vegetarian diet, however, may be of great benefit.', 'Those who suffer from major eye diseases or disorders such as glauco1na, trachoma, cataract, retinal detachment, retinal artery or vein thrombosis, iritis, keratitis or conjunctivitis should only perform yoga practices after consulting an eye specialist. Inverted asanas and kunjal kriya should be avoided altogether while the condition lasts. Adopting a yogic lifestyle and a simple vegetarian diet, however, may be of great benefit.', 'Those who suffer from major eye diseases or disorders such as glauco1na, trachoma, cataract, retinal detachment, retinal artery or vein thrombosis, iritis, keratitis or conjunctivitis should only perform yoga practices after consulting an eye specialist. Inverted asanas and kunjal kriya should be avoided altogether while the condition lasts. Adopting a yogic lifestyle and a simple vegetarian diet, however, may be of great benefit.', 'Those who suffer from major eye diseases or disorders such as glauco1na, trachoma, cataract, retinal detachment, retinal artery or vein thrombosis, iritis, keratitis or conjunctivitis should only perform yoga practices after consulting an eye specialist. Inverted asanas and kunjal kriya should be avoided altogether while the condition lasts. Adopting a yogic lifestyle and a simple vegetarian diet, however, may be of  ...

# %%
import re
new_data2 = []
input_2 = []
for j in range (len(not_to_do)):
    line1 = not_to_do[j]
    line1 = line1.lower()
    line1 = re.sub(r'[^A-Za-z\n]+', ' ', line1)
    line1 = remove_stopwords(line1)
    input_2.append(line1)

# %%
import spacy
from collections import Counter
from string import punctuation
nlp = spacy.load("en_core_web_sm")
length_input_2 = len(input_2)
word_soup_not_to_do = []
def get_hotwords(text):
    result = []
    pos_tag = ['PROPN', 'ADJ', 'NOUN'] 
    doc = nlp(text.lower()) 
    for token in doc:
        if(token.text in nlp.Defaults.stop_words or token.text in punctuation):
            continue
        if(token.pos_ in pos_tag):
            result.append(token.text)
    return result
for i in range(length_input_2):
  new_text = input_2[i]
  output = set(get_hotwords(new_text))
  most_common_list = Counter(output).most_common(25)
  word_soup_not_to_do.append(most_common_list)

# %%
asanas['contradiction_word_soup'] = word_soup_not_to_do[1:]

# %%
k= []
for j in range(len(word_soup_first)):
  k.append([i[0] for i in word_soup_first[j]])

# %%
k[91]
# Out:
# []

# %%
l= []
for j in range(len(word_soup_not_to_do)):
  l.append([i[0] for i in word_soup_not_to_do[j]])

# %%
k
# Out:
# [['benefits'],
#  ['physical',
#   'vigorous',
#   'exercise',
#   'useful',
#   'pressure',
#   'problems',
#   'self',
#   'excellent',
#   'heart',
#   'coordination',
#   'ments',
#   'energy',
#   'awareness',
#   'blockages',
#   'arthritis',
#   'confidence',
#   'group',
#   'asanas',
#   'rheumatism',
#   'high',
#   'body',
#   'joints',
#   'blood'],
#  ['physical',
#   'vigorous',
#   'exercise',
#   'useful',
#   'pressure',
#   'problems',
#   'self',
#   'excellent',
#   'heart',
#   'coordination',
#   'ments',
#   'energy',
#   'awareness',
#   'blockages',
#   'arthritis',
#   'confidence',
#   'group',
#   'asanas',
#   'rheumatism',
#   'high',
#   'body',
#   'joints',
#   'blood'],
#  ['physical',
#   'vigorous',
#   'exercise',
#   'useful',
#   'pressure',
#   'problems',
#   'self',
#   'excellent',
#   'heart',
#   'coordination',
#   'ments',
#   'energy',
#   'awareness',
#   'blockages',
#   'arthritis',
#   'confidence',
#   'group',
#   'asanas',
#   'rheumatism',
#   'high',
#   'body',
#   'joints',
#   'blood'],
#  ['help',
#   'blood',
#   'calf',
#   'relieve',
#   'thrombosis',
#   'foot',
#   'lymph',
#   'post',
#   'patients',
#   'asanas',
#   'tiredness',
#   'bedridden',
#   'operative',
#   'stagnant',
#   'cramp',
#   'venous'],
#  ['physical',
#   'vigorous',
#   'exercise',
#   'useful',
#   'pressure',
#   'problems',
#   'self',
#   'excellent',
#   'heart',
#   'coordination',
#   'ments',
#   'energy',
#   'awareness',
#   'blockages',
#   'arthritis',
#   'confidence',
#   'group',
#   'asanas',
#   'rheumatism',
#   'high',
#   'body',
#   'joints',
#   'blood'],
#  ['physical',
#   'vigorous',
#   'exercise',
#   'useful',
#   'pressure',
#   'problems',
#   'self',
#   'excellent',
#   'heart',
#   'coordination',
#   'ments',
#   'energy',
#   'awareness',
#   'blockages',
#   'arthritis',
#   'confidence',
#   'group',
#   'asanas',
#   'rheumatism',
#   'high',
#   'body',
#   'joints',
#   'blood'],
#  ['muscle',
#   'sprains',
#   'weight',
#   'knee',
#   'injuries',
#   'vulnerable',
#   'asanas',
#   'ligaments',
#   'healing',
#   'joint',
#   'quadriceps',
#   'muscles',
#   'energies',
#   'strong',
#   'body'],
#  ['people',
#   'daily',
#   'practice',
#   'joints',
#   'knee',
#   'meditative',
#   'excellent',
#   'evening',
#   'morning',
#   'legged',
#   'preparatory',
#   'asana',
#   'ardha',
#   'loos',
#   'hip',
#   'positions',
#   'titali'],
#  ['physical',
#   'vigorous',
#   'exercise',
#   'useful',
#   'pressure',
#   'problems',
#   'self',
#   'excellent',
#   'heart',
#   'coordination',
#   'ments',
#   'energy',
#   'awareness',
#   'blockages',
#   'arthritis',
#   'confidence',
#   'group',
#   'asanas',
#   'rheumatism',
#   'high',
#   'body',
#   'joints',
#   'blood'],
#  ['stages',
#   'tension',
#   'meditative',
#   'inner',
#   'long',
#   'asanas',
#   'tiredness',
#   'legs',
#   'mastery',
#   'thigh',
#   'lot',
#   'hours',
#   'muscles',
#   'padmasana'],
#  ['physical',
#   'vigorous',
#   'exercise',
#   'useful',
#   'pressure',
#   'problems',
#   'self',
#   'excellent',
#   'heart',
#   'coordination',
#   'ments',
#   'energy',
#   'awareness',
#   'blockages',
#   'arthritis',
#   'confidence',
#   'group',
#   'asanas',
#   'rheumatism',
#   'high',
#   'body',
#   'joints',
#   'blood'],
#  ['physical',
#   'vigorous',
#   'exercise',
#   'useful',
#   'pressure',
#   'problems',
#   'self',
#   'excellent',
#   'heart',
#   'coordination',
#   'ments',
#   'energy',
#   'awareness',
#   'blockages',
#   'arthritis',
#   'confidence',
#   'group',
#   'asanas',
#   'rheumatism',
#   'high',
#   'body',
#   'joints',
#   'blood'],
#  ['tension',
#   'joints',
#   'hand',
#   'wrist',
#   'prolonged',
#   'asanas',
#   'writing',
#   'beneficial',
#   'typing'],
#  ['physical',
#   'vigorous',
#   'exercise',
#   'useful',
#   'pressure',
#   'problems',
#   'self',
#   'excellent',
#   'heart',
#   'coordination',
#   'ments',
#   'energy',
#   'awareness',
#   'blockages',
#   'arthritis',
#   'confidence',
#   'group',
#   'asanas',
#   'rheumatism',
#   'high',
#   'body',
#   'joints',
#   'blood'],
#  ['physical',
#   'vigorous',
#   'exercise',
#   'useful',
#   'pressure',
#   'problems',
#   'self',
#   'excellent',
#   'heart',
#   'coordination',
#   'ments',
#   'energy',
#   'awareness',
#   'blockages',
#   'arthritis',
#   'confidence',
#   'group',
#   'asanas',
#   'rheumatism',
#   'high',
#   'body',
#   'joints',
#   'blood'],
#  ['office',
#   'help',
#   'pressure',
#   'frozen',
#   'work',
#   'shoulders',
#   'shape',
#   'cervical',
#   'asanas',
#   'shoulder',
#   'spondylitis',
#   'strain'],
#  ['tension',
#   'desk',
#   'work',
#   'shoulders',
#   'nerves',
#   'different',
#   'limbs',
#   'neck',
#   'asanas',
#   'region',
#   'shoulder',
#   'release',
#   'head',
#   'heaviness',
#   'muscles',
#   'organs',
#   'stiffness',
#   'body'],
#  ['strengthens',
#   'perineal',
#   'massages',
#   'digestive',
#   'prolapse',
#   'asana',
#   'abdominal',
#   'pelvic',
#   'muscles',
#   'lower'],
#  ['joints', 'obesity', 'abdominal', 'spinal', 'muscles', 'hip', 'good'],
#  ['joints', 'knee', 'muscles', 'abdominal', 'lower', 'hip', 'good'],
#  ['effective',
#   'massages',
#   'digestive',
#   'lower',
#   'useful',
#   'problems',
#   'constipation',
#   'vertebrae',
#   'wind',
#   'pelvic',
#   'spinal',
#   'pawanmuktasana',
#   'sterility',
#   'muscles',
#   'menstrual',
#   'supta',
#   'reproductive',
#   'impotence',
#   'organs'],
#  ['morning', 'massages', 'hips', 'asana', 'thing', 'useful'],
#  ['column',
#   'distance',
#   'area',
#   'sitting',
#   'lower',
#   'constipation',
#   'relieves',
#   'excellent',
#   'prolonged',
#   'placement',
#   'stretch',
#   'cardiac',
#   'feet',
#   'twist',
#   'stiffness',
#   'twisting',
#   'buttocks',
#   'efore',
#   'diges',
#   'asana',
#   'tion',
#   'spinal',
#   'muscles',
#   'vertebra',
#   'time'],
#  ['action',
#   'tiredness',
#   'abdominal',
#   'tightness',
#   'pelvic',
#   'organs',
#   'lower'],
#  ['deep',
#   'latory',
#   'digestive',
#   'useful',
#   'tones',
#   'muscular',
#   'systems',
#   'trimester',
#   'freshness',
#   'relaxation',
#   'tension',
#   'nervous',
#   'pregnancy',
#   'asana',
#   'lethargy',
#   'second',
#   'childbearing',
#   'state',
#   'hormonal',
#   'deeper',
#   'circu',
#   'women',
#   'order',
#   'organs',
#   'shavasana'],
#  ['breast',
#   'joints',
#   'upper',
#   'asana',
#   'shoulder',
#   'firms',
#   'muscles',
#   'loosens',
#   'chest'],
#  ['flexibility', 'increases', 'asana', 'spine', 'stiffness'],
#  ['abdomen',
#   'cycle',
#   'organs',
#   'excellent',
#   'nerves',
#   'postnatal',
#   'pelvis',
#   'asana',
#   'recovery',
#   'exercise',
#   'toning',
#   'menstrual',
#   'useful',
#   'months'],
#  ['abdomen',
#   'disorders',
#   'constipation',
#   'natal',
#   'gynaecological',
#   'pelvis',
#   'asana',
#   'effect',
#   'areas',
#   'recovery',
#   'positive',
#   'post',
#   'energy',
#   'useful',
#   'blockages'],
#  ['special',
#   'joints',
#   'upper',
#   'lighten',
#   'inaccessible',
#   'blades',
#   'asana',
#   'effect',
#   'shoulder',
#   'pelvic',
#   'mood',
#   'frustration',
#   'muscles',
#   'girdle',
#   'tones'],
#  ['arms',
#   'flexibility',
#   'thighs',
#   'hips',
#   'neck',
#   'asana',
#   'effect',
#   'profound',
#   'muscles'],
#  ['namaskarasana',
#   'arm',
#   'effect',
#   'beneficial',
#   'useful',
#   'pressure',
#   'vertebrae',
#   'flatulence',
#   'stretch',
#   'mas',
#   'pelvic',
#   'leg',
#   'arms',
#   'thighs',
#   'neck',
#   'toned',
#   'equal',
#   'spinal',
#   'muscles',
#   'joints',
#   'nerves',
#   'spine',
#   'organs'],
#  ['constipation',
#   'blood',
#   'asanas',
#   'asana',
#   'legs',
#   'meditation',
#   'circulation'],
#  ['constipation',
#   'region',
#   'abdominal',
#   'muscles',
#   'organs',
#   'ailments',
#   'useful'],
#  ['defective',
#   'vision',
#   'relaxes',
#   'humour',
#   'aqueous',
#   'stimulates',
#   'liquid',
#   'correction',
#   'palming',
#   'cornea',
#   'circulation',
#   'muscles',
#   'eye'],
#  ['people',
#   'eyesight',
#   'tension',
#   'eyes',
#   'becmne',
#   'habitual',
#   'muscles',
#   'relaxation',
#   'encourages',
#   'blink',
#   'reflex',
#   'defective',
#   'eye',
#   'spontaneous',
#   'state'],
#  ['tension',
#   'corrects',
#   'work',
#   'sideways',
#   'muscles',
#   'close',
#   'reading',
#   'constant',
#   'viewing'],
#  ['eyeball',
#   'sideways',
#   'coordination',
#   'lateral',
#   'muscles',
#   'medial',
#   'viewing'],
#  ['balances', 'muscles', 'eyeball', 'lower'],
#  ['rotational', 'vities', 'coordinated', 'muscles', 'acti', 'viewing', 'eye'],
#  ['power', 'muscles', 'exercise', 'eye'],
#  ['movements', 'power', 'exercise', 'muscles', 'eye'],
#  ['sleep',
#   'practice',
#   'practi',
#   'exercises',
#   'pratyahara',
#   'dynamic',
#   'awareness',
#   'relaxed',
#   'asana',
#   'tioner',
#   'tired',
#   'psycho',
#   'physiological',
#   'namaskara',
#   'mind',
#   'body'],
#  ['figure', 'neck', 'stiff', 'disc'],
#  ['upper',
#   'complaints',
#   'cervical',
#   'stiff',
#   'asana',
#   'neck',
#   'spinal',
#   'helpful',
#   'spondylitis'],
#  ['column',
#   'pain',
#   'effective',
#   'shape',
#   'air',
#   'lung',
#   'lower',
#   'disc',
#   'people',
#   'types',
#   'normal',
#   'awareness',
#   'simple',
#   'compression',
#   'certain',
#   'vertebral',
#   'asana',
#   'periods',
#   'releases',
#   'spinal',
#   'lungs',
#   'sciatica',
#   'time',
#   'nerves',
#   'ailments'],
#  ['sciatic',
#   'pain',
#   'ideal',
#   'nidra',
#   'digestive',
#   'matsya',
#   'cause',
#   'pressure',
#   'people',
#   'practise',
#   'fotward',
#   'knee',
#   'comfort',
#   'kridasana',
#   'tnended',
#   'block',
#   'bent',
#   'perineum',
#   'head',
#   'tension',
#   'asanas',
#   'asana',
#   'circumstances',
#   'circulation',
#   'peristalsis'],
#  ['mental',
#   'comfortable',
#   'pain',
#   'physical',
#   'sukhasana',
#   'easiest',
#   'unable',
#   'persons',
#   'ill',
#   'effect',
#   'tion',
#   'balance',
#   'meditation',
#   'postures',
#   'difficult',
#   'strain',
#   'medita'],
#  ['level', 'benefits', 'padmasana'],
#  ['trunk',
#   'experience',
#   'digestive',
#   'firm',
#   'prana',
#   'chakra',
#   'effect',
#   'slow',
#   'meditation',
#   'padmasana',
#   'lower',
#   'flow',
#   'pressure',
#   'pillar',
#   'muscular',
#   'perineum',
#   'head',
#   'process',
#   'tension',
#   'sahasrara',
#   'large',
#   'step',
#   'nervous',
#   'calm',
#   'region'],
#  ['abdomen',
#   'noticeable',
#   'locks',
#   'reduction',
#   'area',
#   'psychic',
#   'centres',
#   'bandha',
#   'chakra',
#   'vajroli',
#   'psycho',
#   'cord',
#   'necessary',
#   'lower',
#   'hormones',
#   'pressure',
#   'flow',
#   'mudra',
#   'muscular',
#   'posture',
#   'moola',
#   'brahmacharya',
#   'perineum',
#   'swadhisthana',
#   'spiritual'],
#  ['abdomen',
#   'noticeable',
#   'locks',
#   'reduction',
#   'area',
#   'psychic',
#   'centres',
#   'point',
#   'bandha',
#   'chakra',
#   'vajroli',
#   'psycho',
#   'cord',
#   'necessary',
#   'lower',
#   'hormones',
#   'pressure',
#   'flow',
#   'mudra',
#   'muscular',
#   'posture',
#   'moola',
#   'brahmacharya',
#   'perineum',
#   'swadhisthana'],
#  ['position',
#   'varicose',
#   'tired',
#   'healthy',
#   'swastikasana',
#   'retention',
#   'legs',
#   'fluid',
#   'veins',
#   'muscles'],
#  ['area',
#   'massages',
#   'hips',
#   'thigh',
#   'meditation',
#   'outer',
#   'useful',
#   'knees',
#   'structure',
#   'pelvic',
#   'alternative',
#   'large',
#   'contact',
#   'inner',
#   'asanas',
#   'asana',
#   'periods',
#   'sustain',
#   'muscles',
#   'floor',
#   'body',
#   'comfortable',
#   'position',
#   'time',
#   'outwards'],
#  ['nerve',
#   'measure',
#   'massages',
#   'digestive',
#   'efficiency',
#   'hyperacidity',
#   'feed',
#   'useful',
#   'flow',
#   'piles',
#   'alters',
#   'disorders',
#   'preventative',
#   'peptic',
#   'pelvic',
#   'ulcer',
#   'stomach',
#   'testicles',
#   'nervous',
#   'hernia',
#   'entire',
#   'region',
#   'dilated',
#   'muscles',
#   'menstrual'],
#  ['ajna',
#   'nervous',
#   'calms',
#   'benefits',
#   'asana',
#   'chakra',
#   'mind',
#   'vajrasana'],
#  ['pressure',
#   'facilitate',
#   'practice',
#   'pranayama',
#   'systems',
#   'activities',
#   'nervous',
#   'balance',
#   'autonomic',
#   'nostrils',
#   'armpits',
#   'breath',
#   'right',
#   'influences',
#   'parasympathetic',
#   'state',
#   'flow'],
#  ['aspirants',
#   'excellent',
#   'influence',
#   'mooladhara',
#   'benefits',
#   'chakra',
#   'spiritual',
#   'meditation',
#   'vajrasana'],
#  ['physical',
#   'stability',
#   'total',
#   'cord',
#   'spinal',
#   'definite',
#   'posture',
#   'body',
#   'extension'],
#  ['introverted',
#   'stutter',
#   'frustration',
#   'nose',
#   'chest',
#   'useful',
#   'people',
#   'mudra',
#   'excellent',
#   'ears',
#   'early',
#   'voice',
#   'beautiful',
#   'healing',
#   'tension',
#   'diaphragm',
#   'simhagarjanasana',
#   'nervous',
#   'benefits',
#   'asana',
#   'emotional',
#   'strong',
#   'eyes',
#   'throat',
#   'mouth'],
#  ['physical',
#   'uncontrollable',
#   'useful',
#   'mental',
#   'realms',
#   'concentration',
#   'unconscious',
#   'precise',
#   'relaxation',
#   'beco',
#   'clear',
#   'nuch',
#   'awareness',
#   'process',
#   'thoughts',
#   'asana',
#   'nes',
#   'balances',
#   'kidneys',
#   'power',
#   'reproductive',
#   'abdominal',
#   'organs',
#   'mind',
#   'good'],
#  ['flexibility',
#   'abdomen',
#   'shoulders',
#   'cramps',
#   'pregnancy',
#   'neck',
#   'asana',
#   'relief',
#   'reproductive',
#   'forceful',
#   'contraction',
#   'female',
#   'menstrual',
#   'leucorrhea'],
#  ['sciatic',
#   'hips',
#   'female',
#   'beneficial',
#   'tones',
#   'birth',
#   'directions',
#   'loosens',
#   'thighs',
#   'exercises',
#   'digestion',
#   'asana',
#   'spinal',
#   'circulation',
#   'muscles',
#   'children',
#   'hip',
#   'sciatica',
#   'joints',
#   'blood',
#   'weight',
#   'nerves',
#   'legs',
#   'reproductive',
#   'abdominal'],
#  ['nerve',
#   'sciatic',
#   'cord',
#   'discs',
#   'female',
#   'connections',
#   'beneficial',
#   'male',
#   'tones',
#   'pressure',
#   'correct',
#   'constipation',
#   'vertebrae',
#   'backache',
#   'pelvic',
#   'adrenal',
#   'problem',
#   'strengthens',
#   'glands',
#   'practice',
#   'asana',
#   'spinal',
#   'cases',
#   'muscles',
#   'position'],
#  ['final',
#   'female',
#   'male',
#   'tones',
#   'disorders',
#   'excellent',
#   'pelvic',
#   'liver',
#   'bhujangasana',
#   'natal',
#   'visceral',
#   'benefits',
#   'asana',
#   'region',
#   'muscles',
#   'menstrual',
#   'position',
#   'similar',
#   'kidneys',
#   'reproductive',
#   'shashank',
#   'abdominal',
#   'spine',
#   'postures',
#   'organs'],
#  ['extra',
#   'pressure',
#   'practice',
#   'lesser',
#   'benefits',
#   'preparatory',
#   'brain',
#   'head',
#   'sirshasana',
#   'degree',
#   'body',
#   'headstand'],
#  ['strengthens',
#   'ankles',
#   'good',
#   'nervous',
#   'hips',
#   'stretch',
#   'asana',
#   'legs',
#   'abdominal',
#   'balance',
#   'feet',
#   'organs',
#   'lower',
#   'tones'],
#  ['level', 'ushtrasana'],
#  ['shoulders',
#   'intestines',
#   'digestive',
#   'beneficial',
#   'people',
#   'constipation',
#   'vertebrae',
#   'systems',
#   'backache',
#   'loosens',
#   'rounded',
#   'stomach',
#   'neck',
#   'asana',
#   'region',
#   'spinal',
#   'helpful',
#   'asthma',
#   'thyroid',
#   'nerves',
#   'reproductive',
#   'posture',
#   'organs'],
#  ['shoulders',
#   'gland',
#   'massages',
#   'digestive',
#   'om',
#   'meditation',
#   'lung',
#   'beneficial',
#   'organs',
#   'chest',
#   'tones',
#   'constipation',
#   'flexible',
#   'spiritual',
#   'loosens',
#   'sexual',
#   'energy',
#   'purposes',
#   'rounded',
#   'capacity',
#   'neck',
#   'asana',
#   'asanas',
#   'realigns',
#   'oxygen'],
#  ['deep',
#   'shoulders',
#   'round',
#   'rectifies',
#   'breaths',
#   'breathing',
#   'upper',
#   'heart',
#   'influences',
#   'stiffness',
#   'capacity',
#   'extra',
#   'asana',
#   'brain',
#   'oxygen',
#   'circulation',
#   'body',
#   'blood',
#   'supply'],
#  ['pain',
#   'deep',
#   'smoothes',
#   'shoulders',
#   'blades',
#   'spondylitis',
#   'cramp',
#   'flow',
#   'people',
#   'alternate',
#   'bad',
#   'stiffness',
#   'energy',
#   'short',
#   'tension',
#   'writer',
#   'exercises',
#   'tensing',
#   'neck',
#   'asana',
#   'postural',
#   'helpful',
#   'ann',
#   'muscles',
#   'cervical'],
#  ['column',
#   'physical',
#   'points',
#   'useful',
#   'mental',
#   'rectus',
#   'congestion',
#   'longer',
#   'balance',
#   'clear',
#   'pregnancy',
#   'entire',
#   'asana',
#   'abdomini',
#   'ligaments',
#   'spinal',
#   'tadasana',
#   'muscles',
#   'months',
#   'height',
#   'nerves',
#   'abdominal',
#   'spine',
#   'bones'],
#  ['groups', 'sides', 'waist', 'massages', 'postural', 'tadasana', 'muscles'],
#  ['physical',
#   'shoulders',
#   'useful',
#   'tones',
#   'problems',
#   'mental',
#   'waist',
#   'relaxation',
#   'stiffness',
#   'twisting',
#   'tension',
#   'movement',
#   'neck',
#   'asana',
#   'postural',
#   'lightness',
#   'time',
#   'day',
#   'feeling'],
#  ['coordination', 'asana', 'balance', 'kati', 'chakrasana', 'muscles'],
#  ['weight', 'excess', 'asana', 'waistline', 'spine', 'muscles', 'tones'],
#  ['middle', 'thighs', 'uterus', 'pelvis', 'asana', 'muscles', 'ankles'],
#  ['legs', 'muscles'],
#  ['shoulders', 'posture', 'asana', 'rectifies', 'poor', 'chest'],
#  ['bodies',
#   'upper',
#   'blades',
#   'neck',
#   'asana',
#   'shoulder',
#   'spine',
#   'young',
#   'muscles',
#   'chest',
#   'good'],
#  ['trunk',
#   'fat',
#   'area',
#   'waistline',
#   'tones',
#   'depression',
#   'alleviates',
#   'waist',
#   'pelvic',
#   'practice',
#   'digestion',
#   'sides',
#   'series',
#   'nervous',
#   'muscles',
#   'help',
#   'regular',
#   'legs',
#   'reproductive',
#   'organs'],
#  ['massages',
#   'tiredness',
#   'han',
#   'excellent',
#   'prepranayama',
#   'practice',
#   'visceral',
#   'benefits',
#   'asanas',
#   'asana',
#   'spinal',
#   'circulation',
#   'muscles',
#   'alveoli',
#   'strings',
#   'nerves',
#   'mucus',
#   'stagnant',
#   'organs'],
#  ['blood',
#   'face',
#   'nerves',
#   'hamstrings',
#   'asana',
#   'spinal',
#   'head',
#   'circulation',
#   'muscles',
#   'supple',
#   'tones'],
#  ['practice', 'concentration', 'calmness', 'preparation', 'state'],
#  [],
#  [],
#  [],
#  ['strengthens',
#   'height',
#   'upper',
#   'longer',
#   'limbs',
#   'blades',
#   'ligaments',
#   'shoulder',
#   'spine',
#   'bones',
#   'circulation',
#   'muscles'],
#  ['strengthens',
#   'exercises',
#   'arm',
#   'blades',
#   'region',
#   'shoulder',
#   'leg',
#   'spine',
#   'muscles',
#   'chest'],
#  [],
#  ['constipation',
#   'vertebrae',
#   'good',
#   'excellent',
#   'health',
#   'yogamudrasana',
#   'nerves',
#   'indigestion',
#   'asana',
#   'abdominal',
#   'chakra',
#   'spinal',
#   'general',
#   'manipura',
#   'organs',
#   'spaces'],
#  ['thymus',
#   'deep',
#   'gland',
#   'glasses',
#   'useful',
#   'piles',
#   'pressure',
#   'constipation',
#   'relieves',
#   'stretch',
#   'backache',
#   'pelvic',
#   'feet',
#   'thighs',
#   'stimulates',
#   'asana',
#   'region',
#   'water',
#   'circulation',
#   'asthma',
#   'blood',
#   'function',
#   'thyroid',
#   'respiration',
#   'legs'],
#  ['defects',
#   'productive',
#   'stability',
#   'asana',
#   'balance',
#   'postural',
#   'relaxation',
#   'meditation',
#   'posture',
#   'emotional',
#   'peace',
#   'useful'],
#  ['arms',
#   'kundalini',
#   'pain',
#   'chests',
#   'shoulders',
#   'normal',
#   'awakening',
#   'children',
#   'growth'],
#  ['excited',
#   'uncontrollable',
#   'massages',
#   'experience',
#   'digestive',
#   'effect',
#   'appetite',
#   'practise',
#   'security',
#   'balance',
#   'adrenal',
#   'glands',
#   'stability',
#   'stimulates',
#   'increases',
#   'asana',
#   'emotional',
#   'calms',
#   'sense',
#   'abdominal',
#   'anger',
#   'organs',
#   'mind'],
#  ['strength',
#   'equanimity',
#   'weight',
#   'excess',
#   'asana',
#   'abdominal',
#   'relaxation',
#   'thigh',
#   'muscles',
#   'organs',
#   'lower',
#   'state',
#   'tones'],
#  ['arms', 'backs', 'shoulders', 'stiff', 'asana', 'good'],
#  ['arms', 'bhujangasana', 'influence'],
#  ['bhujangasana',
#   'shoulders',
#   'effect',
#   'profound',
#   'addition',
#   'sarpasana',
#   'posture',
#   'muscles'],
#  ['tension',
#   'excellent',
#   'area',
#   'asana',
#   'ardha',
#   'pelvic',
#   'organs',
#   'shalabhasana'],
#  ['bowels',
#   'mild',
#   'appetite',
#   'lower',
#   'disc',
#   'tones',
#   'mudra',
#   'relief',
#   'backache',
#   'pelvic',
#   'liver',
#   'stomach',
#   'buttocks',
#   'stimulates',
#   'balances',
#   'muscles',
#   'body',
#   'sciatica',
#   'shalabhasana',
#   'long',
#   'abdominal',
#   'condition',
#   'organs'],
#  ['pain',
#   'respiratory',
#   'disorders',
#   'levels',
#   'disc',
#   'benefits',
#   'cervical',
#   'heart',
#   'creased',
#   'discomfort',
#   'dhanurasana',
#   'posture',
#   'spondylitis',
#   'beneficial',
#   'lungs',
#   'lower',
#   'useful',
#   'tones'],
#  ['column',
#   'alimentary',
#   'area',
#   'excess',
#   'digestive',
#   'sluggishness',
#   'canal',
#   'thoracic',
#   'netves',
#   'organs',
#   'useful',
#   'disorders',
#   'constipation',
#   'correct',
#   'upper',
#   'dhanurasana',
#   'secretions',
#   'leg',
#   'adrenal',
#   'chronic',
#   'cetvical',
#   'stiffness',
#   'liver',
#   'energy',
#   'glands'],
#  ['realign',
#   'shoulders',
#   'massages',
#   'miscarry',
#   'female',
#   'useful',
#   'tones',
#   'disorders',
#   'backache',
#   'rounded',
#   'digestion',
#   'bronchial',
#   'asana',
#   'asthma',
#   'colon',
#   'menstrual',
#   'thyroid',
#   'prolapse',
#   'abdominal',
#   'reproductive',
#   'conditions',
#   'spine',
#   'management',
#   'women',
#   'organs'],
#  ['constipation',
#   'exercises',
#   'excellent',
#   'time',
#   'diaphragm',
#   'benefits',
#   'blades',
#   'entire',
#   'asana',
#   'asanas',
#   'shoulder',
#   'risk',
#   'tightness',
#   'effects',
#   'piles',
#   'chest',
#   'tones'],
#  ['thighs',
#   'achilles',
#   'shoulders',
#   'similar',
#   'benefits',
#   'wrists',
#   'asana',
#   'region',
#   'tendons',
#   'spine',
#   'lumbar',
#   'chakrasana'],
#  ['shoulders',
#   'area',
#   'tiredness',
#   'cramp',
#   'chest',
#   'supple',
#   'alleviates',
#   'ache',
#   'relieves',
#   'excellent',
#   'relaxation',
#   'leg',
#   'stiffness',
#   'energy',
#   'minutes',
#   'awareness',
#   'tension',
#   'rheumatism',
#   'asana',
#   'neck',
#   'general',
#   'muscles',
#   'gomukhasana',
#   'sciatica',
#   'legs'],
#  ['thighs',
#   'joints',
#   'nervous',
#   'massages',
#   'insides',
#   'asana',
#   'region',
#   'abdominal',
#   'pelvic',
#   'organs',
#   'alternately',
#   'hip'],
#  ['area',
#   'massages',
#   'excess',
#   'uro',
#   'pelvic',
#   'adrenal',
#   'liver',
#   'glands',
#   'hamstring',
#   'entire',
#   'asana',
#   'region',
#   'circulation',
#   'muscles',
#   'hip',
#   'flexibility',
#   'joints',
#   'weight',
#   'pancreas',
#   'spleen',
#   'kidneys',
#   'genital',
#   'abdominal',
#   'spine'],
#  ['level',
#   'practice',
#   'physical',
#   'dynamic',
#   'processes',
#   'flexible',
#   'benefits',
#   'paschimottanasana',
#   'metabolic',
#   'addition',
#   'speeds',
#   'circulation',
#   'pranic',
#   'energy',
#   'body'],
#  ['upper',
#   'benefits',
#   'paschimottanasana',
#   'blades',
#   'stretch',
#   'asana',
#   'effect',
#   'legs',
#   'shoulder',
#   'lower',
#   'parts',
#   'muscles',
#   'chest',
#   'body'],
#  ['practice',
#   'paschimottanasana',
#   'asanas',
#   'loosening',
#   'legs',
#   'meditation',
#   'preparation'],
#  ['intense',
#   'hips',
#   'meditation',
#   'sirshasana',
#   'identical',
#   'constipation',
#   'turn',
#   'bent',
#   'leg',
#   'janu',
#   'massage',
#   'benefits',
#   'asanas',
#   'asana',
#   'peristalsis',
#   'characteristic',
#   'foot',
#   'paschimottanasana',
#   'alleviate',
#   'legs',
#   'distinct',
#   'abdominal',
#   'organs',
#   'intestinal'],
#  ['proper',
#   'excess',
#   'hips',
#   'development',
#   'flexible',
#   'coordination',
#   'balance',
#   'young',
#   'practice',
#   'thighs',
#   'girls',
#   'hip',
#   'steady',
#   'joints',
#   'weight',
#   'graceful',
#   'pelvis',
#   'sense',
#   'posture'],
#  ['hips',
#   'thigh',
#   'reduces',
#   'stronger',
#   'flexible',
#   'coordination',
#   'balance',
#   'thighs',
#   'inner',
#   'sides',
#   'asana',
#   'muscles',
#   'body',
#   'steady',
#   'weight',
#   'graceful',
#   'sense',
#   'abdominal',
#   'posture'],
#  ['hamstring',
#   'weight',
#   'area',
#   'waist',
#   'nervous',
#   'complaints',
#   'blades',
#   'cles',
#   'asana',
#   'stretch',
#   'lateral',
#   'shoulder',
#   'appetite',
#   'abdominal',
#   'thigh',
#   'excess',
#   'mus',
#   'body'],
#  ['hamstring',
#   'joints',
#   'pancreas',
#   'stimulates',
#   'nerves',
#   'massages',
#   'asana',
#   'brain',
#   'spinal',
#   'muscles',
#   'hip'],
#  ['hamstring',
#   'joints',
#   'flexible',
#   'adrenals',
#   'asana',
#   'muscles',
#   'hip',
#   'tones'],
#  ['beginners',
#   'pain',
#   'twists',
#   'vertebrae',
#   'wakrasana',
#   'meru',
#   'lumbago',
#   'nerves',
#   'neck',
#   'asana',
#   'mild',
#   'loosening',
#   'forms',
#   'spine',
#   'spinal',
#   'difficult',
#   'good'],
#  ['nerves', 'asana', 'spine', 'muscles', 'supple'],
#  ['abdomen',
#   'tendency',
#   'adjoining',
#   'gland',
#   'musrular',
#   'massages',
#   'digestive',
#   'beneficial',
#   'tones',
#   'problems',
#   'vertebrae',
#   'relieves',
#   'calcium',
#   'deposits',
#   'secretions',
#   'adrenal',
#   'liver',
#   'spasms',
#   'ailments',
#   'asana',
#   'muscles',
#   'inflammatory',
#   'pancreas',
#   'nerves',
#   'kidneys'],
#  ['shoulders',
#   'compression',
#   'long',
#   'hamstrings',
#   'stretch',
#   'asana',
#   'asanas',
#   'lateral',
#   'abdominal',
#   'muscles',
#   'hours',
#   'meditation',
#   'beneficial',
#   'organs',
#   'body'],
#  [],
#  [],
#  ['low',
#   'sirshasana',
#   'crown',
#   'pressure',
#   'influx',
#   'accustoms',
#   'strengthens',
#   'preliminary',
#   'nervous',
#   'neck',
#   'asana',
#   'brain',
#   'cases',
#   'muscles',
#   'body',
#   'blood',
#   'rich',
#   'supply',
#   'weight'],
#  ['gland',
#   'low',
#   'chakra',
#   'sirshasana',
#   'crown',
#   'pressure',
#   'influx',
#   'vishuddhi',
#   'spiritual',
#   'accustoms',
#   'strengthens',
#   'preliminary',
#   'nervous',
#   'neck',
#   'asana',
#   'brain',
#   'cases',
#   'breath',
#   'muscles',
#   'body',
#   'blood',
#   'rich',
#   'supply',
#   'weight',
#   'thyroid'],
#  ['effective',
#   'additional',
#   'sarvangasana',
#   'piles',
#   'internal',
#   'treatment',
#   'stretch',
#   'balance',
#   'free',
#   'pelvic',
#   'drainage',
#   'coordinates',
#   'leg',
#   'massage',
#   'asana',
#   'region',
#   'muscles',
#   'blood',
#   'sense',
#   'legs',
#   'veins',
#   'organs'],
#  ['halasana',
#   'weight',
#   'intestines',
#   'kidneys',
#   'excess',
#   'pelvis',
#   'preparatory',
#   'good'],
#  ['place',
#   'massages',
#   'production',
#   'constipation',
#   'internal',
#   'kidney',
#   'suprarenal',
#   'liver',
#   'halasana',
#   'glands',
#   'practice',
#   'digestion',
#   'diaphragm',
#   'insulin',
#   'movement',
#   'spasms',
#   'muscles',
#   'function',
#   'pancreas',
#   'abdominal',
#   'dyspepsia',
#   'organs'],
#  ['gall',
#   'constipation',
#   'pelvic',
#   'facilitates',
#   'abdomin',
#   'liver',
#   'halasana',
#   'fats',
#   'al',
#   'practice',
#   'benefits',
#   'diges',
#   'bladder',
#   'region',
#   'tion',
#   'peristalsis',
#   'muscles',
#   'paschimottanasana',
#   'intestinal'],
#  ['fats',
#   'al',
#   'constipation',
#   'diges',
#   'facilitates',
#   'bladder',
#   'region',
#   'tion',
#   'gall',
#   'pelvic',
#   'peristalsis',
#   'muscles',
#   'abdomin',
#   'intestinal',
#   'liver'],
#  ['fats',
#   'al',
#   'constipation',
#   'diges',
#   'facilitates',
#   'bladder',
#   'region',
#   'tion',
#   'gall',
#   'pelvic',
#   'peristalsis',
#   'muscles',
#   'abdomin',
#   'intestinal',
#   'liver'],
#  ['form',
#   'deep',
#   'gravity',
#   'effect',
#   'chakra',
#   'cause',
#   'eration',
#   'sirshasana',
#   'awakening',
#   'flow',
#   'disorders',
#   'disorder',
#   'regions',
#   'reversed',
#   'exhalation',
#   'root',
#   'sahasrara',
#   'greatest',
#   'dioxide',
#   'visceral',
#   'nervous',
#   'diaphragm',
#   'asanas',
#   'asana',
#   'entire'],
#  ['form',
#   'deep',
#   'gravity',
#   'effect',
#   'chakra',
#   'cause',
#   'eration',
#   'sirshasana',
#   'awakening',
#   'flow',
#   'disorders',
#   'disorder',
#   'regions',
#   'reversed',
#   'exhalation',
#   'root',
#   'sahasrara',
#   'greatest',
#   'dioxide',
#   'visceral',
#   'nervous',
#   'diaphragm',
#   'asanas',
#   'asana',
#   'entire'],
#  ['form',
#   'deep',
#   'gravity',
#   'effect',
#   'chakra',
#   'cause',
#   'eration',
#   'sirshasana',
#   'awakening',
#   'flow',
#   'disorders',
#   'disorder',
#   'regions',
#   'reversed',
#   'exhalation',
#   'root',
#   'sahasrara',
#   'greatest',
#   'dioxide',
#   'visceral',
#   'nervous',
#   'diaphragm',
#   'asanas',
#   'asana',
#   'entire'],
#  ['blood',
#   'internal',
#   'expansion',
#   'massages',
#   'asana',
#   'region',
#   'legs',
#   'sense',
#   'balance',
#   'free',
#   'pelvic',
#   'drainage',
#   'coordinates',
#   'sirshasana',
#   'leg',
#   'muscles',
#   'organs',
#   'chest'],
#  ['form',
#   'deep',
#   'gravity',
#   'effect',
#   'chakra',
#   'cause',
#   'eration',
#   'sirshasana',
#   'awakening',
#   'flow',
#   'disorders',
#   'disorder',
#   'regions',
#   'reversed',
#   'exhalation',
#   'root',
#   'sahasrara',
#   'greatest',
#   'dioxide',
#   'visceral',
#   'nervous',
#   'diaphragm',
#   'asanas',
#   'asana',
#   'entire'],
#  ['foot',
#   'nervous',
#   'asana',
#   'balance',
#   'ankle',
#   'leg',
#   'muscles',
#   'streng',
#   'thens'],
#  ['balance', 'nervous', 'concentration', 'natavarasana'],
#  ['arms',
#   'garudasana',
#   'joints',
#   'concentration',
#   'upper',
#   'legs',
#   'muscles',
#   'good'],
#  ['control',
#   'mental',
#   'concentration',
#   'develops',
#   'nervous',
#   'asana',
#   'legs',
#   'balances',
#   'body'],
#  ['arms',
#   'concentration',
#   'shoulders',
#   'hips',
#   'coordination',
#   'asana',
#   'sense',
#   'legs',
#   'balance'],
#  ['arms',
#   'concentration',
#   'shoulders',
#   'hips',
#   'coordination',
#   'asana',
#   'sense',
#   'legs',
#   'balance'],
#  ['arms',
#   'concentration',
#   'muscular',
#   'nervous',
#   'wrists',
#   'hips',
#   'asana',
#   'coordina',
#   'balance',
#   'tion',
#   'leg',
#   'muscles'],
#  ['blood',
#   'concentration',
#   'compression',
#   'nervous',
#   'coordination',
#   'balance',
#   'abdominal',
#   'leg',
#   'circulation',
#   'muscles',
#   'organs',
#   'hip',
#   'beneficial'],
#  ['ed',
#   'joints',
#   'concentration',
#   'muscular',
#   'knee',
#   'nervous',
#   'hamstrings',
#   'hips',
#   'balance',
#   'ankle',
#   'coordinates',
#   'leg',
#   'muscles'],
#  ['sympathetic',
#   'tiredness',
#   'intestinal',
#   'knees',
#   'tones',
#   'constipation',
#   'systems',
#   'balance',
#   'nervous',
#   'asana',
#   'lightness',
#   'peristalsis',
#   'muscles',
#   'legs',
#   'abdominal',
#   'spine',
#   'organs',
#   'parasympathetic',
#   'good'],
#  ['ofbalance',
#   'similar',
#   'paschimottan',
#   'benefits',
#   'asana',
#   'sense',
#   'addition'],
#  ['constipation', 'sense', 'asana', 'balance', 'peristalsis', 'intestinal'],
#  ['constipation',
#   'blood',
#   'digestion',
#   'stimulates',
#   'asana',
#   'legs',
#   'circulation'],
#  ['joints',
#   'knee',
#   'ability',
#   'asana',
#   'seminal',
#   'brahmacharya',
#   'leg',
#   'fluid',
#   'muscles',
#   'maintenance'],
#  ['strengthens',
#   'concentration',
#   'toes',
#   'asana',
#   'reproductive',
#   'brahmacharya',
#   'ankles'],
#  ['arms',
#   'physical',
#   'nervous',
#   'wrists',
#   'asana',
#   'sense',
#   'balance',
#   'balances',
#   'streng'],
#  [],
#  ['flexibility',
#   'abdomen',
#   'joints',
#   'arm',
#   'pancreas',
#   'visceral',
#   'massages',
#   'asana',
#   'shoulder',
#   'muscles',
#   'organs',
#   'lower'],
#  ['flexibility',
#   'strengthens',
#   'preservation',
#   'shoulders',
#   'contract',
#   'asana',
#   'energy',
#   'abdominal',
#   'perin',
#   'eum',
#   'purposes',
#   'spiritual',
#   'muscles',
#   'organs',
#   'sexual',
#   'lower',
#   'tones'],
#  ['massages',
#   'digestive',
#   'hamsasana',
#   'abdominal',
#   'healthy',
#   'muscles',
#   'organs',
#   'beneficial'],
#  ['arms',
#   'inner',
#   'equilibrium',
#   'harmony',
#   'shoulders',
#   'nervous',
#   'sense',
#   'asana',
#   'balance',
#   'muscles'],
#  ['arms',
#   'nervous',
#   'asana',
#   'balance',
#   'leg',
#   'muscles',
#   'supple',
#   'lower',
#   'tones'],
#  ['effect',
#   'manipura',
#   'beneficial',
#   'ovaries',
#   'tones',
#   'level',
#   'anahata',
#   'vishuddhi',
#   'healthy',
#   'swadhisthana',
#   'uterus',
#   'asana',
#   'strong',
#   'kidneys',
#   'abdominal',
#   'spine',
#   'pranic',
#   'organs',
#   'supple'],
#  ['abdomen',
#   'surrender',
#   'passion',
#   'tones',
#   'mental',
#   'ache',
#   'flatulence',
#   'security',
#   'relaxation',
#   'head',
#   'consti',
#   'subside',
#   'practice',
#   'composure',
#   'inner',
#   'neck',
#   'pation',
#   'helpful',
#   'introversion',
#   'circulation',
#   'diabetes',
#   'body',
#   'nerves',
#   'anger',
#   'koormasana'],
#  ['stomach',
#   'mudra',
#   'poorna',
#   'buttocks',
#   'body',
#   'benefits',
#   'bowels',
#   'asanas',
#   'muscles',
#   'abdominal',
#   'appetite',
#   'pelvic',
#   'balances',
#   'shalabhasana',
#   'organs',
#   'liver',
#   'tones'],
#  [],
#  ['arms',
#   'tension',
#   'people',
#   'joints',
#   'excellent',
#   'neck',
#   'asana',
#   'loosening',
#   'legs',
#   'abdominal',
#   'helpful',
#   'organs',
#   'supple',
#   'hip',
#   'tones'],
#  ['nerves',
#   'toning',
#   'asana',
#   'legs',
#   'abdominal',
#   'balance',
#   'spine',
#   'circulation',
#   'muscles',
#   'organs',
#   'streng'],
#  ['abdomen',
#   'trunk',
#   'fat',
#   'massages',
#   'accumulation',
#   'stretch',
#   'region',
#   'lateral',
#   'abdominal',
#   'pelvic',
#   'posture',
#   'skin',
#   'muscles',
#   'organs',
#   'good'],
#  ['cardiovascular',
#   'disorders',
#   'respiratory',
#   'glandular',
#   'systems',
#   'nervous',
#   'gynaecological',
#   'digestive',
#   'legs',
#   'onal',
#   'secretions',
#   'chakrasana',
#   'beneficial',
#   'influences'],
#  ['flexibility',
#   'n',
#   'blood',
#   'area',
#   'massages',
#   'legs',
#   'abdominal',
#   'reproductive',
#   'pelvic',
#   'circulation',
#   'organs',
#   'supple',
#   'tones'],
#  ['arms',
#   'important',
#   'mudra',
#   'contract',
#   'ashwini',
#   'moola',
#   'asana',
#   'vajroli',
#   'abdominal',
#   'bandha',
#   'purposes',
#   'perineum',
#   'spiritual',
#   'muscles',
#   'organs',
#   'sexual',
#   'energy',
#   'conservation'],
#  ['thighs', 'neck', 'sense', 'balance', 'grivasana'],
#  ['blood',
#   'excellent',
#   'stimulates',
#   'nerves',
#   'neck',
#   'asana',
#   'abdominal',
#   'relaxation',
#   'spinal',
#   'thigh',
#   'circulation',
#   'muscles',
#   'supple',
#   'strong'],
#  ['abdomen',
#   'tendency',
#   'adjoining',
#   'gland',
#   'massages',
#   'digestive',
#   'beneficial',
#   'tones',
#   'problems',
#   'vertebrae',
#   'relieves',
#   'muscular',
#   'calcium',
#   'deposits',
#   'secretions',
#   'adrenal',
#   'liver',
#   'spasms',
#   'ailments',
#   'asana',
#   'muscles',
#   'inflammatory',
#   'pancreas',
#   'nerves',
#   'kidneys'],
#  ['physical',
#   'pitta',
#   'digestive',
#   'sluggishness',
#   'metabolic',
#   'elimination',
#   'useful',
#   'mental',
#   'constipation',
#   'muscular',
#   'processes',
#   'toxins',
#   'flatulence',
#   'different',
#   'removal',
#   'balance',
#   'wind',
#   'vata',
#   'liver',
#   'glands',
#   'control',
#   'harmonizes',
#   'harmony',
#   'stimulates',
#   'asana'],
#  [],
#  ['important',
#   'tones',
#   'moola',
#   'asana',
#   'bandha',
#   'chakra',
#   'reproductive',
#   'eliminatory',
#   'legs',
#   'supple',
#   'feet',
#   'organs',
#   'sexual',
#   'energy',
#   'conservation'],
#  ['reverses',
#   'meditative',
#   'states',
#   'centres',
#   'apana',
#   'asana',
#   'legs',
#   'supple',
#   'feet',
#   'higher'],
#  ['control',
#   'abdomen',
#   'reverses',
#   'celibacy',
#   'arm',
#   'wrists',
#   'apana',
#   'asana',
#   'energy',
#   'muscles',
#   'chakra',
#   'brahmacharya',
#   'manipura',
#   'leg',
#   'netvous',
#   'mind',
#   'body'],
#  ['abdomen',
#   'physical',
#   'gland',
#   'prana',
#   'vrischikasana',
#   'lower',
#   'tones',
#   'flow',
#   'systems',
#   'balance',
#   'loosens',
#   'pituitary',
#   'process',
#   'strengthens',
#   'arms',
#   'brain',
#   'circulation',
#   'ing',
#   'body',
#   'blood',
#   'position',
#   'nerves',
#   'limbs',
#   'sense',
#   'reproductive'],
#  ['abdomen',
#   'tones',
#   'level',
#   'constipation',
#   'internal',
#   'vitalizing',
#   'energy',
#   'asana',
#   'varicose',
#   'circulation',
#   'peristalsis',
#   'body',
#   'blood',
#   'chakras',
#   'legs',
#   'veins',
#   'ductive',
#   'organs',
#   'mind'],
#  ['concentration',
#   'pada',
#   'asana',
#   'addition',
#   'thigh',
#   'muscles',
#   'eka',
#   'sirasana'],
#  [],
#  ['glands',
#   'organs',
#   'systems',
#   'nervous',
#   'digestive',
#   'asana',
#   'vitality',
#   'mas',
#   'abdominal',
#   'pelvic',
#   'plexus',
#   'efficiency',
#   'adrenal',
#   'reproductive',
#   'solar',
#   'eliminatory',
#   'tones'],
#  ['benefits', 'sense', 'asana', 'balance', 'addition', 'padmasana'],
#  ['arms',
#   'vayu',
#   'concentration',
#   'samana',
#   'shoulders',
#   'anahata',
#   'chakras',
#   'asana',
#   'sense',
#   'legs',
#   'balance',
#   'manipura',
#   'chest'],
#  ['arms',
#   'sciatic',
#   'internal',
#   'concentration',
#   'nerves',
#   'asana',
#   'sense',
#   'legs',
#   'balance',
#   'muscles',
#   'organs',
#   'tones'],
#  ['hemisphere',
#   'slow',
#   'profound',
#   'breathing',
#   'flow',
#   'minor',
#   'activates',
#   'awareness',
#   'blockages',
#   'technique',
#   'brain',
#   'breath',
#   'right',
#   'energies',
#   'stage',
#   'balanced',
#   'nostril',
#   'sensitivity',
#   'effects',
#   'nostrils'],
#  ['centres',
#   'prana',
#   'thirst',
#   'flow',
#   'important',
#   'mental',
#   'sleep',
#   'muscular',
#   'free',
#   'relaxation',
#   'biological',
#   'hunger',
#   'control',
#   'practice',
#   'temperature',
#   'tranquillizer',
#   'brain',
#   'excitation',
#   'emotional',
#   'cools',
#   'satisfaction',
#   'body',
#   'tranquillity',
#   'regulation'],
#  [],
#  ['insomnia',
#   'effect',
#   'voice',
#   'healing',
#   'awareness',
#   'capacity',
#   'strengthens',
#   'tension',
#   'meditative',
#   'bhramari',
#   'nen',
#   'state',
#   'body',
#   'sound',
#   'cerebral',
#   'ous',
#   'anger',
#   'vibration',
#   'anxiety',
#   'mind'],
#  ['insomnia',
#   'psychic',
#   'effect',
#   'useful',
#   'pressure',
#   'people',
#   'level',
#   'sleep',
#   'heart',
#   'soothes',
#   'practice',
#   'nervous',
#   'tranquillizing',
#   'high',
#   'calms',
#   'body',
#   'heating',
#   'blood',
#   'pranayama',
#   'rate',
#   'shavasana'],
#  ['proper',
#   'air',
#   'pitta',
#   'massages',
#   'digestive',
#   'metabolic',
#   'meditation',
#   'organs',
#   'useful',
#   'level',
#   'bhastrika',
#   'toxins',
#   'exchange',
#   'wind',
#   'rapid',
#   'vata',
#   'mind',
#   'onepointedness',
#   'practice',
#   'dioxide',
#   'visceral',
#   'stimulates',
#   'diaphragm',
#   'rhythmic',
#   'movement'],
#  ['respiratory',
#   'digestive',
#   'kapalbhati',
#   'effect',
#   'purifies',
#   'tones',
#   'mental',
#   'disorders',
#   'energizes',
#   'sensory',
#   'distractions',
#   'practice',
#   'nadis',
#   'work',
#   'sleepiness',
#   'nervous',
#   'cleansing',
#   'organs',
#   'good'],
#  ['physical',
#   'psychic',
#   'prana',
#   'moorchha',
#   'meditation',
#   'mental',
#   'level',
#   'excellent',
#   'distractions',
#   'world',
#   'tension',
#   'cuts',
#   'inhibits',
#   'body',
#   'state',
#   'inwards',
#   'neuroses',
#   'pranayama',
#   'tranquillity',
#   'anger',
#   'identification',
#   'preparation',
#   'anxiety',
#   'mind'],
#  ['physical',
#   'imbalances',
#   'activities',
#   'communicate',
#   'alert',
#   'meditation',
#   'nadi',
#   'depression',
#   'excellent',
#   'dynamism',
#   'wind',
#   'vata',
#   'energy',
#   'world',
#   'mind',
#   'practice',
#   'stimulates',
#   'external',
#   'pingala',
#   'lethargic',
#   'difficult',
#   'extroversion',
#   'perceptive',
#   'body',
#   'dull'],
#  ['neural',
#   'nerve',
#   'circuit',
#   'area',
#   'index',
#   'experience',
#   'prana',
#   'psycho',
#   'chakra',
#   'practitioner',
#   'meditation',
#   'nadi',
#   'maintains',
#   'chest',
#   'finger',
#   'knees',
#   'receptivity',
#   'important',
#   'mudra',
#   'endings',
#   'addition',
#   'perineum',
#   'energy',
#   'root',
#   'simple'],
#  ['neural',
#   'nerve',
#   'circuit',
#   'area',
#   'index',
#   'experience',
#   'prana',
#   'psycho',
#   'chakra',
#   'practitioner',
#   'meditation',
#   'nadi',
#   'maintains',
#   'chest',
#   'finger',
#   'knees',
#   'receptivity',
#   'important',
#   'mudra',
#   'endings',
#   'addition',
#   'perineum',
#   'energy',
#   'root',
#   'simple'],
#  ['physical',
#   'hand',
#   'area',
#   'index',
#   'activities',
#   'point',
#   'prana',
#   'complete',
#   'meditation',
#   'intensifies',
#   'stable',
#   'chest',
#   'mudra',
#   'concentration',
#   'internal',
#   'balance',
#   'relaxation',
#   'awareness',
#   'practice',
#   'cross',
#   'brain',
#   'right',
#   'energies',
#   'body',
#   'vice'],
#  ['consciousness',
#   'mudra',
#   'practice',
#   'pranayama',
#   'prano',
#   'bhairava',
#   'hands',
#   'dis',
#   'ida',
#   'pingala',
#   'meditation',
#   'union',
#   'supreme',
#   'individual'],
#  ['circuit',
#   'area',
#   'prana',
#   'fmgers',
#   'hridaya',
#   'beneficial',
#   'flow',
#   'mudra',
#   'heart',
#   'ring',
#   'simple',
#   'nadis',
#   'thumb',
#   'diverts',
#   'emotional',
#   'acts',
#   'unburden',
#   'middle',
#   'acute',
#   'conflict',
#   'situations',
#   'crisis',
#   'emotion',
#   'hands',
#   'vitality'],
#  ['thoughtlessness',
#   'tension',
#   'mudra',
#   'mind',
#   'mental',
#   'concentration',
#   'stability',
#   'area',
#   'anger',
#   'emotional',
#   'stress',
#   'muscles',
#   'eye',
#   'calms',
#   'state'],
#  ['aware',
#   'nosetip',
#   'drishti',
#   'psychic',
#   'concentrates',
#   'practitioner',
#   'mudra',
#   'concentration',
#   'excellent',
#   'powers',
#   'nasikagra',
#   'spiritual',
#   'world',
#   'aim',
#   'consciousness',
#   'practice',
#   'meditative',
#   'calming',
#   'technique',
#   'eyes',
#   'open',
#   'states',
#   'anger',
#   'introspection',
#   'planes'],
#  ['kundalini',
#   'number',
#   'points',
#   'awaken',
#   'prana',
#   'shakti',
#   'beneficial',
#   'thirst',
#   'nasal',
#   'hormones',
#   'pressure',
#   'khechari',
#   'mudra',
#   'cavity',
#   'healing',
#   'stillness',
#   'hunger',
#   'glands',
#   'practice',
#   'inner',
#   'certain',
#   'calm',
#   'saliva',
#   'body',
#   'state'],
#  ['tensions',
#   'air',
#   'drishti',
#   'digestive',
#   'lips',
#   'mental',
#   'mudra',
#   'nasikagra',
#   'addition',
#   'soothes',
#   'secretions',
#   'process',
#   'practice',
#   'contact',
#   'membranes',
#   'stimulates',
#   'benefits',
#   'act',
#   'cools',
#   'kaki',
#   'body',
#   'mouth',
#   'mind'],
#  ['stomach',
#   'mudra',
#   'disorders',
#   'time',
#   'float',
#   'air',
#   'length',
#   'abdominal',
#   'practitioner',
#   'wind',
#   'water',
#   'bhujangini',
#   'stagnant',
#   'tones'],
#  ['psychic',
#   'chakra',
#   'practitioner',
#   'beneficial',
#   'mental',
#   'mudra',
#   'concentration',
#   'spiritual',
#   'thoughtlessness',
#   'consciousness',
#   'ajna',
#   'meditative',
#   'stability',
#   'calming',
#   'memory',
#   'state',
#   'bhoochari',
#   'tranquillizes',
#   'states',
#   'power',
#   'anger',
#   'stress',
#   'planes'],
#  ['control',
#   'khechari',
#   'consciousness',
#   'practice',
#   'kumbhaka',
#   'processes',
#   'states',
#   'benefits',
#   'higher',
#   'tranquillity',
#   'induces',
#   'calmness',
#   'arrests'],
#  ['pratyahara',
#   'state',
#   'nerves',
#   'withdrawal',
#   'fingers',
#   'hands',
#   'sense',
#   'heat',
#   'muscles',
#   'energy',
#   'awareness'],
#  ['mudra', 'meditative', 'state', 'agitation', 'calms', 'unmani'],
#  ['physical',
#   'activities',
#   'prana',
#   'effect',
#   'disease',
#   'karani',
#   'flow',
#   'mental',
#   'energy',
#   'awareness',
#   'downward',
#   'practice',
#   'nadis',
#   'benefits',
#   'movement',
#   'asana',
#   'equal',
#   'pingala',
#   'balances',
#   'breath',
#   'vipareeta',
#   'ida',
#   'outward',
#   'posture',
#   'nostrils'],
#  ['drawal',
#   'mudra',
#   'pratyahara',
#   'stimulates',
#   'nervous',
#   'sensory',
#   'pashinee',
#   'nerves',
#   'tranquillity',
#   'massages',
#   'balance',
#   'induces',
#   'abdominal',
#   'spinal',
#   'spine',
#   'muscles',
#   'organs'],
#  ['nerve',
#   'dia',
#   'bending',
#   'trunk',
#   'ward',
#   'area',
#   'areas',
#   'prana',
#   'chakra',
#   'manipura',
#   'tones',
#   'pressure',
#   'mudra',
#   'level',
#   'pelvic',
#   'energy',
#   'tension',
#   'stomach',
#   'plexuses',
#   'visceral',
#   'stimulates',
#   'diaphragm',
#   'phragm',
#   'toned',
#   'circulation'],
#  ['strength',
#   'prana',
#   'health',
#   'flow',
#   'mudra',
#   'energy',
#   'awareness',
#   'subtle',
#   'confidence',
#   'nadis',
#   'attitude',
#   'inner',
#   'equanimity',
#   'external',
#   'source',
#   'peace',
#   'body',
#   'vital',
#   'dormant',
#   'chakras',
#   'cosmic'],
#  ['awaken',
#   'psychic',
#   'massages',
#   'chakra',
#   'meditation',
#   'manipura',
#   'health',
#   'relieves',
#   'excellent',
#   'preparatory',
#   'addition',
#   'relaxation',
#   'energy',
#   'awareness',
#   'control',
#   'tension',
#   'practice',
#   'general',
#   'engendering',
#   'sense',
#   'tranquillity',
#   'abdominal',
#   'anger',
#   'stretches',
#   'organs'],
#  ['counterpose',
#   'mind',
#   'mudra',
#   'fluctuations',
#   'meditative',
#   'nadis',
#   'cross',
#   'mooladhara',
#   'legged',
#   'asanas',
#   'asana',
#   'manduki',
#   'chakra',
#   'ida',
#   'pingala',
#   'meditation',
#   'calms'],
#  ['khechari',
#   'mudra',
#   'ajna',
#   'kumbhaka',
#   'circuit',
#   'spontaneous',
#   'mooladhara',
#   'benefits',
#   'moola',
#   'maha',
#   'prana',
#   'bandha',
#   'chakra',
#   'meditation',
#   'intensifies',
#   'energy',
#   'awareness',
#   'blockages'],
#  ['profound',
#   'manipura',
#   'meditation',
#   'bheda',
#   'mudra',
#   'level',
#   'concentration',
#   'vishuddhi',
#   'influences',
#   'energies',
#   'body',
#   'complex',
#   'influence',
#   'mooladhara',
#   'chakras',
#   'maha',
#   'supercharge',
#   'pranic',
#   'supplements',
#   'mind'],
#  ['kundalini',
#   'practice',
#   'faculties',
#   'introverting',
#   'psychic',
#   'mooladhara',
#   'chakra',
#   'mind',
#   'powerful'],
#  ['practice',
#   'upward',
#   'escape',
#   'purposes',
#   'anal',
#   'spiritual',
#   'redirects',
#   'pranic',
#   'muscles',
#   'energy',
#   'vents'],
#  ['unwanted',
#   'mudra',
#   'meditative',
#   'states',
#   'entire',
#   'genital',
#   'uro',
#   'vajroli',
#   'psycho',
#   'thoughts',
#   'conserves',
#   'sexual',
#   'energy',
#   'conflicts',
#   'tones'],
#  ['variation',
#   'tendency',
#   'respiratory',
#   'compresses',
#   'arteries',
#   'bandha',
#   'pointedness',
#   'breathing',
#   'pressure',
#   'mental',
#   'exerts',
#   'systems',
#   'heart',
#   'relaxation',
#   'metabolism',
#   'subtler',
#   'process',
#   'increase',
#   'simple',
#   'dioxide',
#   'practice',
#   'meditative',
#   'jalandhara',
#   'main',
#   'neck'],
#  ['physical',
#   'ment',
#   'psychic',
#   'uro',
#   'bandha',
#   'enhancement',
#   'relations',
#   'illnesses',
#   'health',
#   'awakening',
#   'tones',
#   'mental',
#   'depression',
#   'systems',
#   'moola',
#   'pelvic',
#   'brahmacharya',
#   'spiritual',
#   'sexual',
#   'energy',
#   'control',
#   'psychosomatic',
#   'excretory',
#   'benefits',
#   'helpful'],
#  ['abdomen',
#   'digestive',
#   'prana',
#   'bandha',
#   'chakra',
#   'panacea',
#   'manipura',
#   'flow',
#   'pressure',
#   'internal',
#   'adrenal',
#   'influences',
#   'energy',
#   'liver',
#   'subtle',
#   'glands',
#   'tension',
#   'samana',
#   'stimulates',
#   'suction',
#   'apana',
#   'uddiyana',
#   'lethargy',
#   'torso',
#   'circulation'],
#  ['culmination',
#   'pranayamas',
#   'gland',
#   'prana',
#   'bandha',
#   'merger',
#   'chakra',
#   'prior',
#   'meditation',
#   'manipura',
#   'processes',
#   'secretions',
#   'endocrine',
#   'samana',
#   'benefits',
#   'introverts',
#   'main',
#   'entire',
#   'ageing',
#   'apana',
#   'pineal',
#   'body',
#   'cell',
#   'hormonal',
#   'chakras'],
#  ['appear',
#   'nerve',
#   'passages',
#   'respiratory',
#   'awaken',
#   'air',
#   'jala',
#   'chakra',
#   'practitioner',
#   'ance',
#   'nose',
#   'health',
#   'nasal',
#   'flow',
#   'depression',
#   'diseases',
#   'muscular',
#   'overall',
#   'ala',
#   'ears',
#   'fresh',
#   'endings',
#   'balance',
#   'head',
#   'tract'],
#  ['bone',
#   'fleshy',
#   'months',
#   'neti',
#   'outgrowths',
#   'obstructions',
#   'friction',
#   'benefits',
#   'sutra',
#   'regular',
#   'jala',
#   'addition',
#   'nostrils',
#   'nasal',
#   'septum',
#   'problem']]

# %%
l
# Out:
# [['contraindications'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['pressure',
#   'people',
#   'practice',
#   'blood',
#   'strenuous',
#   'weak',
#   'heart',
#   'high',
#   'abdominal',
#   'conditions',
#   'muscles',
#   'stage'],
#  [],
#  [],
#  [],
#  ['people', 'asana', 'conditions', 'sacral'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['pressure',
#   'people',
#   'problems',
#   'blood',
#   'patients',
#   'fotward',
#   'ex',
#   'movements',
#   'cervical',
#   'expert',
#   'neck',
#   'high',
#   'low',
#   'treme',
#   'elderly',
#   'vertigo',
#   'advice',
#   'spondylosis'],
#  ['pressure', 'blood', 'persons', 'high', 'conditions', 'disc', 'sciatica'],
#  ['pressure', 'blood', 'persons', 'high', 'conditions', 'disc', 'sciatica'],
#  ['pressure', 'blood', 'persons', 'high', 'conditions', 'disc', 'sciatica'],
#  ['pressure', 'blood', 'persons', 'high', 'conditions', 'disc', 'sciatica'],
#  ['conditions', 'persons'],
#  [],
#  ['practice', 'realign', 'painful', 'asana', 'joint', 'hip'],
#  [],
#  [],
#  ['people', 'conditions', 'asana'],
#  [],
#  [],
#  ['people', 'problems'],
#  ['people', 'problems'],
#  ['pressure',
#   'people',
#   'problems',
#   'practise',
#   'blood',
#   'high',
#   'sclerosis',
#   'asana',
#   'postures',
#   'inverted',
#   'arterio'],
#  ['people', 'disorders', 'toes', 'asana', 'ankles'],
#  ['people', 'knee', 'r', 'problems'],
#  ['yogic',
#   'artery',
#   'kunjal',
#   'retinal',
#   'disorders',
#   'diseases',
#   'lifestyle',
#   'diet',
#   'conjunctivitis',
#   'kriya',
#   'keratitis',
#   'simple',
#   'asanas',
#   'specialist',
#   'trachoma',
#   'vein',
#   'practices',
#   'yoga',
#   'iritis',
#   'thrombosis',
#   'benefit',
#   'great',
#   'condition',
#   'vegetarian',
#   'detachment'],
#  ['yogic',
#   'artery',
#   'kunjal',
#   'retinal',
#   'disorders',
#   'diseases',
#   'lifestyle',
#   'diet',
#   'conjunctivitis',
#   'kriya',
#   'keratitis',
#   'simple',
#   'asanas',
#   'specialist',
#   'trachoma',
#   'vein',
#   'practices',
#   'yoga',
#   'iritis',
#   'thrombosis',
#   'benefit',
#   'great',
#   'condition',
#   'vegetarian',
#   'detachment'],
#  ['yogic',
#   'artery',
#   'kunjal',
#   'retinal',
#   'disorders',
#   'diseases',
#   'lifestyle',
#   'diet',
#   'conjunctivitis',
#   'kriya',
#   'keratitis',
#   'simple',
#   'asanas',
#   'specialist',
#   'trachoma',
#   'vein',
#   'practices',
#   'yoga',
#   'iritis',
#   'thrombosis',
#   'benefit',
#   'great',
#   'condition',
#   'vegetarian',
#   'detachment'],
#  ['yogic',
#   'artery',
#   'kunjal',
#   'retinal',
#   'disorders',
#   'diseases',
#   'lifestyle',
#   'diet',
#   'conjunctivitis',
#   'kriya',
#   'keratitis',
#   'simple',
#   'asanas',
#   'specialist',
#   'trachoma',
#   'vein',
#   'practices',
#   'yoga',
#   'iritis',
#   'thrombosis',
#   'benefit',
#   'great',
#   'condition',
#   'vegetarian',
#   'detachment'],
#  ['yogic',
#   'artery',
#   'kunjal',
#   'retinal',
#   'disorders',
#   'diseases',
#   'lifestyle',
#   'diet',
#   'conjunctivitis',
#   'kriya',
#   'keratitis',
#   'simple',
#   'asanas',
#   'specialist',
#   'trachoma',
#   'vein',
#   'practices',
#   'yoga',
#   'iritis',
#   'thrombosis',
#   'benefit',
#   'great',
#   'condition',
#   'vegetarian',
#   'detachment'],
#  ['yogic',
#   'artery',
#   'kunjal',
#   'retinal',
#   'disorders',
#   'diseases',
#   'lifestyle',
#   'diet',
#   'conjunctivitis',
#   'kriya',
#   'keratitis',
#   'simple',
#   'asanas',
#   'specialist',
#   'trachoma',
#   'vein',
#   'practices',
#   'yoga',
#   'iritis',
#   'thrombosis',
#   'benefit',
#   'great',
#   'condition',
#   'vegetarian',
#   'detachment'],
#  ['yogic',
#   'artery',
#   'kunjal',
#   'retinal',
#   'disorders',
#   'diseases',
#   'lifestyle',
#   'diet',
#   'conjunctivitis',
#   'kriya',
#   'keratitis',
#   'simple',
#   'asanas',
#   'specialist',
#   'trachoma',
#   'vein',
#   'practices',
#   'yoga',
#   'iritis',
#   'thrombosis',
#   'benefit',
#   'great',
#   'condition',
#   'vegetarian',
#   'detachment'],
#  ['yogic',
#   'artery',
#   'kunjal',
#   'retinal',
#   'disorders',
#   'diseases',
#   'lifestyle',
#   'diet',
#   'conjunctivitis',
#   'kriya',
#   'keratitis',
#   'simple',
#   'asanas',
#   'specialist',
#   'trachoma',
#   'vein',
#   'practices',
#   'yoga',
#   'iritis',
#   'thrombosis',
#   'benefit',
#   'great',
#   'condition',
#   'vegetarian',
#   'detachment'],
#  [],
#  [],
#  [],
#  ['pain', 'practise', 'exag', 'asana', 'conditions', 'lumbar', 'curve'],
#  [],
#  [],
#  ['problems', 'asana', 'knee', 'sciatica'],
#  ['flexibility',
#   'practice',
#   'lation',
#   'sciatica',
#   'weak',
#   'advisable',
#   'pre',
#   'pregnancy',
#   'asanas',
#   'asana',
#   'legs',
#   'circu',
#   'meditation',
#   'knees'],
#  ['infections', 'siddhasana', 'sacral', 'sciatica'],
#  ['infections', 'yoni', 'asana', 'sacral', 'siddha', 'sciatica'],
#  ['infections', 'people', 'swastikasana', 'sacral'],
#  [],
#  ['short',
#   'beginners',
#   'pain',
#   'thighs',
#   'remedy',
#   'time',
#   'sit',
#   'feet',
#   'stiffness',
#   'vajrasana',
#   'resume',
#   'legs',
#   'release',
#   'posture',
#   'shake',
#   'ankles',
#   'knees'],
#  ['alternative',
#   'ananda',
#   'classical',
#   'madirasana',
#   'meditation',
#   'postures'],
#  ['pressure',
#   'pranayama',
#   'hand',
#   'place',
#   'seconds',
#   'nostril',
#   'opposite',
#   'armpit',
#   'changes',
#   'nostrils',
#   'padadhirasana',
#   'inute',
#   'preparation',
#   'useful'],
#  ['blanket',
#   'important',
#   'buttocks',
#   'ground',
#   'mooladhara',
#   'chakra',
#   'necessary',
#   'order'],
#  ['variation',
#   'simhaga',
#   'mental',
#   'practice',
#   'janasana',
#   'attitude',
#   'deep',
#   'meditative',
#   'states',
#   'simhasana',
#   'lion',
#   'scriptures',
#   'asana',
#   'posture',
#   'order',
#   'mind'],
#  [],
#  ['variation',
#   'people',
#   'arthritis',
#   'inflammatory',
#   'weakness',
#   'conditions'],
#  [],
#  [],
#  ['pressure', 'people', 'blood', 'suffer', 'high', 'vertigo', 'disc'],
#  ['pressure',
#   'people',
#   'ulcer',
#   'competent',
#   'blood',
#   'hyperthyroidism',
#   'peptic',
#   'guidance',
#   'tuberculosis',
#   'hernia',
#   'high',
#   'asana',
#   'teacher',
#   'vertigo',
#   'intestinal',
#   'disc'],
#  ['pressure',
#   'people',
#   'blood',
#   'weak',
#   'neck',
#   'high',
#   'postures',
#   'inverted'],
#  ['people', 'ankles', 'knees'],
#  ['severe', 'people', 'ailments', 'asana'],
#  ['severe',
#   'people',
#   'competent',
#   'lumbago',
#   'guidance',
#   'asana',
#   'attempt',
#   'teacher',
#   'ailments'],
#  ['problems',
#   'people',
#   'knee',
#   'complaints',
#   'sacral',
#   'neck',
#   'posture',
#   'ailments',
#   'disc',
#   'sciatica'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['problems', 'strenuouus', 'asana', 'disc', 'sciatica'],
#  ['people', 'backache', 'stiff', 'asana'],
#  ['people',
#   'stages',
#   'problems',
#   'practise',
#   'uterus',
#   'prolapse',
#   'pregnancy',
#   'initial',
#   'women'],
#  ['pregnancy', 'utthanasana', 'othexwise'],
#  ['people',
#   'acute',
#   'avoid',
#   'waist',
#   'hips',
#   'asana',
#   'om',
#   'backache',
#   'fi',
#   'care',
#   'sciatica'],
#  [],
#  ['conditions', 'suffering'],
#  ['pressure',
#   'people',
#   'n',
#   'blood',
#   'o',
#   'high',
#   'conditions',
#   'postures',
#   'fi',
#   'inverted',
#   'vertigo'],
#  ['pressure',
#   'people',
#   'blood',
#   'hiatus',
#   'hernia',
#   'high',
#   'postures',
#   'inverted',
#   'vertigo',
#   'sciatica'],
#  [],
#  [],
#  ['cautions',
#   'people',
#   'comfortable',
#   'angle',
#   'hips',
#   'legs',
#   'conditions',
#   'straight',
#   'spine',
#   'forms',
#   'postures',
#   'degree'],
#  ['people', 'problems', 'knee', 'ankle', 'su', 'etch'],
#  ['inverted', 'postures'],
#  ['pressure', 'people', 'blood', 'heart', 'high', 'conditions'],
#  ['ulcer',
#   'people',
#   'peptic',
#   'hernia',
#   'thyroidism',
#   'tuberculosis',
#   'intestinal'],
#  ['pressure',
#   'people',
#   'blood',
#   'delivery',
#   'post',
#   'period',
#   'heart',
#   'high',
#   'asana',
#   'conditions',
#   'attempt',
#   'operative',
#   'eye'],
#  ['people',
#   'practise',
#   'peptic',
#   'heart',
#   'hernia',
#   'asana',
#   'disease',
#   'illness',
#   'conditions',
#   'pregnant',
#   'women',
#   'ulcers'],
#  [],
#  ['pressure',
#   'people',
#   'hydro',
#   'practise',
#   'blood',
#   'variation',
#   'post',
#   'delivery',
#   'period',
#   'heart',
#   'hernia',
#   'high',
#   'asana',
#   'conditions',
#   'operative',
#   'cele',
#   'eye'],
#  [],
#  [],
#  [],
#  [],
#  ['ulcer',
#   'people',
#   'competent',
#   'pressure',
#   'hyperthyroidism',
#   'blood',
#   'peptic',
#   'guidance',
#   'heart',
#   'hernia',
#   'asana',
#   'high',
#   'conditions',
#   'teacher',
#   'tuberculosis',
#   'intestinal'],
#  [],
#  ['physical',
#   'deal',
#   'tuber',
#   'pressure',
#   'people',
#   'practise',
#   'peptic',
#   'culosis',
#   'heart',
#   'effort',
#   'ulcer',
#   'coronary',
#   'hernia',
#   'high',
#   'asana',
#   'shalabhasana',
#   'thrombosis',
#   'blood',
#   'great',
#   'weak',
#   'conditions',
#   'intestinal'],
#  [],
#  ['night',
#   'attempt',
#   'pressure',
#   'people',
#   'sleep',
#   'peptic',
#   'heart',
#   'adrenal',
#   'duodenal',
#   'ulcers',
#   'colitis',
#   'glands',
#   'practice',
#   'stimulates',
#   'hernia',
#   'high',
#   'asana',
#   'blood',
#   'weak',
#   'netvous'],
#  ['people',
#   'stages',
#   'practise',
#   'peptic',
#   'raise',
#   'women',
#   'hernia',
#   'pregnancy',
#   'asana',
#   'abdominal',
#   'practising',
#   'advanced',
#   'duodenal',
#   'ulcers'],
#  [],
#  ['pressure',
#   'stomach',
#   'blood',
#   'weak',
#   'heart',
#   'cervical',
#   'hernia',
#   'high',
#   'asana',
#   'disease',
#   'wrists',
#   'spondylosis'],
#  [],
#  ['people', 'comfortable', 'conditions', 'lower'],
#  ['people', 'paschimottanasana', 'hernia', 'disc', 'sciatica'],
#  ['pressure',
#   'people',
#   'practice',
#   'blood',
#   'strenuous',
#   'paschimottanasana',
#   'heart',
#   'high',
#   'addition',
#   'conditions',
#   'suitable',
#   'problem'],
#  ['practice', 'paschimottanasana'],
#  [],
#  ['short',
#   'holding',
#   'position',
#   'time',
#   'breathe',
#   'inhale',
#   'final',
#   'upright',
#   'breath',
#   'exhale'],
#  ['asana', 'practise', 'sciatica'],
#  ['people',
#   'practise',
#   'cervical',
#   'asana',
#   'spondylitis',
#   'disc',
#   'sciatica'],
#  ['pressure',
#   'people',
#   'blood',
#   'heart',
#   'high',
#   'disease',
#   'asana',
#   'conditions',
#   'postures',
#   'inverted',
#   'disc',
#   'sciatica'],
#  ['people', 'asana', 'conditions', 'postures', 'inverted'],
#  ['people', 'practise', 'coccyx', 'asana', 'dis'],
#  [],
#  ['ulcer',
#   'people',
#   'pressure',
#   'problems',
#   'hyperthyroidism',
#   'blood',
#   'peptic',
#   'heart',
#   'hernia',
#   'high',
#   'asana'],
#  ['ulcer',
#   'people',
#   'competent',
#   'practice',
#   'hyperthyroidism',
#   'practise',
#   'peptic',
#   'guidance',
#   'hernia',
#   'pregnant',
#   'teacher',
#   'women',
#   'disc',
#   'sciatica'],
#  ['people', 'practice', 'complaints', 'pregnant', 'women'],
#  [],
#  [],
#  ['bosis',
#   'throm',
#   'tuberculosis',
#   'disc',
#   'pressure',
#   'people',
#   'problems',
#   'practise',
#   'capillaries',
#   'sinusitis',
#   'heart',
#   'pituitary',
#   'glands',
#   'severe',
#   'cold',
#   'high',
#   'asana',
#   'asthma',
#   'inflammation',
#   'sightedness',
#   'blood',
#   'weak',
#   'impure',
#   'cerebral',
#   'conditions'],
#  ['tuberculosis',
#   'disc',
#   'pressure',
#   'people',
#   'problems',
#   'thrombo',
#   'practise',
#   'capillaries',
#   'sinusitis',
#   'heart',
#   'vertigo',
#   'pituitary',
#   'glands',
#   'severe',
#   'cold',
#   'high',
#   'asana',
#   'asthma',
#   'inflammation',
#   'sightedness',
#   'blood',
#   'weak',
#   'impure',
#   'cerebral',
#   'conditions'],
#  ['spondylitis',
#   'sarvangasana',
#   'padmasana',
#   'disc',
#   'knees',
#   'pressure',
#   'menstruation',
#   'practise',
#   'heart',
#   'healthy',
#   'liver',
#   'vessels',
#   'pregnancy',
#   'asana',
#   'high',
#   'strong',
#   'body',
#   'sciatica',
#   'eyes',
#   'blood',
#   'thrombosis',
#   'weak',
#   'spleen',
#   'cervical',
#   'impure'],
#  ['hernia', 'asana', 'infirm', 'old', 'disc', 'sciatica'],
#  ['pressure',
#   'arthritis',
#   'blood',
#   'suffer',
#   'hernia',
#   'neck',
#   'asana',
#   'high',
#   'problem',
#   'disc',
#   'sciatica'],
#  ['halasana',
#   'people',
#   'pressure',
#   'blood',
#   'ail',
#   'druta',
#   'heart',
#   'hernia',
#   'neck',
#   'ments',
#   'high',
#   'ailments',
#   'sciatica'],
#  ['pressure',
#   'people',
#   'problems',
#   'practice',
#   'blood',
#   'ail',
#   'heart',
#   'hernia',
#   'neck',
#   'ments',
#   'high',
#   'ailments',
#   'sciatica'],
#  ['pressure',
#   'people',
#   'problems',
#   'practice',
#   'blood',
#   'ail',
#   'heart',
#   'hernia',
#   'neck',
#   'ments',
#   'high',
#   'ailments',
#   'sciatica'],
#  ['haemorrhage',
#   'disease',
#   'sirshasana',
#   'pressure',
#   'people',
#   'problems',
#   'constipation',
#   'menstruation',
#   'conjunctivitis',
#   'heart',
#   'ears',
#   'kidney',
#   'head',
#   'catarrh',
#   'chronic',
#   'vessels',
#   'severe',
#   'pregnancy',
#   'neck',
#   'high',
#   'inflammation',
#   'sightedness',
#   'blood',
#   'thrombosis',
#   'weak'],
#  ['haemorrhage',
#   'disease',
#   'sirshasana',
#   'pressure',
#   'people',
#   'problems',
#   'constipation',
#   'menstruation',
#   'conjunctivitis',
#   'heart',
#   'ears',
#   'kidney',
#   'head',
#   'catarrh',
#   'chronic',
#   'vessels',
#   'severe',
#   'pregnancy',
#   'neck',
#   'high',
#   'inflammation',
#   'sightedness',
#   'blood',
#   'thrombosis',
#   'weak'],
#  ['haemorrhage',
#   'disease',
#   'sirshasana',
#   'pressure',
#   'people',
#   'problems',
#   'constipation',
#   'menstruation',
#   'conjunctivitis',
#   'heart',
#   'ears',
#   'kidney',
#   'head',
#   'catarrh',
#   'chronic',
#   'vessels',
#   'severe',
#   'pregnancy',
#   'neck',
#   'high',
#   'inflammation',
#   'sightedness',
#   'blood',
#   'thrombosis',
#   'weak'],
#  ['spondylitis',
#   'sarvangasana',
#   'padmasana',
#   'supple',
#   'disc',
#   'knees',
#   'pressure',
#   'menstruation',
#   'practise',
#   'heart',
#   'healthy',
#   'liver',
#   'vessels',
#   'pregnancy',
#   'asana',
#   'high',
#   'strong',
#   'body',
#   'sciatica',
#   'eyes',
#   'blood',
#   'thrombosis',
#   'weak',
#   'spleen',
#   'cervical'],
#  ['haemorrhage',
#   'disease',
#   'sirshasana',
#   'pressure',
#   'people',
#   'problems',
#   'constipation',
#   'menstruation',
#   'conjunctivitis',
#   'heart',
#   'ears',
#   'kidney',
#   'head',
#   'catarrh',
#   'chronic',
#   'vessels',
#   'severe',
#   'pregnancy',
#   'neck',
#   'high',
#   'inflammation',
#   'sightedness',
#   'blood',
#   'thrombosis',
#   'weak'],
#  [],
#  [],
#  [],
#  [],
#  ['pressure',
#   'people',
#   'blood',
#   'weak',
#   'peptic',
#   'heart',
#   'hernia',
#   'high',
#   'asana',
#   'duodenal',
#   'ulcers',
#   'colitis'],
#  ['pressure',
#   'people',
#   'blood',
#   'weak',
#   'peptic',
#   'heart',
#   'hernia',
#   'high',
#   'asana',
#   'duodenal',
#   'ulcers',
#   'colitis'],
#  ['pressure', 'people', 'problems', 'blood', 'heart', 'high', 'asana'],
#  ['pressure',
#   'people',
#   'practise',
#   'blood',
#   'heart',
#   'asanas',
#   'high',
#   'asana',
#   'inverted',
#   'vertigo'],
#  ['people', 'complaints', 'hip', 'asana'],
#  ['pressure',
#   'people',
#   'infections',
#   'blood',
#   'heart',
#   'high',
#   'sacral',
#   'merudandasana',
#   'ailments',
#   'disc'],
#  ['infections',
#   'people',
#   'pressure',
#   'blood',
#   'heart',
#   'high',
#   'disease',
#   'asana',
#   'sacral',
#   'disc',
#   'sciatica'],
#  [],
#  ['pressure',
#   'people',
#   'practise',
#   'blood',
#   'weak',
#   'hernia',
#   'high',
#   'asana',
#   'legs',
#   'postures',
#   'inverted',
#   'disc',
#   'sciatica'],
#  ['pressure',
#   'people',
#   'practice',
#   'blood',
#   'strenuous',
#   'weak',
#   'heart',
#   'hips',
#   'hernia',
#   'high',
#   'knees',
#   'asana',
#   'ankles',
#   'disc',
#   'sciatica'],
#  ['people', 'problems', 'knee', 'asana', 'ankle', 'disc', 'sciatica'],
#  ['pressure',
#   'people',
#   'practice',
#   'blood',
#   'thrombosis',
#   'heart',
#   'high',
#   'disease',
#   'cerebral',
#   'attempt'],
#  [],
#  ['pressure',
#   'people',
#   'blood',
#   'weak',
#   'heart',
#   'hernia',
#   'high',
#   'asana',
#   'disc',
#   'sciatica'],
#  ['inhale', 'floor', 'breath', 'exhale', 'body'],
#  ['pressure',
#   'people',
#   'blood',
#   'peptic',
#   'women',
#   'hernia',
#   'high',
#   'asana',
#   'attempt',
#   'pregnant',
#   'duodenal',
#   'hyperacidity',
#   'ulcers'],
#  [],
#  ['pressure',
#   'people',
#   'blood',
#   'weakness',
#   'heart',
#   'hernia',
#   'limbs',
#   'high',
#   'asana',
#   'conditions',
#   'ailments'],
#  ['ulcer',
#   'people',
#   'competent',
#   'pressure',
#   'hyperthyroidism',
#   'blood',
#   'peptic',
#   'guidance',
#   'cervical',
#   'hernia',
#   'heart',
#   'asana',
#   'high',
#   'condition',
#   'teacher',
#   'spondylitis',
#   'tuberculosis',
#   'intestinal'],
#  ['arthritis',
#   'flexible',
#   'hernia',
#   'asana',
#   'perform',
#   'spine',
#   'chronic',
#   'disc',
#   'sciatica'],
#  ['form',
#   'strenuous',
#   'spondylitis',
#   'tuber',
#   'pressure',
#   'people',
#   'practise',
#   'peptic',
#   'culosis',
#   'heart',
#   'inverted',
#   'ulcer',
#   'coronary',
#   'hernia',
#   'asanas',
#   'high',
#   'asana',
#   'shalabhasana',
#   'thrombosis',
#   'backs',
#   'blood',
#   'weak',
#   'cervical',
#   'conditions',
#   'advanced'],
#  [],
#  ['dislocation', 'joints', 'hip', 'disc', 'sciatica'],
#  ['pressure',
#   'stomach',
#   'people',
#   'blood',
#   'thrombosis',
#   'coronary',
#   'high',
#   'ailment'],
#  ['people', 'complaints', 'asana'],
#  ['cautions',
#   'people',
#   'weak',
#   'pregnancy',
#   'wrists',
#   'tired',
#   'postures',
#   'inverted',
#   'chakrasana',
#   'feeling'],
#  ['people',
#   'dislocation',
#   'hernia',
#   'asana',
#   'conditions',
#   'attempt',
#   'joint',
#   'hip',
#   'disc',
#   'sciatica'],
#  ['pressure',
#   'people',
#   'blood',
#   'heart',
#   'hernia',
#   'high',
#   'asana',
#   'ailment'],
#  ['strenuous',
#   'attempt',
#   'spondylitis',
#   'health',
#   'disc',
#   'pressure',
#   'people',
#   'problems',
#   'practise',
#   'diseases',
#   'myopia',
#   'acid',
#   'inverted',
#   'stomach',
#   'arthritis',
#   'coronary',
#   'hernia',
#   'neck',
#   'high',
#   'asana',
#   'asanas',
#   'blood',
#   'prolapse',
#   'sound',
#   'conditions'],
#  ['strenuous',
#   'attempt',
#   'teacher',
#   'health',
#   'disc',
#   'pressure',
#   'people',
#   'competent',
#   'problems',
#   'practise',
#   'guidance',
#   'heart',
#   'myopia',
#   'acid',
#   'inverted',
#   'chronic',
#   'stomach',
#   'arthritis',
#   'hernia',
#   'neck',
#   'high',
#   'asana',
#   'asanas',
#   'blood',
#   'prolapse'],
#  ['ulcer',
#   'people',
#   'practise',
#   'hyperthyroidism',
#   'peptic',
#   'hernia',
#   'disc',
#   'sciatica'],
#  ['physical',
#   'pressure',
#   'people',
#   'practise',
#   'peptic',
#   'heart',
#   'pregnant',
#   'postures',
#   'ailment',
#   'duodenal',
#   'inverted',
#   'mayurasana',
#   'ulcer',
#   'weakness',
#   'hernia',
#   'high',
#   'asana',
#   'blood',
#   'sign',
#   'illness',
#   'women'],
#  ['sciatica', 'weak', 'asana', 'nayurasana', 'addition', 'knees'],
#  ['flexible', 'ankles', 'knees'],
#  ['flexible', 'knees', 'atte', 'npted', 'beecome'],
#  ['arms',
#   'people',
#   'pressure',
#   'problems',
#   'blood',
#   'shoulders',
#   'heart',
#   'hips',
#   'high',
#   'asana',
#   'conditions',
#   'strong'],
#  ['strenuous',
#   'bosis',
#   'throm',
#   'disease',
#   'attempt',
#   'pressure',
#   'people',
#   'heart',
#   'poses',
#   'catarrh',
#   'inverted',
#   'chronic',
#   'high',
#   'asana',
#   'difficulty',
#   'blood',
#   'slightest',
#   'cerebral',
#   'postures',
#   'vertigo'],
#  ['problems',
#   'people',
#   'prevent',
#   'strained',
#   'flexible',
#   'hernia',
#   'asana',
#   'ligaments',
#   'posture',
#   'muscles',
#   'ailmen',
#   'hip',
#   'body'],
#  ['pressure',
#   'ankles',
#   'blood',
#   'strenuous',
#   'pada',
#   'high',
#   'asana',
#   'addition',
#   'vertigo',
#   'eka',
#   'sirasana',
#   'knees'],
#  [],
#  ['flexible',
#   'persons',
#   'asana',
#   'ligaments',
#   'ailment',
#   'strained',
#   'muscles',
#   'body'],
#  [],
#  [],
#  [],
#  ['fever', 'shodhana', 'colds', 'nadi', 'flu', 'suffering'],
#  ['respiratory',
#   'centres',
#   'low',
#   'disease',
#   'cool',
#   'lower',
#   'pressure',
#   'people',
#   'disorders',
#   'practise',
#   'constipation',
#   'excessive',
#   'heart',
#   'chronic',
#   'energy',
#   'practice',
#   'mucous',
#   'breath',
#   'asthma',
#   'blood',
#   'pranayama',
#   'activity',
#   'winter',
#   'retention',
#   'climates'],
#  ['pranayama', 'sheetali', 'sensitive', 'practitioners', 'teeth', 'dentures'],
#  ['infections', 'people', 'severe', 'pranayama', 'bhramari', 'ear'],
#  ['people', 'practice', 'perform', 'nature'],
#  ['bronchitis',
#   'disease',
#   'retinal',
#   'elderly',
#   'lung',
#   'teacher',
#   'tuberculosis',
#   'pressure',
#   'people',
#   'problems',
#   'practise',
#   'bhastrika',
#   'diseases',
#   'trimester',
#   'competent',
#   'guidance',
#   'heart',
#   'chronic',
#   'ulcer',
#   'stroke',
#   'pregnancy',
#   'hernia',
#   'high',
#   'gastric',
#   'asthma'],
#  ['pressure',
#   'ulcer',
#   'blood',
#   'stroke',
#   'heart',
#   'hernia',
#   'pregnancy',
#   'high',
#   'disease',
#   'kapalbhati',
#   'gastric',
#   'epilepsy',
#   'vertigo'],
#  ['pressure',
#   'aim',
#   'disorders',
#   'practice',
#   'blood',
#   'sensation',
#   'arteries',
#   'heart',
#   'carotid',
#   'high',
#   'disease',
#   'technique',
#   'basilar',
#   'brain',
#   'complete',
#   'epilepsy',
#   'unconsciousness',
#   'suffering'],
#  ['ulcer',
#   'people',
#   'practise',
#   'pranayama',
#   'peptic',
#   'hypertension',
#   'heart',
#   'disease',
#   'acidity',
#   'epilepsy',
#   'hyperthyroid',
#   'anxiety'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['cataract',
#   'final',
#   'retinal',
#   'diabetic',
#   'release',
#   'teacher',
#   'people',
#   'mudra',
#   'surgery',
#   'competent',
#   'guidance',
#   'operation',
#   'retinopathy',
#   'shambhavi',
#   'implant',
#   'lens',
#   'sensitive',
#   'strain',
#   'eyes',
#   'position',
#   'weak',
#   'glaucoma',
#   'long',
#   'nerves',
#   'detachment'],
#  ['people',
#   'mudra',
#   'practice',
#   'surgery',
#   'competent',
#   'depression',
#   'guidance',
#   'glaucoma',
#   'nasikagra',
#   'drishti',
#   'cataract',
#   'implant',
#   'diabetic',
#   'lens',
#   'teacher',
#   'eye',
#   'operations',
#   'retinopathy'],
#  ['mudra',
#   'practice',
#   'sign',
#   'performance',
#   'mouth',
#   'toxins',
#   'common',
#   'secretion',
#   'ailments',
#   'tongue',
#   'ulcers',
#   'bitter'],
#  ['air',
#   'cataract',
#   'low',
#   'diabetic',
#   'teacher',
#   'nose',
#   'operations',
#   'pressure',
#   'people',
#   'mudra',
#   'depression',
#   'constipation',
#   'surgery',
#   'competent',
#   'normal',
#   'guidance',
#   'chronic',
#   'retinopathy',
#   'cold',
#   'weather',
#   'practice',
#   'polluted',
#   'implant',
#   'lens',
#   'strain'],
#  [],
#  ['people',
#   'mudra',
#   'surgery',
#   'competent',
#   'guidance',
#   'glaucoma',
#   'cataract',
#   'implant',
#   'diabetic',
#   'lens',
#   'teacher',
#   'eye',
#   'operations',
#   'retinopathy',
#   'bhoochari'],
#  ['pressure',
#   'competent',
#   'people',
#   'practice',
#   'blood',
#   'disorders',
#   'epilepsy',
#   'mudra',
#   'guidance',
#   'high',
#   'technique',
#   'brain',
#   'teacher',
#   'faintness',
#   'vertigo'],
#  ['people', 'practice', 'depression'],
#  ['competent',
#   'guidance',
#   'glaucoma',
#   'diabetic',
#   'teacher',
#   'unmani',
#   'perform',
#   'eye',
#   'operations',
#   'retinopathy'],
#  ['pressure',
#   'people',
#   'practice',
#   'blood',
#   'toxins',
#   'precautions',
#   'heart',
#   'excessive',
#   'high',
#   'disease',
#   'healthy',
#   'postures',
#   'inverted',
#   'thyroid',
#   'body'],
#  ['halasana',
#   'people',
#   'practice',
#   'precautions',
#   'condition',
#   'spinal',
#   'postures',
#   'sarvangasana'],
#  ['practice', 'prolapse', 'hernia', 'pregnant', 'women'],
#  [],
#  ['pressure',
#   'people',
#   'practice',
#   'blood',
#   'inflammatory',
#   'high',
#   'disease',
#   'abdominal',
#   'pelvic',
#   'ailment',
#   'sciatica'],
#  ['drishti',
#   'cataract',
#   'hips',
#   'slow',
#   'diabetic',
#   'teacher',
#   'operations',
#   'people',
#   'competent',
#   'surgery',
#   'guidance',
#   'nasikagra',
#   'flexible',
#   'manduki',
#   'retinopathy',
#   'rhythmic',
#   'asana',
#   'implant',
#   'lens',
#   'glaucoma',
#   'eye',
#   'ankles'],
#  ['impurity',
#   'cataract',
#   'diabetic',
#   'opera',
#   'teacher',
#   'prior',
#   'people',
#   'competent',
#   'surgery',
#   'mudra',
#   'active',
#   'menstruation',
#   'guidance',
#   'toxins',
#   'heart',
#   'retinopathy',
#   'practice',
#   'complaints',
#   'pregnancy',
#   'high',
#   'hot',
#   'implant',
#   'eruptions',
#   'lens',
#   'symptoms'],
#  ['prior',
#   'bheda',
#   'pressure',
#   'people',
#   'problems',
#   'mudra',
#   'active',
#   'kumbhaka',
#   'menstruation',
#   'heart',
#   'moola',
#   'lot',
#   'diaphragmatic',
#   'spondylosis',
#   'ulcer',
#   'stomach',
#   'practice',
#   'jalandhara',
#   'precautions',
#   'complaints',
#   'hernia',
#   'pregnancy',
#   'uddiyana',
#   'high',
#   'purification'],
#  ['area',
#   'cushions',
#   'disease',
#   'attempt',
#   'impact',
#   'wide',
#   'knees',
#   'pressure',
#   'important',
#   'people',
#   'problems',
#   'active',
#   'menstruation',
#   'coccyx',
#   'mat',
#   'heart',
#   'pelvic',
#   'injury',
#   'practice',
#   'buttocks',
#   'land',
#   'complaints',
#   'pregnancy',
#   'high',
#   'infection'],
#  ['pressure',
#   'people',
#   'blood',
#   'kumbhaka',
#   'heart',
#   'high',
#   'disease',
#   'antar'],
#  ['people',
#   'mudra',
#   'pain',
#   'increase',
#   'irritation',
#   'vajroli',
#   'urethritis'],
#  ['refrain',
#   'disease',
#   'bandha',
#   'spon',
#   'pressure',
#   'people',
#   'heart',
#   'lock',
#   'light',
#   'practice',
#   'jalandhara',
#   'neck',
#   'high',
#   'breath',
#   'dizziness',
#   'blood',
#   'long',
#   'cervical',
#   'intracranial',
#   'retention',
#   'effects',
#   'dylosis',
#   'vertigo'],
#  ['competent',
#   'menstruation',
#   'practice',
#   'guidance',
#   'moola',
#   'hyperactivity',
#   'bandha',
#   'precipitate',
#   'teacher',
#   'energy'],
#  ['persons',
#   'disease',
#   'pressure',
#   'problems',
#   'heart',
#   'diaphragmatic',
#   'colitis',
#   'ulcer',
#   'stomach',
#   'practice',
#   'pregnancy',
#   'hernia',
#   'high',
#   'blood',
#   'glaucoma',
#   'abdominal',
#   'intracranial',
#   'perform',
#   'intestinal',
#   'major'],
#  ['pressure',
#   'people',
#   'stomach',
#   'ulcer',
#   'blood',
#   'practice',
#   'visceral',
#   'heart',
#   'hernia',
#   'high',
#   'low',
#   'conditions',
#   'pregnant',
#   'ailment',
#   'women',
#   'intestinal'],
#  ['infections',
#   'colds',
#   'blockage',
#   'jala',
#   'teacher',
#   'nose',
#   'people',
#   'competent',
#   'sinusitis',
#   'expert',
#   'prone',
#   'structural',
#   'chronic',
#   'ear',
#   'culty',
#   'water',
#   'diffi',
#   'advice',
#   'neti',
#   'great',
#   'flu'],
#  ['people',
#   'severe',
#   'advice',
#   'yogic',
#   'doctor',
#   'ayurvedic',
#   'neti',
#   'sutra',
#   'ulcers',
#   'nose',
#   'chronic',
#   'turbinates',
#   'nasal',
#   'malformations',
#   'septum']]

# %%
asanas['Word_Soup_new'] = k[1:]

# %%
asanas['Word_Soup_Not_To_Do'] = l[1:]

# %%
asanas = asanas.drop(['word_soup','contradiction_word_soup'],axis = 1)

# %%
asanas.to_csv('asanas_word_soup.csv')

# %%
#Getting the user's input for genre, actors and directors of their liking.

def get_goals():
  genres = input("What is your fitness goal to achieve? [Type 'skip' to skip this question] ")
  genres = " ".join(["".join(n.split()) for n in genres.lower().split(',')])
  return genres

def get_wt_height_gender():
  actors = input("Please enter your Weight(kg) and Height(m) and gender(M/F) (e.g. 64kg, 1.7m, M ====> (64,1.7,M))? [Type 'skip' to skip this question] ")
  actors = " ".join(["".join(n.split()) for n in actors.lower().split(',')])
  return actors

def get_steps_thr():
  directors = input("Please enter your daily step count and THR and fat burnt/day (if multiple, please separate them with a comma)? [Type 'skip' to skip this question] ")
  directors = " ".join(["".join(n.split()) for n in directors.lower().split(',')])
  return directors

def get_keywords():
  keywords = input("Please enter the physical problems faced by you if any?")
  keywords = " ".join(["".join(n.split()) for n in keywords.lower().split(',')])
  return keywords

def get_searchTerms():
  searchTerms = [] 
  genres = get_genres()
  if genres != 'skip':
    searchTerms.append(genres)

  actors = get_actors()
  if actors != 'skip':
    searchTerms.append(actors)

  directors = get_directors()
  if directors != 'skip':
    searchTerms.append(directors)

  keywords = get_keywords()
  if keywords != 'skip':
    searchTerms.append(keywords)
  
  return searchTerms

# %%
import pandas as pd
BFAB = pd.read_csv('/content/drive/MyDrive/BloomFitbitAndBMIDataset.csv')

# %%
BFAB.describe()
# Out:
#                SID          BMI          Sex         Steps          THR  \
# count  1801.000000  1801.000000  1801.000000   1801.000000  1801.000000
# mean    901.000000    24.599833     0.381455  10595.295465   171.071919
# std     520.048235     5.178591     0.485879   2605.662181   118.634997
# min       1.000000    14.500000     0.000000   1054.000000     0.000000
# 25%     451.000000    21.100000     0.000000   8963.965812    94.592233
# 50%     901.000000    23.300000     0.000000  10380.203250   141.258929
# 75%    1351.000000    26.500000     1.000000  12032.057380   207.681319
# max    1801.000000    49.400000     1.000000  24410.826090  1146.211382
#
#            FatBurn       Cardio         Peak          Age
# count  1801.000000  1801.000000  1801.000000  1801.000000
# mean    156.456978    11.246749     3.368193    19.024986
# std      98.768331    24.351886    12.821958     1.307218
# min       0.000000     0.000000     0.000000    16.000000
# 25%      88.657407     2.459459     0.290909    18.000000
# 50%     132.883929     4.739837     0.796748    19.000000
# 75%     194.766667     9.350427     2.206897    19.000000
# max     838.454545   336.489796   210.571429    24.000000

# %%
BFAB
# Out:
#        SID   BMI  Sex         Steps         THR     FatBurn     Cardio  \
# 0        1  14.5    0   8244.168142  110.327434  108.168142   2.097345
# 1        2  15.7    0   8888.471545  347.089431  338.130081   8.487805
# 2        3  15.8    0  15412.228070  138.052632  123.850877   9.535088
# 3        4  15.8    0  13337.075470  145.518868  133.924528   9.443396
# 4        5  15.9    1  11913.763640  230.881818  210.118182  15.900000
# ...    ...   ...  ...           ...         ...         ...        ...
# 1796  1797  46.9    1  10460.324320  490.216216  452.009009  30.306306
# 1797  1798  47.6    0  10501.043480  186.034783  179.252174   5.104348
# 1798  1799  47.8    0   5071.616541  140.736842  138.090226   2.571429
# 1799  1800  49.4    0  10473.840000  150.640000  149.440000   1.160000
# 1800  1801  49.4    0   7040.859504  180.909091  171.429752   8.619835
#
#           Peak  Age Class
# 0     0.061947   18   FR
# 1     0.471545   18   FR
# 2     4.666667   19   FR
# 3     2.150943   19   SO
# 4     4.863636   19   SO
# ...        ...  ...   ...
# 1796  7.900901   24   FR
# 1797  1.678261   19   FR
# 1798  0.075188   18   FR
# 1799  0.040000   19    FR
# 1800  0.859504   21   SO
#
# [1801 rows x 10 columns]

# %%
BFAB_BodyType = pd.read_csv('/content/drive/MyDrive/Body_Type.csv')

# %%
BFAB_BodyType = BFAB_BodyType.drop(['Unnamed: 0','SID','Class'],axis=1)

# %%
BFAB_BodyType
# Out:
#        BMI  Sex         Steps         THR     FatBurn     Cardio      Peak  \
# 0     14.5    0   8244.168142  110.327434  108.168142   2.097345  0.061947
# 1     15.7    0   8888.471545  347.089431  338.130081   8.487805  0.471545
# 2     15.8    0  15412.228070  138.052632  123.850877   9.535088  4.666667
# 3     15.8    0  13337.075470  145.518868  133.924528   9.443396  2.150943
# 4     15.9    1  11913.763640  230.881818  210.118182  15.900000  4.863636
# ...    ...  ...           ...         ...         ...        ...       ...
# 1796  46.9    1  10460.324320  490.216216  452.009009  30.306306  7.900901
# 1797  47.6    0  10501.043480  186.034783  179.252174   5.104348  1.678261
# 1798  47.8    0   5071.616541  140.736842  138.090226   2.571429  0.075188
# 1799  49.4    0  10473.840000  150.640000  149.440000   1.160000  0.040000
# 1800  49.4    0   7040.859504  180.909091  171.429752   8.619835  0.859504
#
#       Age  Active  Healthy BMI  Healthy Heart Body Type
# 0      18       0            0              1        VP
# 1      18       0            0              2         V
# 2      19       1            0              1        VP
# 3      19       1            0              1        VP
# 4      19       1            0              1        VP
# ...   ...     ...          ...            ...       ...
# 1796   24       1            2              2        KV
# 1797   19       1            2              1         K
# 1798   18       0            2              1        KP
# 1799   19       1            2              1         K
# 1800   21       0            2              1        KP
#
# [1801 rows x 12 columns]

# %%
BFAB_BodyType.groupby(['Body Type'])
BFAB_BodyType['Body Type'].value_counts()
# Out:
# P     697
# KP    329
# K     293
# VK    151
# PV    131
# KV     99
# VP     96
# V       5
# Name: Body Type, dtype: int64

# %%
stud_count  = BFAB_BodyType['Active'].value_counts()
stud_count = stud_count[:2,]

# %%
import seaborn as sns
from matplotlib import pyplot as plt
plt.figure(figsize=(5,5))
sns.barplot(stud_count.index, stud_count.values, alpha=0.8)
plt.title('Weekly Activity tracker')
# Set x-axis label
plt.xlabel('Inactive=0//Active=1')
# Set y-axis label
plt.ylabel('Number of students')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'Number of students')

# %%
BMI_count  = BFAB_BodyType['Healthy BMI'].value_counts()
BMI_count = BMI_count[:3,]

# %%
plt.figure(figsize=(5,5))
sns.barplot(BMI_count.index, BMI_count.values, alpha=0.8)
plt.title('BMI tracker')
# Set x-axis label
plt.xlabel('Underweight=0   Healthy=1   Obese=2')
# Set y-axis label
plt.ylabel('Number of students')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'Number of students')

# %%
HH_count  = BFAB_BodyType['Healthy Heart'].value_counts()
HH_count = HH_count[:3,]

# %%
plt.figure(figsize=(5,5))
sns.barplot(HH_count.index, HH_count.values, alpha=0.8)
plt.title('Heart Rate tracker')
# Set x-axis label
plt.xlabel('Low Heart Rate=0   Healthy Heart Rate=1   Unhealthy Heart=2')
# Set y-axis label
plt.ylabel('Number of students')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'Number of students')

# %%
# load and summarize the dataset
from pandas import read_csv
from collections import Counter
from matplotlib import pyplot
from sklearn.preprocessing import LabelEncoder
# define the dataset location
#url = '/content/drive/MyDrive/Body_Type.csv'
# load the csv file as a data frame

data = BFAB_BodyType.values
# split into input and output elements
X, y = data[:, :-1], data[:, -1]
# label encode the target variable
#y = LabelEncoder().fit_transform(y)
# summarize distribution
counter = Counter(y)
for k,v in counter.items():
	per = v / len(y) * 100
	print('Class=%s, n=%d (%.3f%%)' % (k, v, per))
# plot the distribution
pyplot.title('Body Type Constitution')
pyplot.bar(counter.keys(), counter.values())
pyplot.show()
# Out:
# Class=VP, n=96 (5.330%)
# Class=V, n=5 (0.278%)
# Class=VK, n=151 (8.384%)
# Class=P, n=697 (38.701%)
# Class=KP, n=329 (18.268%)
# Class=KV, n=99 (5.497%)
# Class=PV, n=131 (7.274%)
# Class=K, n=293 (16.269%)

# %%
# example of oversampling a multi-class classification dataset
from pandas import read_csv
from imblearn.over_sampling import RandomOverSampler
from collections import Counter
from matplotlib import pyplot
from sklearn.preprocessing import LabelEncoder
# define the dataset location

data = BFAB_BodyType.values
# split into input and output elements
X, y = data[:, :-1], data[:, -1]
# label encode the target variable
#y = LabelEncoder().fit_transform(y)
# transform the dataset
oversample = RandomOverSampler()
X, y = oversample.fit_resample(X, y)
# summarize distribution
counter = Counter(y)
for k,v in counter.items():
	per = v / len(y) * 100
	print('Class=%s, n=%d (%.3f%%)' % (k, v, per))
# plot the distribution
pyplot.title('Body Type Constitution Balanced')
pyplot.bar(counter.keys(), counter.values())
pyplot.show()
# Out:
# Class=VP, n=697 (12.500%)
# Class=V, n=697 (12.500%)
# Class=VK, n=697 (12.500%)
# Class=P, n=697 (12.500%)
# Class=KP, n=697 (12.500%)
# Class=KV, n=697 (12.500%)
# Class=PV, n=697 (12.500%)
# Class=K, n=697 (12.500%)

# %%
df = pd.DataFrame(X,columns =['BMI','Sex','Steps','THR','FatBurn','Cardio','Peak','Age','Active','Healthy BMI','Healthy Heart'])

# %%
df_1 = pd.DataFrame(y,columns =['Body Type'])

# %%
df_Oversampled = pd.merge(df, df_1, left_index=True, right_index=True)

# %%
df_Oversampled.to_csv('CSV_Oversampled.csv')

# %%
#Importing the necessary packages and libaries
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn import svm, datasets
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state = 0)

# %%
linear = svm.SVC(kernel='linear', C=1, decision_function_shape='ovo').fit(X_train, y_train)
rbf = svm.SVC(kernel='rbf', gamma=1, C=1, decision_function_shape='ovo').fit(X_train, y_train)
poly = svm.SVC(kernel='poly', degree=3, C=1, decision_function_shape='ovo').fit(X_train, y_train)
sig = svm.SVC(kernel='sigmoid', C=1, decision_function_shape='ovo').fit(X_train, y_train)

# %%
poly_pred = poly.predict(X_test)
rbf_pred = rbf.predict(X_test)
linear_pred = linear.predict(X_test)
sig_pred = sig.predict(X_test)

# %%
poly_accuracy = accuracy_score(y_test, poly_pred)
poly_f1 = f1_score(y_test, poly_pred, average='weighted')
print('Accuracy (Polynomial Kernel): ', "%.2f" % (poly_accuracy*100))
print('F1 (Polynomial Kernel): ', "%.2f" % (poly_f1*100))
# Out:
# Accuracy (Polynomial Kernel):  36.38
# F1 (Polynomial Kernel):  33.69

# %%
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
print(precision_score(y_test, poly_pred,average=None))
print(recall_score(y_test, poly_pred,average=None))
# Out:
# [0.41726619 0.3699187  0.         0.55555556 0.64383562 0.20168067
#  0.61904762 0.07777778]
# [0.46031746 0.57961783 0.         0.07407407 0.56287425 0.36090226
#  0.7        0.10144928]

# %%
from sklearn.metrics import precision_recall_fscore_support
precision_recall_fscore_support(y_test, poly_pred, average=None, labels=['V', 'P', 'K', 'VP', 'VK', 'KV', 'KP', 'PV'])
# Out:
# (array([0.20168067, 0.55555556, 0.41726619, 0.07777778, 0.61904762,
#         0.        , 0.3699187 , 0.64383562]),
#  array([0.36090226, 0.07407407, 0.46031746, 0.10144928, 0.7       ,
#         0.        , 0.57961783, 0.56287425]),
#  array([0.25876011, 0.13071895, 0.43773585, 0.08805031, 0.65703971,
#         0.        , 0.4516129 , 0.60063898]),
#  array([133, 135, 126, 138, 130, 130, 157, 167]))

# %%
labels=['V', 'P', 'K', 'VP', 'VK', 'KV', 'KP', 'PV']

# %%
rbf_accuracy = accuracy_score(y_test, rbf_pred)
rbf_f1 = f1_score(y_test, rbf_pred, average='weighted')
print('Accuracy (RBF Kernel): ', "%.2f" % (rbf_accuracy*100))
print('F1 (RBF Kernel): ', "%.2f" % (rbf_f1*100))
# Out:
# Accuracy (RBF Kernel):  95.43
# F1 (RBF Kernel):  95.59

# %%
precision_recall_fscore_support(y_test, rbf_pred, average=None, labels=['V', 'P', 'K', 'VP', 'VK', 'KV', 'KP', 'PV'])
# Out:
# (array([1.        , 0.72580645, 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        ]),
#  array([1.        , 1.        , 0.86507937, 1.        , 1.        ,
#         1.        , 0.8089172 , 0.9760479 ]),
#  array([1.        , 0.8411215 , 0.92765957, 1.        , 1.        ,
#         1.        , 0.8943662 , 0.98787879]),
#  array([133, 135, 126, 138, 130, 130, 157, 167]))

# %%
linear_accuracy = accuracy_score(y_test, linear_pred)
linear_f1 = f1_score(y_test, linear_pred, average='weighted')
print('Accuracy (Linear Kernel): ', "%.2f" % (linear_accuracy*100))
print('F1 (Linear Kernel): ', "%.2f" % (linear_f1*100))
# Out:
# Accuracy (Linear Kernel):  82.97
# F1 (Linear Kernel):  82.57

# %%
sig_accuracy = accuracy_score(y_test, sig_pred)
sig_f1 = f1_score(y_test, sig_pred, average='weighted')
print('Accuracy (sig Kernel): ', "%.2f" % (sig_accuracy*100))
print('F1 (sig Kernel): ', "%.2f" % (sig_f1*100))
# Out:
# Accuracy (sig Kernel):  6.72
# F1 (sig Kernel):  3.40

# %%
# training a DescisionTreeClassifier
from sklearn.tree import DecisionTreeClassifier
dtree_model = DecisionTreeClassifier(max_depth = 5).fit(X_train, y_train)
dtree_predictions = dtree_model.predict(X_test)
  
# creating a confusion matrix
accuracy_DT = accuracy_score(y_test, dtree_predictions)
Snew_f1_score = f1_score(y_test, dtree_predictions, average='weighted')

# %%
accuracy_DT
# Out:
# 0.9874551971326165

# %%
Snew_f1_score
# Out:
# 0.987433650715478

# %%
precision_recall_fscore_support(y_test, dtree_predictions, average=None, labels=['V', 'P', 'K', 'VP', 'VK', 'KV', 'KP', 'PV'])
# Out:
# (array([0.9047619, 1.       , 1.       , 1.       , 1.       , 1.       ,
#         1.       , 1.       ]),
#  array([1.        , 1.        , 1.        , 0.89855072, 1.        ,
#         1.        , 1.        , 1.        ]),
#  array([0.95      , 1.        , 1.        , 0.94656489, 1.        ,
#         1.        , 1.        , 1.        ]),
#  array([133, 135, 126, 138, 130, 130, 157, 167]))

# %%
from sklearn.ensemble import RandomForestClassifier
# Fitting Random Forest Classification to the Training set
rf_classifier = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 42)
rf_classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=42)

# %%
# Predicting the Test set results
y_pred_rf = rf_classifier.predict(X_test)

# %%
precision_recall_fscore_support(y_test, y_pred_rf, average=None, labels=['V', 'P', 'K', 'VP', 'VK', 'KV', 'KP', 'PV'])
# Out:
# (array([1., 1., 1., 1., 1., 1., 1., 1.]),
#  array([1., 1., 1., 1., 1., 1., 1., 1.]),
#  array([1., 1., 1., 1., 1., 1., 1., 1.]),
#  array([133, 135, 126, 138, 130, 130, 157, 167]))

# %%
rf_accuracy = accuracy_score(y_test, y_pred_rf)
rf_f1 = f1_score(y_test, y_pred_rf, average='weighted')
print('Accuracy (RF): ', "%.2f" % (rf_accuracy*100))
print('F1 (RF): ', "%.2f" % (rf_f1*100))
# Out:
# Accuracy (RF):  100.00
# F1 (RF):  100.00

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_pred_rf)
# Out:
# array([[126,   0,   0,   0,   0,   0,   0,   0],
#        [  0, 157,   0,   0,   0,   0,   0,   0],
#        [  0,   0, 130,   0,   0,   0,   0,   0],
#        [  0,   0,   0, 135,   0,   0,   0,   0],
#        [  0,   0,   0,   0, 167,   0,   0,   0],
#        [  0,   0,   0,   0,   0, 133,   0,   0],
#        [  0,   0,   0,   0,   0,   0, 130,   0],
#        [  0,   0,   0,   0,   0,   0,   0, 138]])

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors=1)
neigh_model = neigh.fit(X_train, y_train)
neigh_pred = neigh.predict(X_test)
accuracy_knn = accuracy_score(y_test, neigh_pred)
knn_f1_score = f1_score(y_test, neigh_pred, average='weighted')

# %%
accuracy_knn
# Out:
# 0.9453405017921147

# %%
knn_f1_score
# Out:
# 0.9438417847826767

# %%
precision_recall_fscore_support(y_test, neigh_pred, average=None, labels=['V', 'P', 'K', 'VP', 'VK', 'KV', 'KP', 'PV'])
# Out:
# (array([0.98518519, 0.7654321 , 0.65      , 0.86075949, 0.89208633,
#         0.96992481, 0.9858156 , 0.98816568]),
#  array([1.        , 0.45925926, 0.82539683, 0.98550725, 0.95384615,
#         0.99230769, 0.88535032, 1.        ]),
#  array([0.99253731, 0.57407407, 0.72727273, 0.91891892, 0.92193309,
#         0.98098859, 0.93288591, 0.99404762]),
#  array([133, 135, 126, 138, 130, 130, 157, 167]))

# %%
importance = rf_classifier.feature_importances_
# summarize feature importance
for i,v in enumerate(importance):
	print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()
# Out:
# Feature: 0, Score: 0.14323
# Feature: 1, Score: 0.00287
# Feature: 2, Score: 0.11192
# Feature: 3, Score: 0.13725
# Feature: 4, Score: 0.09928
# Feature: 5, Score: 0.02023
# Feature: 6, Score: 0.00717
# Feature: 7, Score: 0.01060
# Feature: 8, Score: 0.09358
# Feature: 9, Score: 0.21875
# Feature: 10, Score: 0.15512

# %%
rf_classifier.feature_importances_
# Out:
# array([0.14323449, 0.00286994, 0.11191992, 0.13725125, 0.09927697,
#        0.0202329 , 0.00717289, 0.01059731, 0.09358291, 0.21874556,
#        0.15511587])

# %%
f1_score
# Out:
# 1.0

# %%
# training a KNN classifier
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 7).fit(X_train, y_train)
  
# accuracy on X_test
accuracy = knn.score(X_test, y_test)
print(accuracy)
  
# creating a confusion matrix
knn_predictions = knn.predict(X_test) 
cm = confusion_matrix(y_test, knn_predictions)
# Out:
# 0.8064516129032258

# %%
# training a Naive Bayes classifier
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB().fit(X_train, y_train)
gnb_predictions = gnb.predict(X_test)
  
# accuracy on X_test
accuracy = gnb.score(X_test, y_test)
print(accuracy)
# Out:
# 0.8620071684587813

# %%
import pandas as pd
import seaborn as sns
import numpy as np

#creating sample data 
sample_data={'BMI':BFAB_BodyType['BMI'],
      'Body Type': BFAB_BodyType['Body Type']}
df= pd.DataFrame(sample_data)
sns.scatterplot(x="BMI", y="Body Type", data=df)

# %%
#creating sample data 
sample_data={'Steps':BFAB_BodyType['Steps'],
      'Body Type': BFAB_BodyType['Body Type']}
df= pd.DataFrame(sample_data)
sns.scatterplot(x="Steps", y="Body Type", data=df)

# %%
line_sample_data = {'BMI':BFAB_BodyType['BMI'],
                    'Steps':BFAB_BodyType['Steps']}
df= pd.DataFrame(line_sample_data)                
   
plot2 = sns.scatterplot(x="BMI", y="Steps", data=df)
plot2.set_xlim(20,30)
# Out:
# (20.0, 30.0)

# %%
line_sample_data = {'BMI':BFAB_BodyType['BMI'],
                    'Steps':BFAB_BodyType['Steps']}
df= pd.DataFrame(line_sample_data)                
   
plot2 = sns.scatterplot(x="BMI", y="Steps", data=df)
plot2.set_xlim(30,50)
# Out:
# (30.0, 50.0)

# %%
line_sample_data = {'BMI':BFAB_BodyType['BMI'],
                    'THR':BFAB_BodyType['THR']}
df= pd.DataFrame(line_sample_data)                
   
plot2 = sns.scatterplot(x="BMI", y="THR", data=df)
plot2.set_xlim(20,30)
# Out:
# (20.0, 30.0)

# %%
line_sample_data = {'BMI':BFAB_BodyType['BMI'],
                    'THR':BFAB_BodyType['THR']}
df= pd.DataFrame(line_sample_data)                
   
plot2 = sns.scatterplot(x="BMI", y="THR", data=df)
plot2.set_xlim(30,50)
# Out:
# (30.0, 50.0)

# %%
line_sample_data = {'BMI':BFAB_BodyType['BMI'],
                    'THR':BFAB_BodyType['THR']}
df= pd.DataFrame(line_sample_data)                
   
plot2 = sns.scatterplot(x="BMI", y="THR", data=df)
plot2.set_xlim(30,35)
# Out:
# (30.0, 35.0)

# %% [markdown]
# First sentence embedding technique:Doc2Vec

# %%
word_soup_new = []
benefits_asanas = []
word_soup_new = asanas['Word_Soup_new'].to_list()
asanas['Benefits'] = asanas['Benefits'].apply(str)
benefits_asanas = asanas['Benefits'].to_list()

sentence_not_to_do = []
asanas['Contraindications'] = asanas['Contraindications'].apply(str)
sentence_not_to_do = asanas['Contraindications'].to_list()

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
import numpy as np
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
# import
tagged_data = []
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
tagged_data = [TaggedDocument(d, [i]) for i, d in enumerate(word_soup_new)]
tagged_data
# Out:
# [TaggedDocument(words=['self', 'group', 'blood', 'pressure', 'excellent', 'asanas', 'useful', 'energy', 'awareness', 'rheumatism', 'heart', 'problems', 'ments', 'arthritis', 'exercise', 'body', 'blockages', 'confidence', 'high', 'coordination', 'physical', 'joints', 'vigorous'], tags=[0]),
#  TaggedDocument(words=['self', 'group', 'blood', 'pressure', 'excellent', 'asanas', 'useful', 'energy', 'awareness', 'rheumatism', 'heart', 'problems', 'ments', 'arthritis', 'exercise', 'body', 'blockages', 'confidence', 'high', 'coordination', 'physical', 'joints', 'vigorous'], tags=[1]),
#  TaggedDocument(words=['self', 'group', 'blood', 'pressure', 'excellent', 'asanas', 'useful', 'energy', 'awareness', 'rheumatism', 'heart', 'problems', 'ments', 'arthritis', 'exercise', 'body', 'blockages', 'confidence', 'high', 'coordination', 'physical', 'joints', 'vigorous'], tags=[2]),
#  TaggedDocument(words=['stagnant', 'lymph', 'foot', 'blood', 'cramp', 'help', 'tiredness', 'post', 'bedridden', 'relieve', 'operative', 'venous', 'calf', 'asanas', 'thrombosis', 'patients'], tags=[3]),
#  TaggedDocument(words=['self', 'group', 'blood', 'pressure', 'excellent', 'asanas', 'useful', 'energy', 'awareness', 'rheumatism', 'heart', 'problems', 'ments', 'arthritis', 'exercise', 'body', 'blockages', 'confidence', 'high', 'coordination', 'physical', 'joints', 'vigorous'], tags=[4]),
#  TaggedDocument(words=['self', 'group', 'blood', 'pressure', 'excellent', 'asanas', 'useful', 'energy', 'awareness', 'rheumatism', 'heart', 'problems', 'ments', 'arthritis', 'exercise', 'body', 'blockages', 'confidence', 'high', 'coordination', 'physical', 'joints', 'vigorous'], tags=[5]),
#  TaggedDocument(words=['asanas', 'ligaments', 'knee', 'strong', 'muscles', 'body', 'vulnerable', 'quadriceps', 'muscle', 'weight', 'sprains', 'healing', 'joint', 'injuries', 'energies'], tags=[6]),
#  TaggedDocument(words=['preparatory', 'titali', 'ardha', 'knee', 'positions', 'joints', 'practice', 'morning', 'excellent', 'loos', 'evening', 'daily', 'asana', 'meditative', 'hip', 'legged', 'people'], tags=[7]),
#  TaggedDocument(words=['self', 'group', 'blood', 'pressure', 'excellent', 'asanas', 'useful', 'energy', 'awareness', 'rheumatism', 'heart', 'problems', 'ments', 'arthritis', 'exercise', 'body', 'blockages', 'confidence', 'high', 'coordination', 'physical', 'joints', 'vigorous'], tags=[8]),
#  TaggedDocument(words=['inner', 'hours', 'muscles', 'stages', 'tiredness', 'legs', 'tension', 'padmasana', 'long', 'mastery', 'asanas', 'meditative', 'thigh', 'lot'], tags=[9]),
#  TaggedDocument(words=['self', 'group', 'blood', 'pressure', 'excellent', 'asanas', 'useful', 'energy', 'awareness', 'rheumatism', 'heart', 'problems', 'ments', 'arthritis', 'exercise', 'body', 'blockages', 'confidence', 'high', 'coordination', 'physical', 'joints', 'vigorous'], tags=[10]),
#  TaggedDocument(words=['self', 'group', 'blood', 'pressure', 'excellent', 'asanas', 'useful', 'energy', 'awareness', 'rheumatism', 'heart', 'problems', 'ments', 'arthritis', 'exercise', 'body', 'blockages', 'confidence', 'high', 'coordination', 'physical', 'joints', 'vigorous'], tags=[11]),
#  TaggedDocument(words=['prolonged', 'joints', 'typing', 'beneficial', 'writing', 'asanas', 'tension', 'hand', 'wrist'], tags=[12]),
#  TaggedDocument(words=['self', 'group', 'blood', 'pressure', 'excellent', 'asanas', 'useful', 'energy', 'awareness', 'rheumatism', 'heart', 'problems', 'ments', 'arthritis', 'exercise', 'body', 'blockages', 'confidence', 'high', 'coordination', 'physical', 'joints', 'vigorous'], tags=[13]),
#  TaggedDocument(words=['self', 'group', 'blood', 'pressure', 'excellent', 'asanas', 'useful', 'energy', 'awareness', 'rheumatism', 'heart', 'problems', 'ments', 'arthritis', 'exercise', 'body', 'blockages', 'confidence', 'high', 'coordination', 'physical', 'joints', 'vigorous'], tags=[14]),
#  TaggedDocument(words=['help', 'pressure', 'frozen', 'cervical', 'strain', 'shape', 'shoulder', 'shoulders', 'asanas', 'office', 'spondylitis', 'work'], tags=[15]),
#  TaggedDocument(words=['limbs', 'region', 'body', 'desk', 'heaviness', 'stiffness', 'organs', 'shoulder', 'nerves', 'shoulders', 'release', 'different', 'muscles', 'asanas', 'tension', 'head', 'neck', 'work'], tags=[16]),
#  TaggedDocument(words=['strengthens', 'perineal', 'abdominal', 'digestive', 'prolapse', 'asana', 'muscles', 'lower', 'massages', 'pelvic'], tags=[17]),
#  TaggedDocument(words=['obesity', 'joints', 'good', 'abdominal', 'muscles', 'hip', 'spinal'], tags=[18]),
#  TaggedDocument(words=['knee', 'good', 'joints', 'abdominal', 'muscles', 'lower', 'hip'], tags=[19]),
#  TaggedDocument(words=['useful', 'constipation', 'pawanmuktasana', 'vertebrae', 'lower', 'problems', 'muscles', 'wind', 'effective', 'reproductive', 'supta', 'spinal', 'impotence', 'menstrual', 'sterility', 'organs', 'digestive', 'massages', 'pelvic'], tags=[20]),
#  TaggedDocument(words=['hips', 'morning', 'thing', 'asana', 'massages', 'useful'], tags=[21]),
#  TaggedDocument(words=['vertebra', 'excellent', 'time', 'asana', 'stiffness', 'stretch', 'sitting', 'prolonged', 'constipation', 'spine', 'twist', 'tion', 'plexus', 'lower', 'ther', 'buttocks', 'twisting', 'distance', 'abdominal', 'cardiac', 'diges', 'muscles', 'spinal', 'placement', 'efore'], tags=[22]),
#  TaggedDocument(words=['tiredness', 'tightness', 'abdominal', 'organs', 'action', 'lower', 'pelvic'], tags=[23]),
#  TaggedDocument(words=['r', 'deep', 'asana', 'tension', 'systems', 'useful', 'women', 'circu', 'pregnancy', 'childbearing', 'nervous', 'state', 'second', 'muscular', 'deeper', 'relaxation', 'hormonal', 'lethargy', 'latory', 'shavasana', 'trimester', 'order', 'organs', 'digestive', 'tones'], tags=[24]),
#  TaggedDocument(words=['firms', 'joints', 'upper', 'loosens', 'breast', 'chest', 'shoulder', 'asana', 'muscles'], tags=[25]),
#  TaggedDocument(words=['spine', 'flexibility', 'asana', 'increases', 'stiffness'], tags=[26]),
#  TaggedDocument(words=['recovery', 'menstrual', 'exercise', 'cycle', 'postnatal', 'pelvis', 'toning', 'organs', 'abdomen', 'excellent', 'nerves', 'months', 'asana', 'useful'], tags=[27]),
#  TaggedDocument(words=['energy', 'recovery', 'areas', 'constipation', 'effect', 'positive', 'disorders', 'post', 'blockages', 'pelvis', 'abdomen', 'natal', 'asana', 'useful', 'gynaecological'], tags=[28]),
#  TaggedDocument(words=['blades', 'effect', 'joints', 'upper', 'frustration', 'mood', 'special', 'inaccessible', 'girdle', 'shoulder', 'lighten', 'tones', 'asana', 'muscles', 'pelvic'], tags=[29]),
#  TaggedDocument(words=['effect', 'hips', 'flexibility', 'arms', 'profound', 'thighs', 'asana', 'muscles', 'neck'], tags=[30]),
#  TaggedDocument(words=['mas', 'pressure', 'arms', 'leg', 'neck', 'useful', 'stretch', 'effect', 'spine', 'vertebrae', 'toned', 'flatulence', 'thighs', 'namaskarasana', 'muscles', 'equal', 'spinal', 'joints', 'beneficial', 'organs', 'nerves', 'arm', 'pelvic'], tags=[31]),
#  TaggedDocument(words=['blood', 'meditation', 'constipation', 'legs', 'asana', 'circulation', 'asanas'], tags=[32]),
#  TaggedDocument(words=['ailments', 'region', 'constipation', 'abdominal', 'organs', 'muscles', 'useful'], tags=[33]),
#  TaggedDocument(words=['correction', 'relaxes', 'eye', 'aqueous', 'palming', 'stimulates', 'circulation', 'vision', 'muscles', 'liquid', 'defective', 'humour', 'cornea'], tags=[34]),
#  TaggedDocument(words=['eye', 'muscles', 'habitual', 'eyesight', 'spontaneous', 'relaxation', 'reflex', 'eyes', 'becmne', 'encourages', 'blink', 'tension', 'defective', 'state', 'people'], tags=[35]),
#  TaggedDocument(words=['sideways', 'close', 'corrects', 'constant', 'viewing', 'reading', 'muscles', 'tension', 'work'], tags=[36]),
#  TaggedDocument(words=['sideways', 'lateral', 'medial', 'viewing', 'eyeball', 'muscles', 'coordination'], tags=[37]),
#  TaggedDocument(words=['muscles', 'lower', 'balances', 'eyeball'], tags=[38]),
#  TaggedDocument(words=['acti', 'coordinated', 'eye', 'viewing', 'rotational', 'muscles', 'vities'], tags=[39]),
#  TaggedDocument(words=['eye', 'muscles', 'exercise', 'power'], tags=[40]),
#  TaggedDocument(words=['eye', 'movements', 'exercise', 'power', 'muscles'], tags=[41]),
#  TaggedDocument(words=['awareness', 'practi', 'tioner', 'physiological', 'psycho', 'pratyahara', 'body', 'sleep', 'mind', 'practice', 'exercises', 'namaskara', 'relaxed', 'asana', 'tired', 'dynamic'], tags=[42]),
#  TaggedDocument(words=['figure', 'stiff', 'disc', 'neck'], tags=[43]),
#  TaggedDocument(words=['upper', 'cervical', 'spondylitis', 'asana', 'complaints', 'helpful', 'neck', 'spinal', 'stiff'], tags=[44]),
#  TaggedDocument(words=['air', 'time', 'compression', 'asana', 'people', 'awareness', 'pain', 'periods', 'shape', 'lower', 'sciatica', 'normal', 'releases', 'effective', 'spinal', 'vertebral', 'simple', 'ailments', 'lungs', 'types', 'disc', 'nerves', 'certain', 'column', 'lung'], tags=[45]),
#  TaggedDocument(words=['pressure', 'nidra', 'veins', 'asana', 'head', 'asanas', 'tension', 'circumstances', 'perineum', 'people', 'ideal', 'bent', 'kridasana', 'matsya', 'posture', 'pain', 'months', 'backward', 'block', 'circulation', 'comfort', 'relaxing', 'sciatic', 'tnended', 'knee'], tags=[46]),
#  TaggedDocument(words=['difficult', 'physical', 'persons', 'meditation', 'postures', 'sukhasana', 'effect', 'mental', 'medita', 'balance', 'strain', 'pain', 'unable', 'tion', 'comfortable', 'easiest', 'ill'], tags=[47]),
#  TaggedDocument(words=['padmasana', 'level', 'benefits'], tags=[48]),
#  TaggedDocument(words=['pressure', 'blood', 'experience', 'step', 'time', 'long', 'pillar', 'head', 'process', 'tension', 'trunk', 'perineum', 'calm', 'meditation', 'effect', 'mind', 'sahasrara', 'legs', 'spine', 'posture', 'periods', 'nervous', 'lower', 'relaxing', 'muscular'], tags=[49]),
#  TaggedDocument(words=['lumbar', 'chakras', 'foot', 'pressure', 'pubic', 'sahajoli', 'swadhisthana', 'blood', 'presses', 'pelvis', 'psychic', 'sensations', 'locks', 'sexual', 'perineum', 'flow', 'brain', 'energy', 'bone', 'necessary', 'tingling', 'control', 'cord', 'spine', 'posture'], tags=[50]),
#  TaggedDocument(words=['lumbar', 'chakras', 'foot', 'pressure', 'pubic', 'sahajoli', 'swadhisthana', 'blood', 'presses', 'pelvis', 'psychic', 'sensations', 'asana', 'locks', 'sexual', 'perineum', 'flow', 'brain', 'energy', 'bone', 'necessary', 'tingling', 'control', 'cord', 'spine'], tags=[51]),
#  TaggedDocument(words=['position', 'retention', 'fluid', 'healthy', 'legs', 'veins', 'swastikasana', 'muscles', 'varicose', 'tired'], tags=[52]),
#  TaggedDocument(words=['centre', 'time', 'long', 'asana', 'asanas', 'thigh', 'useful', 'inner', 'meditation', 'legs', 'periods', 'outer', 'easy', 'body', 'hips', 'contact', 'structure', 'muscles', 'comfortable', 'knees', 'reproductive', 'floor', 'position', 'postures', 'large'], tags=[53]),
#  TaggedDocument(words=['alters', 'blood', 'ulcer', 'stomach', 'men', 'veins', 'hyperacidity', 'nerve', 'useful', 'hernia', 'hydrocele', 'dilated', 'measure', 'nervous', 'entire', 'genitals', 'impulses', 'piles', 'muscles', 'peptic', 'feed', 'testicles', 'menstrual', 'region', 'fibres'], tags=[54]),
#  TaggedDocument(words=['ajna', 'mind', 'calms', 'benefits', 'chakra', 'asana', 'nervous', 'vajrasana'], tags=[55]),
#  TaggedDocument(words=['autonomic', 'activities', 'pressure', 'facilitate', 'nostrils', 'pranayama', 'breath', 'right', 'parasympathetic', 'systems', 'practice', 'balance', 'state', 'nervous', 'influences', 'armpits', 'flow'], tags=[56]),
#  TaggedDocument(words=['influence', 'meditation', 'aspirants', 'benefits', 'spiritual', 'chakra', 'excellent', 'mooladhara', 'vajrasana'], tags=[57]),
#  TaggedDocument(words=['physical', 'total', 'stability', 'cord', 'body', 'posture', 'extension', 'definite', 'spinal'], tags=[58]),
#  TaggedDocument(words=['mouth', 'frustration', 'throat', 'chest', 'excellent', 'asana', 'tension', 'useful', 'people', 'simhagarjanasana', 'sun', 'nervous', 'stutter', 'beautiful', 'early', 'emotional', 'voice', 'ears', 'strong', 'rays', 'morning', 'benefits', 'eyes', 'nose', 'mudra'], tags=[59]),
#  TaggedDocument(words=['balances', 'precise', 'clear', 'realms', 'concentration', 'process', 'asana', 'beco', 'useful', 'kidneys', 'awareness', 'unconscious', 'mental', 'mind', 'good', 'nuch', 'nes', 'abdominal', 'power', 'relaxation', 'reproductive', 'uncontrollable', 'physical', 'organs', 'thoughts'], tags=[60]),
#  TaggedDocument(words=['menstrual', 'cramps', 'forceful', 'pregnancy', 'female', 'flexibility', 'abdomen', 'relief', 'leucorrhea', 'shoulders', 'asana', 'reproductive', 'neck', 'contraction'], tags=[61]),
#  TaggedDocument(words=['blood', 'asana', 'hip', 'directions', 'women', 'legs', 'digestion', 'female', 'circulation', 'sciatic', 'hips', 'exercises', 'sciatica', 'abdominal', 'thighs', 'children', 'weight', 'muscles', 'reproductive', 'spinal', 'joints', 'birth', 'loosens', 'beneficial', 'organs'], tags=[62]),
#  TaggedDocument(words=['problem', 'pressure', 'discs', 'asana', 'nerve', 'strengthens', 'forms', 'constipation', 'cord', 'practice', 'posture', 'female', 'vertebrae', 'male', 'correct', 'sciatic', 'individual', 'backache', 'adrenal', 'muscles', 'cases', 'reproductive', 'spinal', 'position', 'glands'], tags=[63]),
#  TaggedDocument(words=['excellent', 'natal', 'asana', 'shashank', 'kidneys', 'spine', 'female', 'male', 'shashankasana', 'final', 'abdominal', 'benefits', 'muscles', 'reproductive', 'position', 'postures', 'menstrual', 'region', 'liver', 'disorders', 'organs', 'tones', 'bhujangasana', 'similar', 'pelvic'], tags=[64]),
#  TaggedDocument(words=['brain', 'preparatory', 'pressure', 'degree', 'sirshasana', 'body', 'practice', 'benefits', 'extra', 'headstand', 'head', 'lesser'], tags=[65]),
#  TaggedDocument(words=['stretch', 'strengthens', 'good', 'feet', 'hips', 'legs', 'abdominal', 'balance', 'organs', 'tones', 'asana', 'ankles', 'nervous', 'lower'], tags=[66]),
#  TaggedDocument(words=['level', 'ushtrasana'], tags=[67]),
#  TaggedDocument(words=['stomach', 'asana', 'helpful', 'systems', 'neck', 'people', 'intestines', 'rounded', 'constipation', 'posture', 'vertebrae', 'backache', 'thyroid', 'reproductive', 'spinal', 'asthma', 'region', 'loosens', 'beneficial', 'organs', 'digestive', 'nerves', 'shoulders'], tags=[68]),
#  TaggedDocument(words=['realigns', 'gland', 'chest', 'suffering', 'asana', 'asanas', 'capacity', 'sexual', 'neck', 'brain', 'energy', 'rounded', 'meditation', 'constipation', 'oxygen', 'thyroid', 'abdominal', 'om', 'spinal', 'asthma', 'lungs', 'ailments', 'loosens', 'flexible', 'beneficial'], tags=[69]),
#  TaggedDocument(words=['blood', 'deep', 'asana', 'influences', 'capacity', 'stiffness', 'breaths', 'brain', 'breathing', 'rectifies', 'round', 'upper', 'extra', 'oxygen', 'circulation', 'heart', 'body', 'supply', 'shoulders'], tags=[70]),
#  TaggedDocument(words=['cramp', 'tensing', 'ann', 'shoulder', 'deep', 'asana', 'tension', 'helpful', 'stiffness', 'neck', 'people', 'energy', 'blades', 'significant', 'bad', 'postural', 'posture', 'pain', 'smoothes', 'spondylitis', 'exercises', 'alternate', 'muscles', 'responsible', 'short'], tags=[71]),
#  TaggedDocument(words=['ligaments', 'tadasana', 'clear', 'longer', 'bones', 'points', 'asana', 'useful', 'mental', 'pregnancy', 'spine', 'balance', 'abdomini', 'congestion', 'months', 'entire', 'rectus', 'abdominal', 'muscles', 'spinal', 'physical', 'height', 'nerves', 'column'], tags=[72]),
#  TaggedDocument(words=['tadasana', 'groups', 'sides', 'waist', 'postural', 'muscles', 'massages'], tags=[73]),
#  TaggedDocument(words=['time', 'asana', 'tension', 'stiffness', 'useful', 'neck', 'movement', 'mental', 'postural', 'day', 'lightness', 'twisting', 'problems', 'waist', 'relaxation', 'feeling', 'physical', 'shoulders', 'tones'], tags=[74]),
#  TaggedDocument(words=['kati', 'balance', 'chakrasana', 'asana', 'muscles', 'coordination'], tags=[75]),
#  TaggedDocument(words=['excess', 'spine', 'tones', 'weight', 'asana', 'muscles', 'waistline'], tags=[76]),
#  TaggedDocument(words=['ankles', 'pelvis', 'thighs', 'uterus', 'asana', 'muscles', 'middle'], tags=[77]),
#  TaggedDocument(words=['muscles', 'legs'], tags=[78]),
#  TaggedDocument(words=['rectifies', 'posture', 'chest', 'poor', 'shoulders', 'asana'], tags=[79]),
#  TaggedDocument(words=['young', 'blades', 'upper', 'good', 'spine', 'chest', 'shoulder', 'asana', 'muscles', 'bodies', 'neck'], tags=[80]),
#  TaggedDocument(words=['sides', 'fat', 'trunk', 'legs', 'digestion', 'practice', 'help', 'nervous', 'waist', 'muscles', 'reproductive', 'depression', 'waistline', 'alleviates', 'organs', 'tones', 'area', 'series', 'regular', 'pelvic'], tags=[81]),
#  TaggedDocument(words=['stagnant', 'han', 'excellent', 'asana', 'asanas', 'practice', 'alveoli', 'mucus', 'circulation', 'tiredness', 'benefits', 'strings', 'prepranayama', 'muscles', 'spinal', 'organs', 'nerves', 'massages', 'visceral'], tags=[82]),
#  TaggedDocument(words=['blood', 'supple', 'circulation', 'nerves', 'tones', 'hamstrings', 'asana', 'muscles', 'head', 'face', 'spinal'], tags=[83]),
#  TaggedDocument(words=['practice', 'concentration', 'calmness', 'preparation', 'state'], tags=[84]),
#  TaggedDocument(words=[], tags=[85]),
#  TaggedDocument(words=[], tags=[86]),
#  TaggedDocument(words=[], tags=[87]),
#  TaggedDocument(words=['strengthens', 'limbs', 'height', 'ligaments', 'blades', 'upper', 'spine', 'longer', 'circulation', 'shoulder', 'bones', 'muscles'], tags=[88]),
#  TaggedDocument(words=['strengthens', 'region', 'blades', 'spine', 'exercises', 'chest', 'shoulder', 'arm', 'muscles', 'leg'], tags=[89]),
#  TaggedDocument(words=[], tags=[90]),
#  TaggedDocument(words=['spaces', 'indigestion', 'general', 'yogamudrasana', 'constipation', 'good', 'health', 'abdominal', 'vertebrae', 'organs', 'chakra', 'excellent', 'nerves', 'asana', 'manipura', 'spinal'], tags=[91]),
#  TaggedDocument(words=['stagnant', 'blood', 'pressure', 'gland', 'stimulates', 'deep', 'asana', 'vitality', 'useful', 'stretch', 'constipation', 'good', 'thymus', 'water', 'legs', 'circulation', 'immune', 'backache', 'thyroid', 'abdominal', 'respiration', 'thighs', 'perform', 'piles', 'asthma'], tags=[92]),
#  TaggedDocument(words=['peace', 'productive', 'emotional', 'meditation', 'stability', 'postural', 'posture', 'balance', 'relaxation', 'asana', 'useful', 'defects'], tags=[93]),
#  TaggedDocument(words=['growth', 'chests', 'arms', 'pain', 'normal', 'children', 'shoulders', 'awakening', 'kundalini'], tags=[94]),
#  TaggedDocument(words=['experience', 'stimulates', 'asana', 'increases', 'security', 'effect', 'mind', 'balance', 'appetite', 'anger', 'emotional', 'excited', 'adrenal', 'calms', 'abdominal', 'practise', 'uncontrollable', 'sense', 'stability', 'glands', 'organs', 'digestive', 'massages'], tags=[95]),
#  TaggedDocument(words=['excess', 'equanimity', 'abdominal', 'relaxation', 'organs', 'strength', 'tones', 'weight', 'asana', 'muscles', 'lower', 'thigh', 'state'], tags=[96]),
#  TaggedDocument(words=['good', 'arms', 'shoulders', 'asana', 'stiff', 'backs'], tags=[97]),
#  TaggedDocument(words=['bhujangasana', 'influence', 'arms'], tags=[98]),
#  TaggedDocument(words=['muscles', 'effect', 'posture', 'profound', 'shoulders', 'bhujangasana', 'sarpasana', 'addition'], tags=[99]),
#  TaggedDocument(words=['organs', 'shalabhasana', 'excellent', 'area', 'asana', 'tension', 'pelvic', 'ardha'], tags=[100]),
#  TaggedDocument(words=['balances', 'stomach', 'mild', 'stimulates', 'long', 'appetite', 'shalabhasana', 'relief', 'lower', 'buttocks', 'backache', 'condition', 'body', 'sciatica', 'abdominal', 'muscles', 'mudra', 'liver', 'disc', 'organs', 'bowels', 'tones', 'pelvic'], tags=[101]),
#  TaggedDocument(words=['respiratory', 'lungs', 'discomfort', 'disorders', 'creased', 'posture', 'dhanurasana', 'benefits', 'pain', 'disc', 'beneficial', 'tones', 'levels', 'cervical', 'lower', 'heart', 'useful', 'spondylitis'], tags=[102]),
#  TaggedDocument(words=['secretions', 'blood', 'ligaments', 'ed', 'cetvical', 'netves', 'asana', 'leg', 'balancing', 'useful', 'stiffness', 'kidneys', 'strengthens', 'energy', 'constipation', 'upper', 'pancreas', 'dhanurasana', 'circulation', 'correct', 'entire', 'sluggishness', 'alimentary', 'gastrointestinal', 'excess'], tags=[103]),
#  TaggedDocument(words=['bronchial', 'asana', 'useful', 'miscarry', 'rounded', 'colon', 'women', 'spine', 'digestion', 'female', 'prolapse', 'backache', 'management', 'abdominal', 'thyroid', 'reproductive', 'asthma', 'conditions', 'menstrual', 'disorders', 'realign', 'organs', 'shoulders', 'tones', 'massages'], tags=[104]),
#  TaggedDocument(words=['blades', 'constipation', 'tightness', 'exercises', 'chest', 'benefits', 'risk', 'effects', 'excellent', 'tones', 'shoulder', 'asana', 'time', 'asanas', 'diaphragm', 'entire', 'piles'], tags=[105]),
#  TaggedDocument(words=['lumbar', 'region', 'tendons', 'achilles', 'spine', 'wrists', 'benefits', 'thighs', 'chakrasana', 'shoulders', 'asana', 'similar'], tags=[106]),
#  TaggedDocument(words=['cramp', 'gomukhasana', 'chest', 'excellent', 'asana', 'leg', 'tension', 'stiffness', 'neck', 'energy', 'awareness', 'legs', 'rheumatism', 'posture', 'general', 'tiredness', 'ache', 'sciatica', 'relaxation', 'supple', 'muscles', 'minutes', 'relieves', 'alleviates', 'anxiety'], tags=[107]),
#  TaggedDocument(words=['region', 'joints', 'alternately', 'abdominal', 'thighs', 'organs', 'insides', 'asana', 'massages', 'nervous', 'hip', 'pelvic'], tags=[108]),
#  TaggedDocument(words=['asana', 'hip', 'kidneys', 'genital', 'pancreas', 'spine', 'flexibility', 'circulation', 'entire', 'hamstring', 'excess', 'uro', 'adrenal', 'abdominal', 'weight', 'muscles', 'spleen', 'region', 'joints', 'liver', 'glands', 'area', 'massages', 'pelvic'], tags=[109]),
#  TaggedDocument(words=['physical', 'paschimottanasana', 'energy', 'speeds', 'body', 'practice', 'flexible', 'benefits', 'processes', 'level', 'metabolic', 'pranic', 'circulation', 'dynamic', 'addition'], tags=[110]),
#  TaggedDocument(words=['paschimottanasana', 'stretch', 'blades', 'effect', 'upper', 'body', 'legs', 'benefits', 'chest', 'shoulder', 'asana', 'muscles', 'lower', 'parts'], tags=[111]),
#  TaggedDocument(words=['paschimottanasana', 'meditation', 'legs', 'practice', 'loosening', 'asanas', 'preparation'], tags=[112]),
#  TaggedDocument(words=['foot', 'janu', 'asana', 'leg', 'asanas', 'intense', 'turn', 'intestinal', 'identical', 'bent', 'meditation', 'sirshasana', 'constipation', 'legs', 'distinct', 'characteristic', 'alleviate', 'hips', 'abdominal', 'benefits', 'peristalsis', 'paschimottanasana', 'organs', 'massage'], tags=[113]),
#  TaggedDocument(words=['pelvis', 'proper', 'hip', 'young', 'practice', 'posture', 'balance', 'girls', 'excess', 'steady', 'hips', 'development', 'thighs', 'weight', 'coordination', 'sense', 'joints', 'flexible', 'graceful'], tags=[114]),
#  TaggedDocument(words=['sides', 'asana', 'thigh', 'inner', 'posture', 'balance', 'stronger', 'steady', 'body', 'hips', 'abdominal', 'thighs', 'weight', 'muscles', 'coordination', 'sense', 'flexible', 'graceful', 'reduces'], tags=[115]),
#  TaggedDocument(words=['lateral', 'stretch', 'hamstring', 'complaints', 'excess', 'mus', 'cles', 'blades', 'body', 'waist', 'abdominal', 'appetite', 'shoulder', 'weight', 'area', 'asana', 'nervous', 'thigh'], tags=[116]),
#  TaggedDocument(words=['brain', 'hamstring', 'joints', 'pancreas', 'stimulates', 'massages', 'nerves', 'asana', 'muscles', 'hip', 'spinal'], tags=[117]),
#  TaggedDocument(words=['adrenals', 'hamstring', 'joints', 'flexible', 'tones', 'asana', 'muscles', 'hip'], tags=[118]),
#  TaggedDocument(words=['difficult', 'forms', 'beginners', 'good', 'mild', 'spine', 'loosening', 'pain', 'vertebrae', 'nerves', 'lumbago', 'asana', 'twists', 'meru', 'wakrasana', 'neck', 'spinal'], tags=[119]),
#  TaggedDocument(words=['spine', 'supple', 'nerves', 'asana', 'muscles'], tags=[120]),
#  TaggedDocument(words=['secretions', 'duces', 'calcium', 'adjoining', 'gland', 'asana', 'kidneys', 'inflammatory', 'tendency', 'spine', 'pancreas', 'vertebrae', 'musrular', 'problems', 'deposits', 'adrenal', 'abdominal', 'abdomen', 'supple', 'muscles', 'relieves', 'ailments', 'liver', 'beneficial', 'organs'], tags=[121]),
#  TaggedDocument(words=['lateral', 'stretch', 'hours', 'meditation', 'asanas', 'muscles', 'body', 'abdominal', 'beneficial', 'organs', 'shoulders', 'hamstrings', 'asana', 'compression', 'long'], tags=[122]),
#  TaggedDocument(words=[], tags=[123]),
#  TaggedDocument(words=[], tags=[124]),
#  TaggedDocument(words=['pressure', 'blood', 'low', 'asana', 'neck', 'brain', 'strengthens', 'sirshasana', 'influx', 'nervous', 'crown', 'body', 'weight', 'rich', 'muscles', 'cases', 'supply', 'accustoms', 'preliminary'], tags=[125]),
#  TaggedDocument(words=['pressure', 'blood', 'low', 'gland', 'asana', 'neck', 'brain', 'strengthens', 'sirshasana', 'influx', 'nervous', 'crown', 'body', 'thyroid', 'vishuddhi', 'weight', 'rich', 'muscles', 'cases', 'supply', 'breath', 'spiritual', 'chakra', 'accustoms', 'preliminary'], tags=[126]),
#  TaggedDocument(words=['drainage', 'blood', 'treatment', 'veins', 'free', 'additional', 'asana', 'leg', 'stretch', 'coordinates', 'legs', 'balance', 'internal', 'piles', 'muscles', 'effective', 'sarvangasana', 'sense', 'region', 'organs', 'massage', 'pelvic'], tags=[127]),
#  TaggedDocument(words=['kidneys', 'preparatory', 'intestines', 'excess', 'good', 'halasana', 'pelvis', 'weight'], tags=[128]),
#  TaggedDocument(words=['movement', 'production', 'constipation', 'pancreas', 'practice', 'digestion', 'internal', 'suprarenal', 'kidney', 'insulin', 'place', 'dyspepsia', 'abdominal', 'muscles', 'halasana', 'liver', 'function', 'glands', 'organs', 'diaphragm', 'massages', 'spasms'], tags=[129]),
#  TaggedDocument(words=['intestinal', 'constipation', 'practice', 'gall', 'tion', 'abdomin', 'bladder', 'benefits', 'diges', 'muscles', 'peristalsis', 'paschimottanasana', 'region', 'halasana', 'al', 'liver', 'facilitates', 'fats', 'pelvic'], tags=[130]),
#  TaggedDocument(words=['region', 'abdomin', 'constipation', 'al', 'liver', 'bladder', 'facilitates', 'pelvic', 'gall', 'tion', 'diges', 'muscles', 'peristalsis', 'fats', 'intestinal'], tags=[131]),
#  TaggedDocument(words=['region', 'abdomin', 'constipation', 'al', 'liver', 'bladder', 'facilitates', 'pelvic', 'gall', 'tion', 'diges', 'muscles', 'peristalsis', 'fats', 'intestinal'], tags=[132]),
#  TaggedDocument(words=['fever', 'glandular', 'blood', 'imbalance', 'reversed', 'strain', 'root', 'psychological', 'asana', 'deep', 'asanas', 'regions', 'forms', 'sirshasana', 'effect', 'sahasrara', 'mind', 'legs', 'menopausal', 'dioxide', 'disorder', 'awakening', 'nervous', 'carbon', 'entire'], tags=[133]),
#  TaggedDocument(words=['fever', 'glandular', 'blood', 'imbalance', 'reversed', 'strain', 'root', 'psychological', 'asana', 'deep', 'asanas', 'regions', 'forms', 'sirshasana', 'effect', 'sahasrara', 'mind', 'legs', 'menopausal', 'dioxide', 'disorder', 'awakening', 'nervous', 'carbon', 'entire'], tags=[134]),
#  TaggedDocument(words=['fever', 'glandular', 'blood', 'imbalance', 'reversed', 'strain', 'root', 'psychological', 'asana', 'deep', 'asanas', 'regions', 'forms', 'sirshasana', 'effect', 'sahasrara', 'mind', 'legs', 'menopausal', 'dioxide', 'disorder', 'awakening', 'nervous', 'carbon', 'entire'], tags=[135]),
#  TaggedDocument(words=['drainage', 'expansion', 'blood', 'sense', 'sirshasana', 'region', 'coordinates', 'legs', 'balance', 'chest', 'internal', 'organs', 'free', 'asana', 'muscles', 'leg', 'massages', 'pelvic'], tags=[136]),
#  TaggedDocument(words=['fever', 'glandular', 'blood', 'imbalance', 'reversed', 'strain', 'root', 'psychological', 'asana', 'deep', 'asanas', 'regions', 'forms', 'sirshasana', 'effect', 'sahasrara', 'mind', 'legs', 'menopausal', 'dioxide', 'disorder', 'awakening', 'nervous', 'carbon', 'entire'], tags=[137]),
#  TaggedDocument(words=['ankle', 'foot', 'thens', 'leg', 'balance', 'streng', 'asana', 'muscles', 'nervous'], tags=[138]),
#  TaggedDocument(words=['natavarasana', 'nervous', 'balance', 'concentration'], tags=[139]),
#  TaggedDocument(words=['garudasana', 'good', 'joints', 'upper', 'legs', 'arms', 'concentration', 'muscles'], tags=[140]),
#  TaggedDocument(words=['balances', 'control', 'mental', 'body', 'legs', 'develops', 'concentration', 'asana', 'nervous'], tags=[141]),
#  TaggedDocument(words=['sense', 'hips', 'legs', 'balance', 'arms', 'shoulders', 'concentration', 'asana', 'coordination'], tags=[142]),
#  TaggedDocument(words=['sense', 'hips', 'legs', 'balance', 'arms', 'shoulders', 'concentration', 'asana', 'coordination'], tags=[143]),
#  TaggedDocument(words=['muscular', 'hips', 'wrists', 'balance', 'arms', 'tion', 'concentration', 'asana', 'muscles', 'leg', 'nervous', 'coordina'], tags=[144]),
#  TaggedDocument(words=['blood', 'abdominal', 'beneficial', 'balance', 'organs', 'circulation', 'compression', 'concentration', 'muscles', 'leg', 'nervous', 'hip', 'coordination'], tags=[145]),
#  TaggedDocument(words=['muscular', 'ankle', 'ed', 'knee', 'joints', 'coordinates', 'hips', 'leg', 'balance', 'concentration', 'hamstrings', 'muscles', 'nervous'], tags=[146]),
#  TaggedDocument(words=['asana', 'sympathetic', 'systems', 'intestinal', 'constipation', 'parasympathetic', 'good', 'legs', 'spine', 'balance', 'lightness', 'nervous', 'tiredness', 'abdominal', 'muscles', 'knees', 'peristalsis', 'organs', 'tones'], tags=[147]),
#  TaggedDocument(words=['sense', 'paschimottan', 'benefits', 'asana', 'ofbalance', 'similar', 'addition'], tags=[148]),
#  TaggedDocument(words=['sense', 'constipation', 'balance', 'asana', 'peristalsis', 'intestinal'], tags=[149]),
#  TaggedDocument(words=['blood', 'constipation', 'legs', 'digestion', 'stimulates', 'asana', 'circulation'], tags=[150]),
#  TaggedDocument(words=['brahmacharya', 'knee', 'seminal', 'joints', 'ability', 'fluid', 'maintenance', 'asana', 'muscles', 'leg'], tags=[151]),
#  TaggedDocument(words=['strengthens', 'brahmacharya', 'toes', 'asana', 'ankles', 'concentration', 'reproductive'], tags=[152]),
#  TaggedDocument(words=['physical', 'sense', 'balances', 'wrists', 'balance', 'arms', 'streng', 'asana', 'nervous'], tags=[153]),
#  TaggedDocument(words=[], tags=[154]),
#  TaggedDocument(words=['joints', 'pancreas', 'flexibility', 'abdomen', 'organs', 'shoulder', 'arm', 'asana', 'muscles', 'lower', 'massages', 'visceral'], tags=[155]),
#  TaggedDocument(words=['energy', 'strengthens', 'eum', 'flexibility', 'abdominal', 'spiritual', 'organs', 'perin', 'purposes', 'shoulders', 'tones', 'asana', 'muscles', 'contract', 'lower', 'sexual', 'preservation'], tags=[156]),
#  TaggedDocument(words=['hamsasana', 'healthy', 'abdominal', 'beneficial', 'organs', 'digestive', 'muscles', 'massages'], tags=[157]),
#  TaggedDocument(words=['inner', 'sense', 'equilibrium', 'balance', 'arms', 'shoulders', 'asana', 'muscles', 'nervous', 'harmony'], tags=[158]),
#  TaggedDocument(words=['leg', 'balance', 'arms', 'supple', 'tones', 'asana', 'muscles', 'nervous', 'lower'], tags=[159]),
#  TaggedDocument(words=['swadhisthana', 'asana', 'anahata', 'kidneys', 'effect', 'healthy', 'spine', 'uterus', 'level', 'strong', 'vishuddhi', 'abdominal', 'supple', 'pranic', 'ovaries', 'beneficial', 'organs', 'tones', 'manipura'], tags=[160]),
#  TaggedDocument(words=['introversion', 'pation', 'head', 'helpful', 'security', 'neck', 'inner', 'koormasana', 'passion', 'mental', 'mind', 'spine', 'practice', 'composure', 'circulation', 'anger', 'flatulence', 'body', 'surrender', 'ache', 'abdomen', 'relaxation', 'diabetes', 'subside', 'organs'], tags=[161]),
#  TaggedDocument(words=['mudra', 'balances', 'stomach', 'liver', 'body', 'abdominal', 'appetite', 'benefits', 'organs', 'shalabhasana', 'bowels', 'tones', 'muscles', 'asanas', 'buttocks', 'poorna', 'pelvic'], tags=[162]),
#  TaggedDocument(words=[], tags=[163]),
#  TaggedDocument(words=['helpful', 'joints', 'legs', 'loosening', 'abdominal', 'arms', 'supple', 'organs', 'excellent', 'tones', 'asana', 'tension', 'hip', 'neck', 'people'], tags=[164]),
#  TaggedDocument(words=['legs', 'spine', 'abdominal', 'streng', 'toning', 'organs', 'circulation', 'balance', 'nerves', 'asana', 'muscles'], tags=[165]),
#  TaggedDocument(words=['lateral', 'stretch', 'region', 'good', 'muscles', 'fat', 'skin', 'posture', 'abdominal', 'abdomen', 'organs', 'massages', 'trunk', 'pelvic', 'accumulation'], tags=[166]),
#  TaggedDocument(words=['secretions', 'glandular', 'respiratory', 'disorders', 'legs', 'beneficial', 'onal', 'chakrasana', 'digestive', 'nervous', 'influences', 'systems', 'gynaecological', 'cardiovascular'], tags=[167]),
#  TaggedDocument(words=['blood', 'legs', 'flexibility', 'abdominal', 'organs', 'supple', 'tones', 'n', 'area', 'circulation', 'reproductive', 'massages', 'pelvic'], tags=[168]),
#  TaggedDocument(words=['mudra', 'energy', 'conservation', 'moola', 'bandha', 'abdominal', 'arms', 'spiritual', 'organs', 'purposes', 'important', 'ashwini', 'asana', 'muscles', 'contract', 'sexual', 'perineum', 'vajroli'], tags=[169]),
#  TaggedDocument(words=['sense', 'balance', 'thighs', 'grivasana', 'neck'], tags=[170]),
#  TaggedDocument(words=['blood', 'strong', 'stimulates', 'abdominal', 'relaxation', 'supple', 'circulation', 'excellent', 'nerves', 'asana', 'muscles', 'thigh', 'neck', 'spinal'], tags=[171]),
#  TaggedDocument(words=['secretions', 'duces', 'calcium', 'adjoining', 'gland', 'asana', 'kidneys', 'inflammatory', 'tendency', 'spine', 'pancreas', 'vertebrae', 'problems', 'muscular', 'deposits', 'adrenal', 'abdominal', 'abdomen', 'supple', 'muscles', 'relieves', 'ailments', 'liver', 'beneficial', 'organs'], tags=[172]),
#  TaggedDocument(words=['blood', 'removal', 'stimulates', 'kapha', 'asana', 'useful', 'intestinal', 'kidneys', 'control', 'constipation', 'mental', 'balance', 'processes', 'doshas', 'phlegm', 'sluggishness', 'pitta', 'muscular', 'elimination', 'flatulence', 'particular', 'body', 'harmonizes', 'muscles', 'peristalsis'], tags=[173]),
#  TaggedDocument(words=[], tags=[174]),
#  TaggedDocument(words=['energy', 'eliminatory', 'conservation', 'feet', 'moola', 'asana', 'legs', 'chakra', 'organs', 'supple', 'important', 'tones', 'bandha', 'reproductive', 'sexual'], tags=[175]),
#  TaggedDocument(words=['apana', 'states', 'feet', 'legs', 'asana', 'supple', 'reverses', 'centres', 'higher', 'meditative'], tags=[176]),
#  TaggedDocument(words=['energy', 'brahmacharya', 'control', 'apana', 'muscles', 'body', 'mind', 'wrists', 'abdomen', 'chakra', 'reverses', 'netvous', 'asana', 'arm', 'leg', 'manipura', 'celibacy'], tags=[177]),
#  TaggedDocument(words=['pituitary', 'blood', 'ing', 'gland', 'arms', 'process', 'systems', 'brain', 'strengthens', 'limbs', 'vrischikasana', 'spine', 'balance', 'circulation', 'lower', 'body', 'abdomen', 'reproductive', 'prana', 'physical', 'position', 'sense', 'loosens', 'organs', 'nerves'], tags=[178]),
#  TaggedDocument(words=['chakras', 'blood', 'veins', 'asana', 'energy', 'constipation', 'ductive', 'mind', 'legs', 'internal', 'level', 'circulation', 'body', 'abdomen', 'vitalizing', 'peristalsis', 'organs', 'tones', 'varicose'], tags=[179]),
#  TaggedDocument(words=['eka', 'pada', 'sirasana', 'asana', 'muscles', 'concentration', 'thigh', 'addition'], tags=[180]),
#  TaggedDocument(words=[], tags=[181]),
#  TaggedDocument(words=['mas', 'eliminatory', 'efficiency', 'adrenal', 'solar', 'abdominal', 'glands', 'organs', 'digestive', 'tones', 'plexus', 'asana', 'vitality', 'nervous', 'reproductive', 'systems', 'pelvic'], tags=[182]),
#  TaggedDocument(words=['sense', 'balance', 'benefits', 'padmasana', 'asana', 'addition'], tags=[183]),
#  TaggedDocument(words=['chakras', 'sense', 'legs', 'samana', 'vayu', 'arms', 'chest', 'balance', 'shoulders', 'concentration', 'asana', 'anahata', 'manipura'], tags=[184]),
#  TaggedDocument(words=['sense', 'legs', 'balance', 'arms', 'internal', 'organs', 'nerves', 'tones', 'concentration', 'asana', 'muscles', 'sciatic'], tags=[185]),
#  TaggedDocument(words=['balanced', 'nostrils', 'effects', 'activates', 'brain', 'awareness', 'breathing', 'nostril', 'sensitivity', 'slow', 'blockages', 'minor', 'hemisphere', 'energies', 'stage', 'breath', 'right', 'technique', 'profound', 'flow'], tags=[186]),
#  TaggedDocument(words=['temperature', 'important', 'free', 'brain', 'hunger', 'control', 'mental', 'biological', 'practice', 'excitation', 'cools', 'regulation', 'emotional', 'muscular', 'body', 'sleep', 'relaxation', 'thirst', 'satisfaction', 'centres', 'prana', 'tranquillity', 'tranquillizer', 'flow'], tags=[187]),
#  TaggedDocument(words=[], tags=[188]),
#  TaggedDocument(words=['tension', 'capacity', 'strengthens', 'awareness', 'effect', 'mind', 'anger', 'state', 'voice', 'body', 'bhramari', 'vibration', 'cerebral', 'ous', 'anxiety', 'insomnia', 'healing', 'meditative', 'nen', 'sound'], tags=[189]),
#  TaggedDocument(words=['blood', 'pressure', 'pranayama', 'psychic', 'useful', 'tranquillizing', 'people', 'effect', 'rate', 'heating', 'practice', 'level', 'nervous', 'heart', 'body', 'sleep', 'calms', 'high', 'shavasana', 'soothes', 'insomnia'], tags=[190]),
#  TaggedDocument(words=['blood', 'balances', 'stimulates', 'throat', 'air', 'heat', 'kapha', 'proper', 'useful', 'inflammation', 'movement', 'meditation', 'onepointedness', 'women', 'rate', 'rhythmic', 'practice', 'mind', 'dioxide', 'doshas', 'exchange', 'oxygen', 'level', 'carbon', 'nervous'], tags=[191]),
#  TaggedDocument(words=['respiratory', 'purifies', 'kapalbhati', 'nadis', 'distractions', 'good', 'effect', 'cleansing', 'energizes', 'mental', 'practice', 'sleepiness', 'nervous', 'work', 'disorders', 'organs', 'sensory', 'digestive', 'tones'], tags=[192]),
#  TaggedDocument(words=['pranayama', 'moorchha', 'excellent', 'psychic', 'cuts', 'identification', 'tension', 'meditation', 'distractions', 'mental', 'mind', 'inwards', 'level', 'neuroses', 'anger', 'state', 'body', 'inhibits', 'prana', 'physical', 'tranquillity', 'world', 'anxiety', 'preparation'], tags=[193]),
#  TaggedDocument(words=['activities', 'dynamism', 'pranayama', 'stimulates', 'heat', 'kapha', 'pingala', 'imbalances', 'excellent', 'perceptive', 'communicate', 'energy', 'dull', 'meditation', 'alert', 'mind', 'practice', 'pre', 'nadi', 'doshas', 'phlegm', 'difficult', 'body', 'lethargic', 'pranic'], tags=[194]),
#  TaggedDocument(words=['chin', 'absent', 'endings', 'runs', 'experience', 'chest', 'channel', 'maintains', 'important', 'root', 'receptivity', 'asanas', 'nerve', 'perineum', 'finger', 'energy', 'brain', 'meditation', 'gupta', 'travel', 'practitioner', 'neural', 'practice', 'nadi', 'lightness'], tags=[195]),
#  TaggedDocument(words=['chin', 'absent', 'endings', 'runs', 'experience', 'chest', 'channel', 'maintains', 'important', 'root', 'receptivity', 'asanas', 'nerve', 'perineum', 'finger', 'energy', 'brain', 'meditation', 'gupta', 'travel', 'practitioner', 'neural', 'practice', 'nadi', 'lightness'], tags=[196]),
#  TaggedDocument(words=['cross', 'activities', 'chest', 'concentration', 'balancing', 'hand', 'vice', 'brain', 'awareness', 'meditation', 'complete', 'practice', 'balance', 'internal', 'intensifies', 'connection', 'body', 'relaxation', 'hands', 'fingers', 'point', 'prana', 'mudra', 'energies', 'physical'], tags=[197]),
#  TaggedDocument(words=['union', 'mudra', 'individual', 'meditation', 'pranayama', 'dis', 'practice', 'pingala', 'hands', 'prano', 'supreme', 'consciousness', 'ida', 'bhairava'], tags=[198]),
#  TaggedDocument(words=['ring', 'crisis', 'centre', 'hridaya', 'vitality', 'nadis', 'unburden', 'conflict', 'energizer', 'acute', 'heart', 'thumb', 'emotional', 'fmgers', 'hands', 'pranic', 'emotion', 'situations', 'prana', 'middle', 'mudra', 'simple', 'circuit', 'beneficial', 'diverts'], tags=[199]),
#  TaggedDocument(words=['emotional', 'stability', 'eye', 'anger', 'mental', 'mind', 'calms', 'stress', 'area', 'concentration', 'muscles', 'tension', 'mudra', 'state', 'thoughtlessness'], tags=[200]),
#  TaggedDocument(words=['drishti', 'nasikagra', 'planes', 'open', 'aim', 'excellent', 'psychic', 'calming', 'concentration', 'consciousness', 'powers', 'mind', 'practitioner', 'concentrates', 'practice', 'anger', 'states', 'nosetip', 'eyes', 'mudra', 'technique', 'introspection', 'aware', 'world', 'spiritual'], tags=[201]),
#  TaggedDocument(words=['mouth', 'number', 'pressure', 'khechari', 'nasal', 'stillness', 'sensations', 'points', 'vitality', 'hunger', 'calm', 'inner', 'practice', 'potential', 'secretion', 'state', 'awaken', 'body', 'shakti', 'thirst', 'cavity', 'kundalini', 'prana', 'mudra', 'influence'], tags=[202]),
#  TaggedDocument(words=['drishti', 'nasikagra', 'mouth', 'secretions', 'stimulates', 'air', 'process', 'kaki', 'membranes', 'mental', 'mind', 'practice', 'cools', 'lips', 'body', 'benefits', 'contact', 'act', 'tensions', 'mudra', 'addition', 'soothes', 'digestive'], tags=[203]),
#  TaggedDocument(words=['stagnant', 'stomach', 'bhujangini', 'disorders', 'practitioner', 'water', 'abdominal', 'air', 'time', 'tones', 'float', 'wind', 'length', 'mudra'], tags=[204]),
#  TaggedDocument(words=['ajna', 'planes', 'psychic', 'memory', 'concentration', 'calming', 'consciousness', 'mental', 'practitioner', 'tranquillizes', 'anger', 'state', 'states', 'stress', 'power', 'bhoochari', 'mudra', 'stability', 'beneficial', 'chakra', 'spiritual', 'meditative', 'thoughtlessness'], tags=[205]),
#  TaggedDocument(words=['khechari', 'control', 'states', 'tranquillity', 'practice', 'benefits', 'processes', 'higher', 'kumbhaka', 'induces', 'consciousness', 'calmness', 'arrests'], tags=[206]),
#  TaggedDocument(words=['energy', 'awareness', 'sense', 'pratyahara', 'heat', 'hands', 'nerves', 'fingers', 'muscles', 'withdrawal', 'state'], tags=[207]),
#  TaggedDocument(words=['unmani', 'agitation', 'calms', 'meditative', 'mudra', 'state'], tags=[208]),
#  TaggedDocument(words=['activities', 'planes', 'balances', 'nostrils', 'pingala', 'asana', 'outward', 'movement', 'energy', 'awareness', 'nadis', 'mental', 'effect', 'practice', 'posture', 'disease', 'benefits', 'prana', 'equal', 'physical', 'breath', 'karani', 'vipareeta', 'downward', 'ida'], tags=[209]),
#  TaggedDocument(words=['pratyahara', 'pashinee', 'tranquillity', 'drawal', 'spine', 'balance', 'induces', 'stimulates', 'abdominal', 'sensory', 'organs', 'nerves', 'muscles', 'nervous', 'massages', 'mudra', 'spinal'], tags=[210]),
#  TaggedDocument(words=['blood', 'areas', 'pressure', 'distribution', 'stomach', 'stimulates', 'centre', 'tension', 'nerve', 'trunk', 'ward', 'energy', 'phragm', 'level', 'circulation', 'toned', 'plexuses', 'diaphragm', 'body', 'abdominal', 'prana', 'mudra', 'tadagi', 'floor', 'dia'], tags=[211]),
#  TaggedDocument(words=['chakras', 'attitude', 'cosmic', 'dormant', 'strength', 'flow', 'energy', 'awareness', 'inner', 'nadis', 'source', 'subtle', 'vital', 'peace', 'body', 'confidence', 'prana', 'mudra', 'health', 'equanimity', 'external'], tags=[212]),
#  TaggedDocument(words=['preparatory', 'excellent', 'engendering', 'psychic', 'tension', 'energy', 'awareness', 'meditation', 'control', 'good', 'manipura', 'practice', 'anger', 'general', 'awaken', 'abdominal', 'relaxation', 'addition', 'sense', 'relieves', 'health', 'tranquillity', 'chakra', 'organs', 'stretches'], tags=[213]),
#  TaggedDocument(words=['mudra', 'cross', 'fluctuations', 'meditation', 'nadis', 'mind', 'counterpose', 'calms', 'chakra', 'mooladhara', 'ida', 'pingala', 'asana', 'asanas', 'meditative', 'legged', 'manduki'], tags=[214]),
#  TaggedDocument(words=['ajna', 'energy', 'intensifies', 'awareness', 'khechari', 'meditation', 'circuit', 'moola', 'bandha', 'spontaneous', 'blockages', 'benefits', 'chakra', 'maha', 'kumbhaka', 'mooladhara', 'prana', 'mudra'], tags=[215]),
#  TaggedDocument(words=['chakras', 'concentration', 'influences', 'complex', 'meditation', 'mind', 'level', 'supercharge', 'body', 'vishuddhi', 'pranic', 'energies', 'mudra', 'influence', 'bheda', 'profound', 'supplements', 'maha', 'mooladhara', 'manipura'], tags=[216]),
#  TaggedDocument(words=['mind', 'introverting', 'practice', 'chakra', 'psychic', 'powerful', 'mooladhara', 'kundalini', 'faculties'], tags=[217]),
#  TaggedDocument(words=['vents', 'energy', 'redirects', 'upward', 'escape', 'practice', 'spiritual', 'pranic', 'muscles', 'anal', 'purposes'], tags=[218]),
#  TaggedDocument(words=['conflicts', 'energy', 'states', 'psycho', 'conserves', 'genital', 'uro', 'thoughts', 'tones', 'unwanted', 'meditative', 'entire', 'sexual', 'mudra', 'vajroli'], tags=[219]),
#  TaggedDocument(words=['pressure', 'respiratory', 'increase', 'carotid', 'subtler', 'introversion', 'throat', 'process', 'systems', 'neck', 'jalandhara', 'compresses', 'breathing', 'sinuses', 'mental', 'rate', 'tendency', 'practice', 'dioxide', 'main', 'oxygen', 'anger', 'help', 'carbon', 'arteries'], tags=[220]),
#  TaggedDocument(words=['psychic', 'helpful', 'systems', 'sexual', 'energy', 'control', 'mental', 'good', 'genital', 'illnesses', 'relations', 'awakening', 'degenerative', 'bodies', 'sublimate', 'uro', 'moola', 'benefits', 'enhancement', 'ment', 'depression', 'physical', 'brahmacharya', 'health', 'psychosomatic'], tags=[221]),
#  TaggedDocument(words=['blood', 'pressure', 'apana', 'stimulates', 'tension', 'influences', 'energy', 'pancreas', 'panacea', 'samana', 'internal', 'plexus', 'circulation', 'subtle', 'suction', 'body', 'adrenal', 'solar', 'abdominal', 'abdomen', 'torso', 'prana', 'lethargy', 'liver', 'glands'], tags=[222]),
#  TaggedDocument(words=['secretions', 'chakras', 'apana', 'gland', 'merger', 'pineal', 'meditation', 'cell', 'mind', 'samana', 'processes', 'main', 'degenerative', 'entire', 'body', 'bandha', 'benefits', 'ageing', 'bandhas', 'hormonal', 'prana', 'culmination', 'endocrine', 'prior', 'pranayamas'], tags=[223]),
#  TaggedDocument(words=['ajna', 'nasal', 'respiratory', 'endings', 'nostrils', 'ala', 'stimulates', 'drowsiness', 'air', 'light', 'youthful', 'passages', 'hemispheres', 'head', 'tension', 'nerve', 'overall', 'brain', 'sinuses', 'good', 'mind', 'practitioner', 'balance', 'diseases', 'mucus'], tags=[224]),
#  TaggedDocument(words=['problem', 'nasal', 'bone', 'nostrils', 'obstructions', 'outgrowths', 'neti', 'fleshy', 'septum', 'benefits', 'friction', 'months', 'regular', 'jala', 'sutra', 'addition'], tags=[225])]

# %%
## Train doc2vec model
model = Doc2Vec(tagged_data, vector_size = 50, window = 4, min_count = 1, epochs = 200)

'''
vector_size = Dimensionality of the feature vectors.
window = The maximum distance between the current and predicted word within a sentence.
min_count = Ignores all words with total frequency lower than this.
alpha = The initial learning rate.
'''

## Print model vocabulary
model.wv.vocab
# Out:
# WARNING:gensim.models.base_any2vec:consider setting layer size to a multiple of 4 for greater performance
# {'self': <gensim.models.keyedvectors.Vocab at 0x7f295e7502d0>,
#  'group': <gensim.models.keyedvectors.Vocab at 0x7f295e750e10>,
#  'blood': <gensim.models.keyedvectors.Vocab at 0x7f295e750b10>,
#  'pressure': <gensim.models.keyedvectors.Vocab at 0x7f295e750dd0>,
#  'excellent': <gensim.models.keyedvectors.Vocab at 0x7f295e750fd0>,
#  'asanas': <gensim.models.keyedvectors.Vocab at 0x7f295e750410>,
#  'useful': <gensim.models.keyedvectors.Vocab at 0x7f295e750650>,
#  'energy': <gensim.models.keyedvectors.Vocab at 0x7f295e7507d0>,
#  'awareness': <gensim.models.keyedvectors.Vocab at 0x7f295e750590>,
#  'rheumatism': <gensim.models.keyedvectors.Vocab at 0x7f295e750d10>,
#  'heart': <gensim.models.keyedvectors.Vocab at 0x7f295e750a90>,
#  'problems': <gensim.models.keyedvectors.Vocab at 0x7f295e750890>,
#  'ments': <gensim.models.keyedvectors.Vocab at 0x7f295e7501d0>,
#  'arthritis': <gensim.models.keyedvectors.Vocab at 0x7f295e000710>,
#  'exercise': <gensim.models.keyedvectors.Vocab at 0x7f295e000750>,
#  'body': <gensim.models.keyedvectors.Vocab at 0x7f295e000450>,
#  'blockages': <gensim.models.keyedvectors.Vocab at 0x7f295e000790>,
#  'confidence': <gensim.models.keyedvectors.Vocab at 0x7f295e000690>,
#  'high': <gensim.models.keyedvectors.Vocab at 0x7f295e000550>,
#  'coordination': <gensim.models.keyedvectors.Vocab at 0x7f295e000310>,
#  'physical': <gensim.models.keyedvectors.Vocab at 0x7f295e000890>,
#  'joints': <gensim.models.keyedvectors.Vocab at 0x7f295e0007d0>,
#  'vigorous': <gensim.models.keyedvectors.Vocab at 0x7f295e000410>,
#  'stagnant': <gensim.models.keyedvectors.Vocab at 0x7f295e000110>,
#  'lymph': <gensim.models.keyedvectors.Vocab at 0x7f295e000090>,
#  'foot': <gensim.models.keyedvectors.Vocab at 0x7f295e0003d0>,
#  'cramp': <gensim.models.keyedvectors.Vocab at 0x7f295e0000d0>,
#  'help': <gensim.models.keyedvectors.Vocab at 0x7f295e000350>,
#  'tiredness': <gensim.models.keyedvectors.Vocab at 0x7f295e0001d0>,
#  'post': <gensim.models.keyedvectors.Vocab at 0x7f295e000390>,
#  'bedridden': <gensim.models.keyedvectors.Vocab at 0x7f295e000490>,
#  'relieve': <gensim.models.keyedvectors.Vocab at 0x7f295e000810>,
#  'operative': <gensim.models.keyedvectors.Vocab at 0x7f295e0006d0>,
#  'venous': <gensim.models.keyedvectors.Vocab at 0x7f295e000050>,
#  'calf': <gensim.models.keyedvectors.Vocab at 0x7f295e000650>,
#  'thrombosis': <gensim.models.keyedvectors.Vocab at 0x7f295e000610>,
#  'patients': <gensim.models.keyedvectors.Vocab at 0x7f295e000510>,
#  'ligaments': <gensim.models.keyedvectors.Vocab at 0x7f295e000910>,
#  'knee': <gensim.models.keyedvectors.Vocab at 0x7f295e000590>,
#  'strong': <gensim.models.keyedvectors.Vocab at 0x7f295e0005d0>,
#  'muscles': <gensim.models.keyedvectors.Vocab at 0x7f295e0002d0>,
#  'vulnerable': <gensim.models.keyedvectors.Vocab at 0x7f295e0004d0>,
#  'quadriceps': <gensim.models.keyedvectors.Vocab at 0x7f295e0008d0>,
#  'muscle': <gensim.models.keyedvectors.Vocab at 0x7f295e000190>,
#  'weight': <gensim.models.keyedvectors.Vocab at 0x7f295e000250>,
#  'sprains': <gensim.models.keyedvectors.Vocab at 0x7f295e000150>,
#  'healing': <gensim.models.keyedvectors.Vocab at 0x7f295e000850>,
#  'joint': <gensim.models.keyedvectors.Vocab at 0x7f295e000210>,
#  'injuries': <gensim.models.keyedvectors.Vocab at 0x7f295e000290>,
#  'energies': <gensim.models.keyedvectors.Vocab at 0x7f295e02a050>,
#  'preparatory': <gensim.models.keyedvectors.Vocab at 0x7f295e02a090>,
#  'titali': <gensim.models.keyedvectors.Vocab at 0x7f295e02a0d0>,
#  'ardha': <gensim.models.keyedvectors.Vocab at 0x7f295e02a110>,
#  'positions': <gensim.models.keyedvectors.Vocab at 0x7f295e02a150>,
#  'practice': <gensim.models.keyedvectors.Vocab at 0x7f295e02a190>,
#  'morning': <gensim.models.keyedvectors.Vocab at 0x7f295e02a1d0>,
#  'loos': <gensim.models.keyedvectors.Vocab at 0x7f295e02a210>,
#  'evening': <gensim.models.keyedvectors.Vocab at 0x7f295e02a250>,
#  'daily': <gensim.models.keyedvectors.Vocab at 0x7f295e02a290>,
#  'asana': <gensim.models.keyedvectors.Vocab at 0x7f295e02a2d0>,
#  'meditative': <gensim.models.keyedvectors.Vocab at 0x7f295e02a310>,
#  'hip': <gensim.models.keyedvectors.Vocab at 0x7f295e02a350>,
#  'legged': <gensim.models.keyedvectors.Vocab at 0x7f295e02a390>,
#  'people': <gensim.models.keyedvectors.Vocab at 0x7f295e02a3d0>,
#  'inner': <gensim.models.keyedvectors.Vocab at 0x7f295e02a410>,
#  'hours': <gensim.models.keyedvectors.Vocab at 0x7f295e02a450>,
#  'stages': <gensim.models.keyedvectors.Vocab at 0x7f295e02a490>,
#  'legs': <gensim.models.keyedvectors.Vocab at 0x7f295e02a4d0>,
#  'tension': <gensim.models.keyedvectors.Vocab at 0x7f295e02a510>,
#  'padmasana': <gensim.models.keyedvectors.Vocab at 0x7f295e02a550>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x7f295e02a590>,
#  'mastery': <gensim.models.keyedvectors.Vocab at 0x7f295e02a5d0>,
#  'thigh': <gensim.models.keyedvectors.Vocab at 0x7f295e02a610>,
#  'lot': <gensim.models.keyedvectors.Vocab at 0x7f295e02a650>,
#  'prolonged': <gensim.models.keyedvectors.Vocab at 0x7f295e02a690>,
#  'typing': <gensim.models.keyedvectors.Vocab at 0x7f295e02a6d0>,
#  'beneficial': <gensim.models.keyedvectors.Vocab at 0x7f295e02a710>,
#  'writing': <gensim.models.keyedvectors.Vocab at 0x7f295e02a750>,
#  'hand': <gensim.models.keyedvectors.Vocab at 0x7f295e02a790>,
#  'wrist': <gensim.models.keyedvectors.Vocab at 0x7f295e02a7d0>,
#  'frozen': <gensim.models.keyedvectors.Vocab at 0x7f295e02a810>,
#  'cervical': <gensim.models.keyedvectors.Vocab at 0x7f295e02a850>,
#  'strain': <gensim.models.keyedvectors.Vocab at 0x7f295e02a890>,
#  'shape': <gensim.models.keyedvectors.Vocab at 0x7f295e02a8d0>,
#  'shoulder': <gensim.models.keyedvectors.Vocab at 0x7f295e02a910>,
#  'shoulders': <gensim.models.keyedvectors.Vocab at 0x7f295e02a950>,
#  'office': <gensim.models.keyedvectors.Vocab at 0x7f295e02a990>,
#  'spondylitis': <gensim.models.keyedvectors.Vocab at 0x7f295e02a9d0>,
#  'work': <gensim.models.keyedvectors.Vocab at 0x7f295e02aa10>,
#  'limbs': <gensim.models.keyedvectors.Vocab at 0x7f295e02aa50>,
#  'region': <gensim.models.keyedvectors.Vocab at 0x7f295e02aa90>,
#  'desk': <gensim.models.keyedvectors.Vocab at 0x7f295e02aad0>,
#  'heaviness': <gensim.models.keyedvectors.Vocab at 0x7f295e02ab10>,
#  'stiffness': <gensim.models.keyedvectors.Vocab at 0x7f295e02ab50>,
#  'organs': <gensim.models.keyedvectors.Vocab at 0x7f295e02ab90>,
#  'nerves': <gensim.models.keyedvectors.Vocab at 0x7f295e02abd0>,
#  'release': <gensim.models.keyedvectors.Vocab at 0x7f295e02ac10>,
#  'different': <gensim.models.keyedvectors.Vocab at 0x7f295e02ac50>,
#  'head': <gensim.models.keyedvectors.Vocab at 0x7f295e02ac90>,
#  'neck': <gensim.models.keyedvectors.Vocab at 0x7f295e02acd0>,
#  'strengthens': <gensim.models.keyedvectors.Vocab at 0x7f295e02ad10>,
#  'perineal': <gensim.models.keyedvectors.Vocab at 0x7f295e02ad50>,
#  'abdominal': <gensim.models.keyedvectors.Vocab at 0x7f295e02ad90>,
#  'digestive': <gensim.models.keyedvectors.Vocab at 0x7f295e02add0>,
#  'prolapse': <gensim.models.keyedvectors.Vocab at 0x7f295e02ae10>,
#  'lower': <gensim.models.keyedvectors.Vocab at 0x7f295e02ae50>,
#  'massages': <gensim.models.keyedvectors.Vocab at 0x7f295e02ae90>,
#  'pelvic': <gensim.models.keyedvectors.Vocab at 0x7f295e02aed0>,
#  'obesity': <gensim.models.keyedvectors.Vocab at 0x7f295e02af10>,
#  'good': <gensim.models.keyedvectors.Vocab at 0x7f295e02af50>,
#  'spinal': <gensim.models.keyedvectors.Vocab at 0x7f295e02af90>,
#  'constipation': <gensim.models.keyedvectors.Vocab at 0x7f295e02afd0>,
#  'pawanmuktasana': <gensim.models.keyedvectors.Vocab at 0x7f295e02d050>,
#  'vertebrae': <gensim.models.keyedvectors.Vocab at 0x7f295e02d090>,
#  'wind': <gensim.models.keyedvectors.Vocab at 0x7f295e02d0d0>,
#  'effective': <gensim.models.keyedvectors.Vocab at 0x7f295e02d110>,
#  'reproductive': <gensim.models.keyedvectors.Vocab at 0x7f295e02d150>,
#  'supta': <gensim.models.keyedvectors.Vocab at 0x7f295e02d190>,
#  'impotence': <gensim.models.keyedvectors.Vocab at 0x7f295e02d1d0>,
#  'menstrual': <gensim.models.keyedvectors.Vocab at 0x7f295e02d210>,
#  'sterility': <gensim.models.keyedvectors.Vocab at 0x7f295e02d250>,
#  'hips': <gensim.models.keyedvectors.Vocab at 0x7f295e02d290>,
#  'thing': <gensim.models.keyedvectors.Vocab at 0x7f295e02d2d0>,
#  'vertebra': <gensim.models.keyedvectors.Vocab at 0x7f295e02d310>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x7f295e02d350>,
#  'stretch': <gensim.models.keyedvectors.Vocab at 0x7f295e02d390>,
#  'sitting': <gensim.models.keyedvectors.Vocab at 0x7f295e02d3d0>,
#  'spine': <gensim.models.keyedvectors.Vocab at 0x7f295e02d410>,
#  'twist': <gensim.models.keyedvectors.Vocab at 0x7f295e02d450>,
#  'tion': <gensim.models.keyedvectors.Vocab at 0x7f295e02d490>,
#  'plexus': <gensim.models.keyedvectors.Vocab at 0x7f295e02d4d0>,
#  'ther': <gensim.models.keyedvectors.Vocab at 0x7f295e02d510>,
#  'buttocks': <gensim.models.keyedvectors.Vocab at 0x7f295e02d550>,
#  'twisting': <gensim.models.keyedvectors.Vocab at 0x7f295e02d590>,
#  'distance': <gensim.models.keyedvectors.Vocab at 0x7f295e02d5d0>,
#  'cardiac': <gensim.models.keyedvectors.Vocab at 0x7f295e02d610>,
#  'diges': <gensim.models.keyedvectors.Vocab at 0x7f295e02d650>,
#  'placement': <gensim.models.keyedvectors.Vocab at 0x7f295e02d690>,
#  'efore': <gensim.models.keyedvectors.Vocab at 0x7f295e02d6d0>,
#  'tightness': <gensim.models.keyedvectors.Vocab at 0x7f295e02d710>,
#  'action': <gensim.models.keyedvectors.Vocab at 0x7f295e02d750>,
#  'r': <gensim.models.keyedvectors.Vocab at 0x7f295e02d790>,
#  'deep': <gensim.models.keyedvectors.Vocab at 0x7f295e02d7d0>,
#  'systems': <gensim.models.keyedvectors.Vocab at 0x7f295e02d810>,
#  'women': <gensim.models.keyedvectors.Vocab at 0x7f295e02d850>,
#  'circu': <gensim.models.keyedvectors.Vocab at 0x7f295e02d890>,
#  'pregnancy': <gensim.models.keyedvectors.Vocab at 0x7f295e02d8d0>,
#  'childbearing': <gensim.models.keyedvectors.Vocab at 0x7f295e02d910>,
#  'nervous': <gensim.models.keyedvectors.Vocab at 0x7f295e02d950>,
#  'state': <gensim.models.keyedvectors.Vocab at 0x7f295e02d990>,
#  'second': <gensim.models.keyedvectors.Vocab at 0x7f295e02d9d0>,
#  'muscular': <gensim.models.keyedvectors.Vocab at 0x7f295e02da10>,
#  'deeper': <gensim.models.keyedvectors.Vocab at 0x7f295e02da50>,
#  'relaxation': <gensim.models.keyedvectors.Vocab at 0x7f295e02da90>,
#  'hormonal': <gensim.models.keyedvectors.Vocab at 0x7f295e02dad0>,
#  'lethargy': <gensim.models.keyedvectors.Vocab at 0x7f295e02db10>,
#  'latory': <gensim.models.keyedvectors.Vocab at 0x7f295e02db50>,
#  'shavasana': <gensim.models.keyedvectors.Vocab at 0x7f295e02db90>,
#  'trimester': <gensim.models.keyedvectors.Vocab at 0x7f295e02dbd0>,
#  'order': <gensim.models.keyedvectors.Vocab at 0x7f295e02dc10>,
#  'tones': <gensim.models.keyedvectors.Vocab at 0x7f295e02dc50>,
#  'firms': <gensim.models.keyedvectors.Vocab at 0x7f295e02dc90>,
#  'upper': <gensim.models.keyedvectors.Vocab at 0x7f295e02dcd0>,
#  'loosens': <gensim.models.keyedvectors.Vocab at 0x7f295e02dd10>,
#  'breast': <gensim.models.keyedvectors.Vocab at 0x7f295e02dd50>,
#  'chest': <gensim.models.keyedvectors.Vocab at 0x7f295e02dd90>,
#  'flexibility': <gensim.models.keyedvectors.Vocab at 0x7f295e02ddd0>,
#  'increases': <gensim.models.keyedvectors.Vocab at 0x7f295e02de10>,
#  'recovery': <gensim.models.keyedvectors.Vocab at 0x7f295e02de50>,
#  'cycle': <gensim.models.keyedvectors.Vocab at 0x7f295e02de90>,
#  'postnatal': <gensim.models.keyedvectors.Vocab at 0x7f295e02ded0>,
#  'pelvis': <gensim.models.keyedvectors.Vocab at 0x7f295e02df10>,
#  'toning': <gensim.models.keyedvectors.Vocab at 0x7f295e02df50>,
#  'abdomen': <gensim.models.keyedvectors.Vocab at 0x7f295e02df90>,
#  'months': <gensim.models.keyedvectors.Vocab at 0x7f295e02dfd0>,
#  'areas': <gensim.models.keyedvectors.Vocab at 0x7f295e030050>,
#  'effect': <gensim.models.keyedvectors.Vocab at 0x7f295e030090>,
#  'positive': <gensim.models.keyedvectors.Vocab at 0x7f295e0300d0>,
#  'disorders': <gensim.models.keyedvectors.Vocab at 0x7f295e030110>,
#  'natal': <gensim.models.keyedvectors.Vocab at 0x7f295e030150>,
#  'gynaecological': <gensim.models.keyedvectors.Vocab at 0x7f295e030190>,
#  'blades': <gensim.models.keyedvectors.Vocab at 0x7f295e0301d0>,
#  'frustration': <gensim.models.keyedvectors.Vocab at 0x7f295e030210>,
#  'mood': <gensim.models.keyedvectors.Vocab at 0x7f295e030250>,
#  'special': <gensim.models.keyedvectors.Vocab at 0x7f295e030290>,
#  'inaccessible': <gensim.models.keyedvectors.Vocab at 0x7f295e0302d0>,
#  'girdle': <gensim.models.keyedvectors.Vocab at 0x7f295e030310>,
#  'lighten': <gensim.models.keyedvectors.Vocab at 0x7f295e030350>,
#  'arms': <gensim.models.keyedvectors.Vocab at 0x7f295e030390>,
#  'profound': <gensim.models.keyedvectors.Vocab at 0x7f295e0303d0>,
#  'thighs': <gensim.models.keyedvectors.Vocab at 0x7f295e030410>,
#  'mas': <gensim.models.keyedvectors.Vocab at 0x7f295e030450>,
#  'leg': <gensim.models.keyedvectors.Vocab at 0x7f295e030490>,
#  'toned': <gensim.models.keyedvectors.Vocab at 0x7f295e0304d0>,
#  'flatulence': <gensim.models.keyedvectors.Vocab at 0x7f295e030510>,
#  'namaskarasana': <gensim.models.keyedvectors.Vocab at 0x7f295e030550>,
#  'equal': <gensim.models.keyedvectors.Vocab at 0x7f295e030590>,
#  'arm': <gensim.models.keyedvectors.Vocab at 0x7f295e0305d0>,
#  'meditation': <gensim.models.keyedvectors.Vocab at 0x7f295e030610>,
#  'circulation': <gensim.models.keyedvectors.Vocab at 0x7f295e030650>,
#  'ailments': <gensim.models.keyedvectors.Vocab at 0x7f295e030690>,
#  'correction': <gensim.models.keyedvectors.Vocab at 0x7f295e0306d0>,
#  'relaxes': <gensim.models.keyedvectors.Vocab at 0x7f295e030710>,
#  'eye': <gensim.models.keyedvectors.Vocab at 0x7f295e030750>,
#  'aqueous': <gensim.models.keyedvectors.Vocab at 0x7f295e030790>,
#  'palming': <gensim.models.keyedvectors.Vocab at 0x7f295e0307d0>,
#  'stimulates': <gensim.models.keyedvectors.Vocab at 0x7f295e030810>,
#  'vision': <gensim.models.keyedvectors.Vocab at 0x7f295e030850>,
#  'liquid': <gensim.models.keyedvectors.Vocab at 0x7f295e030890>,
#  'defective': <gensim.models.keyedvectors.Vocab at 0x7f295e0308d0>,
#  'humour': <gensim.models.keyedvectors.Vocab at 0x7f295e030910>,
#  'cornea': <gensim.models.keyedvectors.Vocab at 0x7f295e030950>,
#  'habitual': <gensim.models.keyedvectors.Vocab at 0x7f295e030990>,
#  'eyesight': <gensim.models.keyedvectors.Vocab at 0x7f295e0309d0>,
#  'spontaneous': <gensim.models.keyedvectors.Vocab at 0x7f295e030a10>,
#  'reflex': <gensim.models.keyedvectors.Vocab at 0x7f295e030a50>,
#  'eyes': <gensim.models.keyedvectors.Vocab at 0x7f295e030a90>,
#  'becmne': <gensim.models.keyedvectors.Vocab at 0x7f295e030ad0>,
#  'encourages': <gensim.models.keyedvectors.Vocab at 0x7f295e030b10>,
#  'blink': <gensim.models.keyedvectors.Vocab at 0x7f295e030b50>,
#  'sideways': <gensim.models.keyedvectors.Vocab at 0x7f295e030b90>,
#  'close': <gensim.models.keyedvectors.Vocab at 0x7f295e030bd0>,
#  'corrects': <gensim.models.keyedvectors.Vocab at 0x7f295e030c10>,
#  'constant': <gensim.models.keyedvectors.Vocab at 0x7f295e030c50>,
#  'viewing': <gensim.models.keyedvectors.Vocab at 0x7f295e030c90>,
#  'reading': <gensim.models.keyedvectors.Vocab at 0x7f295e030cd0>,
#  'lateral': <gensim.models.keyedvectors.Vocab at 0x7f295e030d10>,
#  'medial': <gensim.models.keyedvectors.Vocab at 0x7f295e030d50>,
#  'eyeball': <gensim.models.keyedvectors.Vocab at 0x7f295e030d90>,
#  'balances': <gensim.models.keyedvectors.Vocab at 0x7f295e030dd0>,
#  'acti': <gensim.models.keyedvectors.Vocab at 0x7f295e030e10>,
#  'coordinated': <gensim.models.keyedvectors.Vocab at 0x7f295e030e50>,
#  'rotational': <gensim.models.keyedvectors.Vocab at 0x7f295e030e90>,
#  'vities': <gensim.models.keyedvectors.Vocab at 0x7f295e030ed0>,
#  'power': <gensim.models.keyedvectors.Vocab at 0x7f295e030f10>,
#  'movements': <gensim.models.keyedvectors.Vocab at 0x7f295e030f50>,
#  'practi': <gensim.models.keyedvectors.Vocab at 0x7f295e030f90>,
#  'tioner': <gensim.models.keyedvectors.Vocab at 0x7f295e030fd0>,
#  'physiological': <gensim.models.keyedvectors.Vocab at 0x7f295e032050>,
#  'psycho': <gensim.models.keyedvectors.Vocab at 0x7f295e032090>,
#  'pratyahara': <gensim.models.keyedvectors.Vocab at 0x7f295e0320d0>,
#  'sleep': <gensim.models.keyedvectors.Vocab at 0x7f295e032110>,
#  'mind': <gensim.models.keyedvectors.Vocab at 0x7f295e032150>,
#  'exercises': <gensim.models.keyedvectors.Vocab at 0x7f295e032190>,
#  'namaskara': <gensim.models.keyedvectors.Vocab at 0x7f295e0321d0>,
#  'relaxed': <gensim.models.keyedvectors.Vocab at 0x7f295e032210>,
#  'tired': <gensim.models.keyedvectors.Vocab at 0x7f295e032250>,
#  'dynamic': <gensim.models.keyedvectors.Vocab at 0x7f295e032290>,
#  'figure': <gensim.models.keyedvectors.Vocab at 0x7f295e7c4850>,
#  'stiff': <gensim.models.keyedvectors.Vocab at 0x7f295e7c4690>,
#  'disc': <gensim.models.keyedvectors.Vocab at 0x7f295e7c4750>,
#  'complaints': <gensim.models.keyedvectors.Vocab at 0x7f295e7c48d0>,
#  'helpful': <gensim.models.keyedvectors.Vocab at 0x7f295e7c4610>,
#  'air': <gensim.models.keyedvectors.Vocab at 0x7f295e7c4650>,
#  'compression': <gensim.models.keyedvectors.Vocab at 0x7f295e7c4710>,
#  'pain': <gensim.models.keyedvectors.Vocab at 0x7f295e7c4450>,
#  'periods': <gensim.models.keyedvectors.Vocab at 0x7f295e7c4790>,
#  'sciatica': <gensim.models.keyedvectors.Vocab at 0x7f295e7c4810>,
#  'normal': <gensim.models.keyedvectors.Vocab at 0x7f295e7c4890>,
#  'releases': <gensim.models.keyedvectors.Vocab at 0x7f295e7c46d0>,
#  'vertebral': <gensim.models.keyedvectors.Vocab at 0x7f295e750950>,
#  'simple': <gensim.models.keyedvectors.Vocab at 0x7f295e750c50>,
#  'lungs': <gensim.models.keyedvectors.Vocab at 0x7f295e750710>,
#  'types': <gensim.models.keyedvectors.Vocab at 0x7f295e750910>,
#  'certain': <gensim.models.keyedvectors.Vocab at 0x7f295e750050>,
#  'column': <gensim.models.keyedvectors.Vocab at 0x7f295e750810>,
#  'lung': <gensim.models.keyedvectors.Vocab at 0x7f295e7506d0>,
#  'nidra': <gensim.models.keyedvectors.Vocab at 0x7f295e750790>,
#  'veins': <gensim.models.keyedvectors.Vocab at 0x7f295e750e50>,
#  'circumstances': <gensim.models.keyedvectors.Vocab at 0x7f295e750510>,
#  'perineum': <gensim.models.keyedvectors.Vocab at 0x7f295e750a10>,
#  'ideal': <gensim.models.keyedvectors.Vocab at 0x7f295e750ed0>,
#  'bent': <gensim.models.keyedvectors.Vocab at 0x7f295e750490>,
#  'kridasana': <gensim.models.keyedvectors.Vocab at 0x7f295e5382d0>,
#  'matsya': <gensim.models.keyedvectors.Vocab at 0x7f295dffed50>,
#  'posture': <gensim.models.keyedvectors.Vocab at 0x7f295dffe810>,
#  'backward': <gensim.models.keyedvectors.Vocab at 0x7f295dffe790>,
#  'block': <gensim.models.keyedvectors.Vocab at 0x7f295dffe490>,
#  'comfort': <gensim.models.keyedvectors.Vocab at 0x7f295dffe390>,
#  'relaxing': <gensim.models.keyedvectors.Vocab at 0x7f295dffefd0>,
#  'sciatic': <gensim.models.keyedvectors.Vocab at 0x7f295dffef10>,
#  'tnended': <gensim.models.keyedvectors.Vocab at 0x7f295dffee10>,
#  'difficult': <gensim.models.keyedvectors.Vocab at 0x7f295dffe9d0>,
#  'persons': <gensim.models.keyedvectors.Vocab at 0x7f295dffeed0>,
#  'postures': <gensim.models.keyedvectors.Vocab at 0x7f295dffef50>,
#  'sukhasana': <gensim.models.keyedvectors.Vocab at 0x7f295dffec10>,
#  'mental': <gensim.models.keyedvectors.Vocab at 0x7f295dffed90>,
#  'medita': <gensim.models.keyedvectors.Vocab at 0x7f295dffead0>,
#  'balance': <gensim.models.keyedvectors.Vocab at 0x7f295e658dd0>,
#  'unable': <gensim.models.keyedvectors.Vocab at 0x7f295e77f4d0>,
#  'comfortable': <gensim.models.keyedvectors.Vocab at 0x7f295e77f910>,
#  'easiest': <gensim.models.keyedvectors.Vocab at 0x7f295e77f410>,
#  'ill': <gensim.models.keyedvectors.Vocab at 0x7f295e0322d0>,
#  'level': <gensim.models.keyedvectors.Vocab at 0x7f295e032310>,
#  'benefits': <gensim.models.keyedvectors.Vocab at 0x7f295e032350>,
#  'experience': <gensim.models.keyedvectors.Vocab at 0x7f295e032390>,
#  'step': <gensim.models.keyedvectors.Vocab at 0x7f295e0323d0>,
#  'pillar': <gensim.models.keyedvectors.Vocab at 0x7f295e032410>,
#  'process': <gensim.models.keyedvectors.Vocab at 0x7f295e032450>,
#  'trunk': <gensim.models.keyedvectors.Vocab at 0x7f295e032490>,
#  'calm': <gensim.models.keyedvectors.Vocab at 0x7f295e0324d0>,
#  'sahasrara': <gensim.models.keyedvectors.Vocab at 0x7f295e032510>,
#  'lumbar': <gensim.models.keyedvectors.Vocab at 0x7f295e032550>,
#  'chakras': <gensim.models.keyedvectors.Vocab at 0x7f295e032590>,
#  'pubic': <gensim.models.keyedvectors.Vocab at 0x7f295e0325d0>,
#  'sahajoli': <gensim.models.keyedvectors.Vocab at 0x7f295e032610>,
#  'swadhisthana': <gensim.models.keyedvectors.Vocab at 0x7f295e032650>,
#  'presses': <gensim.models.keyedvectors.Vocab at 0x7f295e032690>,
#  'psychic': <gensim.models.keyedvectors.Vocab at 0x7f295e0326d0>,
#  'sensations': <gensim.models.keyedvectors.Vocab at 0x7f295e032710>,
#  'locks': <gensim.models.keyedvectors.Vocab at 0x7f295e032750>,
#  'sexual': <gensim.models.keyedvectors.Vocab at 0x7f295e032790>,
#  'flow': <gensim.models.keyedvectors.Vocab at 0x7f295e0327d0>,
#  'brain': <gensim.models.keyedvectors.Vocab at 0x7f295e032810>,
#  'bone': <gensim.models.keyedvectors.Vocab at 0x7f295e032850>,
#  'necessary': <gensim.models.keyedvectors.Vocab at 0x7f295e032890>,
#  'tingling': <gensim.models.keyedvectors.Vocab at 0x7f295e0328d0>,
#  'control': <gensim.models.keyedvectors.Vocab at 0x7f295e032910>,
#  'cord': <gensim.models.keyedvectors.Vocab at 0x7f295e032950>,
#  'position': <gensim.models.keyedvectors.Vocab at 0x7f295e032990>,
#  'retention': <gensim.models.keyedvectors.Vocab at 0x7f295e0329d0>,
#  'fluid': <gensim.models.keyedvectors.Vocab at 0x7f295e032a10>,
#  'healthy': <gensim.models.keyedvectors.Vocab at 0x7f295e032a50>,
#  'swastikasana': <gensim.models.keyedvectors.Vocab at 0x7f295e032a90>,
#  'varicose': <gensim.models.keyedvectors.Vocab at 0x7f295e032ad0>,
#  'centre': <gensim.models.keyedvectors.Vocab at 0x7f295e032b10>,
#  'outer': <gensim.models.keyedvectors.Vocab at 0x7f295e032b50>,
#  'easy': <gensim.models.keyedvectors.Vocab at 0x7f295e032b90>,
#  'contact': <gensim.models.keyedvectors.Vocab at 0x7f295e032bd0>,
#  'structure': <gensim.models.keyedvectors.Vocab at 0x7f295e032c10>,
#  'knees': <gensim.models.keyedvectors.Vocab at 0x7f295e032c50>,
#  'floor': <gensim.models.keyedvectors.Vocab at 0x7f295e032c90>,
#  'large': <gensim.models.keyedvectors.Vocab at 0x7f295e032cd0>,
#  'alters': <gensim.models.keyedvectors.Vocab at 0x7f295e032d10>,
#  'ulcer': <gensim.models.keyedvectors.Vocab at 0x7f295e032d50>,
#  'stomach': <gensim.models.keyedvectors.Vocab at 0x7f295e032d90>,
#  'men': <gensim.models.keyedvectors.Vocab at 0x7f295e032dd0>,
#  'hyperacidity': <gensim.models.keyedvectors.Vocab at 0x7f295e032e10>,
#  'nerve': <gensim.models.keyedvectors.Vocab at 0x7f295e032e50>,
#  'hernia': <gensim.models.keyedvectors.Vocab at 0x7f295e032e90>,
#  'hydrocele': <gensim.models.keyedvectors.Vocab at 0x7f295e032ed0>,
#  'dilated': <gensim.models.keyedvectors.Vocab at 0x7f295e032f10>,
#  'measure': <gensim.models.keyedvectors.Vocab at 0x7f295e032f50>,
#  'entire': <gensim.models.keyedvectors.Vocab at 0x7f295e032f90>,
#  'genitals': <gensim.models.keyedvectors.Vocab at 0x7f295e032fd0>,
#  'impulses': <gensim.models.keyedvectors.Vocab at 0x7f295e037050>,
#  'piles': <gensim.models.keyedvectors.Vocab at 0x7f295e037090>,
#  'peptic': <gensim.models.keyedvectors.Vocab at 0x7f295e0370d0>,
#  'feed': <gensim.models.keyedvectors.Vocab at 0x7f295e037110>,
#  'testicles': <gensim.models.keyedvectors.Vocab at 0x7f295e037150>,
#  'fibres': <gensim.models.keyedvectors.Vocab at 0x7f295e037190>,
#  'ajna': <gensim.models.keyedvectors.Vocab at 0x7f295e0371d0>,
#  'calms': <gensim.models.keyedvectors.Vocab at 0x7f295e037210>,
#  'chakra': <gensim.models.keyedvectors.Vocab at 0x7f295e037250>,
#  'vajrasana': <gensim.models.keyedvectors.Vocab at 0x7f295e037290>,
#  'autonomic': <gensim.models.keyedvectors.Vocab at 0x7f295e0372d0>,
#  'activities': <gensim.models.keyedvectors.Vocab at 0x7f295e037310>,
#  'facilitate': <gensim.models.keyedvectors.Vocab at 0x7f295e037350>,
#  'nostrils': <gensim.models.keyedvectors.Vocab at 0x7f295e037390>,
#  'pranayama': <gensim.models.keyedvectors.Vocab at 0x7f295e0373d0>,
#  'breath': <gensim.models.keyedvectors.Vocab at 0x7f295e037410>,
#  'right': <gensim.models.keyedvectors.Vocab at 0x7f295e037450>,
#  'parasympathetic': <gensim.models.keyedvectors.Vocab at 0x7f295e037490>,
#  'influences': <gensim.models.keyedvectors.Vocab at 0x7f295e0374d0>,
#  'armpits': <gensim.models.keyedvectors.Vocab at 0x7f295e037510>,
#  'influence': <gensim.models.keyedvectors.Vocab at 0x7f295e037550>,
#  'aspirants': <gensim.models.keyedvectors.Vocab at 0x7f295e037590>,
#  'spiritual': <gensim.models.keyedvectors.Vocab at 0x7f295e0375d0>,
#  'mooladhara': <gensim.models.keyedvectors.Vocab at 0x7f295e037610>,
#  'total': <gensim.models.keyedvectors.Vocab at 0x7f295e037650>,
#  'stability': <gensim.models.keyedvectors.Vocab at 0x7f295e037690>,
#  'extension': <gensim.models.keyedvectors.Vocab at 0x7f295e0376d0>,
#  'definite': <gensim.models.keyedvectors.Vocab at 0x7f295e037710>,
#  'mouth': <gensim.models.keyedvectors.Vocab at 0x7f295e037750>,
#  'throat': <gensim.models.keyedvectors.Vocab at 0x7f295e037790>,
#  'simhagarjanasana': <gensim.models.keyedvectors.Vocab at 0x7f295e0377d0>,
#  'sun': <gensim.models.keyedvectors.Vocab at 0x7f295e037810>,
#  'stutter': <gensim.models.keyedvectors.Vocab at 0x7f295e037850>,
#  'beautiful': <gensim.models.keyedvectors.Vocab at 0x7f295e037890>,
#  'early': <gensim.models.keyedvectors.Vocab at 0x7f295e0378d0>,
#  'emotional': <gensim.models.keyedvectors.Vocab at 0x7f295e037910>,
#  'voice': <gensim.models.keyedvectors.Vocab at 0x7f295e037950>,
#  'ears': <gensim.models.keyedvectors.Vocab at 0x7f295e037990>,
#  'rays': <gensim.models.keyedvectors.Vocab at 0x7f295e0379d0>,
#  'nose': <gensim.models.keyedvectors.Vocab at 0x7f295e037a10>,
#  'mudra': <gensim.models.keyedvectors.Vocab at 0x7f295e037a50>,
#  'precise': <gensim.models.keyedvectors.Vocab at 0x7f295e037a90>,
#  'clear': <gensim.models.keyedvectors.Vocab at 0x7f295e037ad0>,
#  'realms': <gensim.models.keyedvectors.Vocab at 0x7f295e037b10>,
#  'concentration': <gensim.models.keyedvectors.Vocab at 0x7f295e037b50>,
#  'beco': <gensim.models.keyedvectors.Vocab at 0x7f295e037b90>,
#  'kidneys': <gensim.models.keyedvectors.Vocab at 0x7f295e037bd0>,
#  'unconscious': <gensim.models.keyedvectors.Vocab at 0x7f295e037c10>,
#  'nuch': <gensim.models.keyedvectors.Vocab at 0x7f295e037c50>,
#  'nes': <gensim.models.keyedvectors.Vocab at 0x7f295e037c90>,
#  'uncontrollable': <gensim.models.keyedvectors.Vocab at 0x7f295e037cd0>,
#  'thoughts': <gensim.models.keyedvectors.Vocab at 0x7f295e037d10>,
#  'cramps': <gensim.models.keyedvectors.Vocab at 0x7f295e037d50>,
#  'forceful': <gensim.models.keyedvectors.Vocab at 0x7f295e037d90>,
#  'female': <gensim.models.keyedvectors.Vocab at 0x7f295e037dd0>,
#  'relief': <gensim.models.keyedvectors.Vocab at 0x7f295e037e10>,
#  'leucorrhea': <gensim.models.keyedvectors.Vocab at 0x7f295e037e50>,
#  'contraction': <gensim.models.keyedvectors.Vocab at 0x7f295e037e90>,
#  'directions': <gensim.models.keyedvectors.Vocab at 0x7f295e037ed0>,
#  'digestion': <gensim.models.keyedvectors.Vocab at 0x7f295e037f10>,
#  'children': <gensim.models.keyedvectors.Vocab at 0x7f295e037f50>,
#  'birth': <gensim.models.keyedvectors.Vocab at 0x7f295e037f90>,
#  'problem': <gensim.models.keyedvectors.Vocab at 0x7f295e037fd0>,
#  'discs': <gensim.models.keyedvectors.Vocab at 0x7f295e039050>,
#  'forms': <gensim.models.keyedvectors.Vocab at 0x7f295e039090>,
#  'male': <gensim.models.keyedvectors.Vocab at 0x7f295e0390d0>,
#  'correct': <gensim.models.keyedvectors.Vocab at 0x7f295e039110>,
#  'individual': <gensim.models.keyedvectors.Vocab at 0x7f295e039150>,
#  'backache': <gensim.models.keyedvectors.Vocab at 0x7f295e039190>,
#  'adrenal': <gensim.models.keyedvectors.Vocab at 0x7f295e0391d0>,
#  'cases': <gensim.models.keyedvectors.Vocab at 0x7f295e039210>,
#  'glands': <gensim.models.keyedvectors.Vocab at 0x7f295e039250>,
#  'shashank': <gensim.models.keyedvectors.Vocab at 0x7f295e039290>,
#  'shashankasana': <gensim.models.keyedvectors.Vocab at 0x7f295e0392d0>,
#  'final': <gensim.models.keyedvectors.Vocab at 0x7f295e039310>,
#  'liver': <gensim.models.keyedvectors.Vocab at 0x7f295e039350>,
#  'bhujangasana': <gensim.models.keyedvectors.Vocab at 0x7f295e039390>,
#  'similar': <gensim.models.keyedvectors.Vocab at 0x7f295e0393d0>,
#  'degree': <gensim.models.keyedvectors.Vocab at 0x7f295e039410>,
#  'sirshasana': <gensim.models.keyedvectors.Vocab at 0x7f295e039450>,
#  'extra': <gensim.models.keyedvectors.Vocab at 0x7f295e039490>,
#  'headstand': <gensim.models.keyedvectors.Vocab at 0x7f295e0394d0>,
#  'lesser': <gensim.models.keyedvectors.Vocab at 0x7f295e039510>,
#  'feet': <gensim.models.keyedvectors.Vocab at 0x7f295e039550>,
#  'ankles': <gensim.models.keyedvectors.Vocab at 0x7f295e039590>,
#  'ushtrasana': <gensim.models.keyedvectors.Vocab at 0x7f295e0395d0>,
#  'intestines': <gensim.models.keyedvectors.Vocab at 0x7f295e039610>,
#  'rounded': <gensim.models.keyedvectors.Vocab at 0x7f295e039650>,
#  'thyroid': <gensim.models.keyedvectors.Vocab at 0x7f295e039690>,
#  'asthma': <gensim.models.keyedvectors.Vocab at 0x7f295e0396d0>,
#  'realigns': <gensim.models.keyedvectors.Vocab at 0x7f295e039710>,
#  'gland': <gensim.models.keyedvectors.Vocab at 0x7f295e039750>,
#  'suffering': <gensim.models.keyedvectors.Vocab at 0x7f295e039790>,
#  'capacity': <gensim.models.keyedvectors.Vocab at 0x7f295e0397d0>,
#  'oxygen': <gensim.models.keyedvectors.Vocab at 0x7f295e039810>,
#  'om': <gensim.models.keyedvectors.Vocab at 0x7f295e039850>,
#  'flexible': <gensim.models.keyedvectors.Vocab at 0x7f295e039890>,
#  'breaths': <gensim.models.keyedvectors.Vocab at 0x7f295e0398d0>,
#  'breathing': <gensim.models.keyedvectors.Vocab at 0x7f295e039910>,
#  'rectifies': <gensim.models.keyedvectors.Vocab at 0x7f295e039950>,
#  'round': <gensim.models.keyedvectors.Vocab at 0x7f295e039990>,
#  'supply': <gensim.models.keyedvectors.Vocab at 0x7f295e0399d0>,
#  'tensing': <gensim.models.keyedvectors.Vocab at 0x7f295e039a10>,
#  'ann': <gensim.models.keyedvectors.Vocab at 0x7f295e039a50>,
#  'significant': <gensim.models.keyedvectors.Vocab at 0x7f295e039a90>,
#  'bad': <gensim.models.keyedvectors.Vocab at 0x7f295e039ad0>,
#  'postural': <gensim.models.keyedvectors.Vocab at 0x7f295e039b10>,
#  'smoothes': <gensim.models.keyedvectors.Vocab at 0x7f295e039b50>,
#  'alternate': <gensim.models.keyedvectors.Vocab at 0x7f295e039b90>,
#  'responsible': <gensim.models.keyedvectors.Vocab at 0x7f295e039bd0>,
#  'short': <gensim.models.keyedvectors.Vocab at 0x7f295e039c10>,
#  'tadasana': <gensim.models.keyedvectors.Vocab at 0x7f295e039c50>,
#  'longer': <gensim.models.keyedvectors.Vocab at 0x7f295e039c90>,
#  'bones': <gensim.models.keyedvectors.Vocab at 0x7f295e039cd0>,
#  'points': <gensim.models.keyedvectors.Vocab at 0x7f295e039d10>,
#  'abdomini': <gensim.models.keyedvectors.Vocab at 0x7f295e039d50>,
#  'congestion': <gensim.models.keyedvectors.Vocab at 0x7f295e039d90>,
#  'rectus': <gensim.models.keyedvectors.Vocab at 0x7f295e039dd0>,
#  'height': <gensim.models.keyedvectors.Vocab at 0x7f295e039e10>,
#  'groups': <gensim.models.keyedvectors.Vocab at 0x7f295e039e50>,
#  'sides': <gensim.models.keyedvectors.Vocab at 0x7f295e039e90>,
#  'waist': <gensim.models.keyedvectors.Vocab at 0x7f295e039ed0>,
#  'movement': <gensim.models.keyedvectors.Vocab at 0x7f295e039f10>,
#  'day': <gensim.models.keyedvectors.Vocab at 0x7f295e039f50>,
#  'lightness': <gensim.models.keyedvectors.Vocab at 0x7f295e039f90>,
#  'feeling': <gensim.models.keyedvectors.Vocab at 0x7f295e039fd0>,
#  'kati': <gensim.models.keyedvectors.Vocab at 0x7f295e03c050>,
#  'chakrasana': <gensim.models.keyedvectors.Vocab at 0x7f295e03c090>,
#  'excess': <gensim.models.keyedvectors.Vocab at 0x7f295e03c0d0>,
#  'waistline': <gensim.models.keyedvectors.Vocab at 0x7f295e03c110>,
#  'uterus': <gensim.models.keyedvectors.Vocab at 0x7f295e03c150>,
#  'middle': <gensim.models.keyedvectors.Vocab at 0x7f295e03c190>,
#  'poor': <gensim.models.keyedvectors.Vocab at 0x7f295e03c1d0>,
#  'young': <gensim.models.keyedvectors.Vocab at 0x7f295e03c210>,
#  'bodies': <gensim.models.keyedvectors.Vocab at 0x7f295e03c250>,
#  'fat': <gensim.models.keyedvectors.Vocab at 0x7f295e03c290>,
#  'depression': <gensim.models.keyedvectors.Vocab at 0x7f295e03c2d0>,
#  'alleviates': <gensim.models.keyedvectors.Vocab at 0x7f295e03c310>,
#  'area': <gensim.models.keyedvectors.Vocab at 0x7f295e03c350>,
#  'series': <gensim.models.keyedvectors.Vocab at 0x7f295e03c390>,
#  'regular': <gensim.models.keyedvectors.Vocab at 0x7f295e03c3d0>,
#  'han': <gensim.models.keyedvectors.Vocab at 0x7f295e03c410>,
#  'alveoli': <gensim.models.keyedvectors.Vocab at 0x7f295e03c450>,
#  'mucus': <gensim.models.keyedvectors.Vocab at 0x7f295e03c490>,
#  'strings': <gensim.models.keyedvectors.Vocab at 0x7f295e03c4d0>,
#  'prepranayama': <gensim.models.keyedvectors.Vocab at 0x7f295e03c510>,
#  'visceral': <gensim.models.keyedvectors.Vocab at 0x7f295e03c550>,
#  'supple': <gensim.models.keyedvectors.Vocab at 0x7f295e03c590>,
#  'hamstrings': <gensim.models.keyedvectors.Vocab at 0x7f295e03c5d0>,
#  'face': <gensim.models.keyedvectors.Vocab at 0x7f295e03c610>,
#  'calmness': <gensim.models.keyedvectors.Vocab at 0x7f295e03c650>,
#  'preparation': <gensim.models.keyedvectors.Vocab at 0x7f295e03c690>,
#  'spaces': <gensim.models.keyedvectors.Vocab at 0x7f295e03c6d0>,
#  'indigestion': <gensim.models.keyedvectors.Vocab at 0x7f295e03c710>,
#  'general': <gensim.models.keyedvectors.Vocab at 0x7f295e03c750>,
#  'yogamudrasana': <gensim.models.keyedvectors.Vocab at 0x7f295e03c790>,
#  'health': <gensim.models.keyedvectors.Vocab at 0x7f295e03c7d0>,
#  'manipura': <gensim.models.keyedvectors.Vocab at 0x7f295e03c810>,
#  'vitality': <gensim.models.keyedvectors.Vocab at 0x7f295e03c850>,
#  'thymus': <gensim.models.keyedvectors.Vocab at 0x7f295e03c890>,
#  'water': <gensim.models.keyedvectors.Vocab at 0x7f295e03c8d0>,
#  'immune': <gensim.models.keyedvectors.Vocab at 0x7f295e03c910>,
#  'respiration': <gensim.models.keyedvectors.Vocab at 0x7f295e03c950>,
#  'perform': <gensim.models.keyedvectors.Vocab at 0x7f295e03c990>,
#  'peace': <gensim.models.keyedvectors.Vocab at 0x7f295e03c9d0>,
#  'productive': <gensim.models.keyedvectors.Vocab at 0x7f295e03ca10>,
#  'defects': <gensim.models.keyedvectors.Vocab at 0x7f295e03ca50>,
#  'growth': <gensim.models.keyedvectors.Vocab at 0x7f295e03ca90>,
#  'chests': <gensim.models.keyedvectors.Vocab at 0x7f295e03cad0>,
#  'awakening': <gensim.models.keyedvectors.Vocab at 0x7f295e03cb10>,
#  'kundalini': <gensim.models.keyedvectors.Vocab at 0x7f295e03cb50>,
#  'security': <gensim.models.keyedvectors.Vocab at 0x7f295e03cb90>,
#  'appetite': <gensim.models.keyedvectors.Vocab at 0x7f295e03cbd0>,
#  'anger': <gensim.models.keyedvectors.Vocab at 0x7f295e03cc10>,
#  'excited': <gensim.models.keyedvectors.Vocab at 0x7f295e03cc50>,
#  'practise': <gensim.models.keyedvectors.Vocab at 0x7f295e03cc90>,
#  'sense': <gensim.models.keyedvectors.Vocab at 0x7f295e03ccd0>,
#  'equanimity': <gensim.models.keyedvectors.Vocab at 0x7f295e03cd10>,
#  'strength': <gensim.models.keyedvectors.Vocab at 0x7f295e03cd50>,
#  'backs': <gensim.models.keyedvectors.Vocab at 0x7f295e03cd90>,
#  'sarpasana': <gensim.models.keyedvectors.Vocab at 0x7f295e03cdd0>,
#  'addition': <gensim.models.keyedvectors.Vocab at 0x7f295e03ce10>,
#  'shalabhasana': <gensim.models.keyedvectors.Vocab at 0x7f295e03ce50>,
#  'mild': <gensim.models.keyedvectors.Vocab at 0x7f295e03ce90>,
#  'condition': <gensim.models.keyedvectors.Vocab at 0x7f295e03ced0>,
#  'bowels': <gensim.models.keyedvectors.Vocab at 0x7f295e03cf10>,
#  'respiratory': <gensim.models.keyedvectors.Vocab at 0x7f295e03cf50>,
#  'discomfort': <gensim.models.keyedvectors.Vocab at 0x7f295e03cf90>,
#  'creased': <gensim.models.keyedvectors.Vocab at 0x7f295e03cfd0>,
#  'dhanurasana': <gensim.models.keyedvectors.Vocab at 0x7f295dfbf050>,
#  'levels': <gensim.models.keyedvectors.Vocab at 0x7f295dfbf090>,
#  'secretions': <gensim.models.keyedvectors.Vocab at 0x7f295dfbf0d0>,
#  'ed': <gensim.models.keyedvectors.Vocab at 0x7f295dfbf110>,
#  'cetvical': <gensim.models.keyedvectors.Vocab at 0x7f295dfbf150>,
#  'netves': <gensim.models.keyedvectors.Vocab at 0x7f295dfbf190>,
#  'balancing': <gensim.models.keyedvectors.Vocab at 0x7f295dfbf1d0>,
#  'pancreas': <gensim.models.keyedvectors.Vocab at 0x7f295dfbf210>,
#  'sluggishness': <gensim.models.keyedvectors.Vocab at 0x7f295dfbf250>,
#  'alimentary': <gensim.models.keyedvectors.Vocab at 0x7f295dfbf290>,
#  'gastrointestinal': <gensim.models.keyedvectors.Vocab at 0x7f295dfbf2d0>,
#  'bronchial': <gensim.models.keyedvectors.Vocab at 0x7f295dfbf310>,
#  'miscarry': <gensim.models.keyedvectors.Vocab at 0x7f295dfbf350>,
#  'colon': <gensim.models.keyedvectors.Vocab at 0x7f295dfbf390>,
#  'management': <gensim.models.keyedvectors.Vocab at 0x7f295dfbf3d0>,
#  'conditions': <gensim.models.keyedvectors.Vocab at 0x7f295dfbf410>,
#  'realign': <gensim.models.keyedvectors.Vocab at 0x7f295dfbf450>,
#  'risk': <gensim.models.keyedvectors.Vocab at 0x7f295dfbf490>,
#  'effects': <gensim.models.keyedvectors.Vocab at 0x7f295dfbf4d0>,
#  'diaphragm': <gensim.models.keyedvectors.Vocab at 0x7f295dfbf510>,
#  'tendons': <gensim.models.keyedvectors.Vocab at 0x7f295dfbf550>,
#  'achilles': <gensim.models.keyedvectors.Vocab at 0x7f295dfbf590>,
#  'wrists': <gensim.models.keyedvectors.Vocab at 0x7f295dfbf5d0>,
#  'gomukhasana': <gensim.models.keyedvectors.Vocab at 0x7f295dfbf610>,
#  'ache': <gensim.models.keyedvectors.Vocab at 0x7f295dfbf650>,
#  'minutes': <gensim.models.keyedvectors.Vocab at 0x7f295dfbf690>,
#  'relieves': <gensim.models.keyedvectors.Vocab at 0x7f295dfbf6d0>,
#  'anxiety': <gensim.models.keyedvectors.Vocab at 0x7f295dfbf710>,
#  'alternately': <gensim.models.keyedvectors.Vocab at 0x7f295dfbf750>,
#  'insides': <gensim.models.keyedvectors.Vocab at 0x7f295dfbf790>,
#  'genital': <gensim.models.keyedvectors.Vocab at 0x7f295dfbf7d0>,
#  'hamstring': <gensim.models.keyedvectors.Vocab at 0x7f295dfbf810>,
#  'uro': <gensim.models.keyedvectors.Vocab at 0x7f295dfbf850>,
#  'spleen': <gensim.models.keyedvectors.Vocab at 0x7f295dfbf890>,
#  'paschimottanasana': <gensim.models.keyedvectors.Vocab at 0x7f295dfbf8d0>,
#  'speeds': <gensim.models.keyedvectors.Vocab at 0x7f295dfbf910>,
#  'processes': <gensim.models.keyedvectors.Vocab at 0x7f295dfbf950>,
#  'metabolic': <gensim.models.keyedvectors.Vocab at 0x7f295dfbf990>,
#  'pranic': <gensim.models.keyedvectors.Vocab at 0x7f295dfbf9d0>,
#  'parts': <gensim.models.keyedvectors.Vocab at 0x7f295dfbfa10>,
#  'loosening': <gensim.models.keyedvectors.Vocab at 0x7f295dfbfa50>,
#  'janu': <gensim.models.keyedvectors.Vocab at 0x7f295dfbfa90>,
#  'intense': <gensim.models.keyedvectors.Vocab at 0x7f295dfbfad0>,
#  'turn': <gensim.models.keyedvectors.Vocab at 0x7f295dfbfb10>,
#  'intestinal': <gensim.models.keyedvectors.Vocab at 0x7f295dfbfb50>,
#  'identical': <gensim.models.keyedvectors.Vocab at 0x7f295dfbfb90>,
#  'distinct': <gensim.models.keyedvectors.Vocab at 0x7f295dfbfbd0>,
#  'characteristic': <gensim.models.keyedvectors.Vocab at 0x7f295dfbfc10>,
#  'alleviate': <gensim.models.keyedvectors.Vocab at 0x7f295dfbfc50>,
#  'peristalsis': <gensim.models.keyedvectors.Vocab at 0x7f295dfbfc90>,
#  'massage': <gensim.models.keyedvectors.Vocab at 0x7f295dfbfcd0>,
#  'proper': <gensim.models.keyedvectors.Vocab at 0x7f295dfbfd10>,
#  'girls': <gensim.models.keyedvectors.Vocab at 0x7f295dfbfd50>,
#  'steady': <gensim.models.keyedvectors.Vocab at 0x7f295dfbfd90>,
#  'development': <gensim.models.keyedvectors.Vocab at 0x7f295dfbfdd0>,
#  'graceful': <gensim.models.keyedvectors.Vocab at 0x7f295dfbfe10>,
#  'stronger': <gensim.models.keyedvectors.Vocab at 0x7f295dfbfe50>,
#  'reduces': <gensim.models.keyedvectors.Vocab at 0x7f295dfbfe90>,
#  'mus': <gensim.models.keyedvectors.Vocab at 0x7f295dfbfed0>,
#  'cles': <gensim.models.keyedvectors.Vocab at 0x7f295dfbff10>,
#  'adrenals': <gensim.models.keyedvectors.Vocab at 0x7f295dfbff50>,
#  'beginners': <gensim.models.keyedvectors.Vocab at 0x7f295dfbff90>,
#  'lumbago': <gensim.models.keyedvectors.Vocab at 0x7f295dfbffd0>,
#  'twists': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3050>,
#  'meru': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3090>,
#  'wakrasana': <gensim.models.keyedvectors.Vocab at 0x7f295dfc30d0>,
#  'duces': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3110>,
#  'calcium': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3150>,
#  'adjoining': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3190>,
#  'inflammatory': <gensim.models.keyedvectors.Vocab at 0x7f295dfc31d0>,
#  'tendency': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3210>,
#  'musrular': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3250>,
#  'deposits': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3290>,
#  'low': <gensim.models.keyedvectors.Vocab at 0x7f295dfc32d0>,
#  'influx': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3310>,
#  'crown': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3350>,
#  'rich': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3390>,
#  'accustoms': <gensim.models.keyedvectors.Vocab at 0x7f295dfc33d0>,
#  'preliminary': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3410>,
#  'vishuddhi': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3450>,
#  'drainage': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3490>,
#  'treatment': <gensim.models.keyedvectors.Vocab at 0x7f295dfc34d0>,
#  'free': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3510>,
#  'additional': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3550>,
#  'coordinates': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3590>,
#  'internal': <gensim.models.keyedvectors.Vocab at 0x7f295dfc35d0>,
#  'sarvangasana': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3610>,
#  'halasana': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3650>,
#  'production': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3690>,
#  'suprarenal': <gensim.models.keyedvectors.Vocab at 0x7f295dfc36d0>,
#  'kidney': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3710>,
#  'insulin': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3750>,
#  'place': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3790>,
#  'dyspepsia': <gensim.models.keyedvectors.Vocab at 0x7f295dfc37d0>,
#  'function': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3810>,
#  'spasms': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3850>,
#  'gall': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3890>,
#  'abdomin': <gensim.models.keyedvectors.Vocab at 0x7f295dfc38d0>,
#  'bladder': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3910>,
#  'al': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3950>,
#  'facilitates': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3990>,
#  'fats': <gensim.models.keyedvectors.Vocab at 0x7f295dfc39d0>,
#  'fever': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3a10>,
#  'glandular': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3a50>,
#  'imbalance': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3a90>,
#  'reversed': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3ad0>,
#  'root': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3b10>,
#  'psychological': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3b50>,
#  'regions': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3b90>,
#  'menopausal': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3bd0>,
#  'dioxide': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3c10>,
#  'disorder': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3c50>,
#  'carbon': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3c90>,
#  'expansion': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3cd0>,
#  'ankle': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3d10>,
#  'thens': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3d50>,
#  'streng': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3d90>,
#  'natavarasana': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3dd0>,
#  'garudasana': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3e10>,
#  'develops': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3e50>,
#  'coordina': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3e90>,
#  'sympathetic': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3ed0>,
#  'paschimottan': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3f10>,
#  'ofbalance': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3f50>,
#  'brahmacharya': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3f90>,
#  'seminal': <gensim.models.keyedvectors.Vocab at 0x7f295dfc3fd0>,
#  'ability': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5050>,
#  'maintenance': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5090>,
#  'toes': <gensim.models.keyedvectors.Vocab at 0x7f295dfc50d0>,
#  'eum': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5110>,
#  'perin': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5150>,
#  'purposes': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5190>,
#  'contract': <gensim.models.keyedvectors.Vocab at 0x7f295dfc51d0>,
#  'preservation': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5210>,
#  'hamsasana': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5250>,
#  'equilibrium': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5290>,
#  'harmony': <gensim.models.keyedvectors.Vocab at 0x7f295dfc52d0>,
#  'anahata': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5310>,
#  'ovaries': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5350>,
#  'introversion': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5390>,
#  'pation': <gensim.models.keyedvectors.Vocab at 0x7f295dfc53d0>,
#  'koormasana': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5410>,
#  'passion': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5450>,
#  'composure': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5490>,
#  'surrender': <gensim.models.keyedvectors.Vocab at 0x7f295dfc54d0>,
#  'diabetes': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5510>,
#  'subside': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5550>,
#  'poorna': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5590>,
#  'skin': <gensim.models.keyedvectors.Vocab at 0x7f295dfc55d0>,
#  'accumulation': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5610>,
#  'onal': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5650>,
#  'cardiovascular': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5690>,
#  'n': <gensim.models.keyedvectors.Vocab at 0x7f295dfc56d0>,
#  'conservation': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5710>,
#  'moola': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5750>,
#  'bandha': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5790>,
#  'important': <gensim.models.keyedvectors.Vocab at 0x7f295dfc57d0>,
#  'ashwini': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5810>,
#  'vajroli': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5850>,
#  'grivasana': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5890>,
#  'removal': <gensim.models.keyedvectors.Vocab at 0x7f295dfc58d0>,
#  'kapha': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5910>,
#  'doshas': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5950>,
#  'phlegm': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5990>,
#  'pitta': <gensim.models.keyedvectors.Vocab at 0x7f295dfc59d0>,
#  'elimination': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5a10>,
#  'particular': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5a50>,
#  'harmonizes': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5a90>,
#  'eliminatory': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5ad0>,
#  'apana': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5b10>,
#  'states': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5b50>,
#  'reverses': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5b90>,
#  'centres': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5bd0>,
#  'higher': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5c10>,
#  'netvous': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5c50>,
#  'celibacy': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5c90>,
#  'pituitary': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5cd0>,
#  'ing': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5d10>,
#  'vrischikasana': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5d50>,
#  'prana': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5d90>,
#  'ductive': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5dd0>,
#  'vitalizing': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5e10>,
#  'eka': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5e50>,
#  'pada': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5e90>,
#  'sirasana': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5ed0>,
#  'efficiency': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5f10>,
#  'solar': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5f50>,
#  'samana': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5f90>,
#  'vayu': <gensim.models.keyedvectors.Vocab at 0x7f295dfc5fd0>,
#  'balanced': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8050>,
#  'activates': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8090>,
#  'nostril': <gensim.models.keyedvectors.Vocab at 0x7f295dfc80d0>,
#  'sensitivity': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8110>,
#  'slow': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8150>,
#  'minor': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8190>,
#  'hemisphere': <gensim.models.keyedvectors.Vocab at 0x7f295dfc81d0>,
#  'stage': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8210>,
#  'technique': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8250>,
#  'temperature': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8290>,
#  'hunger': <gensim.models.keyedvectors.Vocab at 0x7f295dfc82d0>,
#  'biological': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8310>,
#  'excitation': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8350>,
#  'cools': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8390>,
#  'regulation': <gensim.models.keyedvectors.Vocab at 0x7f295dfc83d0>,
#  'thirst': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8410>,
#  'satisfaction': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8450>,
#  'tranquillity': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8490>,
#  'tranquillizer': <gensim.models.keyedvectors.Vocab at 0x7f295dfc84d0>,
#  'bhramari': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8510>,
#  'vibration': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8550>,
#  'cerebral': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8590>,
#  'ous': <gensim.models.keyedvectors.Vocab at 0x7f295dfc85d0>,
#  'insomnia': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8610>,
#  'nen': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8650>,
#  'sound': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8690>,
#  'tranquillizing': <gensim.models.keyedvectors.Vocab at 0x7f295dfc86d0>,
#  'rate': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8710>,
#  'heating': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8750>,
#  'soothes': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8790>,
#  'heat': <gensim.models.keyedvectors.Vocab at 0x7f295dfc87d0>,
#  'inflammation': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8810>,
#  'onepointedness': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8850>,
#  'rhythmic': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8890>,
#  'exchange': <gensim.models.keyedvectors.Vocab at 0x7f295dfc88d0>,
#  'purifies': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8910>,
#  'kapalbhati': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8950>,
#  'nadis': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8990>,
#  'distractions': <gensim.models.keyedvectors.Vocab at 0x7f295dfc89d0>,
#  'cleansing': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8a10>,
#  'energizes': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8a50>,
#  'sleepiness': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8a90>,
#  'sensory': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8ad0>,
#  'moorchha': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8b10>,
#  'cuts': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8b50>,
#  'identification': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8b90>,
#  'inwards': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8bd0>,
#  'neuroses': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8c10>,
#  'inhibits': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8c50>,
#  'world': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8c90>,
#  'dynamism': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8cd0>,
#  'pingala': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8d10>,
#  'imbalances': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8d50>,
#  'perceptive': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8d90>,
#  'communicate': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8dd0>,
#  'dull': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8e10>,
#  'alert': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8e50>,
#  'pre': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8e90>,
#  'nadi': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8ed0>,
#  'lethargic': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8f10>,
#  'chin': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8f50>,
#  'absent': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8f90>,
#  'endings': <gensim.models.keyedvectors.Vocab at 0x7f295dfc8fd0>,
#  'runs': <gensim.models.keyedvectors.Vocab at 0x7f295dfcb050>,
#  'channel': <gensim.models.keyedvectors.Vocab at 0x7f295dfcb090>,
#  'maintains': <gensim.models.keyedvectors.Vocab at 0x7f295dfcb0d0>,
#  'receptivity': <gensim.models.keyedvectors.Vocab at 0x7f295dfcb110>,
#  'finger': <gensim.models.keyedvectors.Vocab at 0x7f295dfcb150>,
#  'gupta': <gensim.models.keyedvectors.Vocab at 0x7f295dfcb190>,
#  'travel': <gensim.models.keyedvectors.Vocab at 0x7f295dfcb1d0>,
#  'practitioner': <gensim.models.keyedvectors.Vocab at 0x7f295dfcb210>,
#  'neural': <gensim.models.keyedvectors.Vocab at 0x7f295dfcb250>,
#  'cross': <gensim.models.keyedvectors.Vocab at 0x7f295dfcb290>,
#  'vice': <gensim.models.keyedvectors.Vocab at 0x7f295dfcb2d0>,
#  'complete': <gensim.models.keyedvectors.Vocab at 0x7f295dfcb310>,
#  'intensifies': <gensim.models.keyedvectors.Vocab at 0x7f295dfcb350>,
#  'connection': <gensim.models.keyedvectors.Vocab at 0x7f295dfcb390>,
#  'hands': <gensim.models.keyedvectors.Vocab at 0x7f295dfcb3d0>,
#  'fingers': <gensim.models.keyedvectors.Vocab at 0x7f295dfcb410>,
#  'point': <gensim.models.keyedvectors.Vocab at 0x7f295dfcb450>,
#  'union': <gensim.models.keyedvectors.Vocab at 0x7f295dfcb490>,
#  'dis': <gensim.models.keyedvectors.Vocab at 0x7f295dfcb4d0>,
#  'prano': <gensim.models.keyedvectors.Vocab at 0x7f295dfcb510>,
#  'supreme': <gensim.models.keyedvectors.Vocab at 0x7f295dfcb550>,
#  'consciousness': <gensim.models.keyedvectors.Vocab at 0x7f295dfcb590>,
#  'ida': <gensim.models.keyedvectors.Vocab at 0x7f295dfcb5d0>,
#  'bhairava': <gensim.models.keyedvectors.Vocab at 0x7f295dfcb610>,
#  'ring': <gensim.models.keyedvectors.Vocab at 0x7f295dfcb650>,
#  'crisis': <gensim.models.keyedvectors.Vocab at 0x7f295dfcb690>,
#  'hridaya': <gensim.models.keyedvectors.Vocab at 0x7f295dfcb6d0>,
#  'unburden': <gensim.models.keyedvectors.Vocab at 0x7f295dfcb710>,
#  'conflict': <gensim.models.keyedvectors.Vocab at 0x7f295dfcb750>,
#  'energizer': <gensim.models.keyedvectors.Vocab at 0x7f295dfcb790>,
#  'acute': <gensim.models.keyedvectors.Vocab at 0x7f295dfcb7d0>,
#  'thumb': <gensim.models.keyedvectors.Vocab at 0x7f295dfcb810>,
#  'fmgers': <gensim.models.keyedvectors.Vocab at 0x7f295dfcb850>,
#  'emotion': <gensim.models.keyedvectors.Vocab at 0x7f295dfcb890>,
#  'situations': <gensim.models.keyedvectors.Vocab at 0x7f295dfcb8d0>,
#  'circuit': <gensim.models.keyedvectors.Vocab at 0x7f295dfcb910>,
#  'diverts': <gensim.models.keyedvectors.Vocab at 0x7f295dfcb950>,
#  'stress': <gensim.models.keyedvectors.Vocab at 0x7f295dfcb990>,
#  'thoughtlessness': <gensim.models.keyedvectors.Vocab at 0x7f295dfcb9d0>,
#  'drishti': <gensim.models.keyedvectors.Vocab at 0x7f295dfcba10>,
#  'nasikagra': <gensim.models.keyedvectors.Vocab at 0x7f295dfcba50>,
#  'planes': <gensim.models.keyedvectors.Vocab at 0x7f295dfcba90>,
#  'open': <gensim.models.keyedvectors.Vocab at 0x7f295dfcbad0>,
#  'aim': <gensim.models.keyedvectors.Vocab at 0x7f295dfcbb10>,
#  'calming': <gensim.models.keyedvectors.Vocab at 0x7f295dfcbb50>,
#  'powers': <gensim.models.keyedvectors.Vocab at 0x7f295dfcbb90>,
#  'concentrates': <gensim.models.keyedvectors.Vocab at 0x7f295dfcbbd0>,
#  'nosetip': <gensim.models.keyedvectors.Vocab at 0x7f295dfcbc10>,
#  'introspection': <gensim.models.keyedvectors.Vocab at 0x7f295dfcbc50>,
#  'aware': <gensim.models.keyedvectors.Vocab at 0x7f295dfcbc90>,
#  'number': <gensim.models.keyedvectors.Vocab at 0x7f295dfcbcd0>,
#  'khechari': <gensim.models.keyedvectors.Vocab at 0x7f295dfcbd10>,
#  'nasal': <gensim.models.keyedvectors.Vocab at 0x7f295dfcbd50>,
#  'stillness': <gensim.models.keyedvectors.Vocab at 0x7f295dfcbd90>,
#  'potential': <gensim.models.keyedvectors.Vocab at 0x7f295dfcbdd0>,
#  'secretion': <gensim.models.keyedvectors.Vocab at 0x7f295dfcbe10>,
#  'awaken': <gensim.models.keyedvectors.Vocab at 0x7f295dfcbe50>,
#  'shakti': <gensim.models.keyedvectors.Vocab at 0x7f295dfcbe90>,
#  'cavity': <gensim.models.keyedvectors.Vocab at 0x7f295dfcbed0>,
#  'kaki': <gensim.models.keyedvectors.Vocab at 0x7f295dfcbf10>,
#  'membranes': <gensim.models.keyedvectors.Vocab at 0x7f295dfcbf50>,
#  'lips': <gensim.models.keyedvectors.Vocab at 0x7f295dfcbf90>,
#  'act': <gensim.models.keyedvectors.Vocab at 0x7f295dfcbfd0>,
#  'tensions': <gensim.models.keyedvectors.Vocab at 0x7f295dfcf050>,
#  'bhujangini': <gensim.models.keyedvectors.Vocab at 0x7f295dfcf090>,
#  'float': <gensim.models.keyedvectors.Vocab at 0x7f295dfcf0d0>,
#  'length': <gensim.models.keyedvectors.Vocab at 0x7f295dfcf110>,
#  'memory': <gensim.models.keyedvectors.Vocab at 0x7f295dfcf150>,
#  'tranquillizes': <gensim.models.keyedvectors.Vocab at 0x7f295dfcf190>,
#  'bhoochari': <gensim.models.keyedvectors.Vocab at 0x7f295dfcf1d0>,
#  'kumbhaka': <gensim.models.keyedvectors.Vocab at 0x7f295dfcf210>,
#  'induces': <gensim.models.keyedvectors.Vocab at 0x7f295dfcf250>,
#  'arrests': <gensim.models.keyedvectors.Vocab at 0x7f295dfcf290>,
#  'withdrawal': <gensim.models.keyedvectors.Vocab at 0x7f295dfcf2d0>,
#  'unmani': <gensim.models.keyedvectors.Vocab at 0x7f295dfcf310>,
#  'agitation': <gensim.models.keyedvectors.Vocab at 0x7f295dfcf350>,
#  'outward': <gensim.models.keyedvectors.Vocab at 0x7f295dfcf390>,
#  'disease': <gensim.models.keyedvectors.Vocab at 0x7f295dfcf3d0>,
#  'karani': <gensim.models.keyedvectors.Vocab at 0x7f295dfcf410>,
#  'vipareeta': <gensim.models.keyedvectors.Vocab at 0x7f295dfcf450>,
#  'downward': <gensim.models.keyedvectors.Vocab at 0x7f295dfcf490>,
#  'pashinee': <gensim.models.keyedvectors.Vocab at 0x7f295dfcf4d0>,
#  'drawal': <gensim.models.keyedvectors.Vocab at 0x7f295dfcf510>,
#  'distribution': <gensim.models.keyedvectors.Vocab at 0x7f295dfcf550>,
#  'ward': <gensim.models.keyedvectors.Vocab at 0x7f295dfcf590>,
#  'phragm': <gensim.models.keyedvectors.Vocab at 0x7f295dfcf5d0>,
#  'plexuses': <gensim.models.keyedvectors.Vocab at 0x7f295dfcf610>,
#  'tadagi': <gensim.models.keyedvectors.Vocab at 0x7f295dfcf650>,
#  'dia': <gensim.models.keyedvectors.Vocab at 0x7f295dfcf690>,
#  'attitude': <gensim.models.keyedvectors.Vocab at 0x7f295dfcf6d0>,
#  'cosmic': <gensim.models.keyedvectors.Vocab at 0x7f295dfcf710>,
#  'dormant': <gensim.models.keyedvectors.Vocab at 0x7f295dfcf750>,
#  'source': <gensim.models.keyedvectors.Vocab at 0x7f295dfcf790>,
#  'subtle': <gensim.models.keyedvectors.Vocab at 0x7f295dfcf7d0>,
#  'vital': <gensim.models.keyedvectors.Vocab at 0x7f295dfcf810>,
#  'external': <gensim.models.keyedvectors.Vocab at 0x7f295dfcf850>,
#  'engendering': <gensim.models.keyedvectors.Vocab at 0x7f295dfcf890>,
#  'stretches': <gensim.models.keyedvectors.Vocab at 0x7f295dfcf8d0>,
#  'fluctuations': <gensim.models.keyedvectors.Vocab at 0x7f295dfcf910>,
#  'counterpose': <gensim.models.keyedvectors.Vocab at 0x7f295dfcf950>,
#  'manduki': <gensim.models.keyedvectors.Vocab at 0x7f295dfcf990>,
#  'maha': <gensim.models.keyedvectors.Vocab at 0x7f295dfcf9d0>,
#  'complex': <gensim.models.keyedvectors.Vocab at 0x7f295dfcfa10>,
#  'supercharge': <gensim.models.keyedvectors.Vocab at 0x7f295dfcfa50>,
#  'bheda': <gensim.models.keyedvectors.Vocab at 0x7f295dfcfa90>,
#  'supplements': <gensim.models.keyedvectors.Vocab at 0x7f295dfcfad0>,
#  'introverting': <gensim.models.keyedvectors.Vocab at 0x7f295dfcfb10>,
#  'powerful': <gensim.models.keyedvectors.Vocab at 0x7f295dfcfb50>,
#  'faculties': <gensim.models.keyedvectors.Vocab at 0x7f295dfcfb90>,
#  'vents': <gensim.models.keyedvectors.Vocab at 0x7f295dfcfbd0>,
#  'redirects': <gensim.models.keyedvectors.Vocab at 0x7f295dfcfc10>,
#  'upward': <gensim.models.keyedvectors.Vocab at 0x7f295dfcfc50>,
#  'escape': <gensim.models.keyedvectors.Vocab at 0x7f295dfcfc90>,
#  'anal': <gensim.models.keyedvectors.Vocab at 0x7f295dfcfcd0>,
#  'conflicts': <gensim.models.keyedvectors.Vocab at 0x7f295dfcfd10>,
#  'conserves': <gensim.models.keyedvectors.Vocab at 0x7f295dfcfd50>,
#  'unwanted': <gensim.models.keyedvectors.Vocab at 0x7f295dfcfd90>,
#  'increase': <gensim.models.keyedvectors.Vocab at 0x7f295dfcfdd0>,
#  'carotid': <gensim.models.keyedvectors.Vocab at 0x7f295dfcfe10>,
#  'subtler': <gensim.models.keyedvectors.Vocab at 0x7f295dfcfe50>,
#  'jalandhara': <gensim.models.keyedvectors.Vocab at 0x7f295dfcfe90>,
#  'compresses': <gensim.models.keyedvectors.Vocab at 0x7f295dfcfed0>,
#  'sinuses': <gensim.models.keyedvectors.Vocab at 0x7f295dfcff10>,
#  'main': <gensim.models.keyedvectors.Vocab at 0x7f295dfcff50>,
#  'arteries': <gensim.models.keyedvectors.Vocab at 0x7f295dfcff90>,
#  'illnesses': <gensim.models.keyedvectors.Vocab at 0x7f295dfcffd0>,
#  'relations': <gensim.models.keyedvectors.Vocab at 0x7f295dfd1050>,
#  'degenerative': <gensim.models.keyedvectors.Vocab at 0x7f295dfd1090>,
#  'sublimate': <gensim.models.keyedvectors.Vocab at 0x7f295dfd10d0>,
#  'enhancement': <gensim.models.keyedvectors.Vocab at 0x7f295dfd1110>,
#  'ment': <gensim.models.keyedvectors.Vocab at 0x7f295dfd1150>,
#  'psychosomatic': <gensim.models.keyedvectors.Vocab at 0x7f295dfd1190>,
#  'panacea': <gensim.models.keyedvectors.Vocab at 0x7f295dfd11d0>,
#  'suction': <gensim.models.keyedvectors.Vocab at 0x7f295dfd1210>,
#  'torso': <gensim.models.keyedvectors.Vocab at 0x7f295dfd1250>,
#  'merger': <gensim.models.keyedvectors.Vocab at 0x7f295dfd1290>,
#  'pineal': <gensim.models.keyedvectors.Vocab at 0x7f295dfd12d0>,
#  'cell': <gensim.models.keyedvectors.Vocab at 0x7f295dfd1310>,
#  'ageing': <gensim.models.keyedvectors.Vocab at 0x7f295dfd1350>,
#  'bandhas': <gensim.models.keyedvectors.Vocab at 0x7f295dfd1390>,
#  'culmination': <gensim.models.keyedvectors.Vocab at 0x7f295dfd13d0>,
#  'endocrine': <gensim.models.keyedvectors.Vocab at 0x7f295dfd1410>,
#  'prior': <gensim.models.keyedvectors.Vocab at 0x7f295dfd1450>,
#  'pranayamas': <gensim.models.keyedvectors.Vocab at 0x7f295dfd1490>,
#  'ala': <gensim.models.keyedvectors.Vocab at 0x7f295dfd14d0>,
#  'drowsiness': <gensim.models.keyedvectors.Vocab at 0x7f295dfd1510>,
#  'light': <gensim.models.keyedvectors.Vocab at 0x7f295dfd1550>,
#  'youthful': <gensim.models.keyedvectors.Vocab at 0x7f295dfd1590>,
#  'passages': <gensim.models.keyedvectors.Vocab at 0x7f295dfd15d0>,
#  'hemispheres': <gensim.models.keyedvectors.Vocab at 0x7f295dfd1610>,
#  'overall': <gensim.models.keyedvectors.Vocab at 0x7f295dfd1650>,
#  'diseases': <gensim.models.keyedvectors.Vocab at 0x7f295dfd1690>,
#  'obstructions': <gensim.models.keyedvectors.Vocab at 0x7f295dfd16d0>,
#  'outgrowths': <gensim.models.keyedvectors.Vocab at 0x7f295dfd1710>,
#  'neti': <gensim.models.keyedvectors.Vocab at 0x7f295dfd1750>,
#  'fleshy': <gensim.models.keyedvectors.Vocab at 0x7f295dfd1790>,
#  'septum': <gensim.models.keyedvectors.Vocab at 0x7f295dfd17d0>,
#  'friction': <gensim.models.keyedvectors.Vocab at 0x7f295dfd1810>,
#  'jala': <gensim.models.keyedvectors.Vocab at 0x7f295dfd1850>,
#  'sutra': <gensim.models.keyedvectors.Vocab at 0x7f295dfd1890>}

# %%
test_doc = word_tokenize("I am facing back muscle pain and sciatica irritation and joint pain.".lower())
test_doc_vector = model.infer_vector(test_doc)
model.docvecs.most_similar(positive = [test_doc_vector])
# Out:
# [(6, 0.668487012386322),
#  (39, 0.5977280735969543),
#  (41, 0.5407358407974243),
#  (40, 0.5348901152610779),
#  (102, 0.5178437829017639),
#  (37, 0.5012862086296082),
#  (15, 0.49706700444221497),
#  (45, 0.4767443537712097),
#  (14, 0.4594787359237671),
#  (34, 0.45601198077201843)]

# %% [markdown]
# With Sentence Transformers

# %%
# !pip install sentence-transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentence-transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      |████████████████████████████████| 85 kB 3.0 MB/s
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.21.1-py3-none-any.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 33.4 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (4.64.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.12.1+cu113)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (0.13.1+cu113)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.21.6)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.7.3)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (3.7)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 52.7 MB/s
# Collecting huggingface-hub>=0.4.0
#   Downloading huggingface_hub-0.9.0-py3-none-any.whl (120 kB)
#      |████████████████████████████████| 120 kB 43.2 MB/s
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (21.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.23.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.12.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.1.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.9->huggingface-hub>=0.4.0->sentence-transformers) (3.0.9)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 41.6 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2022.6.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->huggingface-hub>=0.4.0->sentence-transformers) (3.8.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk->sentence-transformers) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk->sentence-transformers) (7.1.2)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2.10)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sentence-transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence-transformers) (7.1.2)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125938 sha256=27f4a96d191942e557d2859adabcf9e80b57ffda2b4f0b269a249a9b0375c043
#   Stored in directory: /root/.cache/pip/wheels/bf/06/fb/d59c1e5bd1dac7f6cf61ec0036cc3a10ab8fecaa6b2c3d3ee9
# Successfully built sentence-transformers
# Installing collected packages: tokenizers, huggingface-hub, transformers, sentencepiece, sentence-transformers
# Successfully installed huggingface-hub-0.9.0 sentence-transformers-2.2.2 sentencepiece-0.1.97 tokenizers-0.12.1 transformers-4.21.1

# %%
from sentence_transformers import SentenceTransformer
sbert_model = SentenceTransformer('bert-base-nli-mean-tokens')
# Out:
# Downloading:   0%|          | 0.00/391 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.95k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/625 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/399 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]

# %%
sentence_embeddings = sbert_model.encode(benefits_asanas)

#print('Sample BERT embedding vector - length', len(sentence_embeddings[0]))
#print('Sample BERT embedding vector - note includes negative values', sentence_embeddings[0])

# %%
query = "I am facing back muscle pain and sciatica irritation and joint pain."
query_vec = sbert_model.encode([query])[0]

# %%
def cosine(u, v):
    return np.dot(u, v) / (np.linalg.norm(u) * np.linalg.norm(v))

# %%
res = []
for ind,sent in enumerate(benefits_asanas):
  sim = cosine(query_vec, sbert_model.encode([sent])[0])
  #print("Sentence = ", sent, "; similarity = ", sim)
  res.append((ind, sim))

# %%
res_new = sorted(res)

# %%
def Sort_Tuple(tup):
 
    # reverse = None (Sorts in Ascending order)
    # key is set to sort using second element of
    # sublist lambda has been used
    return(sorted(tup, key = lambda x: x[1], reverse=True))

# %%
Sort_Tuple(res)[0:10]
# Out:
# [(138, 0.63768995),
#  (19, 0.6183747),
#  (18, 0.61079365),
#  (79, 0.60985583),
#  (121, 0.60975206),
#  (29, 0.6069901),
#  (71, 0.60580957),
#  (0, 0.59391373),
#  (1, 0.59391373),
#  (2, 0.59391373)]

# %% [markdown]
# 3rd Technique

# %%
import tensorflow as tf
import tensorflow_hub as hub
import numpy as np

# %%
module_url = "https://tfhub.dev/google/universal-sentence-encoder/4" 
model = hub.load(module_url)
print ("module %s loaded" % module_url)
# Out:
# module https://tfhub.dev/google/universal-sentence-encoder/4 loaded

# %%
#@title Load the Universal Sentence Encoder's TF Hub module
from absl import logging

import tensorflow as tf

import tensorflow_hub as hub
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import re
import seaborn as sns

module_url = "https://tfhub.dev/google/universal-sentence-encoder/4" #@param ["https://tfhub.dev/google/universal-sentence-encoder/4", "https://tfhub.dev/google/universal-sentence-encoder-large/5"]
model = hub.load(module_url)
print ("module %s loaded" % module_url)
def embed(input):
  return model(input)
# Out:
# module https://tfhub.dev/google/universal-sentence-encoder/4 loaded

# %%
query = "I am facing back muscle pain and sciatica irritation and joint pain."
sentence_embeddings = model(benefits_asanas)
sentence_not_to_do_sentence_emb = model(sentence_not_to_do)
query_vec = model([query])[0]

# %%
np.shape(query_vec)
# Out:
# TensorShape([512])

# %%
len(model([query])[0])
# Out:
# 512

# %%
def plot_similarity(labels, features, rotation):
  corr = np.inner(features, features)
  sns.set(font_scale=1.2)
  g = sns.heatmap(
      corr,
      xticklabels=labels,
      yticklabels=labels,
      vmin=0,
      vmax=1,
      cmap="YlOrRd")
  g.set_xticklabels(labels, rotation=rotation)
  g.set_title("Semantic Textual Similarity")

def run_and_plot(messages_):
  message_embeddings_ = embed(messages_)
  plot_similarity(messages_, message_embeddings_, 90)

# %%
res_new = []
for ind_new,sent_new in enumerate(benefits_asanas):
  sim_new = cosine(query_vec, model([sent_new])[0])
  #print("Sentence = ", sent, "; similarity = ", sim)
  res_new.append((ind_new, sim_new))

# %%
res_new_not_to_do = []
for ind_new_nt, sent_new_nt in enumerate(sentence_not_to_do):
  sim_new_nt = cosine(query_vec, model([sent_new_nt])[0])
  res_new_not_to_do.append((ind_new_nt,sim_new_nt))

# %%
len(sentence_embeddings)
# Out:
# 226

# %%
final_op = Sort_Tuple(res_new)[0:10]

# %%
final_op_nt_to_do = Sort_Tuple(res_new_not_to_do)[0:10]

# %%
for item_ in range(len(final_op)):

  print(asanas['AName'][final_op[item_][0]])
# Out:
# Meru Wakrasana (spinal twist)
# Pada Sanchalanasana
# Bhu Namanasana (spinal twist prostration pose)
# VYAGHRASANA
# Gomukhasana (cow's face pose)
# DOLASANA
# Jyestikasana (superior posture)
# Utthita Janu Sirshasana (standing head between knees pose)
# Vayu Nishkasana
# Vishwamitrasana (Sage Vishwamitra's pose)

# %%
for item_ in range(len(final_op_nt_to_do)):

  print(asanas['AName'][final_op_nt_to_do[item_][0]])
# Out:
# Pooma Titali Asana
# Kashtha Takshanasana
# Namaskarasana
# Udarakarshanasana
# Utthita Hasta Padangusthasana (raised hand to big toe
# pose)
# Pada Angushthasana (tiptoe pose)
# Hasta Pada Angushthasana (finger to toe stretch)
# TIRYAKA KATI CHAKRASANA
# Ardha Padmasana (half lotus pose)
# SUPTA VAJRASANA

# %%
[(6, 0.7361676096916199),
 (45, 0.7340274453163147),
 (102, 0.6993881464004517),
 (12, 0.6352957487106323),
 (37, 0.5979675054550171),
 (43, 0.5633800029754639),
 (19, 0.5578968524932861),
 (114, 0.5376175045967102),
 (36, 0.5199707746505737),
 (128, 0.5176911950111389)]
# Out:
# [(6, 0.7361676096916199),
#  (45, 0.7340274453163147),
#  (102, 0.6993881464004517),
#  (12, 0.6352957487106323),
#  (37, 0.5979675054550171),
#  (43, 0.5633800029754639),
#  (19, 0.5578968524932861),
#  (114, 0.5376175045967102),
#  (36, 0.5199707746505737),
#  (128, 0.5176911950111389)]

# %%
[(138, 0.63768995),
 (19, 0.6183747),
 (18, 0.61079365),
 (79, 0.60985583),
 (121, 0.60975206),
 (29, 0.6069901),
 (71, 0.60580957),
 (0, 0.59391373),
 (1, 0.59391373),
 (2, 0.59391373)]
# Out:
# [(138, 0.63768995),
#  (19, 0.6183747),
#  (18, 0.61079365),
#  (79, 0.60985583),
#  (121, 0.60975206),
#  (29, 0.6069901),
#  (71, 0.60580957),
#  (0, 0.59391373),
#  (1, 0.59391373),
#  (2, 0.59391373)]

# %%
[(119, 0.5923804),
 (19, 0.52934337),
 (120, 0.51165956),
 (62, 0.49619046),
 (107, 0.48031884),
 (83, 0.46139434),
 (44, 0.4490634),
 (117, 0.44516063),
 (31, 0.42218882),
 (185, 0.4215759)]
# Out:
# [(119, 0.5923804),
#  (19, 0.52934337),
#  (120, 0.51165956),
#  (62, 0.49619046),
#  (107, 0.48031884),
#  (83, 0.46139434),
#  (44, 0.4490634),
#  (117, 0.44516063),
#  (31, 0.42218882),
#  (185, 0.4215759)]

# %%
benefits_asanas[107]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-78ee27ac8e81> in <module>
# ----> 1 benefits_asanas[107]
#
# NameError: name 'benefits_asanas' is not defined

# %%
pip install ml_metrics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ml_metrics
#   Downloading ml_metrics-0.1.4.tar.gz (5.0 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from ml_metrics) (1.21.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from ml_metrics) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ml_metrics) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ml_metrics) (2022.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->ml_metrics) (1.15.0)
# Building wheels for collected packages: ml-metrics
#   Building wheel for ml-metrics (setup.py) ... done
#   Created wheel for ml-metrics: filename=ml_metrics-0.1.4-py3-none-any.whl size=7845 sha256=b7b3b9db220d130a7b9cd2c4f53e279124cf9893f794ac8ae991764ed22b90ed
#   Stored in directory: /root/.cache/pip/wheels/56/41/5b/0c6d42b3604a5c823d8922564c4708f84962fa7f2f4facfa6d
# Successfully built ml-metrics
# Installing collected packages: ml-metrics
# Successfully installed ml-metrics-0.1.4

# %%
asanas['Level'][119]
# Out:
# 'Intermediate'
